# %% [markdown]
# <a href="https://colab.research.google.com/github/GenoKiller777/PythonVarios/blob/main/%20DataWranglir_evaFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Extracción

# %%
#Activacion de paquetes para el tratamiento

import pandas as pd
import numpy as np

# %%
#Fragmento de codigo, para llamar archivos desde la maquina local

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-63259aec-29dd-43f4-9776-d3b58a413f06" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63259aec-29dd-43f4-9776-d3b58a413f06">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Importación de archivos XLSX para realizar el ETL

#colocaciones
colocaciones_01 = pd.read_excel('/content/sdbcol_092021.xlsx',sheet_name='1_01')
colocaciones_02 = pd.read_excel('/content/sdbcol_092021.xlsx',sheet_name='1_02')
colocaciones_03 = pd.read_excel('/content/sdbcol_092021.xlsx',sheet_name='1_03')
colocaciones_04 = pd.read_excel('/content/sdbcol_092021.xlsx',sheet_name='1_04')
colocaciones_05 = pd.read_excel('/content/sdbcol_092021.xlsx',sheet_name='1_05')
colocaciones_06 = pd.read_excel('/content/sdbcol_092021.xlsx',sheet_name='1_06')
colocaciones_07 = pd.read_excel('/content/sdbcol_092021.xlsx',sheet_name='1_07')
colocaciones_08 = pd.read_excel('/content/sdbcol_092021.xlsx',sheet_name='1_08')
colocaciones_09 = pd.read_excel('/content/sdbcol_092021.xlsx',sheet_name='1_09')
colocaciones_10 = pd.read_excel('/content/sdbcol_092021.xlsx',sheet_name='1_10')

# %% [markdown]
# # Colocaciones

# %% [markdown]
# ## Colocación 01

# %%
#Revisión de header

colocaciones_01.head(5)
# Out:
#           Unnamed: 0                                Unnamed: 1  \
# 0     Índice general                               Cuadro 1.01
# 1    Notas generales  Colocaciones totales por tipo de crédito
# 2  Conceptualización               Saldos en millones de pesos
# 3                NaN                                       NaN
# 4                NaN                                       NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
#Elimación de columna 'Unnamed: 0'

colocaciones_01.pop("Unnamed: 0")
# Out:
# 0        Índice general
# 1       Notas generales
# 2     Conceptualización
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# Name: Unnamed: 0, dtype: object

# %%
#Elimación de las primeras 5 filas

colocaciones_01 = colocaciones_01.iloc[5:]

# %%
#Revision de la cola del dataframe

colocaciones_01.tail(7)
# Out:
#                                            Unnamed: 1       Unnamed: 2  \
# 30                                 Bank of China (16)               ND
# 31                                              Total  63289823.285317
# 32                                                NaN              NaN
# 33                                                NaN              NaN
# 34                                ND : No existe dato              NaN
# 35                                                NaN              NaN
# 36  Conceptualización: Vínculo que remite al docum...              NaN
#
#          Unnamed: 3       Unnamed: 4       Unnamed: 5       Unnamed: 6  \
# 30               ND               ND               ND               ND
# 31  63929598.124746  64331272.198998  66239592.233475  67501410.730421
# 32              NaN              NaN              NaN              NaN
# 33              NaN              NaN              NaN              NaN
# ...

# %%
#Eliminacion de las ultimas 6 filas

colocaciones_01.drop(colocaciones_01.tail(6).index,inplace=True)
# Out:
# <ipython-input-8-2aeed8c6289e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colocaciones_01.drop(colocaciones_01.tail(6).index,inplace=True)

# %%
# Revision de cabezera

colocaciones_01.head(3)
# Out:
#                     Unnamed: 1      Unnamed: 2      Unnamed: 3  \
# 5                   Banco Bice  1763607.105975  1808429.613026
# 6  Banco BTG Pactual Chile (9)              ND              ND
# 7          Banco Consorcio (1)    33929.700249    32239.758181
#
#        Unnamed: 4      Unnamed: 5      Unnamed: 6      Unnamed: 7  \
# 5  1842186.397327  1881593.219611  1941444.983769  2019770.333121
# 6              ND              ND              ND              ND
# 7    29778.804888    30171.072657    30523.044437    29617.013329
#
#        Unnamed: 8      Unnamed: 9     Unnamed: 10  ...    Unnamed: 157  \
# 5  1994761.128546  2041350.403024  2097468.789285  ...  6660939.273511
# 6              ND              ND              ND  ...  1207031.841972
# 7    28433.274784    28789.410595    27307.815688  ...  3853309.703266
#
#      Unnamed: 158    Unnamed: 159    Unnamed: 160    Unnamed: 161  \
# 5  6743346.724603  6778835.359596  6855606.729749  6914693.776389
# ...

# %%
# Aplicacion de pd.melt para pasar de tabla ancha  a tabla larga

colocaciones_01 = colocaciones_01.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# Cración de condiciones para crear la columna Fecha

conditions_1 = [(colocaciones_01['myVarname'] == 'Unnamed: 2'),(colocaciones_01['myVarname'] == 'Unnamed: 3'),(colocaciones_01['myVarname'] == 'Unnamed: 4'),(colocaciones_01['myVarname'] == 'Unnamed: 5'),(colocaciones_01['myVarname'] == 'Unnamed: 6'),
 (colocaciones_01['myVarname'] == 'Unnamed: 7'),(colocaciones_01['myVarname'] == 'Unnamed: 8'),(colocaciones_01['myVarname'] == 'Unnamed: 9'),(colocaciones_01['myVarname'] == 'Unnamed: 10'),(colocaciones_01['myVarname'] == 'Unnamed: 11'),
  (colocaciones_01['myVarname'] == 'Unnamed: 12'),(colocaciones_01['myVarname'] == 'Unnamed: 13'),(colocaciones_01['myVarname'] == 'Unnamed: 14'),(colocaciones_01['myVarname'] == 'Unnamed: 15'),(colocaciones_01['myVarname'] == 'Unnamed: 16'),
   (colocaciones_01['myVarname'] == 'Unnamed: 17'),(colocaciones_01['myVarname'] == 'Unnamed: 18'),(colocaciones_01['myVarname'] == 'Unnamed: 19'),(colocaciones_01['myVarname'] == 'Unnamed: 20'),(colocaciones_01['myVarname'] == 'Unnamed: 21'),
    (colocaciones_01['myVarname'] == 'Unnamed: 22'),(colocaciones_01['myVarname'] == 'Unnamed: 23'),(colocaciones_01['myVarname'] == 'Unnamed: 24'),(colocaciones_01['myVarname'] == 'Unnamed: 25'),(colocaciones_01['myVarname'] == 'Unnamed: 26'),
     (colocaciones_01['myVarname'] == 'Unnamed: 27'),(colocaciones_01['myVarname'] == 'Unnamed: 28'),(colocaciones_01['myVarname'] == 'Unnamed: 29'),(colocaciones_01['myVarname'] == 'Unnamed: 30'),(colocaciones_01['myVarname'] == 'Unnamed: 31'),
      (colocaciones_01['myVarname'] == 'Unnamed: 32'),(colocaciones_01['myVarname'] == 'Unnamed: 33'),(colocaciones_01['myVarname'] == 'Unnamed: 34'),(colocaciones_01['myVarname'] == 'Unnamed: 35'),(colocaciones_01['myVarname'] == 'Unnamed: 36'),
       (colocaciones_01['myVarname'] == 'Unnamed: 37'),(colocaciones_01['myVarname'] == 'Unnamed: 38'),(colocaciones_01['myVarname'] == 'Unnamed: 39'),(colocaciones_01['myVarname'] == 'Unnamed: 40'),(colocaciones_01['myVarname'] == 'Unnamed: 41'),
        (colocaciones_01['myVarname'] == 'Unnamed: 42'),(colocaciones_01['myVarname'] == 'Unnamed: 43'),(colocaciones_01['myVarname'] == 'Unnamed: 44'),(colocaciones_01['myVarname'] == 'Unnamed: 45'),(colocaciones_01['myVarname'] == 'Unnamed: 46'),
         (colocaciones_01['myVarname'] == 'Unnamed: 47'),(colocaciones_01['myVarname'] == 'Unnamed: 48'),(colocaciones_01['myVarname'] == 'Unnamed: 49'),(colocaciones_01['myVarname'] == 'Unnamed: 50'),(colocaciones_01['myVarname'] == 'Unnamed: 51'),
          (colocaciones_01['myVarname'] == 'Unnamed: 52'),(colocaciones_01['myVarname'] == 'Unnamed: 53'),(colocaciones_01['myVarname'] == 'Unnamed: 54'),(colocaciones_01['myVarname'] == 'Unnamed: 55'),(colocaciones_01['myVarname'] == 'Unnamed: 56'),
           (colocaciones_01['myVarname'] == 'Unnamed: 57'),(colocaciones_01['myVarname'] == 'Unnamed: 58'),(colocaciones_01['myVarname'] == 'Unnamed: 59'),(colocaciones_01['myVarname'] == 'Unnamed: 60'),(colocaciones_01['myVarname'] == 'Unnamed: 61'),
            (colocaciones_01['myVarname'] == 'Unnamed: 62'),(colocaciones_01['myVarname'] == 'Unnamed: 63'),(colocaciones_01['myVarname'] == 'Unnamed: 64'),(colocaciones_01['myVarname'] == 'Unnamed: 65'),(colocaciones_01['myVarname'] == 'Unnamed: 66'),
             (colocaciones_01['myVarname'] == 'Unnamed: 67'),(colocaciones_01['myVarname'] == 'Unnamed: 68'),(colocaciones_01['myVarname'] == 'Unnamed: 69'),(colocaciones_01['myVarname'] == 'Unnamed: 70'),(colocaciones_01['myVarname'] == 'Unnamed: 71'),
              (colocaciones_01['myVarname'] == 'Unnamed: 72'),(colocaciones_01['myVarname'] == 'Unnamed: 73'),(colocaciones_01['myVarname'] == 'Unnamed: 74'),(colocaciones_01['myVarname'] == 'Unnamed: 75'),(colocaciones_01['myVarname'] == 'Unnamed: 76'),
               (colocaciones_01['myVarname'] == 'Unnamed: 77'),(colocaciones_01['myVarname'] == 'Unnamed: 78'),(colocaciones_01['myVarname'] == 'Unnamed: 79'),(colocaciones_01['myVarname'] == 'Unnamed: 80'),(colocaciones_01['myVarname'] == 'Unnamed: 81'),
                (colocaciones_01['myVarname'] == 'Unnamed: 82'),(colocaciones_01['myVarname'] == 'Unnamed: 83'),(colocaciones_01['myVarname'] == 'Unnamed: 84'),(colocaciones_01['myVarname'] == 'Unnamed: 85'),(colocaciones_01['myVarname'] == 'Unnamed: 86'),
                 (colocaciones_01['myVarname'] == 'Unnamed: 87'),(colocaciones_01['myVarname'] == 'Unnamed: 88'),(colocaciones_01['myVarname'] == 'Unnamed: 89'),(colocaciones_01['myVarname'] == 'Unnamed: 90'),(colocaciones_01['myVarname'] == 'Unnamed: 91'),
                  (colocaciones_01['myVarname'] == 'Unnamed: 92'),(colocaciones_01['myVarname'] == 'Unnamed: 93'),(colocaciones_01['myVarname'] == 'Unnamed: 94'),(colocaciones_01['myVarname'] == 'Unnamed: 95'),(colocaciones_01['myVarname'] == 'Unnamed: 96'),
                   (colocaciones_01['myVarname'] == 'Unnamed: 97'),(colocaciones_01['myVarname'] == 'Unnamed: 98'),(colocaciones_01['myVarname'] == 'Unnamed: 99'),(colocaciones_01['myVarname'] == 'Unnamed: 100'),(colocaciones_01['myVarname'] == 'Unnamed: 101'),
                    (colocaciones_01['myVarname'] == 'Unnamed: 102'),(colocaciones_01['myVarname'] == 'Unnamed: 103'),(colocaciones_01['myVarname'] == 'Unnamed: 104'),(colocaciones_01['myVarname'] == 'Unnamed: 105'),(colocaciones_01['myVarname'] == 'Unnamed: 106'),
                     (colocaciones_01['myVarname'] == 'Unnamed: 107'),(colocaciones_01['myVarname'] == 'Unnamed: 108'),(colocaciones_01['myVarname'] == 'Unnamed: 109'),(colocaciones_01['myVarname'] == 'Unnamed: 110'),(colocaciones_01['myVarname'] == 'Unnamed: 111'),
                      (colocaciones_01['myVarname'] == 'Unnamed: 112'),(colocaciones_01['myVarname'] == 'Unnamed: 113'),(colocaciones_01['myVarname'] == 'Unnamed: 114'),(colocaciones_01['myVarname'] == 'Unnamed: 115'),(colocaciones_01['myVarname'] == 'Unnamed: 116'),
                       (colocaciones_01['myVarname'] == 'Unnamed: 117'),(colocaciones_01['myVarname'] == 'Unnamed: 118'),(colocaciones_01['myVarname'] == 'Unnamed: 119'),(colocaciones_01['myVarname'] == 'Unnamed: 120'),(colocaciones_01['myVarname'] == 'Unnamed: 121'),
                        (colocaciones_01['myVarname'] == 'Unnamed: 122'),(colocaciones_01['myVarname'] == 'Unnamed: 123'),(colocaciones_01['myVarname'] == 'Unnamed: 124'),(colocaciones_01['myVarname'] == 'Unnamed: 125'),(colocaciones_01['myVarname'] == 'Unnamed: 126'),
                         (colocaciones_01['myVarname'] == 'Unnamed: 127'),(colocaciones_01['myVarname'] == 'Unnamed: 128'),(colocaciones_01['myVarname'] == 'Unnamed: 129'),(colocaciones_01['myVarname'] == 'Unnamed: 130'),(colocaciones_01['myVarname'] == 'Unnamed: 131'),
                          (colocaciones_01['myVarname'] == 'Unnamed: 132'),(colocaciones_01['myVarname'] == 'Unnamed: 133'),(colocaciones_01['myVarname'] == 'Unnamed: 134'),(colocaciones_01['myVarname'] == 'Unnamed: 135'),(colocaciones_01['myVarname'] == 'Unnamed: 136'),
                           (colocaciones_01['myVarname'] == 'Unnamed: 137'),(colocaciones_01['myVarname'] == 'Unnamed: 138'),(colocaciones_01['myVarname'] == 'Unnamed: 139'),(colocaciones_01['myVarname'] == 'Unnamed: 140'),(colocaciones_01['myVarname'] == 'Unnamed: 141'),
                            (colocaciones_01['myVarname'] == 'Unnamed: 142'),(colocaciones_01['myVarname'] == 'Unnamed: 143'),(colocaciones_01['myVarname'] == 'Unnamed: 144'),(colocaciones_01['myVarname'] == 'Unnamed: 145'),(colocaciones_01['myVarname'] == 'Unnamed: 146'),
                             (colocaciones_01['myVarname'] == 'Unnamed: 147'),(colocaciones_01['myVarname'] == 'Unnamed: 148'),(colocaciones_01['myVarname'] == 'Unnamed: 149'),(colocaciones_01['myVarname'] == 'Unnamed: 150'),(colocaciones_01['myVarname'] == 'Unnamed: 151'),
                              (colocaciones_01['myVarname'] == 'Unnamed: 152'),(colocaciones_01['myVarname'] == 'Unnamed: 153'),(colocaciones_01['myVarname'] == 'Unnamed: 154'),(colocaciones_01['myVarname'] == 'Unnamed: 155'),(colocaciones_01['myVarname'] == 'Unnamed: 156'),
                               (colocaciones_01['myVarname'] == 'Unnamed: 157'),(colocaciones_01['myVarname'] == 'Unnamed: 158'),(colocaciones_01['myVarname'] == 'Unnamed: 159'),(colocaciones_01['myVarname'] == 'Unnamed: 160'),(colocaciones_01['myVarname'] == 'Unnamed: 161'),
                                (colocaciones_01['myVarname'] == 'Unnamed: 162'),(colocaciones_01['myVarname'] == 'Unnamed: 163'),(colocaciones_01['myVarname'] == 'Unnamed: 164'),(colocaciones_01['myVarname'] == 'Unnamed: 165'),(colocaciones_01['myVarname'] == 'Unnamed: 166')
                                ]

# %%
# Valores para la creacion de la columna Fecha

values = ['2008-01-31','2008-02-29','2008-03-31','2008-04-30','2008-05-31','2008-06-30','2008-07-31','2008-08-31','2008-09-30','2008-10-31',
          '2008-11-30','2008-12-31','2009-01-31','2009-02-28','2009-03-31','2009-04-30','2009-05-31','2009-06-30','2009-07-31','2009-08-31',
          '2009-09-30','2009-10-31','2009-11-30','2009-12-31','2010-01-31','2010-02-28','2010-03-31','2010-04-30','2010-05-31','2010-06-30',
          '2010-07-31','2010-08-31','2010-09-30','2010-10-31','2010-11-30','2010-12-31','2011-01-31','2011-02-28','2011-03-31','2011-04-30',
          '2011-05-31','2011-06-30','2011-07-31','2011-08-31','2011-09-30','2011-10-31','2011-11-30','2011-12-31','2012-01-31','2012-02-29',
          '2012-03-31','2012-04-30','2012-05-31','2012-06-30','2012-07-31','2012-08-31','2012-09-30','2012-10-31','2012-11-30','2012-12-31',
          '2013-01-31','2013-02-28','2013-03-31','2013-04-30','2013-05-31','2013-06-30','2013-07-31','2013-08-31','2013-09-30','2013-10-31',
          '2013-11-30','2013-12-31','2014-01-31','2014-02-28','2014-03-31','2014-04-30','2014-05-31','2014-06-30','2014-07-31','2014-08-31',
          '2014-09-30','2014-10-31','2014-11-30','2014-12-31','2015-01-31','2015-02-28','2015-03-31','2015-04-30','2015-05-31','2015-06-30',
          '2015-07-31','2015-08-31','2015-09-30','2015-10-31','2015-11-30','2015-12-31','2016-01-31','2016-02-29','2016-03-31','2016-04-30',
          '2016-05-31','2016-06-30','2016-07-31','2016-08-31','2016-09-30','2016-10-31','2016-11-30','2016-12-31','2017-01-31','2017-02-28',
          '2017-03-31','2017-04-30','2017-05-31','2017-06-30','2017-07-31','2017-08-31','2017-09-30','2017-10-31','2017-11-30','2017-12-31',
          '2018-01-31','2018-02-28','2018-03-31','2018-04-30','2018-05-31','2018-06-30','2018-07-31','2018-08-31','2018-09-30','2018-10-31',
          '2018-11-30','2018-12-31','2019-01-31','2019-02-28','2019-03-31','2019-04-30','2019-05-31','2019-06-30','2019-07-31','2019-08-31',
          '2019-09-30','2019-10-31','2019-11-30','2019-12-31','2020-01-31','2020-02-29','2020-03-31','2020-04-30','2020-05-31','2020-06-30',
          '2020-07-31','2020-08-31','2020-09-30','2020-10-31','2020-11-30','2020-12-31','2021-01-31','2021-02-28','2021-03-31','2021-04-30',
          '2021-05-31','2021-06-30','2021-07-31','2021-08-31','2021-09-30']

# %%
#Cracion de la columna Fecha

colocaciones_01['Fecha'] = np.select(conditions_1, values)

# %%
#Eliminacion de columna de anclaje para hacer las fechas

colocaciones_01.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
#Renombramiento de columna 'Unnamed:1' a Institucion

colocaciones_01.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
colocaciones_01
# Out:
#                                       Institucion            Valor       Fecha
# 5                                      Banco Bice   1763607.105975  2008-01-31
# 6                     Banco BTG Pactual Chile (9)               ND  2008-01-31
# 7                             Banco Consorcio (1)     33929.700249  2008-01-31
# 8                              Banco de Chile (2)  12877155.584751  2008-01-31
# 9                  Banco de Crédito e Inversiones   7808179.921376  2008-01-31
# ..                                            ...              ...         ...
# 26                     JP Morgan Chase Bank, N.A.                0  2021-09-30
# 27                            Rabobank Chile (15)               ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  27750522.282798  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)               ND  2021-09-30
# 30                             Bank of China (16)                0  2021-09-30
#
# [4290 rows x 3 columns]

# %%
#Creacion de campos faltantes

colocaciones_01['Tipo'] = "Colocación"
colocaciones_01['Subtipo'] = "Colocaciones totales por tipo de crédito"
colocaciones_01['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
#Reorganizacion de columnas para la salida

new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
colocaciones_01 = colocaciones_01.reindex(columns=new_cols)

# %%
colocaciones_01.head(3)
# Out:
#         Fecha                  Institucion        Tipo  \
# 5  2008-01-31                   Banco Bice  Colocación
# 6  2008-01-31  Banco BTG Pactual Chile (9)  Colocación
# 7  2008-01-31          Banco Consorcio (1)  Colocación
#
#                                     Subtipo           Valor  \
# 5  Colocaciones totales por tipo de crédito  1763607.105975
# 6  Colocaciones totales por tipo de crédito              ND
# 7  Colocaciones totales por tipo de crédito    33929.700249
#
#                 Tipo de Moneda
# 5  Saldos en millones de pesos
# 6  Saldos en millones de pesos
# 7  Saldos en millones de pesos

# %% [markdown]
# ## Colocación 02

# %%
colocaciones_02.head(5)
# Out:
#           Unnamed: 0                   Unnamed: 1           Unnamed: 2  \
# 0     Índice general                  Cuadro 1.02                  NaN
# 1    Notas generales     Colocaciones comerciales                  NaN
# 2  Conceptualización  Saldos en millones de pesos                  NaN
# 3                NaN                          NaN                  NaN
# 4                NaN                          NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
colocaciones_02.pop("Unnamed: 0")
# Out:
# 0        Índice general
# 1       Notas generales
# 2     Conceptualización
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# Name: Unnamed: 0, dtype: object

# %%
colocaciones_02 = colocaciones_02.iloc[5:]

# %%
colocaciones_02.tail(7)
# Out:
#                                            Unnamed: 1      Unnamed: 2  \
# 30                                 Bank of China (16)              ND
# 31                                              Total  36566106.13081
# 32                                                NaN             NaN
# 33                                                NaN             NaN
# 34                                ND : No existe dato             NaN
# 35                                                NaN             NaN
# 36  Conceptualización: Vínculo que remite al docum...             NaN
#
#          Unnamed: 3       Unnamed: 4       Unnamed: 5       Unnamed: 6  \
# 30               ND               ND               ND               ND
# 31  36902589.799545  37065960.514809  37929261.027835  38480929.039904
# 32              NaN              NaN              NaN              NaN
# 33              NaN              NaN              NaN              NaN
# ...

# %%
colocaciones_02.drop(colocaciones_02.tail(6).index,inplace=True)
# Out:
# <ipython-input-25-72aa45a4f034>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colocaciones_02.drop(colocaciones_02.tail(6).index,inplace=True)

# %%
colocaciones_02 = colocaciones_02.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
colocaciones_02
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor
# 5     1349840.90608
# 6                ND
# 7      32840.047756
# 8    8012788.068213
# 9    4855261.065818
# ..              ...
# 26                0
# 27               ND
# ...

# %%
# create a list of our conditions
conditions_2 = [(colocaciones_02['myVarname'] == 'Unnamed: 2'),(colocaciones_02['myVarname'] == 'Unnamed: 3'),(colocaciones_02['myVarname'] == 'Unnamed: 4'),(colocaciones_02['myVarname'] == 'Unnamed: 5'),(colocaciones_02['myVarname'] == 'Unnamed: 6'),
 (colocaciones_02['myVarname'] == 'Unnamed: 7'),(colocaciones_02['myVarname'] == 'Unnamed: 8'),(colocaciones_02['myVarname'] == 'Unnamed: 9'),(colocaciones_02['myVarname'] == 'Unnamed: 10'),(colocaciones_02['myVarname'] == 'Unnamed: 11'),
  (colocaciones_02['myVarname'] == 'Unnamed: 12'),(colocaciones_02['myVarname'] == 'Unnamed: 13'),(colocaciones_02['myVarname'] == 'Unnamed: 14'),(colocaciones_02['myVarname'] == 'Unnamed: 15'),(colocaciones_02['myVarname'] == 'Unnamed: 16'),
   (colocaciones_02['myVarname'] == 'Unnamed: 17'),(colocaciones_02['myVarname'] == 'Unnamed: 18'),(colocaciones_02['myVarname'] == 'Unnamed: 19'),(colocaciones_02['myVarname'] == 'Unnamed: 20'),(colocaciones_02['myVarname'] == 'Unnamed: 21'),
    (colocaciones_02['myVarname'] == 'Unnamed: 22'),(colocaciones_02['myVarname'] == 'Unnamed: 23'),(colocaciones_02['myVarname'] == 'Unnamed: 24'),(colocaciones_02['myVarname'] == 'Unnamed: 25'),(colocaciones_02['myVarname'] == 'Unnamed: 26'),
     (colocaciones_02['myVarname'] == 'Unnamed: 27'),(colocaciones_02['myVarname'] == 'Unnamed: 28'),(colocaciones_02['myVarname'] == 'Unnamed: 29'),(colocaciones_02['myVarname'] == 'Unnamed: 30'),(colocaciones_02['myVarname'] == 'Unnamed: 31'),
      (colocaciones_02['myVarname'] == 'Unnamed: 32'),(colocaciones_02['myVarname'] == 'Unnamed: 33'),(colocaciones_02['myVarname'] == 'Unnamed: 34'),(colocaciones_02['myVarname'] == 'Unnamed: 35'),(colocaciones_02['myVarname'] == 'Unnamed: 36'),
       (colocaciones_02['myVarname'] == 'Unnamed: 37'),(colocaciones_02['myVarname'] == 'Unnamed: 38'),(colocaciones_02['myVarname'] == 'Unnamed: 39'),(colocaciones_02['myVarname'] == 'Unnamed: 40'),(colocaciones_02['myVarname'] == 'Unnamed: 41'),
        (colocaciones_02['myVarname'] == 'Unnamed: 42'),(colocaciones_02['myVarname'] == 'Unnamed: 43'),(colocaciones_02['myVarname'] == 'Unnamed: 44'),(colocaciones_02['myVarname'] == 'Unnamed: 45'),(colocaciones_02['myVarname'] == 'Unnamed: 46'),
         (colocaciones_02['myVarname'] == 'Unnamed: 47'),(colocaciones_02['myVarname'] == 'Unnamed: 48'),(colocaciones_02['myVarname'] == 'Unnamed: 49'),(colocaciones_02['myVarname'] == 'Unnamed: 50'),(colocaciones_02['myVarname'] == 'Unnamed: 51'),
          (colocaciones_02['myVarname'] == 'Unnamed: 52'),(colocaciones_02['myVarname'] == 'Unnamed: 53'),(colocaciones_02['myVarname'] == 'Unnamed: 54'),(colocaciones_02['myVarname'] == 'Unnamed: 55'),(colocaciones_02['myVarname'] == 'Unnamed: 56'),
           (colocaciones_02['myVarname'] == 'Unnamed: 57'),(colocaciones_02['myVarname'] == 'Unnamed: 58'),(colocaciones_02['myVarname'] == 'Unnamed: 59'),(colocaciones_02['myVarname'] == 'Unnamed: 60'),(colocaciones_02['myVarname'] == 'Unnamed: 61'),
            (colocaciones_02['myVarname'] == 'Unnamed: 62'),(colocaciones_02['myVarname'] == 'Unnamed: 63'),(colocaciones_02['myVarname'] == 'Unnamed: 64'),(colocaciones_02['myVarname'] == 'Unnamed: 65'),(colocaciones_02['myVarname'] == 'Unnamed: 66'),
             (colocaciones_02['myVarname'] == 'Unnamed: 67'),(colocaciones_02['myVarname'] == 'Unnamed: 68'),(colocaciones_02['myVarname'] == 'Unnamed: 69'),(colocaciones_02['myVarname'] == 'Unnamed: 70'),(colocaciones_02['myVarname'] == 'Unnamed: 71'),
              (colocaciones_02['myVarname'] == 'Unnamed: 72'),(colocaciones_02['myVarname'] == 'Unnamed: 73'),(colocaciones_02['myVarname'] == 'Unnamed: 74'),(colocaciones_02['myVarname'] == 'Unnamed: 75'),(colocaciones_02['myVarname'] == 'Unnamed: 76'),
               (colocaciones_02['myVarname'] == 'Unnamed: 77'),(colocaciones_02['myVarname'] == 'Unnamed: 78'),(colocaciones_02['myVarname'] == 'Unnamed: 79'),(colocaciones_02['myVarname'] == 'Unnamed: 80'),(colocaciones_02['myVarname'] == 'Unnamed: 81'),
                (colocaciones_02['myVarname'] == 'Unnamed: 82'),(colocaciones_02['myVarname'] == 'Unnamed: 83'),(colocaciones_02['myVarname'] == 'Unnamed: 84'),(colocaciones_02['myVarname'] == 'Unnamed: 85'),(colocaciones_02['myVarname'] == 'Unnamed: 86'),
                 (colocaciones_02['myVarname'] == 'Unnamed: 87'),(colocaciones_02['myVarname'] == 'Unnamed: 88'),(colocaciones_02['myVarname'] == 'Unnamed: 89'),(colocaciones_02['myVarname'] == 'Unnamed: 90'),(colocaciones_02['myVarname'] == 'Unnamed: 91'),
                  (colocaciones_02['myVarname'] == 'Unnamed: 92'),(colocaciones_02['myVarname'] == 'Unnamed: 93'),(colocaciones_02['myVarname'] == 'Unnamed: 94'),(colocaciones_02['myVarname'] == 'Unnamed: 95'),(colocaciones_02['myVarname'] == 'Unnamed: 96'),
                   (colocaciones_02['myVarname'] == 'Unnamed: 97'),(colocaciones_02['myVarname'] == 'Unnamed: 98'),(colocaciones_02['myVarname'] == 'Unnamed: 99'),(colocaciones_02['myVarname'] == 'Unnamed: 100'),(colocaciones_02['myVarname'] == 'Unnamed: 101'),
                    (colocaciones_02['myVarname'] == 'Unnamed: 102'),(colocaciones_02['myVarname'] == 'Unnamed: 103'),(colocaciones_02['myVarname'] == 'Unnamed: 104'),(colocaciones_02['myVarname'] == 'Unnamed: 105'),(colocaciones_02['myVarname'] == 'Unnamed: 106'),
                     (colocaciones_02['myVarname'] == 'Unnamed: 107'),(colocaciones_02['myVarname'] == 'Unnamed: 108'),(colocaciones_02['myVarname'] == 'Unnamed: 109'),(colocaciones_02['myVarname'] == 'Unnamed: 110'),(colocaciones_02['myVarname'] == 'Unnamed: 111'),
                      (colocaciones_02['myVarname'] == 'Unnamed: 112'),(colocaciones_02['myVarname'] == 'Unnamed: 113'),(colocaciones_02['myVarname'] == 'Unnamed: 114'),(colocaciones_02['myVarname'] == 'Unnamed: 115'),(colocaciones_02['myVarname'] == 'Unnamed: 116'),
                       (colocaciones_02['myVarname'] == 'Unnamed: 117'),(colocaciones_02['myVarname'] == 'Unnamed: 118'),(colocaciones_02['myVarname'] == 'Unnamed: 119'),(colocaciones_02['myVarname'] == 'Unnamed: 120'),(colocaciones_02['myVarname'] == 'Unnamed: 121'),
                        (colocaciones_02['myVarname'] == 'Unnamed: 122'),(colocaciones_02['myVarname'] == 'Unnamed: 123'),(colocaciones_02['myVarname'] == 'Unnamed: 124'),(colocaciones_02['myVarname'] == 'Unnamed: 125'),(colocaciones_02['myVarname'] == 'Unnamed: 126'),
                         (colocaciones_02['myVarname'] == 'Unnamed: 127'),(colocaciones_02['myVarname'] == 'Unnamed: 128'),(colocaciones_02['myVarname'] == 'Unnamed: 129'),(colocaciones_02['myVarname'] == 'Unnamed: 130'),(colocaciones_02['myVarname'] == 'Unnamed: 131'),
                          (colocaciones_02['myVarname'] == 'Unnamed: 132'),(colocaciones_02['myVarname'] == 'Unnamed: 133'),(colocaciones_02['myVarname'] == 'Unnamed: 134'),(colocaciones_02['myVarname'] == 'Unnamed: 135'),(colocaciones_02['myVarname'] == 'Unnamed: 136'),
                           (colocaciones_02['myVarname'] == 'Unnamed: 137'),(colocaciones_02['myVarname'] == 'Unnamed: 138'),(colocaciones_02['myVarname'] == 'Unnamed: 139'),(colocaciones_02['myVarname'] == 'Unnamed: 140'),(colocaciones_02['myVarname'] == 'Unnamed: 141'),
                            (colocaciones_02['myVarname'] == 'Unnamed: 142'),(colocaciones_02['myVarname'] == 'Unnamed: 143'),(colocaciones_02['myVarname'] == 'Unnamed: 144'),(colocaciones_02['myVarname'] == 'Unnamed: 145'),(colocaciones_02['myVarname'] == 'Unnamed: 146'),
                             (colocaciones_02['myVarname'] == 'Unnamed: 147'),(colocaciones_02['myVarname'] == 'Unnamed: 148'),(colocaciones_02['myVarname'] == 'Unnamed: 149'),(colocaciones_02['myVarname'] == 'Unnamed: 150'),(colocaciones_02['myVarname'] == 'Unnamed: 151'),
                              (colocaciones_02['myVarname'] == 'Unnamed: 152'),(colocaciones_02['myVarname'] == 'Unnamed: 153'),(colocaciones_02['myVarname'] == 'Unnamed: 154'),(colocaciones_02['myVarname'] == 'Unnamed: 155'),(colocaciones_02['myVarname'] == 'Unnamed: 156'),
                               (colocaciones_02['myVarname'] == 'Unnamed: 157'),(colocaciones_02['myVarname'] == 'Unnamed: 158'),(colocaciones_02['myVarname'] == 'Unnamed: 159'),(colocaciones_02['myVarname'] == 'Unnamed: 160'),(colocaciones_02['myVarname'] == 'Unnamed: 161'),
                                (colocaciones_02['myVarname'] == 'Unnamed: 162'),(colocaciones_02['myVarname'] == 'Unnamed: 163'),(colocaciones_02['myVarname'] == 'Unnamed: 164'),(colocaciones_02['myVarname'] == 'Unnamed: 165'),(colocaciones_02['myVarname'] == 'Unnamed: 166')
                                ]

# %%
colocaciones_02['Fecha'] = np.select(conditions_2, values)

# %%
colocaciones_02
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor       Fecha
# 5     1349840.90608  2008-01-31
# 6                ND  2008-01-31
# 7      32840.047756  2008-01-31
# 8    8012788.068213  2008-01-31
# ...

# %%
colocaciones_02.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
colocaciones_02.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
colocaciones_02
# Out:
#                                       Institucion            Valor       Fecha
# 5                                      Banco Bice    1349840.90608  2008-01-31
# 6                     Banco BTG Pactual Chile (9)               ND  2008-01-31
# 7                             Banco Consorcio (1)     32840.047756  2008-01-31
# 8                              Banco de Chile (2)   8012788.068213  2008-01-31
# 9                  Banco de Crédito e Inversiones   4855261.065818  2008-01-31
# ..                                            ...              ...         ...
# 26                     JP Morgan Chase Bank, N.A.                0  2021-09-30
# 27                            Rabobank Chile (15)               ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  13369740.572047  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)               ND  2021-09-30
# 30                             Bank of China (16)                0  2021-09-30
#
# [4290 rows x 3 columns]

# %%
colocaciones_02['Tipo'] = "Colocación"
colocaciones_02['Subtipo'] = "Colocaciones comerciales"
colocaciones_02['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
colocaciones_02 = colocaciones_02.reindex(columns=new_cols)

# %%
colocaciones_02
# Out:
#          Fecha                                    Institucion        Tipo  \
# 5   2008-01-31                                     Banco Bice  Colocación
# 6   2008-01-31                    Banco BTG Pactual Chile (9)  Colocación
# 7   2008-01-31                            Banco Consorcio (1)  Colocación
# 8   2008-01-31                             Banco de Chile (2)  Colocación
# 9   2008-01-31                 Banco de Crédito e Inversiones  Colocación
# ..         ...                                            ...         ...
# 26  2021-09-30                     JP Morgan Chase Bank, N.A.  Colocación
# 27  2021-09-30                            Rabobank Chile (15)  Colocación
# 28  2021-09-30                      Scotiabank Chile (3) (17)  Colocación
# 29  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Colocación
# 30  2021-09-30                             Bank of China (16)  Colocación
#
#                      Subtipo            Valor               Tipo de Moneda
# ...

# %% [markdown]
# ## Colocación 03

# %%
colocaciones_03.head(5)
# Out:
#           Unnamed: 0                   Unnamed: 1           Unnamed: 2  \
# 0     Índice general                  Cuadro 1.03                  NaN
# 1    Notas generales      Colocaciones de consumo                  NaN
# 2  Conceptualización  Saldos en millones de pesos                  NaN
# 3                NaN                          NaN                  NaN
# 4                NaN                          NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
colocaciones_03.pop("Unnamed: 0")
# Out:
# 0        Índice general
# 1       Notas generales
# 2     Conceptualización
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# Name: Unnamed: 0, dtype: object

# %%
colocaciones_03
# Out:
#                                            Unnamed: 1           Unnamed: 2  \
# 0                                         Cuadro 1.03                  NaN
# 1                             Colocaciones de consumo                  NaN
# 2                         Saldos en millones de pesos                  NaN
# 3                                                 NaN                  NaN
# 4                                                 NaN  2008-01-31 00:00:00
# 5                                          Banco Bice          42484.64673
# 6                         Banco BTG Pactual Chile (9)                   ND
# 7                                 Banco Consorcio (1)            76.834077
# 8                                  Banco de Chile (2)       1705989.025857
# 9                      Banco de Crédito e Inversiones        892621.061119
# 10                  Banco de la Nación Argentina (18)            82.000356
# ...

# %%
colocaciones_03 = colocaciones_03.iloc[5:]

# %%
colocaciones_03.tail(7)
# Out:
#                                            Unnamed: 1     Unnamed: 2  \
# 30                                 Bank of China (16)             ND
# 31                                              Total  7916375.83177
# 32                                                NaN            NaN
# 33                                                NaN            NaN
# 34                                ND : No existe dato            NaN
# 35                                                NaN            NaN
# 36  Conceptualización: Vínculo que remite al docum...            NaN
#
#         Unnamed: 3      Unnamed: 4      Unnamed: 5      Unnamed: 6  \
# 30              ND              ND              ND              ND
# 31  7975891.218792  8059479.026468  8157740.164936  8155671.817736
# 32             NaN             NaN             NaN             NaN
# 33             NaN             NaN             NaN             NaN
# 34             NaN             NaN             NaN             NaN
# ...

# %%
colocaciones_03.drop(colocaciones_03.tail(6).index,inplace=True)
# Out:
# <ipython-input-42-8dbce3f2b9f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colocaciones_03.drop(colocaciones_03.tail(6).index,inplace=True)

# %%
colocaciones_03
# Out:
#                                         Unnamed: 1      Unnamed: 2  \
# 5                                       Banco Bice     42484.64673
# 6                      Banco BTG Pactual Chile (9)              ND
# 7                              Banco Consorcio (1)       76.834077
# 8                               Banco de Chile (2)  1705989.025857
# 9                   Banco de Crédito e Inversiones   892621.061119
# 10               Banco de la Nación Argentina (18)       82.000356
# 11                       Banco del Estado de Chile   896800.672731
# 12                            Banco do Brasil S.A.       16.322287
# 13                                 Banco Falabella   400027.812418
# 14                             Banco Internacional      285.151338
# 15                       Banco Itaú Corpbanca (10)   793744.048333
# 16                                Banco Paris (13)   155853.711821
# 17                                Banco Penta (14)               0
# ...

# %%
colocaciones_03.head(3)
# Out:
#                     Unnamed: 1   Unnamed: 2    Unnamed: 3    Unnamed: 4  \
# 5                   Banco Bice  42484.64673  43751.851081  44300.733782
# 6  Banco BTG Pactual Chile (9)           ND            ND            ND
# 7          Banco Consorcio (1)    76.834077     75.320878     73.238322
#
#      Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  \
# 5  45176.256626  44412.174975  44596.006724  45011.932927  45196.213037
# 6            ND            ND            ND            ND            ND
# 7     70.001207      73.41036     67.619363      66.49284     69.820279
#
#     Unnamed: 10  ...   Unnamed: 157   Unnamed: 158   Unnamed: 159  \
# 5  45343.544859  ...  157768.471594  161132.583318  162502.908919
# 6            ND  ...              0              0              0
# 7     67.030063  ...   90519.451257   89009.183331   87382.066591
#
#     Unnamed: 160   Unnamed: 161   Unnamed: 162   Unnamed: 163   Unnamed: 164  \
# ...

# %%
colocaciones_03 = colocaciones_03.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
colocaciones_03
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#              Valor
# 5      42484.64673
# 6               ND
# 7        76.834077
# 8   1705989.025857
# 9    892621.061119
# ..             ...
# 26               0
# 27              ND
# ...

# %%
# create a list of our conditions
# create a list of our conditions
conditions_3 = [(colocaciones_03['myVarname'] == 'Unnamed: 2'),(colocaciones_03['myVarname'] == 'Unnamed: 3'),(colocaciones_03['myVarname'] == 'Unnamed: 4'),(colocaciones_03['myVarname'] == 'Unnamed: 5'),(colocaciones_03['myVarname'] == 'Unnamed: 6'),
 (colocaciones_03['myVarname'] == 'Unnamed: 7'),(colocaciones_03['myVarname'] == 'Unnamed: 8'),(colocaciones_03['myVarname'] == 'Unnamed: 9'),(colocaciones_03['myVarname'] == 'Unnamed: 10'),(colocaciones_03['myVarname'] == 'Unnamed: 11'),
  (colocaciones_03['myVarname'] == 'Unnamed: 12'),(colocaciones_03['myVarname'] == 'Unnamed: 13'),(colocaciones_03['myVarname'] == 'Unnamed: 14'),(colocaciones_03['myVarname'] == 'Unnamed: 15'),(colocaciones_03['myVarname'] == 'Unnamed: 16'),
   (colocaciones_03['myVarname'] == 'Unnamed: 17'),(colocaciones_03['myVarname'] == 'Unnamed: 18'),(colocaciones_03['myVarname'] == 'Unnamed: 19'),(colocaciones_03['myVarname'] == 'Unnamed: 20'),(colocaciones_03['myVarname'] == 'Unnamed: 21'),
    (colocaciones_03['myVarname'] == 'Unnamed: 22'),(colocaciones_03['myVarname'] == 'Unnamed: 23'),(colocaciones_03['myVarname'] == 'Unnamed: 24'),(colocaciones_03['myVarname'] == 'Unnamed: 25'),(colocaciones_03['myVarname'] == 'Unnamed: 26'),
     (colocaciones_03['myVarname'] == 'Unnamed: 27'),(colocaciones_03['myVarname'] == 'Unnamed: 28'),(colocaciones_03['myVarname'] == 'Unnamed: 29'),(colocaciones_03['myVarname'] == 'Unnamed: 30'),(colocaciones_03['myVarname'] == 'Unnamed: 31'),
      (colocaciones_03['myVarname'] == 'Unnamed: 32'),(colocaciones_03['myVarname'] == 'Unnamed: 33'),(colocaciones_03['myVarname'] == 'Unnamed: 34'),(colocaciones_03['myVarname'] == 'Unnamed: 35'),(colocaciones_03['myVarname'] == 'Unnamed: 36'),
       (colocaciones_03['myVarname'] == 'Unnamed: 37'),(colocaciones_03['myVarname'] == 'Unnamed: 38'),(colocaciones_03['myVarname'] == 'Unnamed: 39'),(colocaciones_03['myVarname'] == 'Unnamed: 40'),(colocaciones_03['myVarname'] == 'Unnamed: 41'),
        (colocaciones_03['myVarname'] == 'Unnamed: 42'),(colocaciones_03['myVarname'] == 'Unnamed: 43'),(colocaciones_03['myVarname'] == 'Unnamed: 44'),(colocaciones_03['myVarname'] == 'Unnamed: 45'),(colocaciones_03['myVarname'] == 'Unnamed: 46'),
         (colocaciones_03['myVarname'] == 'Unnamed: 47'),(colocaciones_03['myVarname'] == 'Unnamed: 48'),(colocaciones_03['myVarname'] == 'Unnamed: 49'),(colocaciones_03['myVarname'] == 'Unnamed: 50'),(colocaciones_03['myVarname'] == 'Unnamed: 51'),
          (colocaciones_03['myVarname'] == 'Unnamed: 52'),(colocaciones_03['myVarname'] == 'Unnamed: 53'),(colocaciones_03['myVarname'] == 'Unnamed: 54'),(colocaciones_03['myVarname'] == 'Unnamed: 55'),(colocaciones_03['myVarname'] == 'Unnamed: 56'),
           (colocaciones_03['myVarname'] == 'Unnamed: 57'),(colocaciones_03['myVarname'] == 'Unnamed: 58'),(colocaciones_03['myVarname'] == 'Unnamed: 59'),(colocaciones_03['myVarname'] == 'Unnamed: 60'),(colocaciones_03['myVarname'] == 'Unnamed: 61'),
            (colocaciones_03['myVarname'] == 'Unnamed: 62'),(colocaciones_03['myVarname'] == 'Unnamed: 63'),(colocaciones_03['myVarname'] == 'Unnamed: 64'),(colocaciones_03['myVarname'] == 'Unnamed: 65'),(colocaciones_03['myVarname'] == 'Unnamed: 66'),
             (colocaciones_03['myVarname'] == 'Unnamed: 67'),(colocaciones_03['myVarname'] == 'Unnamed: 68'),(colocaciones_03['myVarname'] == 'Unnamed: 69'),(colocaciones_03['myVarname'] == 'Unnamed: 70'),(colocaciones_03['myVarname'] == 'Unnamed: 71'),
              (colocaciones_03['myVarname'] == 'Unnamed: 72'),(colocaciones_03['myVarname'] == 'Unnamed: 73'),(colocaciones_03['myVarname'] == 'Unnamed: 74'),(colocaciones_03['myVarname'] == 'Unnamed: 75'),(colocaciones_03['myVarname'] == 'Unnamed: 76'),
               (colocaciones_03['myVarname'] == 'Unnamed: 77'),(colocaciones_03['myVarname'] == 'Unnamed: 78'),(colocaciones_03['myVarname'] == 'Unnamed: 79'),(colocaciones_03['myVarname'] == 'Unnamed: 80'),(colocaciones_03['myVarname'] == 'Unnamed: 81'),
                (colocaciones_03['myVarname'] == 'Unnamed: 82'),(colocaciones_03['myVarname'] == 'Unnamed: 83'),(colocaciones_03['myVarname'] == 'Unnamed: 84'),(colocaciones_03['myVarname'] == 'Unnamed: 85'),(colocaciones_03['myVarname'] == 'Unnamed: 86'),
                 (colocaciones_03['myVarname'] == 'Unnamed: 87'),(colocaciones_03['myVarname'] == 'Unnamed: 88'),(colocaciones_03['myVarname'] == 'Unnamed: 89'),(colocaciones_03['myVarname'] == 'Unnamed: 90'),(colocaciones_03['myVarname'] == 'Unnamed: 91'),
                  (colocaciones_03['myVarname'] == 'Unnamed: 92'),(colocaciones_03['myVarname'] == 'Unnamed: 93'),(colocaciones_03['myVarname'] == 'Unnamed: 94'),(colocaciones_03['myVarname'] == 'Unnamed: 95'),(colocaciones_03['myVarname'] == 'Unnamed: 96'),
                   (colocaciones_03['myVarname'] == 'Unnamed: 97'),(colocaciones_03['myVarname'] == 'Unnamed: 98'),(colocaciones_03['myVarname'] == 'Unnamed: 99'),(colocaciones_03['myVarname'] == 'Unnamed: 100'),(colocaciones_03['myVarname'] == 'Unnamed: 101'),
                    (colocaciones_03['myVarname'] == 'Unnamed: 102'),(colocaciones_03['myVarname'] == 'Unnamed: 103'),(colocaciones_03['myVarname'] == 'Unnamed: 104'),(colocaciones_03['myVarname'] == 'Unnamed: 105'),(colocaciones_03['myVarname'] == 'Unnamed: 106'),
                     (colocaciones_03['myVarname'] == 'Unnamed: 107'),(colocaciones_03['myVarname'] == 'Unnamed: 108'),(colocaciones_03['myVarname'] == 'Unnamed: 109'),(colocaciones_03['myVarname'] == 'Unnamed: 110'),(colocaciones_03['myVarname'] == 'Unnamed: 111'),
                      (colocaciones_03['myVarname'] == 'Unnamed: 112'),(colocaciones_03['myVarname'] == 'Unnamed: 113'),(colocaciones_03['myVarname'] == 'Unnamed: 114'),(colocaciones_03['myVarname'] == 'Unnamed: 115'),(colocaciones_03['myVarname'] == 'Unnamed: 116'),
                       (colocaciones_03['myVarname'] == 'Unnamed: 117'),(colocaciones_03['myVarname'] == 'Unnamed: 118'),(colocaciones_03['myVarname'] == 'Unnamed: 119'),(colocaciones_03['myVarname'] == 'Unnamed: 120'),(colocaciones_03['myVarname'] == 'Unnamed: 121'),
                        (colocaciones_03['myVarname'] == 'Unnamed: 122'),(colocaciones_03['myVarname'] == 'Unnamed: 123'),(colocaciones_03['myVarname'] == 'Unnamed: 124'),(colocaciones_03['myVarname'] == 'Unnamed: 125'),(colocaciones_03['myVarname'] == 'Unnamed: 126'),
                         (colocaciones_03['myVarname'] == 'Unnamed: 127'),(colocaciones_03['myVarname'] == 'Unnamed: 128'),(colocaciones_03['myVarname'] == 'Unnamed: 129'),(colocaciones_03['myVarname'] == 'Unnamed: 130'),(colocaciones_03['myVarname'] == 'Unnamed: 131'),
                          (colocaciones_03['myVarname'] == 'Unnamed: 132'),(colocaciones_03['myVarname'] == 'Unnamed: 133'),(colocaciones_03['myVarname'] == 'Unnamed: 134'),(colocaciones_03['myVarname'] == 'Unnamed: 135'),(colocaciones_03['myVarname'] == 'Unnamed: 136'),
                           (colocaciones_03['myVarname'] == 'Unnamed: 137'),(colocaciones_03['myVarname'] == 'Unnamed: 138'),(colocaciones_03['myVarname'] == 'Unnamed: 139'),(colocaciones_03['myVarname'] == 'Unnamed: 140'),(colocaciones_03['myVarname'] == 'Unnamed: 141'),
                            (colocaciones_03['myVarname'] == 'Unnamed: 142'),(colocaciones_03['myVarname'] == 'Unnamed: 143'),(colocaciones_03['myVarname'] == 'Unnamed: 144'),(colocaciones_03['myVarname'] == 'Unnamed: 145'),(colocaciones_03['myVarname'] == 'Unnamed: 146'),
                             (colocaciones_03['myVarname'] == 'Unnamed: 147'),(colocaciones_03['myVarname'] == 'Unnamed: 148'),(colocaciones_03['myVarname'] == 'Unnamed: 149'),(colocaciones_03['myVarname'] == 'Unnamed: 150'),(colocaciones_03['myVarname'] == 'Unnamed: 151'),
                              (colocaciones_03['myVarname'] == 'Unnamed: 152'),(colocaciones_03['myVarname'] == 'Unnamed: 153'),(colocaciones_03['myVarname'] == 'Unnamed: 154'),(colocaciones_03['myVarname'] == 'Unnamed: 155'),(colocaciones_03['myVarname'] == 'Unnamed: 156'),
                               (colocaciones_03['myVarname'] == 'Unnamed: 157'),(colocaciones_03['myVarname'] == 'Unnamed: 158'),(colocaciones_03['myVarname'] == 'Unnamed: 159'),(colocaciones_03['myVarname'] == 'Unnamed: 160'),(colocaciones_03['myVarname'] == 'Unnamed: 161'),
                                (colocaciones_03['myVarname'] == 'Unnamed: 162'),(colocaciones_03['myVarname'] == 'Unnamed: 163'),(colocaciones_03['myVarname'] == 'Unnamed: 164'),(colocaciones_03['myVarname'] == 'Unnamed: 165'),(colocaciones_03['myVarname'] == 'Unnamed: 166')
                                ]

# %%
colocaciones_03['Fecha'] = np.select(conditions_3, values)

# %%
colocaciones_03
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#              Valor       Fecha
# 5      42484.64673  2008-01-31
# 6               ND  2008-01-31
# 7        76.834077  2008-01-31
# 8   1705989.025857  2008-01-31
# 9    892621.061119  2008-01-31
# ...

# %%
colocaciones_03.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
colocaciones_03.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
colocaciones_03
# Out:
#                                       Institucion           Valor       Fecha
# 5                                      Banco Bice     42484.64673  2008-01-31
# 6                     Banco BTG Pactual Chile (9)              ND  2008-01-31
# 7                             Banco Consorcio (1)       76.834077  2008-01-31
# 8                              Banco de Chile (2)  1705989.025857  2008-01-31
# 9                  Banco de Crédito e Inversiones   892621.061119  2008-01-31
# ..                                            ...             ...         ...
# 26                     JP Morgan Chase Bank, N.A.               0  2021-09-30
# 27                            Rabobank Chile (15)              ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  1843567.499188  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)              ND  2021-09-30
# 30                             Bank of China (16)               0  2021-09-30
#
# [4290 rows x 3 columns]

# %%
colocaciones_03['Tipo'] = "Colocación"
colocaciones_03['Subtipo'] = "Colocaciones de consumo"
colocaciones_03['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
colocaciones_03 = colocaciones_03.reindex(columns=new_cols)

# %%
colocaciones_03
# Out:
#          Fecha                                    Institucion        Tipo  \
# 5   2008-01-31                                     Banco Bice  Colocación
# 6   2008-01-31                    Banco BTG Pactual Chile (9)  Colocación
# 7   2008-01-31                            Banco Consorcio (1)  Colocación
# 8   2008-01-31                             Banco de Chile (2)  Colocación
# 9   2008-01-31                 Banco de Crédito e Inversiones  Colocación
# ..         ...                                            ...         ...
# 26  2021-09-30                     JP Morgan Chase Bank, N.A.  Colocación
# 27  2021-09-30                            Rabobank Chile (15)  Colocación
# 28  2021-09-30                      Scotiabank Chile (3) (17)  Colocación
# 29  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Colocación
# 30  2021-09-30                             Bank of China (16)  Colocación
#
#                     Subtipo           Valor               Tipo de Moneda
# ...

# %% [markdown]
# ## Colocación 04

# %%
colocaciones_04.head(5)
# Out:
#           Unnamed: 0                   Unnamed: 1           Unnamed: 2  \
# 0     Índice general                  Cuadro 1.04                  NaN
# 1    Notas generales     Colocaciones de vivienda                  NaN
# 2  Conceptualización  Saldos en millones de pesos                  NaN
# 3                NaN                          NaN                  NaN
# 4                NaN                          NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
colocaciones_04.pop("Unnamed: 0")
# Out:
# 0        Índice general
# 1       Notas generales
# 2     Conceptualización
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# Name: Unnamed: 0, dtype: object

# %%
colocaciones_04
# Out:
#                                            Unnamed: 1           Unnamed: 2  \
# 0                                         Cuadro 1.04                  NaN
# 1                            Colocaciones de vivienda                  NaN
# 2                         Saldos en millones de pesos                  NaN
# 3                                                 NaN                  NaN
# 4                                                 NaN  2008-01-31 00:00:00
# 5                                          Banco Bice        163101.050283
# 6                         Banco BTG Pactual Chile (9)                   ND
# 7                                 Banco Consorcio (1)                    0
# 8                                  Banco de Chile (2)       2012306.905594
# 9                      Banco de Crédito e Inversiones       1359557.577848
# 10                  Banco de la Nación Argentina (18)                    0
# ...

# %%
colocaciones_04 = colocaciones_04.iloc[5:]

# %%
colocaciones_04.tail(7)
# Out:
#                                            Unnamed: 1       Unnamed: 2  \
# 30                                 Bank of China (16)               ND
# 31                                              Total  13711532.591349
# 32                                                NaN              NaN
# 33                                                NaN              NaN
# 34                                ND : No existe dato              NaN
# 35                                                NaN              NaN
# 36  Conceptualización: Vínculo que remite al docum...              NaN
#
#          Unnamed: 3       Unnamed: 4       Unnamed: 5       Unnamed: 6  \
# 30               ND               ND               ND               ND
# 31  13854585.136033  14054684.498926  14333606.154724  14529422.196072
# 32              NaN              NaN              NaN              NaN
# 33              NaN              NaN              NaN              NaN
# ...

# %%
colocaciones_04.drop(colocaciones_04.tail(6).index,inplace=True)
# Out:
# <ipython-input-61-6172504ec9aa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colocaciones_04.drop(colocaciones_04.tail(6).index,inplace=True)

# %%
colocaciones_04
# Out:
#                                         Unnamed: 1      Unnamed: 2  \
# 5                                       Banco Bice   163101.050283
# 6                      Banco BTG Pactual Chile (9)              ND
# 7                              Banco Consorcio (1)               0
# 8                               Banco de Chile (2)  2012306.905594
# 9                   Banco de Crédito e Inversiones  1359557.577848
# 10               Banco de la Nación Argentina (18)               0
# 11                       Banco del Estado de Chile  3448346.463604
# 12                            Banco do Brasil S.A.               0
# 13                                 Banco Falabella   130133.733922
# 14                             Banco Internacional      448.317093
# 15                       Banco Itaú Corpbanca (10)    872620.74493
# 16                                Banco Paris (13)     7169.483641
# 17                                Banco Penta (14)               0
# ...

# %%
colocaciones_04.head(3)
# Out:
#                     Unnamed: 1     Unnamed: 2     Unnamed: 3     Unnamed: 4  \
# 5                   Banco Bice  163101.050283  164535.488761  165000.725227
# 6  Banco BTG Pactual Chile (9)             ND             ND             ND
# 7          Banco Consorcio (1)              0              0              0
#
#       Unnamed: 5     Unnamed: 6     Unnamed: 7     Unnamed: 8     Unnamed: 9  \
# 5  166475.180645  169320.159352  173449.303787  178301.667066  180428.687287
# 6             ND             ND             ND             ND             ND
# 7              0              0              0              0              0
#
#      Unnamed: 10  ...    Unnamed: 157    Unnamed: 158    Unnamed: 159  \
# 5  182160.949913  ...  1278590.301844  1293728.818588  1311926.502364
# 6             ND  ...               0               0               0
# 7              0  ...   709300.349469   741924.143235   768709.917134
#
# ...

# %%
colocaciones_04 = colocaciones_04.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
colocaciones_04
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor
# 5     163101.050283
# 6                ND
# 7                 0
# 8    2012306.905594
# 9    1359557.577848
# ..              ...
# 26                0
# 27               ND
# ...

# %%
# create a list of our conditions
conditions_4 = [(colocaciones_04['myVarname'] == 'Unnamed: 2'),(colocaciones_04['myVarname'] == 'Unnamed: 3'),(colocaciones_04['myVarname'] == 'Unnamed: 4'),(colocaciones_04['myVarname'] == 'Unnamed: 5'),(colocaciones_04['myVarname'] == 'Unnamed: 6'),
 (colocaciones_04['myVarname'] == 'Unnamed: 7'),(colocaciones_04['myVarname'] == 'Unnamed: 8'),(colocaciones_04['myVarname'] == 'Unnamed: 9'),(colocaciones_04['myVarname'] == 'Unnamed: 10'),(colocaciones_04['myVarname'] == 'Unnamed: 11'),
  (colocaciones_04['myVarname'] == 'Unnamed: 12'),(colocaciones_04['myVarname'] == 'Unnamed: 13'),(colocaciones_04['myVarname'] == 'Unnamed: 14'),(colocaciones_04['myVarname'] == 'Unnamed: 15'),(colocaciones_04['myVarname'] == 'Unnamed: 16'),
   (colocaciones_04['myVarname'] == 'Unnamed: 17'),(colocaciones_04['myVarname'] == 'Unnamed: 18'),(colocaciones_04['myVarname'] == 'Unnamed: 19'),(colocaciones_04['myVarname'] == 'Unnamed: 20'),(colocaciones_04['myVarname'] == 'Unnamed: 21'),
    (colocaciones_04['myVarname'] == 'Unnamed: 22'),(colocaciones_04['myVarname'] == 'Unnamed: 23'),(colocaciones_04['myVarname'] == 'Unnamed: 24'),(colocaciones_04['myVarname'] == 'Unnamed: 25'),(colocaciones_04['myVarname'] == 'Unnamed: 26'),
     (colocaciones_04['myVarname'] == 'Unnamed: 27'),(colocaciones_04['myVarname'] == 'Unnamed: 28'),(colocaciones_04['myVarname'] == 'Unnamed: 29'),(colocaciones_04['myVarname'] == 'Unnamed: 30'),(colocaciones_04['myVarname'] == 'Unnamed: 31'),
      (colocaciones_04['myVarname'] == 'Unnamed: 32'),(colocaciones_04['myVarname'] == 'Unnamed: 33'),(colocaciones_04['myVarname'] == 'Unnamed: 34'),(colocaciones_04['myVarname'] == 'Unnamed: 35'),(colocaciones_04['myVarname'] == 'Unnamed: 36'),
       (colocaciones_04['myVarname'] == 'Unnamed: 37'),(colocaciones_04['myVarname'] == 'Unnamed: 38'),(colocaciones_04['myVarname'] == 'Unnamed: 39'),(colocaciones_04['myVarname'] == 'Unnamed: 40'),(colocaciones_04['myVarname'] == 'Unnamed: 41'),
        (colocaciones_04['myVarname'] == 'Unnamed: 42'),(colocaciones_04['myVarname'] == 'Unnamed: 43'),(colocaciones_04['myVarname'] == 'Unnamed: 44'),(colocaciones_04['myVarname'] == 'Unnamed: 45'),(colocaciones_04['myVarname'] == 'Unnamed: 46'),
         (colocaciones_04['myVarname'] == 'Unnamed: 47'),(colocaciones_04['myVarname'] == 'Unnamed: 48'),(colocaciones_04['myVarname'] == 'Unnamed: 49'),(colocaciones_04['myVarname'] == 'Unnamed: 50'),(colocaciones_04['myVarname'] == 'Unnamed: 51'),
          (colocaciones_04['myVarname'] == 'Unnamed: 52'),(colocaciones_04['myVarname'] == 'Unnamed: 53'),(colocaciones_04['myVarname'] == 'Unnamed: 54'),(colocaciones_04['myVarname'] == 'Unnamed: 55'),(colocaciones_04['myVarname'] == 'Unnamed: 56'),
           (colocaciones_04['myVarname'] == 'Unnamed: 57'),(colocaciones_04['myVarname'] == 'Unnamed: 58'),(colocaciones_04['myVarname'] == 'Unnamed: 59'),(colocaciones_04['myVarname'] == 'Unnamed: 60'),(colocaciones_04['myVarname'] == 'Unnamed: 61'),
            (colocaciones_04['myVarname'] == 'Unnamed: 62'),(colocaciones_04['myVarname'] == 'Unnamed: 63'),(colocaciones_04['myVarname'] == 'Unnamed: 64'),(colocaciones_04['myVarname'] == 'Unnamed: 65'),(colocaciones_04['myVarname'] == 'Unnamed: 66'),
             (colocaciones_04['myVarname'] == 'Unnamed: 67'),(colocaciones_04['myVarname'] == 'Unnamed: 68'),(colocaciones_04['myVarname'] == 'Unnamed: 69'),(colocaciones_04['myVarname'] == 'Unnamed: 70'),(colocaciones_04['myVarname'] == 'Unnamed: 71'),
              (colocaciones_04['myVarname'] == 'Unnamed: 72'),(colocaciones_04['myVarname'] == 'Unnamed: 73'),(colocaciones_04['myVarname'] == 'Unnamed: 74'),(colocaciones_04['myVarname'] == 'Unnamed: 75'),(colocaciones_04['myVarname'] == 'Unnamed: 76'),
               (colocaciones_04['myVarname'] == 'Unnamed: 77'),(colocaciones_04['myVarname'] == 'Unnamed: 78'),(colocaciones_04['myVarname'] == 'Unnamed: 79'),(colocaciones_04['myVarname'] == 'Unnamed: 80'),(colocaciones_04['myVarname'] == 'Unnamed: 81'),
                (colocaciones_04['myVarname'] == 'Unnamed: 82'),(colocaciones_04['myVarname'] == 'Unnamed: 83'),(colocaciones_04['myVarname'] == 'Unnamed: 84'),(colocaciones_04['myVarname'] == 'Unnamed: 85'),(colocaciones_04['myVarname'] == 'Unnamed: 86'),
                 (colocaciones_04['myVarname'] == 'Unnamed: 87'),(colocaciones_04['myVarname'] == 'Unnamed: 88'),(colocaciones_04['myVarname'] == 'Unnamed: 89'),(colocaciones_04['myVarname'] == 'Unnamed: 90'),(colocaciones_04['myVarname'] == 'Unnamed: 91'),
                  (colocaciones_04['myVarname'] == 'Unnamed: 92'),(colocaciones_04['myVarname'] == 'Unnamed: 93'),(colocaciones_04['myVarname'] == 'Unnamed: 94'),(colocaciones_04['myVarname'] == 'Unnamed: 95'),(colocaciones_04['myVarname'] == 'Unnamed: 96'),
                   (colocaciones_04['myVarname'] == 'Unnamed: 97'),(colocaciones_04['myVarname'] == 'Unnamed: 98'),(colocaciones_04['myVarname'] == 'Unnamed: 99'),(colocaciones_04['myVarname'] == 'Unnamed: 100'),(colocaciones_04['myVarname'] == 'Unnamed: 101'),
                    (colocaciones_04['myVarname'] == 'Unnamed: 102'),(colocaciones_04['myVarname'] == 'Unnamed: 103'),(colocaciones_04['myVarname'] == 'Unnamed: 104'),(colocaciones_04['myVarname'] == 'Unnamed: 105'),(colocaciones_04['myVarname'] == 'Unnamed: 106'),
                     (colocaciones_04['myVarname'] == 'Unnamed: 107'),(colocaciones_04['myVarname'] == 'Unnamed: 108'),(colocaciones_04['myVarname'] == 'Unnamed: 109'),(colocaciones_04['myVarname'] == 'Unnamed: 110'),(colocaciones_04['myVarname'] == 'Unnamed: 111'),
                      (colocaciones_04['myVarname'] == 'Unnamed: 112'),(colocaciones_04['myVarname'] == 'Unnamed: 113'),(colocaciones_04['myVarname'] == 'Unnamed: 114'),(colocaciones_04['myVarname'] == 'Unnamed: 115'),(colocaciones_04['myVarname'] == 'Unnamed: 116'),
                       (colocaciones_04['myVarname'] == 'Unnamed: 117'),(colocaciones_04['myVarname'] == 'Unnamed: 118'),(colocaciones_04['myVarname'] == 'Unnamed: 119'),(colocaciones_04['myVarname'] == 'Unnamed: 120'),(colocaciones_04['myVarname'] == 'Unnamed: 121'),
                        (colocaciones_04['myVarname'] == 'Unnamed: 122'),(colocaciones_04['myVarname'] == 'Unnamed: 123'),(colocaciones_04['myVarname'] == 'Unnamed: 124'),(colocaciones_04['myVarname'] == 'Unnamed: 125'),(colocaciones_04['myVarname'] == 'Unnamed: 126'),
                         (colocaciones_04['myVarname'] == 'Unnamed: 127'),(colocaciones_04['myVarname'] == 'Unnamed: 128'),(colocaciones_04['myVarname'] == 'Unnamed: 129'),(colocaciones_04['myVarname'] == 'Unnamed: 130'),(colocaciones_04['myVarname'] == 'Unnamed: 131'),
                          (colocaciones_04['myVarname'] == 'Unnamed: 132'),(colocaciones_04['myVarname'] == 'Unnamed: 133'),(colocaciones_04['myVarname'] == 'Unnamed: 134'),(colocaciones_04['myVarname'] == 'Unnamed: 135'),(colocaciones_04['myVarname'] == 'Unnamed: 136'),
                           (colocaciones_04['myVarname'] == 'Unnamed: 137'),(colocaciones_04['myVarname'] == 'Unnamed: 138'),(colocaciones_04['myVarname'] == 'Unnamed: 139'),(colocaciones_04['myVarname'] == 'Unnamed: 140'),(colocaciones_04['myVarname'] == 'Unnamed: 141'),
                            (colocaciones_04['myVarname'] == 'Unnamed: 142'),(colocaciones_04['myVarname'] == 'Unnamed: 143'),(colocaciones_04['myVarname'] == 'Unnamed: 144'),(colocaciones_04['myVarname'] == 'Unnamed: 145'),(colocaciones_04['myVarname'] == 'Unnamed: 146'),
                             (colocaciones_04['myVarname'] == 'Unnamed: 147'),(colocaciones_04['myVarname'] == 'Unnamed: 148'),(colocaciones_04['myVarname'] == 'Unnamed: 149'),(colocaciones_04['myVarname'] == 'Unnamed: 150'),(colocaciones_04['myVarname'] == 'Unnamed: 151'),
                              (colocaciones_04['myVarname'] == 'Unnamed: 152'),(colocaciones_04['myVarname'] == 'Unnamed: 153'),(colocaciones_04['myVarname'] == 'Unnamed: 154'),(colocaciones_04['myVarname'] == 'Unnamed: 155'),(colocaciones_04['myVarname'] == 'Unnamed: 156'),
                               (colocaciones_04['myVarname'] == 'Unnamed: 157'),(colocaciones_04['myVarname'] == 'Unnamed: 158'),(colocaciones_04['myVarname'] == 'Unnamed: 159'),(colocaciones_04['myVarname'] == 'Unnamed: 160'),(colocaciones_04['myVarname'] == 'Unnamed: 161'),
                                (colocaciones_04['myVarname'] == 'Unnamed: 162'),(colocaciones_04['myVarname'] == 'Unnamed: 163'),(colocaciones_04['myVarname'] == 'Unnamed: 164'),(colocaciones_04['myVarname'] == 'Unnamed: 165'),(colocaciones_04['myVarname'] == 'Unnamed: 166')
                                ]

# %%
colocaciones_04['Fecha'] = np.select(conditions_4, values)

# %%
colocaciones_04
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor       Fecha
# 5     163101.050283  2008-01-31
# 6                ND  2008-01-31
# 7                 0  2008-01-31
# 8    2012306.905594  2008-01-31
# ...

# %%
colocaciones_04.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
colocaciones_04.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
colocaciones_04
# Out:
#                                       Institucion            Valor       Fecha
# 5                                      Banco Bice    163101.050283  2008-01-31
# 6                     Banco BTG Pactual Chile (9)               ND  2008-01-31
# 7                             Banco Consorcio (1)                0  2008-01-31
# 8                              Banco de Chile (2)   2012306.905594  2008-01-31
# 9                  Banco de Crédito e Inversiones   1359557.577848  2008-01-31
# ..                                            ...              ...         ...
# 26                     JP Morgan Chase Bank, N.A.                0  2021-09-30
# 27                            Rabobank Chile (15)               ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  10917979.217145  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)               ND  2021-09-30
# 30                             Bank of China (16)                0  2021-09-30
#
# [4290 rows x 3 columns]

# %%
colocaciones_04['Tipo'] = "Colocación"
colocaciones_04['Subtipo'] = "Colocaciones de vivienda"
colocaciones_04['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
colocaciones_04 = colocaciones_04.reindex(columns=new_cols)

# %%
colocaciones_04
# Out:
#          Fecha                                    Institucion        Tipo  \
# 5   2008-01-31                                     Banco Bice  Colocación
# 6   2008-01-31                    Banco BTG Pactual Chile (9)  Colocación
# 7   2008-01-31                            Banco Consorcio (1)  Colocación
# 8   2008-01-31                             Banco de Chile (2)  Colocación
# 9   2008-01-31                 Banco de Crédito e Inversiones  Colocación
# ..         ...                                            ...         ...
# 26  2021-09-30                     JP Morgan Chase Bank, N.A.  Colocación
# 27  2021-09-30                            Rabobank Chile (15)  Colocación
# 28  2021-09-30                      Scotiabank Chile (3) (17)  Colocación
# 29  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Colocación
# 30  2021-09-30                             Bank of China (16)  Colocación
#
#                      Subtipo            Valor               Tipo de Moneda
# ...

# %% [markdown]
# ## Colocación 05

# %%
colocaciones_05.head(5)
# Out:
#           Unnamed: 0                         Unnamed: 1           Unnamed: 2  \
# 0     Índice general                        Cuadro 1.05                  NaN
# 1    Notas generales  Colocaciones de comercio exterior                  NaN
# 2  Conceptualización        Saldos en millones de pesos                  NaN
# 3                NaN                                NaN                  NaN
# 4                NaN                                NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# ...

# %%
colocaciones_05.pop("Unnamed: 0")
# Out:
# 0        Índice general
# 1       Notas generales
# 2     Conceptualización
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# Name: Unnamed: 0, dtype: object

# %%
colocaciones_05 = colocaciones_05.iloc[5:]

# %%
colocaciones_05.tail(7)
# Out:
#                                            Unnamed: 1      Unnamed: 2  \
# 30                                 Bank of China (16)              ND
# 31                                              Total  5095808.731388
# 32                                                NaN             NaN
# 33                                                NaN             NaN
# 34                                ND : No existe dato             NaN
# 35                                                NaN             NaN
# 36  Conceptualización: Vínculo que remite al docum...             NaN
#
#         Unnamed: 3      Unnamed: 4     Unnamed: 5      Unnamed: 6  \
# 30              ND              ND             ND              ND
# 31  5196531.970376  5151148.158795  5818984.88598  6335387.676709
# 32             NaN             NaN            NaN             NaN
# 33             NaN             NaN            NaN             NaN
# 34             NaN             NaN            NaN             NaN
# ...

# %%
colocaciones_05.drop(colocaciones_05.tail(6).index,inplace=True)
# Out:
# <ipython-input-79-0b580720e0a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colocaciones_05.drop(colocaciones_05.tail(6).index,inplace=True)

# %%
colocaciones_05
# Out:
#                                         Unnamed: 1      Unnamed: 2  \
# 5                                       Banco Bice   208180.502882
# 6                      Banco BTG Pactual Chile (9)              ND
# 7                              Banco Consorcio (1)     1012.818416
# 8                               Banco de Chile (2)  1146071.585087
# 9                   Banco de Crédito e Inversiones   700740.216591
# 10               Banco de la Nación Argentina (18)     3429.030188
# 11                       Banco del Estado de Chile    302574.69093
# 12                            Banco do Brasil S.A.    19767.903482
# 13                                 Banco Falabella               0
# 14                             Banco Internacional    30773.490653
# 15                       Banco Itaú Corpbanca (10)    580326.86109
# 16                                Banco Paris (13)               0
# 17                                Banco Penta (14)               0
# ...

# %%
colocaciones_05.head(3)
# Out:
#                     Unnamed: 1     Unnamed: 2    Unnamed: 3     Unnamed: 4  \
# 5                   Banco Bice  208180.502882  222537.64608  226147.337189
# 6  Banco BTG Pactual Chile (9)             ND            ND             ND
# 7          Banco Consorcio (1)    1012.818416    840.247663     850.989224
#
#       Unnamed: 5     Unnamed: 6     Unnamed: 7     Unnamed: 8     Unnamed: 9  \
# 5  246221.824211  265392.950186  296035.915837  282283.714525  273227.760358
# 6             ND             ND             ND             ND             ND
# 7     846.224571     897.561105    1108.627703     928.539921     867.920268
#
#      Unnamed: 10  ...   Unnamed: 157  Unnamed: 158   Unnamed: 159  \
# 5  295075.257962  ...  260815.529369  279210.03817  285223.717593
# 6             ND  ...              0             0              0
# 7      642.95212  ...   56049.286886  52443.953641   58713.973019
#
#     Unnamed: 160   Unnamed: 161   Unnamed: 162   Unnamed: 163   Unnamed: 164  \
# ...

# %%
colocaciones_05 = colocaciones_05.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
colocaciones_05
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#              Valor
# 5    208180.502882
# 6               ND
# 7      1012.818416
# 8   1146071.585087
# 9    700740.216591
# ..             ...
# 26               0
# 27              ND
# ...

# %%
# create a list of our conditions
conditions_5 = [(colocaciones_05['myVarname'] == 'Unnamed: 2'),(colocaciones_05['myVarname'] == 'Unnamed: 3'),(colocaciones_05['myVarname'] == 'Unnamed: 4'),(colocaciones_05['myVarname'] == 'Unnamed: 5'),(colocaciones_05['myVarname'] == 'Unnamed: 6'),
 (colocaciones_05['myVarname'] == 'Unnamed: 7'),(colocaciones_05['myVarname'] == 'Unnamed: 8'),(colocaciones_05['myVarname'] == 'Unnamed: 9'),(colocaciones_05['myVarname'] == 'Unnamed: 10'),(colocaciones_05['myVarname'] == 'Unnamed: 11'),
  (colocaciones_05['myVarname'] == 'Unnamed: 12'),(colocaciones_05['myVarname'] == 'Unnamed: 13'),(colocaciones_05['myVarname'] == 'Unnamed: 14'),(colocaciones_05['myVarname'] == 'Unnamed: 15'),(colocaciones_05['myVarname'] == 'Unnamed: 16'),
   (colocaciones_05['myVarname'] == 'Unnamed: 17'),(colocaciones_05['myVarname'] == 'Unnamed: 18'),(colocaciones_05['myVarname'] == 'Unnamed: 19'),(colocaciones_05['myVarname'] == 'Unnamed: 20'),(colocaciones_05['myVarname'] == 'Unnamed: 21'),
    (colocaciones_05['myVarname'] == 'Unnamed: 22'),(colocaciones_05['myVarname'] == 'Unnamed: 23'),(colocaciones_05['myVarname'] == 'Unnamed: 24'),(colocaciones_05['myVarname'] == 'Unnamed: 25'),(colocaciones_05['myVarname'] == 'Unnamed: 26'),
     (colocaciones_05['myVarname'] == 'Unnamed: 27'),(colocaciones_05['myVarname'] == 'Unnamed: 28'),(colocaciones_05['myVarname'] == 'Unnamed: 29'),(colocaciones_05['myVarname'] == 'Unnamed: 30'),(colocaciones_05['myVarname'] == 'Unnamed: 31'),
      (colocaciones_05['myVarname'] == 'Unnamed: 32'),(colocaciones_05['myVarname'] == 'Unnamed: 33'),(colocaciones_05['myVarname'] == 'Unnamed: 34'),(colocaciones_05['myVarname'] == 'Unnamed: 35'),(colocaciones_05['myVarname'] == 'Unnamed: 36'),
       (colocaciones_05['myVarname'] == 'Unnamed: 37'),(colocaciones_05['myVarname'] == 'Unnamed: 38'),(colocaciones_05['myVarname'] == 'Unnamed: 39'),(colocaciones_05['myVarname'] == 'Unnamed: 40'),(colocaciones_05['myVarname'] == 'Unnamed: 41'),
        (colocaciones_05['myVarname'] == 'Unnamed: 42'),(colocaciones_05['myVarname'] == 'Unnamed: 43'),(colocaciones_05['myVarname'] == 'Unnamed: 44'),(colocaciones_05['myVarname'] == 'Unnamed: 45'),(colocaciones_05['myVarname'] == 'Unnamed: 46'),
         (colocaciones_05['myVarname'] == 'Unnamed: 47'),(colocaciones_05['myVarname'] == 'Unnamed: 48'),(colocaciones_05['myVarname'] == 'Unnamed: 49'),(colocaciones_05['myVarname'] == 'Unnamed: 50'),(colocaciones_05['myVarname'] == 'Unnamed: 51'),
          (colocaciones_05['myVarname'] == 'Unnamed: 52'),(colocaciones_05['myVarname'] == 'Unnamed: 53'),(colocaciones_05['myVarname'] == 'Unnamed: 54'),(colocaciones_05['myVarname'] == 'Unnamed: 55'),(colocaciones_05['myVarname'] == 'Unnamed: 56'),
           (colocaciones_05['myVarname'] == 'Unnamed: 57'),(colocaciones_05['myVarname'] == 'Unnamed: 58'),(colocaciones_05['myVarname'] == 'Unnamed: 59'),(colocaciones_05['myVarname'] == 'Unnamed: 60'),(colocaciones_05['myVarname'] == 'Unnamed: 61'),
            (colocaciones_05['myVarname'] == 'Unnamed: 62'),(colocaciones_05['myVarname'] == 'Unnamed: 63'),(colocaciones_05['myVarname'] == 'Unnamed: 64'),(colocaciones_05['myVarname'] == 'Unnamed: 65'),(colocaciones_05['myVarname'] == 'Unnamed: 66'),
             (colocaciones_05['myVarname'] == 'Unnamed: 67'),(colocaciones_05['myVarname'] == 'Unnamed: 68'),(colocaciones_05['myVarname'] == 'Unnamed: 69'),(colocaciones_05['myVarname'] == 'Unnamed: 70'),(colocaciones_05['myVarname'] == 'Unnamed: 71'),
              (colocaciones_05['myVarname'] == 'Unnamed: 72'),(colocaciones_05['myVarname'] == 'Unnamed: 73'),(colocaciones_05['myVarname'] == 'Unnamed: 74'),(colocaciones_05['myVarname'] == 'Unnamed: 75'),(colocaciones_05['myVarname'] == 'Unnamed: 76'),
               (colocaciones_05['myVarname'] == 'Unnamed: 77'),(colocaciones_05['myVarname'] == 'Unnamed: 78'),(colocaciones_05['myVarname'] == 'Unnamed: 79'),(colocaciones_05['myVarname'] == 'Unnamed: 80'),(colocaciones_05['myVarname'] == 'Unnamed: 81'),
                (colocaciones_05['myVarname'] == 'Unnamed: 82'),(colocaciones_05['myVarname'] == 'Unnamed: 83'),(colocaciones_05['myVarname'] == 'Unnamed: 84'),(colocaciones_05['myVarname'] == 'Unnamed: 85'),(colocaciones_05['myVarname'] == 'Unnamed: 86'),
                 (colocaciones_05['myVarname'] == 'Unnamed: 87'),(colocaciones_05['myVarname'] == 'Unnamed: 88'),(colocaciones_05['myVarname'] == 'Unnamed: 89'),(colocaciones_05['myVarname'] == 'Unnamed: 90'),(colocaciones_05['myVarname'] == 'Unnamed: 91'),
                  (colocaciones_05['myVarname'] == 'Unnamed: 92'),(colocaciones_05['myVarname'] == 'Unnamed: 93'),(colocaciones_05['myVarname'] == 'Unnamed: 94'),(colocaciones_05['myVarname'] == 'Unnamed: 95'),(colocaciones_05['myVarname'] == 'Unnamed: 96'),
                   (colocaciones_05['myVarname'] == 'Unnamed: 97'),(colocaciones_05['myVarname'] == 'Unnamed: 98'),(colocaciones_05['myVarname'] == 'Unnamed: 99'),(colocaciones_05['myVarname'] == 'Unnamed: 100'),(colocaciones_05['myVarname'] == 'Unnamed: 101'),
                    (colocaciones_05['myVarname'] == 'Unnamed: 102'),(colocaciones_05['myVarname'] == 'Unnamed: 103'),(colocaciones_05['myVarname'] == 'Unnamed: 104'),(colocaciones_05['myVarname'] == 'Unnamed: 105'),(colocaciones_05['myVarname'] == 'Unnamed: 106'),
                     (colocaciones_05['myVarname'] == 'Unnamed: 107'),(colocaciones_05['myVarname'] == 'Unnamed: 108'),(colocaciones_05['myVarname'] == 'Unnamed: 109'),(colocaciones_05['myVarname'] == 'Unnamed: 110'),(colocaciones_05['myVarname'] == 'Unnamed: 111'),
                      (colocaciones_05['myVarname'] == 'Unnamed: 112'),(colocaciones_05['myVarname'] == 'Unnamed: 113'),(colocaciones_05['myVarname'] == 'Unnamed: 114'),(colocaciones_05['myVarname'] == 'Unnamed: 115'),(colocaciones_05['myVarname'] == 'Unnamed: 116'),
                       (colocaciones_05['myVarname'] == 'Unnamed: 117'),(colocaciones_05['myVarname'] == 'Unnamed: 118'),(colocaciones_05['myVarname'] == 'Unnamed: 119'),(colocaciones_05['myVarname'] == 'Unnamed: 120'),(colocaciones_05['myVarname'] == 'Unnamed: 121'),
                        (colocaciones_05['myVarname'] == 'Unnamed: 122'),(colocaciones_05['myVarname'] == 'Unnamed: 123'),(colocaciones_05['myVarname'] == 'Unnamed: 124'),(colocaciones_05['myVarname'] == 'Unnamed: 125'),(colocaciones_05['myVarname'] == 'Unnamed: 126'),
                         (colocaciones_05['myVarname'] == 'Unnamed: 127'),(colocaciones_05['myVarname'] == 'Unnamed: 128'),(colocaciones_05['myVarname'] == 'Unnamed: 129'),(colocaciones_05['myVarname'] == 'Unnamed: 130'),(colocaciones_05['myVarname'] == 'Unnamed: 131'),
                          (colocaciones_05['myVarname'] == 'Unnamed: 132'),(colocaciones_05['myVarname'] == 'Unnamed: 133'),(colocaciones_05['myVarname'] == 'Unnamed: 134'),(colocaciones_05['myVarname'] == 'Unnamed: 135'),(colocaciones_05['myVarname'] == 'Unnamed: 136'),
                           (colocaciones_05['myVarname'] == 'Unnamed: 137'),(colocaciones_05['myVarname'] == 'Unnamed: 138'),(colocaciones_05['myVarname'] == 'Unnamed: 139'),(colocaciones_05['myVarname'] == 'Unnamed: 140'),(colocaciones_05['myVarname'] == 'Unnamed: 141'),
                            (colocaciones_05['myVarname'] == 'Unnamed: 142'),(colocaciones_05['myVarname'] == 'Unnamed: 143'),(colocaciones_05['myVarname'] == 'Unnamed: 144'),(colocaciones_05['myVarname'] == 'Unnamed: 145'),(colocaciones_05['myVarname'] == 'Unnamed: 146'),
                             (colocaciones_05['myVarname'] == 'Unnamed: 147'),(colocaciones_05['myVarname'] == 'Unnamed: 148'),(colocaciones_05['myVarname'] == 'Unnamed: 149'),(colocaciones_05['myVarname'] == 'Unnamed: 150'),(colocaciones_05['myVarname'] == 'Unnamed: 151'),
                              (colocaciones_05['myVarname'] == 'Unnamed: 152'),(colocaciones_05['myVarname'] == 'Unnamed: 153'),(colocaciones_05['myVarname'] == 'Unnamed: 154'),(colocaciones_05['myVarname'] == 'Unnamed: 155'),(colocaciones_05['myVarname'] == 'Unnamed: 156'),
                               (colocaciones_05['myVarname'] == 'Unnamed: 157'),(colocaciones_05['myVarname'] == 'Unnamed: 158'),(colocaciones_05['myVarname'] == 'Unnamed: 159'),(colocaciones_05['myVarname'] == 'Unnamed: 160'),(colocaciones_05['myVarname'] == 'Unnamed: 161'),
                                (colocaciones_05['myVarname'] == 'Unnamed: 162'),(colocaciones_05['myVarname'] == 'Unnamed: 163'),(colocaciones_05['myVarname'] == 'Unnamed: 164'),(colocaciones_05['myVarname'] == 'Unnamed: 165'),(colocaciones_05['myVarname'] == 'Unnamed: 166')
                                ]

# %%
colocaciones_05['Fecha'] = np.select(conditions_5, values)

# %%
colocaciones_05
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#              Valor       Fecha
# 5    208180.502882  2008-01-31
# 6               ND  2008-01-31
# 7      1012.818416  2008-01-31
# 8   1146071.585087  2008-01-31
# 9    700740.216591  2008-01-31
# ...

# %%
colocaciones_05.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
colocaciones_05.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
colocaciones_05
# Out:
#                                       Institucion           Valor       Fecha
# 5                                      Banco Bice   208180.502882  2008-01-31
# 6                     Banco BTG Pactual Chile (9)              ND  2008-01-31
# 7                             Banco Consorcio (1)     1012.818416  2008-01-31
# 8                              Banco de Chile (2)  1146071.585087  2008-01-31
# 9                  Banco de Crédito e Inversiones   700740.216591  2008-01-31
# ..                                            ...             ...         ...
# 26                     JP Morgan Chase Bank, N.A.               0  2021-09-30
# 27                            Rabobank Chile (15)              ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  1619234.994418  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)              ND  2021-09-30
# 30                             Bank of China (16)               0  2021-09-30
#
# [4290 rows x 3 columns]

# %%
colocaciones_05['Tipo'] = "Colocación"
colocaciones_05['Subtipo'] = "Colocaciones de comercio exterior"
colocaciones_05['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
colocaciones_05 = colocaciones_05.reindex(columns=new_cols)

# %%
colocaciones_05
# Out:
#          Fecha                                    Institucion        Tipo  \
# 5   2008-01-31                                     Banco Bice  Colocación
# 6   2008-01-31                    Banco BTG Pactual Chile (9)  Colocación
# 7   2008-01-31                            Banco Consorcio (1)  Colocación
# 8   2008-01-31                             Banco de Chile (2)  Colocación
# 9   2008-01-31                 Banco de Crédito e Inversiones  Colocación
# ..         ...                                            ...         ...
# 26  2021-09-30                     JP Morgan Chase Bank, N.A.  Colocación
# 27  2021-09-30                            Rabobank Chile (15)  Colocación
# 28  2021-09-30                      Scotiabank Chile (3) (17)  Colocación
# 29  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Colocación
# 30  2021-09-30                             Bank of China (16)  Colocación
#
#                               Subtipo           Valor  \
# ...

# %% [markdown]
# ## Colocación 06

# %%
colocaciones_06.head(5)
# Out:
#           Unnamed: 0                   Unnamed: 1           Unnamed: 2  \
# 0     Índice general                  Cuadro 1.06                  NaN
# 1    Notas generales     Colocaciones de empresas                  NaN
# 2  Conceptualización  Saldos en millones de pesos                  NaN
# 3                NaN                          NaN                  NaN
# 4                NaN                          NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
colocaciones_06.pop("Unnamed: 0")
# Out:
# 0        Índice general
# 1       Notas generales
# 2     Conceptualización
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# Name: Unnamed: 0, dtype: object

# %%
colocaciones_06 = colocaciones_06.iloc[5:]

# %%
colocaciones_06.tail(7)
# Out:
#                                            Unnamed: 1       Unnamed: 2  \
# 30                                 Bank of China (16)               ND
# 31                                              Total  41661914.862198
# 32                                                NaN              NaN
# 33                                                NaN              NaN
# 34                                ND : No existe dato              NaN
# 35                                                NaN              NaN
# 36  Conceptualización: Vínculo que remite al docum...              NaN
#
#          Unnamed: 3       Unnamed: 4       Unnamed: 5       Unnamed: 6  \
# 30               ND               ND               ND               ND
# 31  42099121.769921  42217108.673604  43748245.913815  44816316.716613
# 32              NaN              NaN              NaN              NaN
# 33              NaN              NaN              NaN              NaN
# ...

# %%
colocaciones_06.drop(colocaciones_06.tail(6).index,inplace=True)
# Out:
# <ipython-input-97-df6c3a834d2e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colocaciones_06.drop(colocaciones_06.tail(6).index,inplace=True)

# %%
colocaciones_06
# Out:
#                                         Unnamed: 1      Unnamed: 2  \
# 5                                       Banco Bice  1558021.408962
# 6                      Banco BTG Pactual Chile (9)              ND
# 7                              Banco Consorcio (1)    33852.866172
# 8                               Banco de Chile (2)    9158859.6533
# 9                   Banco de Crédito e Inversiones  5556001.282409
# 10               Banco de la Nación Argentina (18)     7430.128756
# 11                       Banco del Estado de Chile  3896153.828674
# 12                            Banco do Brasil S.A.    26059.467665
# 13                                 Banco Falabella     3152.892478
# 14                             Banco Internacional   215982.166181
# 15                       Banco Itaú Corpbanca (10)  4574744.624368
# 16                                Banco Paris (13)     1081.159783
# 17                                Banco Penta (14)               0
# ...

# %%
colocaciones_06.head(3)
# Out:
#                     Unnamed: 1      Unnamed: 2      Unnamed: 3  \
# 5                   Banco Bice  1558021.408962  1600142.273184
# 6  Banco BTG Pactual Chile (9)              ND              ND
# 7          Banco Consorcio (1)    33852.866172    32164.437303
#
#        Unnamed: 4     Unnamed: 5      Unnamed: 6     Unnamed: 7  \
# 5  1632884.938318  1669941.78234  1727712.649442  1801725.02261
# 6              ND             ND              ND             ND
# 7    29705.566566    30101.07145    30449.634077   29549.393966
#
#        Unnamed: 8    Unnamed: 9     Unnamed: 10  ...    Unnamed: 157  \
# 5  1771447.528553  1815725.5027  1869964.294513  ...  5224580.500073
# 6              ND            ND              ND  ...  1207031.841972
# 7    28366.781944  28719.590316    27240.785625  ...   3053489.90254
#
#      Unnamed: 158    Unnamed: 159    Unnamed: 160    Unnamed: 161  \
# 5  5288485.322697  5304405.948313  5356333.775644  5401353.292584
# ...

# %%
colocaciones_06 = colocaciones_06.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
colocaciones_06
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor
# 5    1558021.408962
# 6                ND
# 7      33852.866172
# 8      9158859.6533
# 9    5556001.282409
# ..              ...
# 26                0
# 27               ND
# ...

# %%
# create a list of our conditions
conditions_6 = [(colocaciones_06['myVarname'] == 'Unnamed: 2'),(colocaciones_06['myVarname'] == 'Unnamed: 3'),(colocaciones_06['myVarname'] == 'Unnamed: 4'),(colocaciones_06['myVarname'] == 'Unnamed: 5'),(colocaciones_06['myVarname'] == 'Unnamed: 6'),
 (colocaciones_06['myVarname'] == 'Unnamed: 7'),(colocaciones_06['myVarname'] == 'Unnamed: 8'),(colocaciones_06['myVarname'] == 'Unnamed: 9'),(colocaciones_06['myVarname'] == 'Unnamed: 10'),(colocaciones_06['myVarname'] == 'Unnamed: 11'),
  (colocaciones_06['myVarname'] == 'Unnamed: 12'),(colocaciones_06['myVarname'] == 'Unnamed: 13'),(colocaciones_06['myVarname'] == 'Unnamed: 14'),(colocaciones_06['myVarname'] == 'Unnamed: 15'),(colocaciones_06['myVarname'] == 'Unnamed: 16'),
   (colocaciones_06['myVarname'] == 'Unnamed: 17'),(colocaciones_06['myVarname'] == 'Unnamed: 18'),(colocaciones_06['myVarname'] == 'Unnamed: 19'),(colocaciones_06['myVarname'] == 'Unnamed: 20'),(colocaciones_06['myVarname'] == 'Unnamed: 21'),
    (colocaciones_06['myVarname'] == 'Unnamed: 22'),(colocaciones_06['myVarname'] == 'Unnamed: 23'),(colocaciones_06['myVarname'] == 'Unnamed: 24'),(colocaciones_06['myVarname'] == 'Unnamed: 25'),(colocaciones_06['myVarname'] == 'Unnamed: 26'),
     (colocaciones_06['myVarname'] == 'Unnamed: 27'),(colocaciones_06['myVarname'] == 'Unnamed: 28'),(colocaciones_06['myVarname'] == 'Unnamed: 29'),(colocaciones_06['myVarname'] == 'Unnamed: 30'),(colocaciones_06['myVarname'] == 'Unnamed: 31'),
      (colocaciones_06['myVarname'] == 'Unnamed: 32'),(colocaciones_06['myVarname'] == 'Unnamed: 33'),(colocaciones_06['myVarname'] == 'Unnamed: 34'),(colocaciones_06['myVarname'] == 'Unnamed: 35'),(colocaciones_06['myVarname'] == 'Unnamed: 36'),
       (colocaciones_06['myVarname'] == 'Unnamed: 37'),(colocaciones_06['myVarname'] == 'Unnamed: 38'),(colocaciones_06['myVarname'] == 'Unnamed: 39'),(colocaciones_06['myVarname'] == 'Unnamed: 40'),(colocaciones_06['myVarname'] == 'Unnamed: 41'),
        (colocaciones_06['myVarname'] == 'Unnamed: 42'),(colocaciones_06['myVarname'] == 'Unnamed: 43'),(colocaciones_06['myVarname'] == 'Unnamed: 44'),(colocaciones_06['myVarname'] == 'Unnamed: 45'),(colocaciones_06['myVarname'] == 'Unnamed: 46'),
         (colocaciones_06['myVarname'] == 'Unnamed: 47'),(colocaciones_06['myVarname'] == 'Unnamed: 48'),(colocaciones_06['myVarname'] == 'Unnamed: 49'),(colocaciones_06['myVarname'] == 'Unnamed: 50'),(colocaciones_06['myVarname'] == 'Unnamed: 51'),
          (colocaciones_06['myVarname'] == 'Unnamed: 52'),(colocaciones_06['myVarname'] == 'Unnamed: 53'),(colocaciones_06['myVarname'] == 'Unnamed: 54'),(colocaciones_06['myVarname'] == 'Unnamed: 55'),(colocaciones_06['myVarname'] == 'Unnamed: 56'),
           (colocaciones_06['myVarname'] == 'Unnamed: 57'),(colocaciones_06['myVarname'] == 'Unnamed: 58'),(colocaciones_06['myVarname'] == 'Unnamed: 59'),(colocaciones_06['myVarname'] == 'Unnamed: 60'),(colocaciones_06['myVarname'] == 'Unnamed: 61'),
            (colocaciones_06['myVarname'] == 'Unnamed: 62'),(colocaciones_06['myVarname'] == 'Unnamed: 63'),(colocaciones_06['myVarname'] == 'Unnamed: 64'),(colocaciones_06['myVarname'] == 'Unnamed: 65'),(colocaciones_06['myVarname'] == 'Unnamed: 66'),
             (colocaciones_06['myVarname'] == 'Unnamed: 67'),(colocaciones_06['myVarname'] == 'Unnamed: 68'),(colocaciones_06['myVarname'] == 'Unnamed: 69'),(colocaciones_06['myVarname'] == 'Unnamed: 70'),(colocaciones_06['myVarname'] == 'Unnamed: 71'),
              (colocaciones_06['myVarname'] == 'Unnamed: 72'),(colocaciones_06['myVarname'] == 'Unnamed: 73'),(colocaciones_06['myVarname'] == 'Unnamed: 74'),(colocaciones_06['myVarname'] == 'Unnamed: 75'),(colocaciones_06['myVarname'] == 'Unnamed: 76'),
               (colocaciones_06['myVarname'] == 'Unnamed: 77'),(colocaciones_06['myVarname'] == 'Unnamed: 78'),(colocaciones_06['myVarname'] == 'Unnamed: 79'),(colocaciones_06['myVarname'] == 'Unnamed: 80'),(colocaciones_06['myVarname'] == 'Unnamed: 81'),
                (colocaciones_06['myVarname'] == 'Unnamed: 82'),(colocaciones_06['myVarname'] == 'Unnamed: 83'),(colocaciones_06['myVarname'] == 'Unnamed: 84'),(colocaciones_06['myVarname'] == 'Unnamed: 85'),(colocaciones_06['myVarname'] == 'Unnamed: 86'),
                 (colocaciones_06['myVarname'] == 'Unnamed: 87'),(colocaciones_06['myVarname'] == 'Unnamed: 88'),(colocaciones_06['myVarname'] == 'Unnamed: 89'),(colocaciones_06['myVarname'] == 'Unnamed: 90'),(colocaciones_06['myVarname'] == 'Unnamed: 91'),
                  (colocaciones_06['myVarname'] == 'Unnamed: 92'),(colocaciones_06['myVarname'] == 'Unnamed: 93'),(colocaciones_06['myVarname'] == 'Unnamed: 94'),(colocaciones_06['myVarname'] == 'Unnamed: 95'),(colocaciones_06['myVarname'] == 'Unnamed: 96'),
                   (colocaciones_06['myVarname'] == 'Unnamed: 97'),(colocaciones_06['myVarname'] == 'Unnamed: 98'),(colocaciones_06['myVarname'] == 'Unnamed: 99'),(colocaciones_06['myVarname'] == 'Unnamed: 100'),(colocaciones_06['myVarname'] == 'Unnamed: 101'),
                    (colocaciones_06['myVarname'] == 'Unnamed: 102'),(colocaciones_06['myVarname'] == 'Unnamed: 103'),(colocaciones_06['myVarname'] == 'Unnamed: 104'),(colocaciones_06['myVarname'] == 'Unnamed: 105'),(colocaciones_06['myVarname'] == 'Unnamed: 106'),
                     (colocaciones_06['myVarname'] == 'Unnamed: 107'),(colocaciones_06['myVarname'] == 'Unnamed: 108'),(colocaciones_06['myVarname'] == 'Unnamed: 109'),(colocaciones_06['myVarname'] == 'Unnamed: 110'),(colocaciones_06['myVarname'] == 'Unnamed: 111'),
                      (colocaciones_06['myVarname'] == 'Unnamed: 112'),(colocaciones_06['myVarname'] == 'Unnamed: 113'),(colocaciones_06['myVarname'] == 'Unnamed: 114'),(colocaciones_06['myVarname'] == 'Unnamed: 115'),(colocaciones_06['myVarname'] == 'Unnamed: 116'),
                       (colocaciones_06['myVarname'] == 'Unnamed: 117'),(colocaciones_06['myVarname'] == 'Unnamed: 118'),(colocaciones_06['myVarname'] == 'Unnamed: 119'),(colocaciones_06['myVarname'] == 'Unnamed: 120'),(colocaciones_06['myVarname'] == 'Unnamed: 121'),
                        (colocaciones_06['myVarname'] == 'Unnamed: 122'),(colocaciones_06['myVarname'] == 'Unnamed: 123'),(colocaciones_06['myVarname'] == 'Unnamed: 124'),(colocaciones_06['myVarname'] == 'Unnamed: 125'),(colocaciones_06['myVarname'] == 'Unnamed: 126'),
                         (colocaciones_06['myVarname'] == 'Unnamed: 127'),(colocaciones_06['myVarname'] == 'Unnamed: 128'),(colocaciones_06['myVarname'] == 'Unnamed: 129'),(colocaciones_06['myVarname'] == 'Unnamed: 130'),(colocaciones_06['myVarname'] == 'Unnamed: 131'),
                          (colocaciones_06['myVarname'] == 'Unnamed: 132'),(colocaciones_06['myVarname'] == 'Unnamed: 133'),(colocaciones_06['myVarname'] == 'Unnamed: 134'),(colocaciones_06['myVarname'] == 'Unnamed: 135'),(colocaciones_06['myVarname'] == 'Unnamed: 136'),
                           (colocaciones_06['myVarname'] == 'Unnamed: 137'),(colocaciones_06['myVarname'] == 'Unnamed: 138'),(colocaciones_06['myVarname'] == 'Unnamed: 139'),(colocaciones_06['myVarname'] == 'Unnamed: 140'),(colocaciones_06['myVarname'] == 'Unnamed: 141'),
                            (colocaciones_06['myVarname'] == 'Unnamed: 142'),(colocaciones_06['myVarname'] == 'Unnamed: 143'),(colocaciones_06['myVarname'] == 'Unnamed: 144'),(colocaciones_06['myVarname'] == 'Unnamed: 145'),(colocaciones_06['myVarname'] == 'Unnamed: 146'),
                             (colocaciones_06['myVarname'] == 'Unnamed: 147'),(colocaciones_06['myVarname'] == 'Unnamed: 148'),(colocaciones_06['myVarname'] == 'Unnamed: 149'),(colocaciones_06['myVarname'] == 'Unnamed: 150'),(colocaciones_06['myVarname'] == 'Unnamed: 151'),
                              (colocaciones_06['myVarname'] == 'Unnamed: 152'),(colocaciones_06['myVarname'] == 'Unnamed: 153'),(colocaciones_06['myVarname'] == 'Unnamed: 154'),(colocaciones_06['myVarname'] == 'Unnamed: 155'),(colocaciones_06['myVarname'] == 'Unnamed: 156'),
                               (colocaciones_06['myVarname'] == 'Unnamed: 157'),(colocaciones_06['myVarname'] == 'Unnamed: 158'),(colocaciones_06['myVarname'] == 'Unnamed: 159'),(colocaciones_06['myVarname'] == 'Unnamed: 160'),(colocaciones_06['myVarname'] == 'Unnamed: 161'),
                                (colocaciones_06['myVarname'] == 'Unnamed: 162'),(colocaciones_06['myVarname'] == 'Unnamed: 163'),(colocaciones_06['myVarname'] == 'Unnamed: 164'),(colocaciones_06['myVarname'] == 'Unnamed: 165'),(colocaciones_06['myVarname'] == 'Unnamed: 166')
                                ]

# %%
colocaciones_06['Fecha'] = np.select(conditions_6, values)

# %%
colocaciones_06
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor       Fecha
# 5    1558021.408962  2008-01-31
# 6                ND  2008-01-31
# 7      33852.866172  2008-01-31
# 8      9158859.6533  2008-01-31
# ...

# %%
colocaciones_06.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
colocaciones_06.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
colocaciones_06
# Out:
#                                       Institucion            Valor       Fecha
# 5                                      Banco Bice   1558021.408962  2008-01-31
# 6                     Banco BTG Pactual Chile (9)               ND  2008-01-31
# 7                             Banco Consorcio (1)     33852.866172  2008-01-31
# 8                              Banco de Chile (2)     9158859.6533  2008-01-31
# 9                  Banco de Crédito e Inversiones   5556001.282409  2008-01-31
# ..                                            ...              ...         ...
# 26                     JP Morgan Chase Bank, N.A.                0  2021-09-30
# 27                            Rabobank Chile (15)               ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  14988975.566465  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)               ND  2021-09-30
# 30                             Bank of China (16)                0  2021-09-30
#
# [4290 rows x 3 columns]

# %%
colocaciones_06['Tipo'] = "Colocación"
colocaciones_06['Subtipo'] = "Colocaciones de empresas"
colocaciones_06['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
colocaciones_06 = colocaciones_06.reindex(columns=new_cols)

# %%
colocaciones_06
# Out:
#          Fecha                                    Institucion        Tipo  \
# 5   2008-01-31                                     Banco Bice  Colocación
# 6   2008-01-31                    Banco BTG Pactual Chile (9)  Colocación
# 7   2008-01-31                            Banco Consorcio (1)  Colocación
# 8   2008-01-31                             Banco de Chile (2)  Colocación
# 9   2008-01-31                 Banco de Crédito e Inversiones  Colocación
# ..         ...                                            ...         ...
# 26  2021-09-30                     JP Morgan Chase Bank, N.A.  Colocación
# 27  2021-09-30                            Rabobank Chile (15)  Colocación
# 28  2021-09-30                      Scotiabank Chile (3) (17)  Colocación
# 29  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Colocación
# 30  2021-09-30                             Bank of China (16)  Colocación
#
#                      Subtipo            Valor               Tipo de Moneda
# ...

# %% [markdown]
# ## Colocación 07

# %%
colocaciones_07.head(5)
# Out:
#           Unnamed: 0                                 Unnamed: 1  \
# 0     Índice general                                Cuadro 1.07
# 1    Notas generales  Colocaciones efectivas en moneda nacional
# 2  Conceptualización                Saldos en millones de pesos
# 3                NaN                                        NaN
# 4                NaN                                        NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
colocaciones_07.pop("Unnamed: 0")
# Out:
# 0        Índice general
# 1       Notas generales
# 2     Conceptualización
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# Name: Unnamed: 0, dtype: object

# %%
colocaciones_07 = colocaciones_07.iloc[5:]

# %%
colocaciones_07.tail(7)
# Out:
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 30                                 Bank of China (16)         ND         ND
# 31                                              Total   50810737   51384199
# 32                                                NaN        NaN        NaN
# 33                                                NaN        NaN        NaN
# 34                                ND : No existe dato        NaN        NaN
# 35                                                NaN        NaN        NaN
# 36  Conceptualización: Vínculo que remite al docum...        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 30         ND         ND         ND         ND         ND         ND
# 31   51885888   52824283   53072836   53474553   54384859   55075522
# 32        NaN        NaN        NaN        NaN        NaN        NaN
# 33        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
colocaciones_07.drop(colocaciones_07.tail(6).index,inplace=True)
# Out:
# <ipython-input-115-e00949a78319>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colocaciones_07.drop(colocaciones_07.tail(6).index,inplace=True)

# %%
colocaciones_07
# Out:
#                                         Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 5                                       Banco Bice    1285675    1292310
# 6                      Banco BTG Pactual Chile (9)         ND         ND
# 7                              Banco Consorcio (1)      30522      29266
# 8                               Banco de Chile (2)    9952875    9967067
# 9                   Banco de Crédito e Inversiones    5995824    6095609
# 10               Banco de la Nación Argentina (18)       6102       8057
# 11                       Banco del Estado de Chile    7472546    7608816
# 12                            Banco do Brasil S.A.       3240       3423
# 13                                 Banco Falabella     536354     541718
# 14                             Banco Internacional     172435     171338
# 15                       Banco Itaú Corpbanca (10)    4806161    4848584
# 16                                Banco Paris (13)     171718     167217
# ...

# %%
colocaciones_07.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice    1285675    1292310    1342189    1325608
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)      30522      29266      26933      26954
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ...  \
# 5    1356464    1404290    1367589    1412454     1429976  ...
# 6         ND         ND         ND         ND          ND  ...
# 7      27260      26626      25290      25967       23096  ...
#
#      Unnamed: 157    Unnamed: 158    Unnamed: 159    Unnamed: 160  \
# 5  5064560.928274  5128799.776625  5181979.261534  5261198.653284
# 6   892447.944287   928670.569658   926354.527896   956029.874302
# 7  3360641.787919  3413618.150238  3446176.768871  3529786.248819
#
#      Unnamed: 161    Unnamed: 162    Unnamed: 163    Unnamed: 164  \
# 5  5289744.382804  5289109.488657  5319204.096685  5437634.390284
# ...

# %%
colocaciones_07 = colocaciones_07.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
colocaciones_07
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor
# 5           1285675
# 6                ND
# 7             30522
# 8           9952875
# 9           5995824
# ..              ...
# 26                0
# 27               ND
# ...

# %%
# create a list of our conditions
conditions_7 = [(colocaciones_07['myVarname'] == 'Unnamed: 2'),(colocaciones_07['myVarname'] == 'Unnamed: 3'),(colocaciones_07['myVarname'] == 'Unnamed: 4'),(colocaciones_07['myVarname'] == 'Unnamed: 5'),(colocaciones_07['myVarname'] == 'Unnamed: 6'),
 (colocaciones_07['myVarname'] == 'Unnamed: 7'),(colocaciones_07['myVarname'] == 'Unnamed: 8'),(colocaciones_07['myVarname'] == 'Unnamed: 9'),(colocaciones_07['myVarname'] == 'Unnamed: 10'),(colocaciones_07['myVarname'] == 'Unnamed: 11'),
  (colocaciones_07['myVarname'] == 'Unnamed: 12'),(colocaciones_07['myVarname'] == 'Unnamed: 13'),(colocaciones_07['myVarname'] == 'Unnamed: 14'),(colocaciones_07['myVarname'] == 'Unnamed: 15'),(colocaciones_07['myVarname'] == 'Unnamed: 16'),
   (colocaciones_07['myVarname'] == 'Unnamed: 17'),(colocaciones_07['myVarname'] == 'Unnamed: 18'),(colocaciones_07['myVarname'] == 'Unnamed: 19'),(colocaciones_07['myVarname'] == 'Unnamed: 20'),(colocaciones_07['myVarname'] == 'Unnamed: 21'),
    (colocaciones_07['myVarname'] == 'Unnamed: 22'),(colocaciones_07['myVarname'] == 'Unnamed: 23'),(colocaciones_07['myVarname'] == 'Unnamed: 24'),(colocaciones_07['myVarname'] == 'Unnamed: 25'),(colocaciones_07['myVarname'] == 'Unnamed: 26'),
     (colocaciones_07['myVarname'] == 'Unnamed: 27'),(colocaciones_07['myVarname'] == 'Unnamed: 28'),(colocaciones_07['myVarname'] == 'Unnamed: 29'),(colocaciones_07['myVarname'] == 'Unnamed: 30'),(colocaciones_07['myVarname'] == 'Unnamed: 31'),
      (colocaciones_07['myVarname'] == 'Unnamed: 32'),(colocaciones_07['myVarname'] == 'Unnamed: 33'),(colocaciones_07['myVarname'] == 'Unnamed: 34'),(colocaciones_07['myVarname'] == 'Unnamed: 35'),(colocaciones_07['myVarname'] == 'Unnamed: 36'),
       (colocaciones_07['myVarname'] == 'Unnamed: 37'),(colocaciones_07['myVarname'] == 'Unnamed: 38'),(colocaciones_07['myVarname'] == 'Unnamed: 39'),(colocaciones_07['myVarname'] == 'Unnamed: 40'),(colocaciones_07['myVarname'] == 'Unnamed: 41'),
        (colocaciones_07['myVarname'] == 'Unnamed: 42'),(colocaciones_07['myVarname'] == 'Unnamed: 43'),(colocaciones_07['myVarname'] == 'Unnamed: 44'),(colocaciones_07['myVarname'] == 'Unnamed: 45'),(colocaciones_07['myVarname'] == 'Unnamed: 46'),
         (colocaciones_07['myVarname'] == 'Unnamed: 47'),(colocaciones_07['myVarname'] == 'Unnamed: 48'),(colocaciones_07['myVarname'] == 'Unnamed: 49'),(colocaciones_07['myVarname'] == 'Unnamed: 50'),(colocaciones_07['myVarname'] == 'Unnamed: 51'),
          (colocaciones_07['myVarname'] == 'Unnamed: 52'),(colocaciones_07['myVarname'] == 'Unnamed: 53'),(colocaciones_07['myVarname'] == 'Unnamed: 54'),(colocaciones_07['myVarname'] == 'Unnamed: 55'),(colocaciones_07['myVarname'] == 'Unnamed: 56'),
           (colocaciones_07['myVarname'] == 'Unnamed: 57'),(colocaciones_07['myVarname'] == 'Unnamed: 58'),(colocaciones_07['myVarname'] == 'Unnamed: 59'),(colocaciones_07['myVarname'] == 'Unnamed: 60'),(colocaciones_07['myVarname'] == 'Unnamed: 61'),
            (colocaciones_07['myVarname'] == 'Unnamed: 62'),(colocaciones_07['myVarname'] == 'Unnamed: 63'),(colocaciones_07['myVarname'] == 'Unnamed: 64'),(colocaciones_07['myVarname'] == 'Unnamed: 65'),(colocaciones_07['myVarname'] == 'Unnamed: 66'),
             (colocaciones_07['myVarname'] == 'Unnamed: 67'),(colocaciones_07['myVarname'] == 'Unnamed: 68'),(colocaciones_07['myVarname'] == 'Unnamed: 69'),(colocaciones_07['myVarname'] == 'Unnamed: 70'),(colocaciones_07['myVarname'] == 'Unnamed: 71'),
              (colocaciones_07['myVarname'] == 'Unnamed: 72'),(colocaciones_07['myVarname'] == 'Unnamed: 73'),(colocaciones_07['myVarname'] == 'Unnamed: 74'),(colocaciones_07['myVarname'] == 'Unnamed: 75'),(colocaciones_07['myVarname'] == 'Unnamed: 76'),
               (colocaciones_07['myVarname'] == 'Unnamed: 77'),(colocaciones_07['myVarname'] == 'Unnamed: 78'),(colocaciones_07['myVarname'] == 'Unnamed: 79'),(colocaciones_07['myVarname'] == 'Unnamed: 80'),(colocaciones_07['myVarname'] == 'Unnamed: 81'),
                (colocaciones_07['myVarname'] == 'Unnamed: 82'),(colocaciones_07['myVarname'] == 'Unnamed: 83'),(colocaciones_07['myVarname'] == 'Unnamed: 84'),(colocaciones_07['myVarname'] == 'Unnamed: 85'),(colocaciones_07['myVarname'] == 'Unnamed: 86'),
                 (colocaciones_07['myVarname'] == 'Unnamed: 87'),(colocaciones_07['myVarname'] == 'Unnamed: 88'),(colocaciones_07['myVarname'] == 'Unnamed: 89'),(colocaciones_07['myVarname'] == 'Unnamed: 90'),(colocaciones_07['myVarname'] == 'Unnamed: 91'),
                  (colocaciones_07['myVarname'] == 'Unnamed: 92'),(colocaciones_07['myVarname'] == 'Unnamed: 93'),(colocaciones_07['myVarname'] == 'Unnamed: 94'),(colocaciones_07['myVarname'] == 'Unnamed: 95'),(colocaciones_07['myVarname'] == 'Unnamed: 96'),
                   (colocaciones_07['myVarname'] == 'Unnamed: 97'),(colocaciones_07['myVarname'] == 'Unnamed: 98'),(colocaciones_07['myVarname'] == 'Unnamed: 99'),(colocaciones_07['myVarname'] == 'Unnamed: 100'),(colocaciones_07['myVarname'] == 'Unnamed: 101'),
                    (colocaciones_07['myVarname'] == 'Unnamed: 102'),(colocaciones_07['myVarname'] == 'Unnamed: 103'),(colocaciones_07['myVarname'] == 'Unnamed: 104'),(colocaciones_07['myVarname'] == 'Unnamed: 105'),(colocaciones_07['myVarname'] == 'Unnamed: 106'),
                     (colocaciones_07['myVarname'] == 'Unnamed: 107'),(colocaciones_07['myVarname'] == 'Unnamed: 108'),(colocaciones_07['myVarname'] == 'Unnamed: 109'),(colocaciones_07['myVarname'] == 'Unnamed: 110'),(colocaciones_07['myVarname'] == 'Unnamed: 111'),
                      (colocaciones_07['myVarname'] == 'Unnamed: 112'),(colocaciones_07['myVarname'] == 'Unnamed: 113'),(colocaciones_07['myVarname'] == 'Unnamed: 114'),(colocaciones_07['myVarname'] == 'Unnamed: 115'),(colocaciones_07['myVarname'] == 'Unnamed: 116'),
                       (colocaciones_07['myVarname'] == 'Unnamed: 117'),(colocaciones_07['myVarname'] == 'Unnamed: 118'),(colocaciones_07['myVarname'] == 'Unnamed: 119'),(colocaciones_07['myVarname'] == 'Unnamed: 120'),(colocaciones_07['myVarname'] == 'Unnamed: 121'),
                        (colocaciones_07['myVarname'] == 'Unnamed: 122'),(colocaciones_07['myVarname'] == 'Unnamed: 123'),(colocaciones_07['myVarname'] == 'Unnamed: 124'),(colocaciones_07['myVarname'] == 'Unnamed: 125'),(colocaciones_07['myVarname'] == 'Unnamed: 126'),
                         (colocaciones_07['myVarname'] == 'Unnamed: 127'),(colocaciones_07['myVarname'] == 'Unnamed: 128'),(colocaciones_07['myVarname'] == 'Unnamed: 129'),(colocaciones_07['myVarname'] == 'Unnamed: 130'),(colocaciones_07['myVarname'] == 'Unnamed: 131'),
                          (colocaciones_07['myVarname'] == 'Unnamed: 132'),(colocaciones_07['myVarname'] == 'Unnamed: 133'),(colocaciones_07['myVarname'] == 'Unnamed: 134'),(colocaciones_07['myVarname'] == 'Unnamed: 135'),(colocaciones_07['myVarname'] == 'Unnamed: 136'),
                           (colocaciones_07['myVarname'] == 'Unnamed: 137'),(colocaciones_07['myVarname'] == 'Unnamed: 138'),(colocaciones_07['myVarname'] == 'Unnamed: 139'),(colocaciones_07['myVarname'] == 'Unnamed: 140'),(colocaciones_07['myVarname'] == 'Unnamed: 141'),
                            (colocaciones_07['myVarname'] == 'Unnamed: 142'),(colocaciones_07['myVarname'] == 'Unnamed: 143'),(colocaciones_07['myVarname'] == 'Unnamed: 144'),(colocaciones_07['myVarname'] == 'Unnamed: 145'),(colocaciones_07['myVarname'] == 'Unnamed: 146'),
                             (colocaciones_07['myVarname'] == 'Unnamed: 147'),(colocaciones_07['myVarname'] == 'Unnamed: 148'),(colocaciones_07['myVarname'] == 'Unnamed: 149'),(colocaciones_07['myVarname'] == 'Unnamed: 150'),(colocaciones_07['myVarname'] == 'Unnamed: 151'),
                              (colocaciones_07['myVarname'] == 'Unnamed: 152'),(colocaciones_07['myVarname'] == 'Unnamed: 153'),(colocaciones_07['myVarname'] == 'Unnamed: 154'),(colocaciones_07['myVarname'] == 'Unnamed: 155'),(colocaciones_07['myVarname'] == 'Unnamed: 156'),
                               (colocaciones_07['myVarname'] == 'Unnamed: 157'),(colocaciones_07['myVarname'] == 'Unnamed: 158'),(colocaciones_07['myVarname'] == 'Unnamed: 159'),(colocaciones_07['myVarname'] == 'Unnamed: 160'),(colocaciones_07['myVarname'] == 'Unnamed: 161'),
                                (colocaciones_07['myVarname'] == 'Unnamed: 162'),(colocaciones_07['myVarname'] == 'Unnamed: 163'),(colocaciones_07['myVarname'] == 'Unnamed: 164'),(colocaciones_07['myVarname'] == 'Unnamed: 165'),(colocaciones_07['myVarname'] == 'Unnamed: 166')
                                ]

# %%
colocaciones_07['Fecha'] = np.select(conditions_7, values)

# %%
colocaciones_07
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor       Fecha
# 5           1285675  2008-01-31
# 6                ND  2008-01-31
# 7             30522  2008-01-31
# 8           9952875  2008-01-31
# ...

# %%
colocaciones_07.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
colocaciones_07.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
colocaciones_07
# Out:
#                                       Institucion            Valor       Fecha
# 5                                      Banco Bice          1285675  2008-01-31
# 6                     Banco BTG Pactual Chile (9)               ND  2008-01-31
# 7                             Banco Consorcio (1)            30522  2008-01-31
# 8                              Banco de Chile (2)          9952875  2008-01-31
# 9                  Banco de Crédito e Inversiones          5995824  2008-01-31
# ..                                            ...              ...         ...
# 26                     JP Morgan Chase Bank, N.A.                0  2021-09-30
# 27                            Rabobank Chile (15)               ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  22275385.984538  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)               ND  2021-09-30
# 30                             Bank of China (16)                0  2021-09-30
#
# [4290 rows x 3 columns]

# %%
colocaciones_07['Tipo'] = "Colocación"
colocaciones_07['Subtipo'] = "Colocaciones efectivas en moneda nacional"
colocaciones_07['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
colocaciones_07 = colocaciones_07.reindex(columns=new_cols)

# %%
colocaciones_07
# Out:
#          Fecha                                    Institucion        Tipo  \
# 5   2008-01-31                                     Banco Bice  Colocación
# 6   2008-01-31                    Banco BTG Pactual Chile (9)  Colocación
# 7   2008-01-31                            Banco Consorcio (1)  Colocación
# 8   2008-01-31                             Banco de Chile (2)  Colocación
# 9   2008-01-31                 Banco de Crédito e Inversiones  Colocación
# ..         ...                                            ...         ...
# 26  2021-09-30                     JP Morgan Chase Bank, N.A.  Colocación
# 27  2021-09-30                            Rabobank Chile (15)  Colocación
# 28  2021-09-30                      Scotiabank Chile (3) (17)  Colocación
# 29  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Colocación
# 30  2021-09-30                             Bank of China (16)  Colocación
#
#                                       Subtipo            Valor  \
# ...

# %% [markdown]
# ## Colocación 08

# %%
colocaciones_08.head(5)
# Out:
#           Unnamed: 0                                    Unnamed: 1  \
# 0     Índice general                                   Cuadro 1.08
# 1    Notas generales  Colocaciones contingentes en moneda nacional
# 2  Conceptualización                   Saldos en millones de pesos
# 3                NaN                                           NaN
# 4                NaN                                           NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
colocaciones_08.pop("Unnamed: 0")
# Out:
# 0        Índice general
# 1       Notas generales
# 2     Conceptualización
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# Name: Unnamed: 0, dtype: object

# %%
colocaciones_08 = colocaciones_08.iloc[5:]

# %%
colocaciones_08.tail(7)
# Out:
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 30                                 Bank of China (16)         ND         ND
# 31                                              Total    2981927    3169908
# 32                                                NaN        NaN        NaN
# 33                                                NaN        NaN        NaN
# 34                                ND : No existe dato        NaN        NaN
# 35                                                NaN        NaN        NaN
# 36  Conceptualización: Vínculo que remite al docum...        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 30         ND         ND         ND         ND         ND         ND
# 31    3279476    3282189    3454708    3738555    3793411    3677848
# 32        NaN        NaN        NaN        NaN        NaN        NaN
# 33        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
colocaciones_08.drop(colocaciones_08.tail(6).index,inplace=True)
# Out:
# <ipython-input-133-644713cfa304>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colocaciones_08.drop(colocaciones_08.tail(6).index,inplace=True)

# %%
colocaciones_08
# Out:
#                                         Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 5                                       Banco Bice     117084     126637
# 6                      Banco BTG Pactual Chile (9)         ND         ND
# 7                              Banco Consorcio (1)       1503       1469
# 8                               Banco de Chile (2)     823462     806791
# 9                   Banco de Crédito e Inversiones     400895     403312
# 10               Banco de la Nación Argentina (18)        811        812
# 11                       Banco del Estado de Chile     165636     379007
# 12                            Banco do Brasil S.A.        458        458
# 13                                 Banco Falabella          0          0
# 14                             Banco Internacional       8963       9484
# 15                       Banco Itaú Corpbanca (10)     247246     243587
# 16                                Banco Paris (13)          0          0
# ...

# %%
colocaciones_08.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice     117084     126637     126797     127415
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)       1503       1469       1435       1493
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ...   Unnamed: 157  \
# 5     129835     129107     165084     171474      182255  ...  532882.801096
# 6         ND         ND         ND         ND          ND  ...  110215.660877
# 7       1506        957       1032        929         834  ...   43520.720198
#
#     Unnamed: 158   Unnamed: 159   Unnamed: 160   Unnamed: 161   Unnamed: 162  \
# 5  520753.450617  498218.744002  503998.287182  505477.901681  505717.788438
# 6  104786.791023  115011.001642  114257.705803  115905.141133  114898.594312
# 7   42751.892564   43568.641568   44655.589141   48131.026929   51350.402394
#
# ...

# %%
colocaciones_08 = colocaciones_08.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
colocaciones_08
# Out:
#                                        Unnamed: 1     myVarname          Valor
# 5                                      Banco Bice    Unnamed: 2         117084
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2             ND
# 7                             Banco Consorcio (1)    Unnamed: 2           1503
# 8                              Banco de Chile (2)    Unnamed: 2         823462
# 9                  Banco de Crédito e Inversiones    Unnamed: 2         400895
# ..                                            ...           ...            ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166              0
# 27                            Rabobank Chile (15)  Unnamed: 166             ND
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166  814126.607977
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166             ND
# 30                             Bank of China (16)  Unnamed: 166              0
#
# [4290 rows x 3 columns]

# %%
# create a list of our conditions
conditions_8 = [(colocaciones_08['myVarname'] == 'Unnamed: 2'),(colocaciones_08['myVarname'] == 'Unnamed: 3'),(colocaciones_08['myVarname'] == 'Unnamed: 4'),(colocaciones_08['myVarname'] == 'Unnamed: 5'),(colocaciones_08['myVarname'] == 'Unnamed: 6'),
 (colocaciones_08['myVarname'] == 'Unnamed: 7'),(colocaciones_08['myVarname'] == 'Unnamed: 8'),(colocaciones_08['myVarname'] == 'Unnamed: 9'),(colocaciones_08['myVarname'] == 'Unnamed: 10'),(colocaciones_08['myVarname'] == 'Unnamed: 11'),
  (colocaciones_08['myVarname'] == 'Unnamed: 12'),(colocaciones_08['myVarname'] == 'Unnamed: 13'),(colocaciones_08['myVarname'] == 'Unnamed: 14'),(colocaciones_08['myVarname'] == 'Unnamed: 15'),(colocaciones_08['myVarname'] == 'Unnamed: 16'),
   (colocaciones_08['myVarname'] == 'Unnamed: 17'),(colocaciones_08['myVarname'] == 'Unnamed: 18'),(colocaciones_08['myVarname'] == 'Unnamed: 19'),(colocaciones_08['myVarname'] == 'Unnamed: 20'),(colocaciones_08['myVarname'] == 'Unnamed: 21'),
    (colocaciones_08['myVarname'] == 'Unnamed: 22'),(colocaciones_08['myVarname'] == 'Unnamed: 23'),(colocaciones_08['myVarname'] == 'Unnamed: 24'),(colocaciones_08['myVarname'] == 'Unnamed: 25'),(colocaciones_08['myVarname'] == 'Unnamed: 26'),
     (colocaciones_08['myVarname'] == 'Unnamed: 27'),(colocaciones_08['myVarname'] == 'Unnamed: 28'),(colocaciones_08['myVarname'] == 'Unnamed: 29'),(colocaciones_08['myVarname'] == 'Unnamed: 30'),(colocaciones_08['myVarname'] == 'Unnamed: 31'),
      (colocaciones_08['myVarname'] == 'Unnamed: 32'),(colocaciones_08['myVarname'] == 'Unnamed: 33'),(colocaciones_08['myVarname'] == 'Unnamed: 34'),(colocaciones_08['myVarname'] == 'Unnamed: 35'),(colocaciones_08['myVarname'] == 'Unnamed: 36'),
       (colocaciones_08['myVarname'] == 'Unnamed: 37'),(colocaciones_08['myVarname'] == 'Unnamed: 38'),(colocaciones_08['myVarname'] == 'Unnamed: 39'),(colocaciones_08['myVarname'] == 'Unnamed: 40'),(colocaciones_08['myVarname'] == 'Unnamed: 41'),
        (colocaciones_08['myVarname'] == 'Unnamed: 42'),(colocaciones_08['myVarname'] == 'Unnamed: 43'),(colocaciones_08['myVarname'] == 'Unnamed: 44'),(colocaciones_08['myVarname'] == 'Unnamed: 45'),(colocaciones_08['myVarname'] == 'Unnamed: 46'),
         (colocaciones_08['myVarname'] == 'Unnamed: 47'),(colocaciones_08['myVarname'] == 'Unnamed: 48'),(colocaciones_08['myVarname'] == 'Unnamed: 49'),(colocaciones_08['myVarname'] == 'Unnamed: 50'),(colocaciones_08['myVarname'] == 'Unnamed: 51'),
          (colocaciones_08['myVarname'] == 'Unnamed: 52'),(colocaciones_08['myVarname'] == 'Unnamed: 53'),(colocaciones_08['myVarname'] == 'Unnamed: 54'),(colocaciones_08['myVarname'] == 'Unnamed: 55'),(colocaciones_08['myVarname'] == 'Unnamed: 56'),
           (colocaciones_08['myVarname'] == 'Unnamed: 57'),(colocaciones_08['myVarname'] == 'Unnamed: 58'),(colocaciones_08['myVarname'] == 'Unnamed: 59'),(colocaciones_08['myVarname'] == 'Unnamed: 60'),(colocaciones_08['myVarname'] == 'Unnamed: 61'),
            (colocaciones_08['myVarname'] == 'Unnamed: 62'),(colocaciones_08['myVarname'] == 'Unnamed: 63'),(colocaciones_08['myVarname'] == 'Unnamed: 64'),(colocaciones_08['myVarname'] == 'Unnamed: 65'),(colocaciones_08['myVarname'] == 'Unnamed: 66'),
             (colocaciones_08['myVarname'] == 'Unnamed: 67'),(colocaciones_08['myVarname'] == 'Unnamed: 68'),(colocaciones_08['myVarname'] == 'Unnamed: 69'),(colocaciones_08['myVarname'] == 'Unnamed: 70'),(colocaciones_08['myVarname'] == 'Unnamed: 71'),
              (colocaciones_08['myVarname'] == 'Unnamed: 72'),(colocaciones_08['myVarname'] == 'Unnamed: 73'),(colocaciones_08['myVarname'] == 'Unnamed: 74'),(colocaciones_08['myVarname'] == 'Unnamed: 75'),(colocaciones_08['myVarname'] == 'Unnamed: 76'),
               (colocaciones_08['myVarname'] == 'Unnamed: 77'),(colocaciones_08['myVarname'] == 'Unnamed: 78'),(colocaciones_08['myVarname'] == 'Unnamed: 79'),(colocaciones_08['myVarname'] == 'Unnamed: 80'),(colocaciones_08['myVarname'] == 'Unnamed: 81'),
                (colocaciones_08['myVarname'] == 'Unnamed: 82'),(colocaciones_08['myVarname'] == 'Unnamed: 83'),(colocaciones_08['myVarname'] == 'Unnamed: 84'),(colocaciones_08['myVarname'] == 'Unnamed: 85'),(colocaciones_08['myVarname'] == 'Unnamed: 86'),
                 (colocaciones_08['myVarname'] == 'Unnamed: 87'),(colocaciones_08['myVarname'] == 'Unnamed: 88'),(colocaciones_08['myVarname'] == 'Unnamed: 89'),(colocaciones_08['myVarname'] == 'Unnamed: 90'),(colocaciones_08['myVarname'] == 'Unnamed: 91'),
                  (colocaciones_08['myVarname'] == 'Unnamed: 92'),(colocaciones_08['myVarname'] == 'Unnamed: 93'),(colocaciones_08['myVarname'] == 'Unnamed: 94'),(colocaciones_08['myVarname'] == 'Unnamed: 95'),(colocaciones_08['myVarname'] == 'Unnamed: 96'),
                   (colocaciones_08['myVarname'] == 'Unnamed: 97'),(colocaciones_08['myVarname'] == 'Unnamed: 98'),(colocaciones_08['myVarname'] == 'Unnamed: 99'),(colocaciones_08['myVarname'] == 'Unnamed: 100'),(colocaciones_08['myVarname'] == 'Unnamed: 101'),
                    (colocaciones_08['myVarname'] == 'Unnamed: 102'),(colocaciones_08['myVarname'] == 'Unnamed: 103'),(colocaciones_08['myVarname'] == 'Unnamed: 104'),(colocaciones_08['myVarname'] == 'Unnamed: 105'),(colocaciones_08['myVarname'] == 'Unnamed: 106'),
                     (colocaciones_08['myVarname'] == 'Unnamed: 107'),(colocaciones_08['myVarname'] == 'Unnamed: 108'),(colocaciones_08['myVarname'] == 'Unnamed: 109'),(colocaciones_08['myVarname'] == 'Unnamed: 110'),(colocaciones_08['myVarname'] == 'Unnamed: 111'),
                      (colocaciones_08['myVarname'] == 'Unnamed: 112'),(colocaciones_08['myVarname'] == 'Unnamed: 113'),(colocaciones_08['myVarname'] == 'Unnamed: 114'),(colocaciones_08['myVarname'] == 'Unnamed: 115'),(colocaciones_08['myVarname'] == 'Unnamed: 116'),
                       (colocaciones_08['myVarname'] == 'Unnamed: 117'),(colocaciones_08['myVarname'] == 'Unnamed: 118'),(colocaciones_08['myVarname'] == 'Unnamed: 119'),(colocaciones_08['myVarname'] == 'Unnamed: 120'),(colocaciones_08['myVarname'] == 'Unnamed: 121'),
                        (colocaciones_08['myVarname'] == 'Unnamed: 122'),(colocaciones_08['myVarname'] == 'Unnamed: 123'),(colocaciones_08['myVarname'] == 'Unnamed: 124'),(colocaciones_08['myVarname'] == 'Unnamed: 125'),(colocaciones_08['myVarname'] == 'Unnamed: 126'),
                         (colocaciones_08['myVarname'] == 'Unnamed: 127'),(colocaciones_08['myVarname'] == 'Unnamed: 128'),(colocaciones_08['myVarname'] == 'Unnamed: 129'),(colocaciones_08['myVarname'] == 'Unnamed: 130'),(colocaciones_08['myVarname'] == 'Unnamed: 131'),
                          (colocaciones_08['myVarname'] == 'Unnamed: 132'),(colocaciones_08['myVarname'] == 'Unnamed: 133'),(colocaciones_08['myVarname'] == 'Unnamed: 134'),(colocaciones_08['myVarname'] == 'Unnamed: 135'),(colocaciones_08['myVarname'] == 'Unnamed: 136'),
                           (colocaciones_08['myVarname'] == 'Unnamed: 137'),(colocaciones_08['myVarname'] == 'Unnamed: 138'),(colocaciones_08['myVarname'] == 'Unnamed: 139'),(colocaciones_08['myVarname'] == 'Unnamed: 140'),(colocaciones_08['myVarname'] == 'Unnamed: 141'),
                            (colocaciones_08['myVarname'] == 'Unnamed: 142'),(colocaciones_08['myVarname'] == 'Unnamed: 143'),(colocaciones_08['myVarname'] == 'Unnamed: 144'),(colocaciones_08['myVarname'] == 'Unnamed: 145'),(colocaciones_08['myVarname'] == 'Unnamed: 146'),
                             (colocaciones_08['myVarname'] == 'Unnamed: 147'),(colocaciones_08['myVarname'] == 'Unnamed: 148'),(colocaciones_08['myVarname'] == 'Unnamed: 149'),(colocaciones_08['myVarname'] == 'Unnamed: 150'),(colocaciones_08['myVarname'] == 'Unnamed: 151'),
                              (colocaciones_08['myVarname'] == 'Unnamed: 152'),(colocaciones_08['myVarname'] == 'Unnamed: 153'),(colocaciones_08['myVarname'] == 'Unnamed: 154'),(colocaciones_08['myVarname'] == 'Unnamed: 155'),(colocaciones_08['myVarname'] == 'Unnamed: 156'),
                               (colocaciones_08['myVarname'] == 'Unnamed: 157'),(colocaciones_08['myVarname'] == 'Unnamed: 158'),(colocaciones_08['myVarname'] == 'Unnamed: 159'),(colocaciones_08['myVarname'] == 'Unnamed: 160'),(colocaciones_08['myVarname'] == 'Unnamed: 161'),
                                (colocaciones_08['myVarname'] == 'Unnamed: 162'),(colocaciones_08['myVarname'] == 'Unnamed: 163'),(colocaciones_08['myVarname'] == 'Unnamed: 164'),(colocaciones_08['myVarname'] == 'Unnamed: 165'),(colocaciones_08['myVarname'] == 'Unnamed: 166')
                                ]

# %%
colocaciones_08['Fecha'] = np.select(conditions_8, values)

# %%
colocaciones_08
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#             Valor       Fecha
# 5          117084  2008-01-31
# 6              ND  2008-01-31
# 7            1503  2008-01-31
# 8          823462  2008-01-31
# 9          400895  2008-01-31
# ...

# %%
colocaciones_08.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
colocaciones_08.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
colocaciones_08
# Out:
#                                       Institucion          Valor       Fecha
# 5                                      Banco Bice         117084  2008-01-31
# 6                     Banco BTG Pactual Chile (9)             ND  2008-01-31
# 7                             Banco Consorcio (1)           1503  2008-01-31
# 8                              Banco de Chile (2)         823462  2008-01-31
# 9                  Banco de Crédito e Inversiones         400895  2008-01-31
# ..                                            ...            ...         ...
# 26                     JP Morgan Chase Bank, N.A.              0  2021-09-30
# 27                            Rabobank Chile (15)             ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  814126.607977  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)             ND  2021-09-30
# 30                             Bank of China (16)              0  2021-09-30
#
# [4290 rows x 3 columns]

# %%
colocaciones_08['Tipo'] = "Colocación"
colocaciones_08['Subtipo'] = "Colocaciones contingentes en moneda nacional"
colocaciones_08['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
colocaciones_08 = colocaciones_08.reindex(columns=new_cols)

# %%
colocaciones_08
# Out:
#          Fecha                                    Institucion        Tipo  \
# 5   2008-01-31                                     Banco Bice  Colocación
# 6   2008-01-31                    Banco BTG Pactual Chile (9)  Colocación
# 7   2008-01-31                            Banco Consorcio (1)  Colocación
# 8   2008-01-31                             Banco de Chile (2)  Colocación
# 9   2008-01-31                 Banco de Crédito e Inversiones  Colocación
# ..         ...                                            ...         ...
# 26  2021-09-30                     JP Morgan Chase Bank, N.A.  Colocación
# 27  2021-09-30                            Rabobank Chile (15)  Colocación
# 28  2021-09-30                      Scotiabank Chile (3) (17)  Colocación
# 29  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Colocación
# 30  2021-09-30                             Bank of China (16)  Colocación
#
#                                          Subtipo          Valor  \
# ...

# %% [markdown]
# ## Colocación 09

# %%
colocaciones_09.head(5)
# Out:
#           Unnamed: 0                                   Unnamed: 1  \
# 0     Índice general                                  Cuadro 1.09
# 1    Notas generales  Colocaciones efectivas en moneda extranjera
# 2  Conceptualización                Saldos en millones de dólares
# 3                NaN                                          NaN
# 4                NaN                                          NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
colocaciones_09.pop("Unnamed: 0")
# Out:
# 0        Índice general
# 1       Notas generales
# 2     Conceptualización
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# Name: Unnamed: 0, dtype: object

# %%
colocaciones_09 = colocaciones_09.iloc[5:]

# %%
colocaciones_09.tail(7)
# Out:
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 30                                 Bank of China (16)         ND         ND
# 31                                              Total  11922.494  12181.864
# 32                                                NaN        NaN        NaN
# 33                                                NaN        NaN        NaN
# 34                                ND : No existe dato        NaN        NaN
# 35                                                NaN        NaN        NaN
# 36  Conceptualización: Vínculo que remite al docum...        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 30         ND         ND         ND         ND         ND         ND
# 31  12555.185  13341.216   14027.05  14649.006  14471.373  14228.669
# 32        NaN        NaN        NaN        NaN        NaN        NaN
# 33        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
colocaciones_09.drop(colocaciones_09.tail(6).index,inplace=True)

# %%
colocaciones_09
# Out:
#                                         Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 5                                       Banco Bice    410.266    435.569
# 6                      Banco BTG Pactual Chile (9)         ND         ND
# 7                              Banco Consorcio (1)      3.491      2.692
# 8                               Banco de Chile (2)   2526.652   2458.932
# 9                   Banco de Crédito e Inversiones   2227.232   2449.835
# 10               Banco de la Nación Argentina (18)     13.148     16.815
# 11                       Banco del Estado de Chile    600.798    575.885
# 12                            Banco do Brasil S.A.     39.666     46.118
# 13                                 Banco Falabella      0.133        0.2
# 14                             Banco Internacional     47.945     48.795
# 15                       Banco Itaú Corpbanca (10)   1509.185   1502.915
# 16                                Banco Paris (13)      0.016      0.019
# ...

# %%
colocaciones_09.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice    410.266    435.569    478.342    508.379
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)      3.491      2.692      2.647      2.042
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 157  \
# 5    519.746    527.824    529.796     517.23     518.633  ...   983.498506
# 6         ND         ND         ND         ND          ND  ...    290.92934
# 7          2      2.342      2.243      2.091       2.007  ...    555.08327
#
#   Unnamed: 158 Unnamed: 159 Unnamed: 160 Unnamed: 161 Unnamed: 162  \
# 5   957.478371  1005.294352   937.166951  1008.478022  1020.343418
# 6   287.715256   299.231128   287.761923   263.469904   260.922672
# 7   542.933773   571.524774   567.857182   576.589198   560.573805
#
#   Unnamed: 163 Unnamed: 164 Unnamed: 165 Unnamed: 166
# ...

# %%
colocaciones_09 = colocaciones_09.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
colocaciones_09
# Out:
#                                        Unnamed: 1     myVarname       Valor
# 5                                      Banco Bice    Unnamed: 2     410.266
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2          ND
# 7                             Banco Consorcio (1)    Unnamed: 2       3.491
# 8                              Banco de Chile (2)    Unnamed: 2    2526.652
# 9                  Banco de Crédito e Inversiones    Unnamed: 2    2227.232
# ..                                            ...           ...         ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166           0
# 27                            Rabobank Chile (15)  Unnamed: 166          ND
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166  5401.73573
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166          ND
# 30                             Bank of China (16)  Unnamed: 166           0
#
# [4290 rows x 3 columns]

# %%
# create a list of our conditions
conditions_9 = [(colocaciones_09['myVarname'] == 'Unnamed: 2'),(colocaciones_09['myVarname'] == 'Unnamed: 3'),(colocaciones_09['myVarname'] == 'Unnamed: 4'),(colocaciones_09['myVarname'] == 'Unnamed: 5'),(colocaciones_09['myVarname'] == 'Unnamed: 6'),
 (colocaciones_09['myVarname'] == 'Unnamed: 7'),(colocaciones_09['myVarname'] == 'Unnamed: 8'),(colocaciones_09['myVarname'] == 'Unnamed: 9'),(colocaciones_09['myVarname'] == 'Unnamed: 10'),(colocaciones_09['myVarname'] == 'Unnamed: 11'),
  (colocaciones_09['myVarname'] == 'Unnamed: 12'),(colocaciones_09['myVarname'] == 'Unnamed: 13'),(colocaciones_09['myVarname'] == 'Unnamed: 14'),(colocaciones_09['myVarname'] == 'Unnamed: 15'),(colocaciones_09['myVarname'] == 'Unnamed: 16'),
   (colocaciones_09['myVarname'] == 'Unnamed: 17'),(colocaciones_09['myVarname'] == 'Unnamed: 18'),(colocaciones_09['myVarname'] == 'Unnamed: 19'),(colocaciones_09['myVarname'] == 'Unnamed: 20'),(colocaciones_09['myVarname'] == 'Unnamed: 21'),
    (colocaciones_09['myVarname'] == 'Unnamed: 22'),(colocaciones_09['myVarname'] == 'Unnamed: 23'),(colocaciones_09['myVarname'] == 'Unnamed: 24'),(colocaciones_09['myVarname'] == 'Unnamed: 25'),(colocaciones_09['myVarname'] == 'Unnamed: 26'),
     (colocaciones_09['myVarname'] == 'Unnamed: 27'),(colocaciones_09['myVarname'] == 'Unnamed: 28'),(colocaciones_09['myVarname'] == 'Unnamed: 29'),(colocaciones_09['myVarname'] == 'Unnamed: 30'),(colocaciones_09['myVarname'] == 'Unnamed: 31'),
      (colocaciones_09['myVarname'] == 'Unnamed: 32'),(colocaciones_09['myVarname'] == 'Unnamed: 33'),(colocaciones_09['myVarname'] == 'Unnamed: 34'),(colocaciones_09['myVarname'] == 'Unnamed: 35'),(colocaciones_09['myVarname'] == 'Unnamed: 36'),
       (colocaciones_09['myVarname'] == 'Unnamed: 37'),(colocaciones_09['myVarname'] == 'Unnamed: 38'),(colocaciones_09['myVarname'] == 'Unnamed: 39'),(colocaciones_09['myVarname'] == 'Unnamed: 40'),(colocaciones_09['myVarname'] == 'Unnamed: 41'),
        (colocaciones_09['myVarname'] == 'Unnamed: 42'),(colocaciones_09['myVarname'] == 'Unnamed: 43'),(colocaciones_09['myVarname'] == 'Unnamed: 44'),(colocaciones_09['myVarname'] == 'Unnamed: 45'),(colocaciones_09['myVarname'] == 'Unnamed: 46'),
         (colocaciones_09['myVarname'] == 'Unnamed: 47'),(colocaciones_09['myVarname'] == 'Unnamed: 48'),(colocaciones_09['myVarname'] == 'Unnamed: 49'),(colocaciones_09['myVarname'] == 'Unnamed: 50'),(colocaciones_09['myVarname'] == 'Unnamed: 51'),
          (colocaciones_09['myVarname'] == 'Unnamed: 52'),(colocaciones_09['myVarname'] == 'Unnamed: 53'),(colocaciones_09['myVarname'] == 'Unnamed: 54'),(colocaciones_09['myVarname'] == 'Unnamed: 55'),(colocaciones_09['myVarname'] == 'Unnamed: 56'),
           (colocaciones_09['myVarname'] == 'Unnamed: 57'),(colocaciones_09['myVarname'] == 'Unnamed: 58'),(colocaciones_09['myVarname'] == 'Unnamed: 59'),(colocaciones_09['myVarname'] == 'Unnamed: 60'),(colocaciones_09['myVarname'] == 'Unnamed: 61'),
            (colocaciones_09['myVarname'] == 'Unnamed: 62'),(colocaciones_09['myVarname'] == 'Unnamed: 63'),(colocaciones_09['myVarname'] == 'Unnamed: 64'),(colocaciones_09['myVarname'] == 'Unnamed: 65'),(colocaciones_09['myVarname'] == 'Unnamed: 66'),
             (colocaciones_09['myVarname'] == 'Unnamed: 67'),(colocaciones_09['myVarname'] == 'Unnamed: 68'),(colocaciones_09['myVarname'] == 'Unnamed: 69'),(colocaciones_09['myVarname'] == 'Unnamed: 70'),(colocaciones_09['myVarname'] == 'Unnamed: 71'),
              (colocaciones_09['myVarname'] == 'Unnamed: 72'),(colocaciones_09['myVarname'] == 'Unnamed: 73'),(colocaciones_09['myVarname'] == 'Unnamed: 74'),(colocaciones_09['myVarname'] == 'Unnamed: 75'),(colocaciones_09['myVarname'] == 'Unnamed: 76'),
               (colocaciones_09['myVarname'] == 'Unnamed: 77'),(colocaciones_09['myVarname'] == 'Unnamed: 78'),(colocaciones_09['myVarname'] == 'Unnamed: 79'),(colocaciones_09['myVarname'] == 'Unnamed: 80'),(colocaciones_09['myVarname'] == 'Unnamed: 81'),
                (colocaciones_09['myVarname'] == 'Unnamed: 82'),(colocaciones_09['myVarname'] == 'Unnamed: 83'),(colocaciones_09['myVarname'] == 'Unnamed: 84'),(colocaciones_09['myVarname'] == 'Unnamed: 85'),(colocaciones_09['myVarname'] == 'Unnamed: 86'),
                 (colocaciones_09['myVarname'] == 'Unnamed: 87'),(colocaciones_09['myVarname'] == 'Unnamed: 88'),(colocaciones_09['myVarname'] == 'Unnamed: 89'),(colocaciones_09['myVarname'] == 'Unnamed: 90'),(colocaciones_09['myVarname'] == 'Unnamed: 91'),
                  (colocaciones_09['myVarname'] == 'Unnamed: 92'),(colocaciones_09['myVarname'] == 'Unnamed: 93'),(colocaciones_09['myVarname'] == 'Unnamed: 94'),(colocaciones_09['myVarname'] == 'Unnamed: 95'),(colocaciones_09['myVarname'] == 'Unnamed: 96'),
                   (colocaciones_09['myVarname'] == 'Unnamed: 97'),(colocaciones_09['myVarname'] == 'Unnamed: 98'),(colocaciones_09['myVarname'] == 'Unnamed: 99'),(colocaciones_09['myVarname'] == 'Unnamed: 100'),(colocaciones_09['myVarname'] == 'Unnamed: 101'),
                    (colocaciones_09['myVarname'] == 'Unnamed: 102'),(colocaciones_09['myVarname'] == 'Unnamed: 103'),(colocaciones_09['myVarname'] == 'Unnamed: 104'),(colocaciones_09['myVarname'] == 'Unnamed: 105'),(colocaciones_09['myVarname'] == 'Unnamed: 106'),
                     (colocaciones_09['myVarname'] == 'Unnamed: 107'),(colocaciones_09['myVarname'] == 'Unnamed: 108'),(colocaciones_09['myVarname'] == 'Unnamed: 109'),(colocaciones_09['myVarname'] == 'Unnamed: 110'),(colocaciones_09['myVarname'] == 'Unnamed: 111'),
                      (colocaciones_09['myVarname'] == 'Unnamed: 112'),(colocaciones_09['myVarname'] == 'Unnamed: 113'),(colocaciones_09['myVarname'] == 'Unnamed: 114'),(colocaciones_09['myVarname'] == 'Unnamed: 115'),(colocaciones_09['myVarname'] == 'Unnamed: 116'),
                       (colocaciones_09['myVarname'] == 'Unnamed: 117'),(colocaciones_09['myVarname'] == 'Unnamed: 118'),(colocaciones_09['myVarname'] == 'Unnamed: 119'),(colocaciones_09['myVarname'] == 'Unnamed: 120'),(colocaciones_09['myVarname'] == 'Unnamed: 121'),
                        (colocaciones_09['myVarname'] == 'Unnamed: 122'),(colocaciones_09['myVarname'] == 'Unnamed: 123'),(colocaciones_09['myVarname'] == 'Unnamed: 124'),(colocaciones_09['myVarname'] == 'Unnamed: 125'),(colocaciones_09['myVarname'] == 'Unnamed: 126'),
                         (colocaciones_09['myVarname'] == 'Unnamed: 127'),(colocaciones_09['myVarname'] == 'Unnamed: 128'),(colocaciones_09['myVarname'] == 'Unnamed: 129'),(colocaciones_09['myVarname'] == 'Unnamed: 130'),(colocaciones_09['myVarname'] == 'Unnamed: 131'),
                          (colocaciones_09['myVarname'] == 'Unnamed: 132'),(colocaciones_09['myVarname'] == 'Unnamed: 133'),(colocaciones_09['myVarname'] == 'Unnamed: 134'),(colocaciones_09['myVarname'] == 'Unnamed: 135'),(colocaciones_09['myVarname'] == 'Unnamed: 136'),
                           (colocaciones_09['myVarname'] == 'Unnamed: 137'),(colocaciones_09['myVarname'] == 'Unnamed: 138'),(colocaciones_09['myVarname'] == 'Unnamed: 139'),(colocaciones_09['myVarname'] == 'Unnamed: 140'),(colocaciones_09['myVarname'] == 'Unnamed: 141'),
                            (colocaciones_09['myVarname'] == 'Unnamed: 142'),(colocaciones_09['myVarname'] == 'Unnamed: 143'),(colocaciones_09['myVarname'] == 'Unnamed: 144'),(colocaciones_09['myVarname'] == 'Unnamed: 145'),(colocaciones_09['myVarname'] == 'Unnamed: 146'),
                             (colocaciones_09['myVarname'] == 'Unnamed: 147'),(colocaciones_09['myVarname'] == 'Unnamed: 148'),(colocaciones_09['myVarname'] == 'Unnamed: 149'),(colocaciones_09['myVarname'] == 'Unnamed: 150'),(colocaciones_09['myVarname'] == 'Unnamed: 151'),
                              (colocaciones_09['myVarname'] == 'Unnamed: 152'),(colocaciones_09['myVarname'] == 'Unnamed: 153'),(colocaciones_09['myVarname'] == 'Unnamed: 154'),(colocaciones_09['myVarname'] == 'Unnamed: 155'),(colocaciones_09['myVarname'] == 'Unnamed: 156'),
                               (colocaciones_09['myVarname'] == 'Unnamed: 157'),(colocaciones_09['myVarname'] == 'Unnamed: 158'),(colocaciones_09['myVarname'] == 'Unnamed: 159'),(colocaciones_09['myVarname'] == 'Unnamed: 160'),(colocaciones_09['myVarname'] == 'Unnamed: 161'),
                                (colocaciones_09['myVarname'] == 'Unnamed: 162'),(colocaciones_09['myVarname'] == 'Unnamed: 163'),(colocaciones_09['myVarname'] == 'Unnamed: 164'),(colocaciones_09['myVarname'] == 'Unnamed: 165'),(colocaciones_09['myVarname'] == 'Unnamed: 166')
                                ]

# %%
colocaciones_09['Fecha'] = np.select(conditions_9, values)

# %%
colocaciones_09
# Out:
#                                        Unnamed: 1     myVarname       Valor  \
# 5                                      Banco Bice    Unnamed: 2     410.266
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2          ND
# 7                             Banco Consorcio (1)    Unnamed: 2       3.491
# 8                              Banco de Chile (2)    Unnamed: 2    2526.652
# 9                  Banco de Crédito e Inversiones    Unnamed: 2    2227.232
# ..                                            ...           ...         ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166           0
# 27                            Rabobank Chile (15)  Unnamed: 166          ND
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166  5401.73573
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166          ND
# 30                             Bank of China (16)  Unnamed: 166           0
#
#          Fecha
# 5   2008-01-31
# 6   2008-01-31
# ...

# %%
colocaciones_09.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
colocaciones_09.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
colocaciones_09
# Out:
#                                       Institucion       Valor       Fecha
# 5                                      Banco Bice     410.266  2008-01-31
# 6                     Banco BTG Pactual Chile (9)          ND  2008-01-31
# 7                             Banco Consorcio (1)       3.491  2008-01-31
# 8                              Banco de Chile (2)    2526.652  2008-01-31
# 9                  Banco de Crédito e Inversiones    2227.232  2008-01-31
# ..                                            ...         ...         ...
# 26                     JP Morgan Chase Bank, N.A.           0  2021-09-30
# 27                            Rabobank Chile (15)          ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  5401.73573  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)          ND  2021-09-30
# 30                             Bank of China (16)           0  2021-09-30
#
# [4290 rows x 3 columns]

# %%
colocaciones_09['Tipo'] = "Colocación"
colocaciones_09['Subtipo'] = "Colocaciones efectivas en moneda extranjera"
colocaciones_09['Tipo de Moneda'] = "Saldos en millones de dólares"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
colocaciones_09 = colocaciones_09.reindex(columns=new_cols)

# %%
colocaciones_09
# Out:
#          Fecha                                    Institucion        Tipo  \
# 5   2008-01-31                                     Banco Bice  Colocación
# 6   2008-01-31                    Banco BTG Pactual Chile (9)  Colocación
# 7   2008-01-31                            Banco Consorcio (1)  Colocación
# 8   2008-01-31                             Banco de Chile (2)  Colocación
# 9   2008-01-31                 Banco de Crédito e Inversiones  Colocación
# ..         ...                                            ...         ...
# 26  2021-09-30                     JP Morgan Chase Bank, N.A.  Colocación
# 27  2021-09-30                            Rabobank Chile (15)  Colocación
# 28  2021-09-30                      Scotiabank Chile (3) (17)  Colocación
# 29  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Colocación
# 30  2021-09-30                             Bank of China (16)  Colocación
#
#                                         Subtipo       Valor  \
# ...

# %% [markdown]
# ## Colocación 10

# %%
colocaciones_10.head(5)
# Out:
#           Unnamed: 0                                      Unnamed: 1  \
# 0     Índice general                                     Cuadro 1.10
# 1    Notas generales  Colocaciones contingentes en moneda extranjera
# 2  Conceptualización                   Saldos en millones de dólares
# 3                NaN                                             NaN
# 4                NaN                                             NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
colocaciones_10.pop("Unnamed: 0")
# Out:
# 0        Índice general
# 1       Notas generales
# 2     Conceptualización
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
# 30                  NaN
# 31                  NaN
# 32                  NaN
# 33                  NaN
# 34                  NaN
# 35                  NaN
# 36                  NaN
# Name: Unnamed: 0, dtype: object

# %%
colocaciones_10 = colocaciones_10.iloc[5:]

# %%
colocaciones_10.tail(7)
# Out:
#                                            Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 30                                 Bank of China (16)         ND         ND
# 31                                              Total   4840.408   5291.047
# 32                                                NaN        NaN        NaN
# 33                                                NaN        NaN        NaN
# 34                                ND : No existe dato        NaN        NaN
# 35                                                NaN        NaN        NaN
# 36  Conceptualización: Vínculo que remite al docum...        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 30         ND         ND         ND         ND         ND         ND
# 31   5297.422   5455.062   5544.199   5886.826   5633.291   5783.068
# 32        NaN        NaN        NaN        NaN        NaN        NaN
# 33        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
colocaciones_10.drop(colocaciones_10.tail(6).index,inplace=True)
# Out:
# <ipython-input-169-40218fd23cd7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   colocaciones_10.drop(colocaciones_10.tail(6).index,inplace=True)

# %%
colocaciones_10
# Out:
#                                         Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 5                                       Banco Bice    141.415    159.112
# 6                      Banco BTG Pactual Chile (9)         ND         ND
# 7                              Banco Consorcio (1)      0.139      0.139
# 8                               Banco de Chile (2)    992.281    1168.13
# 9                   Banco de Crédito e Inversiones    769.702    840.014
# 10               Banco de la Nación Argentina (18)      5.277       6.18
# 11                       Banco del Estado de Chile    345.989    391.295
# 12                            Banco do Brasil S.A.     37.351     36.258
# 13                                 Banco Falabella          0          0
# 14                             Banco Internacional     10.367     11.269
# 15                       Banco Itaú Corpbanca (10)    431.815    385.091
# 16                                Banco Paris (13)          0          0
# ...

# %%
colocaciones_10.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice    141.415    159.112    145.231    147.826
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)      0.139      0.139      0.115      0.407
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 157  \
# 5    165.579    157.662      146.6     130.27     126.731  ...   100.029371
# 6         ND         ND         ND         ND          ND  ...     9.120316
# 7      0.407      0.407      0.727      0.403       0.403  ...     9.726882
#
#   Unnamed: 158 Unnamed: 159 Unnamed: 160 Unnamed: 161 Unnamed: 162  \
# 5   127.175419   137.015462   149.520636   182.807744   162.956589
# 6     9.019227     8.352838     8.011573     8.479528      1.08177
# 7     9.463846     12.56283    15.089762    15.209068     17.38402
#
#   Unnamed: 163 Unnamed: 164 Unnamed: 165 Unnamed: 166
# ...

# %%
colocaciones_10 = colocaciones_10.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
colocaciones_10
# Out:
#                                        Unnamed: 1     myVarname       Valor
# 5                                      Banco Bice    Unnamed: 2     141.415
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2          ND
# 7                             Banco Consorcio (1)    Unnamed: 2       0.139
# 8                              Banco de Chile (2)    Unnamed: 2     992.281
# 9                  Banco de Crédito e Inversiones    Unnamed: 2     769.702
# ..                                            ...           ...         ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166           0
# 27                            Rabobank Chile (15)  Unnamed: 166          ND
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166  746.281117
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166          ND
# 30                             Bank of China (16)  Unnamed: 166           0
#
# [4290 rows x 3 columns]

# %%
# create a list of our conditions
conditions_10 = [(colocaciones_10['myVarname'] == 'Unnamed: 2'),(colocaciones_10['myVarname'] == 'Unnamed: 3'),(colocaciones_10['myVarname'] == 'Unnamed: 4'),(colocaciones_10['myVarname'] == 'Unnamed: 5'),(colocaciones_10['myVarname'] == 'Unnamed: 6'),
 (colocaciones_10['myVarname'] == 'Unnamed: 7'),(colocaciones_10['myVarname'] == 'Unnamed: 8'),(colocaciones_10['myVarname'] == 'Unnamed: 9'),(colocaciones_10['myVarname'] == 'Unnamed: 10'),(colocaciones_10['myVarname'] == 'Unnamed: 11'),
  (colocaciones_10['myVarname'] == 'Unnamed: 12'),(colocaciones_10['myVarname'] == 'Unnamed: 13'),(colocaciones_10['myVarname'] == 'Unnamed: 14'),(colocaciones_10['myVarname'] == 'Unnamed: 15'),(colocaciones_10['myVarname'] == 'Unnamed: 16'),
   (colocaciones_10['myVarname'] == 'Unnamed: 17'),(colocaciones_10['myVarname'] == 'Unnamed: 18'),(colocaciones_10['myVarname'] == 'Unnamed: 19'),(colocaciones_10['myVarname'] == 'Unnamed: 20'),(colocaciones_10['myVarname'] == 'Unnamed: 21'),
    (colocaciones_10['myVarname'] == 'Unnamed: 22'),(colocaciones_10['myVarname'] == 'Unnamed: 23'),(colocaciones_10['myVarname'] == 'Unnamed: 24'),(colocaciones_10['myVarname'] == 'Unnamed: 25'),(colocaciones_10['myVarname'] == 'Unnamed: 26'),
     (colocaciones_10['myVarname'] == 'Unnamed: 27'),(colocaciones_10['myVarname'] == 'Unnamed: 28'),(colocaciones_10['myVarname'] == 'Unnamed: 29'),(colocaciones_10['myVarname'] == 'Unnamed: 30'),(colocaciones_10['myVarname'] == 'Unnamed: 31'),
      (colocaciones_10['myVarname'] == 'Unnamed: 32'),(colocaciones_10['myVarname'] == 'Unnamed: 33'),(colocaciones_10['myVarname'] == 'Unnamed: 34'),(colocaciones_10['myVarname'] == 'Unnamed: 35'),(colocaciones_10['myVarname'] == 'Unnamed: 36'),
       (colocaciones_10['myVarname'] == 'Unnamed: 37'),(colocaciones_10['myVarname'] == 'Unnamed: 38'),(colocaciones_10['myVarname'] == 'Unnamed: 39'),(colocaciones_10['myVarname'] == 'Unnamed: 40'),(colocaciones_10['myVarname'] == 'Unnamed: 41'),
        (colocaciones_10['myVarname'] == 'Unnamed: 42'),(colocaciones_10['myVarname'] == 'Unnamed: 43'),(colocaciones_10['myVarname'] == 'Unnamed: 44'),(colocaciones_10['myVarname'] == 'Unnamed: 45'),(colocaciones_10['myVarname'] == 'Unnamed: 46'),
         (colocaciones_10['myVarname'] == 'Unnamed: 47'),(colocaciones_10['myVarname'] == 'Unnamed: 48'),(colocaciones_10['myVarname'] == 'Unnamed: 49'),(colocaciones_10['myVarname'] == 'Unnamed: 50'),(colocaciones_10['myVarname'] == 'Unnamed: 51'),
          (colocaciones_10['myVarname'] == 'Unnamed: 52'),(colocaciones_10['myVarname'] == 'Unnamed: 53'),(colocaciones_10['myVarname'] == 'Unnamed: 54'),(colocaciones_10['myVarname'] == 'Unnamed: 55'),(colocaciones_10['myVarname'] == 'Unnamed: 56'),
           (colocaciones_10['myVarname'] == 'Unnamed: 57'),(colocaciones_10['myVarname'] == 'Unnamed: 58'),(colocaciones_10['myVarname'] == 'Unnamed: 59'),(colocaciones_10['myVarname'] == 'Unnamed: 60'),(colocaciones_10['myVarname'] == 'Unnamed: 61'),
            (colocaciones_10['myVarname'] == 'Unnamed: 62'),(colocaciones_10['myVarname'] == 'Unnamed: 63'),(colocaciones_10['myVarname'] == 'Unnamed: 64'),(colocaciones_10['myVarname'] == 'Unnamed: 65'),(colocaciones_10['myVarname'] == 'Unnamed: 66'),
             (colocaciones_10['myVarname'] == 'Unnamed: 67'),(colocaciones_10['myVarname'] == 'Unnamed: 68'),(colocaciones_10['myVarname'] == 'Unnamed: 69'),(colocaciones_10['myVarname'] == 'Unnamed: 70'),(colocaciones_10['myVarname'] == 'Unnamed: 71'),
              (colocaciones_10['myVarname'] == 'Unnamed: 72'),(colocaciones_10['myVarname'] == 'Unnamed: 73'),(colocaciones_10['myVarname'] == 'Unnamed: 74'),(colocaciones_10['myVarname'] == 'Unnamed: 75'),(colocaciones_10['myVarname'] == 'Unnamed: 76'),
               (colocaciones_10['myVarname'] == 'Unnamed: 77'),(colocaciones_10['myVarname'] == 'Unnamed: 78'),(colocaciones_10['myVarname'] == 'Unnamed: 79'),(colocaciones_10['myVarname'] == 'Unnamed: 80'),(colocaciones_10['myVarname'] == 'Unnamed: 81'),
                (colocaciones_10['myVarname'] == 'Unnamed: 82'),(colocaciones_10['myVarname'] == 'Unnamed: 83'),(colocaciones_10['myVarname'] == 'Unnamed: 84'),(colocaciones_10['myVarname'] == 'Unnamed: 85'),(colocaciones_10['myVarname'] == 'Unnamed: 86'),
                 (colocaciones_10['myVarname'] == 'Unnamed: 87'),(colocaciones_10['myVarname'] == 'Unnamed: 88'),(colocaciones_10['myVarname'] == 'Unnamed: 89'),(colocaciones_10['myVarname'] == 'Unnamed: 90'),(colocaciones_10['myVarname'] == 'Unnamed: 91'),
                  (colocaciones_10['myVarname'] == 'Unnamed: 92'),(colocaciones_10['myVarname'] == 'Unnamed: 93'),(colocaciones_10['myVarname'] == 'Unnamed: 94'),(colocaciones_10['myVarname'] == 'Unnamed: 95'),(colocaciones_10['myVarname'] == 'Unnamed: 96'),
                   (colocaciones_10['myVarname'] == 'Unnamed: 97'),(colocaciones_10['myVarname'] == 'Unnamed: 98'),(colocaciones_10['myVarname'] == 'Unnamed: 99'),(colocaciones_10['myVarname'] == 'Unnamed: 100'),(colocaciones_10['myVarname'] == 'Unnamed: 101'),
                    (colocaciones_10['myVarname'] == 'Unnamed: 102'),(colocaciones_10['myVarname'] == 'Unnamed: 103'),(colocaciones_10['myVarname'] == 'Unnamed: 104'),(colocaciones_10['myVarname'] == 'Unnamed: 105'),(colocaciones_10['myVarname'] == 'Unnamed: 106'),
                     (colocaciones_10['myVarname'] == 'Unnamed: 107'),(colocaciones_10['myVarname'] == 'Unnamed: 108'),(colocaciones_10['myVarname'] == 'Unnamed: 109'),(colocaciones_10['myVarname'] == 'Unnamed: 110'),(colocaciones_10['myVarname'] == 'Unnamed: 111'),
                      (colocaciones_10['myVarname'] == 'Unnamed: 112'),(colocaciones_10['myVarname'] == 'Unnamed: 113'),(colocaciones_10['myVarname'] == 'Unnamed: 114'),(colocaciones_10['myVarname'] == 'Unnamed: 115'),(colocaciones_10['myVarname'] == 'Unnamed: 116'),
                       (colocaciones_10['myVarname'] == 'Unnamed: 117'),(colocaciones_10['myVarname'] == 'Unnamed: 118'),(colocaciones_10['myVarname'] == 'Unnamed: 119'),(colocaciones_10['myVarname'] == 'Unnamed: 120'),(colocaciones_10['myVarname'] == 'Unnamed: 121'),
                        (colocaciones_10['myVarname'] == 'Unnamed: 122'),(colocaciones_10['myVarname'] == 'Unnamed: 123'),(colocaciones_10['myVarname'] == 'Unnamed: 124'),(colocaciones_10['myVarname'] == 'Unnamed: 125'),(colocaciones_10['myVarname'] == 'Unnamed: 126'),
                         (colocaciones_10['myVarname'] == 'Unnamed: 127'),(colocaciones_10['myVarname'] == 'Unnamed: 128'),(colocaciones_10['myVarname'] == 'Unnamed: 129'),(colocaciones_10['myVarname'] == 'Unnamed: 130'),(colocaciones_10['myVarname'] == 'Unnamed: 131'),
                          (colocaciones_10['myVarname'] == 'Unnamed: 132'),(colocaciones_10['myVarname'] == 'Unnamed: 133'),(colocaciones_10['myVarname'] == 'Unnamed: 134'),(colocaciones_10['myVarname'] == 'Unnamed: 135'),(colocaciones_10['myVarname'] == 'Unnamed: 136'),
                           (colocaciones_10['myVarname'] == 'Unnamed: 137'),(colocaciones_10['myVarname'] == 'Unnamed: 138'),(colocaciones_10['myVarname'] == 'Unnamed: 139'),(colocaciones_10['myVarname'] == 'Unnamed: 140'),(colocaciones_10['myVarname'] == 'Unnamed: 141'),
                            (colocaciones_10['myVarname'] == 'Unnamed: 142'),(colocaciones_10['myVarname'] == 'Unnamed: 143'),(colocaciones_10['myVarname'] == 'Unnamed: 144'),(colocaciones_10['myVarname'] == 'Unnamed: 145'),(colocaciones_10['myVarname'] == 'Unnamed: 146'),
                             (colocaciones_10['myVarname'] == 'Unnamed: 147'),(colocaciones_10['myVarname'] == 'Unnamed: 148'),(colocaciones_10['myVarname'] == 'Unnamed: 149'),(colocaciones_10['myVarname'] == 'Unnamed: 150'),(colocaciones_10['myVarname'] == 'Unnamed: 151'),
                              (colocaciones_10['myVarname'] == 'Unnamed: 152'),(colocaciones_10['myVarname'] == 'Unnamed: 153'),(colocaciones_10['myVarname'] == 'Unnamed: 154'),(colocaciones_10['myVarname'] == 'Unnamed: 155'),(colocaciones_10['myVarname'] == 'Unnamed: 156'),
                               (colocaciones_10['myVarname'] == 'Unnamed: 157'),(colocaciones_10['myVarname'] == 'Unnamed: 158'),(colocaciones_10['myVarname'] == 'Unnamed: 159'),(colocaciones_10['myVarname'] == 'Unnamed: 160'),(colocaciones_10['myVarname'] == 'Unnamed: 161'),
                                (colocaciones_10['myVarname'] == 'Unnamed: 162'),(colocaciones_10['myVarname'] == 'Unnamed: 163'),(colocaciones_10['myVarname'] == 'Unnamed: 164'),(colocaciones_10['myVarname'] == 'Unnamed: 165'),(colocaciones_10['myVarname'] == 'Unnamed: 166')
                                ]

# %%
colocaciones_10['Fecha'] = np.select(conditions_10, values)

# %%
colocaciones_10
# Out:
#                                        Unnamed: 1     myVarname       Valor  \
# 5                                      Banco Bice    Unnamed: 2     141.415
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2          ND
# 7                             Banco Consorcio (1)    Unnamed: 2       0.139
# 8                              Banco de Chile (2)    Unnamed: 2     992.281
# 9                  Banco de Crédito e Inversiones    Unnamed: 2     769.702
# ..                                            ...           ...         ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166           0
# 27                            Rabobank Chile (15)  Unnamed: 166          ND
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166  746.281117
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166          ND
# 30                             Bank of China (16)  Unnamed: 166           0
#
#          Fecha
# 5   2008-01-31
# 6   2008-01-31
# ...

# %%
colocaciones_10.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
colocaciones_10.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
colocaciones_10
# Out:
#                                       Institucion       Valor       Fecha
# 5                                      Banco Bice     141.415  2008-01-31
# 6                     Banco BTG Pactual Chile (9)          ND  2008-01-31
# 7                             Banco Consorcio (1)       0.139  2008-01-31
# 8                              Banco de Chile (2)     992.281  2008-01-31
# 9                  Banco de Crédito e Inversiones     769.702  2008-01-31
# ..                                            ...         ...         ...
# 26                     JP Morgan Chase Bank, N.A.           0  2021-09-30
# 27                            Rabobank Chile (15)          ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  746.281117  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)          ND  2021-09-30
# 30                             Bank of China (16)           0  2021-09-30
#
# [4290 rows x 3 columns]

# %%
colocaciones_10['Tipo'] = "Colocación"
colocaciones_10['Subtipo'] = "Colocaciones contingentes en moneda extranjera"
colocaciones_10['Tipo de Moneda'] = "Saldos en millones de dólares"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
colocaciones10 = colocaciones_10.reindex(columns=new_cols)

# %%
colocaciones_10
# Out:
#                                       Institucion       Valor       Fecha  \
# 5                                      Banco Bice     141.415  2008-01-31
# 6                     Banco BTG Pactual Chile (9)          ND  2008-01-31
# 7                             Banco Consorcio (1)       0.139  2008-01-31
# 8                              Banco de Chile (2)     992.281  2008-01-31
# 9                  Banco de Crédito e Inversiones     769.702  2008-01-31
# ..                                            ...         ...         ...
# 26                     JP Morgan Chase Bank, N.A.           0  2021-09-30
# 27                            Rabobank Chile (15)          ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  746.281117  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)          ND  2021-09-30
# 30                             Bank of China (16)           0  2021-09-30
#
#           Tipo                                         Subtipo  \
# ...

# %% [markdown]
# # Depósitos

# %%
#depositos
depositos_01 = pd.read_excel('/content/sdbdep_092021.xlsx',sheet_name='2_01')
depositos_02 = pd.read_excel('/content/sdbdep_092021.xlsx',sheet_name='2_02')
depositos_03 = pd.read_excel('/content/sdbdep_092021.xlsx',sheet_name='2_03')
depositos_04 = pd.read_excel('/content/sdbdep_092021.xlsx',sheet_name='2_04')
depositos_05 = pd.read_excel('/content/sdbdep_092021.xlsx',sheet_name='2_05')
depositos_06 = pd.read_excel('/content/sdbdep_092021.xlsx',sheet_name='2_06')
depositos_07 = pd.read_excel('/content/sdbdep_092021.xlsx',sheet_name='2_07')
depositos_08 = pd.read_excel('/content/sdbdep_092021.xlsx',sheet_name='2_08')
depositos_09 = pd.read_excel('/content/sdbdep_092021.xlsx',sheet_name='2_09')

# %% [markdown]
# ## Depósito 01

# %%
depositos_01.head(5)
# Out:
#         Unnamed: 0                                         Unnamed: 1  \
# 0   Índice general                                        Cuadro 2.01
# 1  Notas generales  Total de depósitos y captaciones en moneda nac...
# 2              NaN                        Saldos en millones de pesos
# 3              NaN                                                NaN
# 4              NaN                                                NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
depositos_01.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
depositos_01 = depositos_01.iloc[5:]

# %%
depositos_01.tail(7)
# Out:
#                                        Unnamed: 1       Unnamed: 2  \
# 28                      Scotiabank Chile (3) (17)   7819739.843782
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)      15949.94476
# 30                             Bank of China (16)               ND
# 31                                          Total  55311058.175889
# 32                                            NaN              NaN
# 33                                            NaN              NaN
# 34                            ND : No existe dato              NaN
#
#          Unnamed: 3      Unnamed: 4       Unnamed: 5       Unnamed: 6  \
# 28   7613858.993884  7860055.218457     7966271.1234   7952344.265245
# 29     21152.853304    17081.062719      13633.55934            10808
# 30               ND              ND               ND               ND
# 31  55296153.067447  56443768.86689  57767540.878023  57571584.822978
# 32              NaN             NaN              NaN              NaN
# ...

# %%
depositos_01.drop(depositos_01.tail(4).index,inplace=True)
# Out:
# <ipython-input-188-b354760258ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   depositos_01.drop(depositos_01.tail(4).index,inplace=True)

# %%
depositos_01
# Out:
#                                         Unnamed: 1       Unnamed: 2  \
# 5                                       Banco Bice   1664974.257994
# 6                      Banco BTG Pactual Chile (9)               ND
# 7                              Banco Consorcio (1)            46886
# 8                               Banco de Chile (2)    9840744.71966
# 9                   Banco de Crédito e Inversiones   6301615.124066
# 10               Banco de la Nación Argentina (18)              319
# 11                       Banco del Estado de Chile   9955495.286867
# 12                            Banco do Brasil S.A.             1525
# 13                                 Banco Falabella    484156.235321
# 14                             Banco Internacional    224783.124665
# 15                       Banco Itaú Corpbanca (10)   4769471.912736
# 16                                Banco Paris (13)    149671.721906
# 17                                Banco Penta (14)       53251.2489
# ...

# %%
depositos_01.head(3)
# Out:
#                     Unnamed: 1      Unnamed: 2      Unnamed: 3  \
# 5                   Banco Bice  1664974.257994  1589216.875918
# 6  Banco BTG Pactual Chile (9)              ND              ND
# 7          Banco Consorcio (1)           46886     52209.89463
#
#        Unnamed: 4      Unnamed: 5     Unnamed: 6     Unnamed: 7  \
# 5  1542217.284431  1576172.980908  1614458.49492  1610399.93193
# 6              ND              ND             ND             ND
# 7    45016.031596       41240.159   43479.550185   61636.196908
#
#        Unnamed: 8      Unnamed: 9   Unnamed: 10  ...    Unnamed: 157  \
# 5  1551606.073614  1535597.880996  1617078.2478  ...  5867940.500464
# 6              ND              ND            ND  ...   812378.370024
# 7    33377.144365    37253.499132  46786.459566  ...  3349112.923216
#
#      Unnamed: 158    Unnamed: 159    Unnamed: 160    Unnamed: 161  \
# 5  5830057.037309  5846735.463343  5865836.150869  5616739.879909
# ...

# %%
depositos_01 = depositos_01.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
depositos_01
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor
# 5    1664974.257994
# 6                ND
# 7             46886
# 8     9840744.71966
# 9    6301615.124066
# ..              ...
# 26    319205.349605
# 27               ND
# ...

# %%
# create a list of our conditions
conditions_1 = [(depositos_01['myVarname'] == 'Unnamed: 2'),(depositos_01['myVarname'] == 'Unnamed: 3'),(depositos_01['myVarname'] == 'Unnamed: 4'),(depositos_01['myVarname'] == 'Unnamed: 5'),(depositos_01['myVarname'] == 'Unnamed: 6'),
 (depositos_01['myVarname'] == 'Unnamed: 7'),(depositos_01['myVarname'] == 'Unnamed: 8'),(depositos_01['myVarname'] == 'Unnamed: 9'),(depositos_01['myVarname'] == 'Unnamed: 10'),(depositos_01['myVarname'] == 'Unnamed: 11'),
  (depositos_01['myVarname'] == 'Unnamed: 12'),(depositos_01['myVarname'] == 'Unnamed: 13'),(depositos_01['myVarname'] == 'Unnamed: 14'),(depositos_01['myVarname'] == 'Unnamed: 15'),(depositos_01['myVarname'] == 'Unnamed: 16'),
   (depositos_01['myVarname'] == 'Unnamed: 17'),(depositos_01['myVarname'] == 'Unnamed: 18'),(depositos_01['myVarname'] == 'Unnamed: 19'),(depositos_01['myVarname'] == 'Unnamed: 20'),(depositos_01['myVarname'] == 'Unnamed: 21'),
    (depositos_01['myVarname'] == 'Unnamed: 22'),(depositos_01['myVarname'] == 'Unnamed: 23'),(depositos_01['myVarname'] == 'Unnamed: 24'),(depositos_01['myVarname'] == 'Unnamed: 25'),(depositos_01['myVarname'] == 'Unnamed: 26'),
     (depositos_01['myVarname'] == 'Unnamed: 27'),(depositos_01['myVarname'] == 'Unnamed: 28'),(depositos_01['myVarname'] == 'Unnamed: 29'),(depositos_01['myVarname'] == 'Unnamed: 30'),(depositos_01['myVarname'] == 'Unnamed: 31'),
      (depositos_01['myVarname'] == 'Unnamed: 32'),(depositos_01['myVarname'] == 'Unnamed: 33'),(depositos_01['myVarname'] == 'Unnamed: 34'),(depositos_01['myVarname'] == 'Unnamed: 35'),(depositos_01['myVarname'] == 'Unnamed: 36'),
       (depositos_01['myVarname'] == 'Unnamed: 37'),(depositos_01['myVarname'] == 'Unnamed: 38'),(depositos_01['myVarname'] == 'Unnamed: 39'),(depositos_01['myVarname'] == 'Unnamed: 40'),(depositos_01['myVarname'] == 'Unnamed: 41'),
        (depositos_01['myVarname'] == 'Unnamed: 42'),(depositos_01['myVarname'] == 'Unnamed: 43'),(depositos_01['myVarname'] == 'Unnamed: 44'),(depositos_01['myVarname'] == 'Unnamed: 45'),(depositos_01['myVarname'] == 'Unnamed: 46'),
         (depositos_01['myVarname'] == 'Unnamed: 47'),(depositos_01['myVarname'] == 'Unnamed: 48'),(depositos_01['myVarname'] == 'Unnamed: 49'),(depositos_01['myVarname'] == 'Unnamed: 50'),(depositos_01['myVarname'] == 'Unnamed: 51'),
          (depositos_01['myVarname'] == 'Unnamed: 52'),(depositos_01['myVarname'] == 'Unnamed: 53'),(depositos_01['myVarname'] == 'Unnamed: 54'),(depositos_01['myVarname'] == 'Unnamed: 55'),(depositos_01['myVarname'] == 'Unnamed: 56'),
           (depositos_01['myVarname'] == 'Unnamed: 57'),(depositos_01['myVarname'] == 'Unnamed: 58'),(depositos_01['myVarname'] == 'Unnamed: 59'),(depositos_01['myVarname'] == 'Unnamed: 60'),(depositos_01['myVarname'] == 'Unnamed: 61'),
            (depositos_01['myVarname'] == 'Unnamed: 62'),(depositos_01['myVarname'] == 'Unnamed: 63'),(depositos_01['myVarname'] == 'Unnamed: 64'),(depositos_01['myVarname'] == 'Unnamed: 65'),(depositos_01['myVarname'] == 'Unnamed: 66'),
             (depositos_01['myVarname'] == 'Unnamed: 67'),(depositos_01['myVarname'] == 'Unnamed: 68'),(depositos_01['myVarname'] == 'Unnamed: 69'),(depositos_01['myVarname'] == 'Unnamed: 70'),(depositos_01['myVarname'] == 'Unnamed: 71'),
              (depositos_01['myVarname'] == 'Unnamed: 72'),(depositos_01['myVarname'] == 'Unnamed: 73'),(depositos_01['myVarname'] == 'Unnamed: 74'),(depositos_01['myVarname'] == 'Unnamed: 75'),(depositos_01['myVarname'] == 'Unnamed: 76'),
               (depositos_01['myVarname'] == 'Unnamed: 77'),(depositos_01['myVarname'] == 'Unnamed: 78'),(depositos_01['myVarname'] == 'Unnamed: 79'),(depositos_01['myVarname'] == 'Unnamed: 80'),(depositos_01['myVarname'] == 'Unnamed: 81'),
                (depositos_01['myVarname'] == 'Unnamed: 82'),(depositos_01['myVarname'] == 'Unnamed: 83'),(depositos_01['myVarname'] == 'Unnamed: 84'),(depositos_01['myVarname'] == 'Unnamed: 85'),(depositos_01['myVarname'] == 'Unnamed: 86'),
                 (depositos_01['myVarname'] == 'Unnamed: 87'),(depositos_01['myVarname'] == 'Unnamed: 88'),(depositos_01['myVarname'] == 'Unnamed: 89'),(depositos_01['myVarname'] == 'Unnamed: 90'),(depositos_01['myVarname'] == 'Unnamed: 91'),
                  (depositos_01['myVarname'] == 'Unnamed: 92'),(depositos_01['myVarname'] == 'Unnamed: 93'),(depositos_01['myVarname'] == 'Unnamed: 94'),(depositos_01['myVarname'] == 'Unnamed: 95'),(depositos_01['myVarname'] == 'Unnamed: 96'),
                   (depositos_01['myVarname'] == 'Unnamed: 97'),(depositos_01['myVarname'] == 'Unnamed: 98'),(depositos_01['myVarname'] == 'Unnamed: 99'),(depositos_01['myVarname'] == 'Unnamed: 100'),(depositos_01['myVarname'] == 'Unnamed: 101'),
                    (depositos_01['myVarname'] == 'Unnamed: 102'),(depositos_01['myVarname'] == 'Unnamed: 103'),(depositos_01['myVarname'] == 'Unnamed: 104'),(depositos_01['myVarname'] == 'Unnamed: 105'),(depositos_01['myVarname'] == 'Unnamed: 106'),
                     (depositos_01['myVarname'] == 'Unnamed: 107'),(depositos_01['myVarname'] == 'Unnamed: 108'),(depositos_01['myVarname'] == 'Unnamed: 109'),(depositos_01['myVarname'] == 'Unnamed: 110'),(depositos_01['myVarname'] == 'Unnamed: 111'),
                      (depositos_01['myVarname'] == 'Unnamed: 112'),(depositos_01['myVarname'] == 'Unnamed: 113'),(depositos_01['myVarname'] == 'Unnamed: 114'),(depositos_01['myVarname'] == 'Unnamed: 115'),(depositos_01['myVarname'] == 'Unnamed: 116'),
                       (depositos_01['myVarname'] == 'Unnamed: 117'),(depositos_01['myVarname'] == 'Unnamed: 118'),(depositos_01['myVarname'] == 'Unnamed: 119'),(depositos_01['myVarname'] == 'Unnamed: 120'),(depositos_01['myVarname'] == 'Unnamed: 121'),
                        (depositos_01['myVarname'] == 'Unnamed: 122'),(depositos_01['myVarname'] == 'Unnamed: 123'),(depositos_01['myVarname'] == 'Unnamed: 124'),(depositos_01['myVarname'] == 'Unnamed: 125'),(depositos_01['myVarname'] == 'Unnamed: 126'),
                         (depositos_01['myVarname'] == 'Unnamed: 127'),(depositos_01['myVarname'] == 'Unnamed: 128'),(depositos_01['myVarname'] == 'Unnamed: 129'),(depositos_01['myVarname'] == 'Unnamed: 130'),(depositos_01['myVarname'] == 'Unnamed: 131'),
                          (depositos_01['myVarname'] == 'Unnamed: 132'),(depositos_01['myVarname'] == 'Unnamed: 133'),(depositos_01['myVarname'] == 'Unnamed: 134'),(depositos_01['myVarname'] == 'Unnamed: 135'),(depositos_01['myVarname'] == 'Unnamed: 136'),
                           (depositos_01['myVarname'] == 'Unnamed: 137'),(depositos_01['myVarname'] == 'Unnamed: 138'),(depositos_01['myVarname'] == 'Unnamed: 139'),(depositos_01['myVarname'] == 'Unnamed: 140'),(depositos_01['myVarname'] == 'Unnamed: 141'),
                            (depositos_01['myVarname'] == 'Unnamed: 142'),(depositos_01['myVarname'] == 'Unnamed: 143'),(depositos_01['myVarname'] == 'Unnamed: 144'),(depositos_01['myVarname'] == 'Unnamed: 145'),(depositos_01['myVarname'] == 'Unnamed: 146'),
                             (depositos_01['myVarname'] == 'Unnamed: 147'),(depositos_01['myVarname'] == 'Unnamed: 148'),(depositos_01['myVarname'] == 'Unnamed: 149'),(depositos_01['myVarname'] == 'Unnamed: 150'),(depositos_01['myVarname'] == 'Unnamed: 151'),
                              (depositos_01['myVarname'] == 'Unnamed: 152'),(depositos_01['myVarname'] == 'Unnamed: 153'),(depositos_01['myVarname'] == 'Unnamed: 154'),(depositos_01['myVarname'] == 'Unnamed: 155'),(depositos_01['myVarname'] == 'Unnamed: 156'),
                               (depositos_01['myVarname'] == 'Unnamed: 157'),(depositos_01['myVarname'] == 'Unnamed: 158'),(depositos_01['myVarname'] == 'Unnamed: 159'),(depositos_01['myVarname'] == 'Unnamed: 160'),(depositos_01['myVarname'] == 'Unnamed: 161'),
                                (depositos_01['myVarname'] == 'Unnamed: 162'),(depositos_01['myVarname'] == 'Unnamed: 163'),(depositos_01['myVarname'] == 'Unnamed: 164'),(depositos_01['myVarname'] == 'Unnamed: 165'),(depositos_01['myVarname'] == 'Unnamed: 166')
                                ]

# %%
depositos_01['Fecha'] = np.select(conditions_1, values)

# %%
depositos_01
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor       Fecha
# 5    1664974.257994  2008-01-31
# 6                ND  2008-01-31
# 7             46886  2008-01-31
# 8     9840744.71966  2008-01-31
# ...

# %%
depositos_01.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
depositos_01.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
depositos_01
# Out:
#                                       Institucion            Valor       Fecha
# 5                                      Banco Bice   1664974.257994  2008-01-31
# 6                     Banco BTG Pactual Chile (9)               ND  2008-01-31
# 7                             Banco Consorcio (1)            46886  2008-01-31
# 8                              Banco de Chile (2)    9840744.71966  2008-01-31
# 9                  Banco de Crédito e Inversiones   6301615.124066  2008-01-31
# ..                                            ...              ...         ...
# 26                     JP Morgan Chase Bank, N.A.    319205.349605  2021-09-30
# 27                            Rabobank Chile (15)               ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  18914640.913769  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)               ND  2021-09-30
# 30                             Bank of China (16)       192.749815  2021-09-30
#
# [4290 rows x 3 columns]

# %%
depositos_01['Tipo'] = "Depósito"
depositos_01['Subtipo'] = "Total de depósitos y captaciones en moneda nacional"
depositos_01['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
depositos_01 = depositos_01.reindex(columns=new_cols)

# %%
depositos_01
# Out:
#          Fecha                                    Institucion      Tipo  \
# 5   2008-01-31                                     Banco Bice  Depósito
# 6   2008-01-31                    Banco BTG Pactual Chile (9)  Depósito
# 7   2008-01-31                            Banco Consorcio (1)  Depósito
# 8   2008-01-31                             Banco de Chile (2)  Depósito
# 9   2008-01-31                 Banco de Crédito e Inversiones  Depósito
# ..         ...                                            ...       ...
# 26  2021-09-30                     JP Morgan Chase Bank, N.A.  Depósito
# 27  2021-09-30                            Rabobank Chile (15)  Depósito
# 28  2021-09-30                      Scotiabank Chile (3) (17)  Depósito
# 29  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Depósito
# 30  2021-09-30                             Bank of China (16)  Depósito
#
#                                               Subtipo            Valor  \
# ...

# %% [markdown]
# ##############################################################################################33

# %% [markdown]
# ## Depósito 02

# %%
depositos_02.head(5)
# Out:
#         Unnamed: 0                             Unnamed: 1  \
# 0   Índice general                            Cuadro 2.02
# 1  Notas generales  Total de depósitos en moneda nacional
# 2              NaN            Saldos en millones de pesos
# 3              NaN                                    NaN
# 4              NaN                                    NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# ...

# %%
depositos_02.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
depositos_02 = depositos_02.iloc[5:]

# %%
depositos_02.tail(7)
# Out:
#                                        Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 28                      Scotiabank Chile (3) (17)    7110236    6887145
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)      13353      17798
# 30                             Bank of China (16)         ND         ND
# 31                                          Total   50061000   50261274
# 32                                            NaN        NaN        NaN
# 33                                            NaN        NaN        NaN
# 34                            ND : No existe dato        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 28    7123817    7219678    7193462    7107628    7146797    7164289
# 29      14557      12253      10808       9920       7606      14446
# 30         ND         ND         ND         ND         ND         ND
# 31   51276828   52412974   52119907   52227438   51901111   51783755
# ...

# %%
depositos_02.drop(depositos_02.tail(4).index,inplace=True)

# %%
depositos_02
# Out:
#                                         Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 5                                       Banco Bice    1599945    1522756
# 6                      Banco BTG Pactual Chile (9)         ND         ND
# 7                              Banco Consorcio (1)      46836      52170
# 8                               Banco de Chile (2)    9357494    9256667
# 9                   Banco de Crédito e Inversiones    5973570    6085339
# 10               Banco de la Nación Argentina (18)        319        342
# 11                       Banco del Estado de Chile    7592241    7795460
# 12                            Banco do Brasil S.A.       1525       1266
# 13                                 Banco Falabella     386402     393934
# 14                             Banco Internacional     218249     218172
# 15                       Banco Itaú Corpbanca (10)    4260647    4266909
# 16                                Banco Paris (13)     142622     139703
# ...

# %%
depositos_02.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice    1599945    1522756    1478967    1507907
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)      46836      52170      44765      41090
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ...  \
# 5    1558582    1539837    1502414    1477911     1565394  ...
# 6         ND         ND         ND         ND          ND  ...
# 7      42602      40636      33329      35373       42407  ...
#
#      Unnamed: 157    Unnamed: 158    Unnamed: 159    Unnamed: 160  \
# 5  5831281.087169  5775800.112518  5844290.881435  5865023.352037
# 6   811378.463869   849885.495622   721748.336575   789353.902988
# 7  3279729.986668  3445082.842603   3552420.96982  3528869.853524
#
#      Unnamed: 161    Unnamed: 162    Unnamed: 163    Unnamed: 164  \
# 5  5616071.492761   5808144.44444  5581882.558734  5596304.985703
# ...

# %%
depositos_02 = depositos_02.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
depositos_02
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor
# 5           1599945
# 6                ND
# 7             46836
# 8           9357494
# 9           5973570
# ..              ...
# 26    319205.349605
# 27               ND
# ...

# %%
# create a list of our conditions
conditions_2 = [(depositos_02['myVarname'] == 'Unnamed: 2'),(depositos_02['myVarname'] == 'Unnamed: 3'),(depositos_02['myVarname'] == 'Unnamed: 4'),(depositos_02['myVarname'] == 'Unnamed: 5'),(depositos_02['myVarname'] == 'Unnamed: 6'),
 (depositos_02['myVarname'] == 'Unnamed: 7'),(depositos_02['myVarname'] == 'Unnamed: 8'),(depositos_02['myVarname'] == 'Unnamed: 9'),(depositos_02['myVarname'] == 'Unnamed: 10'),(depositos_02['myVarname'] == 'Unnamed: 11'),
  (depositos_02['myVarname'] == 'Unnamed: 12'),(depositos_02['myVarname'] == 'Unnamed: 13'),(depositos_02['myVarname'] == 'Unnamed: 14'),(depositos_02['myVarname'] == 'Unnamed: 15'),(depositos_02['myVarname'] == 'Unnamed: 16'),
   (depositos_02['myVarname'] == 'Unnamed: 17'),(depositos_02['myVarname'] == 'Unnamed: 18'),(depositos_02['myVarname'] == 'Unnamed: 19'),(depositos_02['myVarname'] == 'Unnamed: 20'),(depositos_02['myVarname'] == 'Unnamed: 21'),
    (depositos_02['myVarname'] == 'Unnamed: 22'),(depositos_02['myVarname'] == 'Unnamed: 23'),(depositos_02['myVarname'] == 'Unnamed: 24'),(depositos_02['myVarname'] == 'Unnamed: 25'),(depositos_02['myVarname'] == 'Unnamed: 26'),
     (depositos_02['myVarname'] == 'Unnamed: 27'),(depositos_02['myVarname'] == 'Unnamed: 28'),(depositos_02['myVarname'] == 'Unnamed: 29'),(depositos_02['myVarname'] == 'Unnamed: 30'),(depositos_02['myVarname'] == 'Unnamed: 31'),
      (depositos_02['myVarname'] == 'Unnamed: 32'),(depositos_02['myVarname'] == 'Unnamed: 33'),(depositos_02['myVarname'] == 'Unnamed: 34'),(depositos_02['myVarname'] == 'Unnamed: 35'),(depositos_02['myVarname'] == 'Unnamed: 36'),
       (depositos_02['myVarname'] == 'Unnamed: 37'),(depositos_02['myVarname'] == 'Unnamed: 38'),(depositos_02['myVarname'] == 'Unnamed: 39'),(depositos_02['myVarname'] == 'Unnamed: 40'),(depositos_02['myVarname'] == 'Unnamed: 41'),
        (depositos_02['myVarname'] == 'Unnamed: 42'),(depositos_02['myVarname'] == 'Unnamed: 43'),(depositos_02['myVarname'] == 'Unnamed: 44'),(depositos_02['myVarname'] == 'Unnamed: 45'),(depositos_02['myVarname'] == 'Unnamed: 46'),
         (depositos_02['myVarname'] == 'Unnamed: 47'),(depositos_02['myVarname'] == 'Unnamed: 48'),(depositos_02['myVarname'] == 'Unnamed: 49'),(depositos_02['myVarname'] == 'Unnamed: 50'),(depositos_02['myVarname'] == 'Unnamed: 51'),
          (depositos_02['myVarname'] == 'Unnamed: 52'),(depositos_02['myVarname'] == 'Unnamed: 53'),(depositos_02['myVarname'] == 'Unnamed: 54'),(depositos_02['myVarname'] == 'Unnamed: 55'),(depositos_02['myVarname'] == 'Unnamed: 56'),
           (depositos_02['myVarname'] == 'Unnamed: 57'),(depositos_02['myVarname'] == 'Unnamed: 58'),(depositos_02['myVarname'] == 'Unnamed: 59'),(depositos_02['myVarname'] == 'Unnamed: 60'),(depositos_02['myVarname'] == 'Unnamed: 61'),
            (depositos_02['myVarname'] == 'Unnamed: 62'),(depositos_02['myVarname'] == 'Unnamed: 63'),(depositos_02['myVarname'] == 'Unnamed: 64'),(depositos_02['myVarname'] == 'Unnamed: 65'),(depositos_02['myVarname'] == 'Unnamed: 66'),
             (depositos_02['myVarname'] == 'Unnamed: 67'),(depositos_02['myVarname'] == 'Unnamed: 68'),(depositos_02['myVarname'] == 'Unnamed: 69'),(depositos_02['myVarname'] == 'Unnamed: 70'),(depositos_02['myVarname'] == 'Unnamed: 71'),
              (depositos_02['myVarname'] == 'Unnamed: 72'),(depositos_02['myVarname'] == 'Unnamed: 73'),(depositos_02['myVarname'] == 'Unnamed: 74'),(depositos_02['myVarname'] == 'Unnamed: 75'),(depositos_02['myVarname'] == 'Unnamed: 76'),
               (depositos_02['myVarname'] == 'Unnamed: 77'),(depositos_02['myVarname'] == 'Unnamed: 78'),(depositos_02['myVarname'] == 'Unnamed: 79'),(depositos_02['myVarname'] == 'Unnamed: 80'),(depositos_02['myVarname'] == 'Unnamed: 81'),
                (depositos_02['myVarname'] == 'Unnamed: 82'),(depositos_02['myVarname'] == 'Unnamed: 83'),(depositos_02['myVarname'] == 'Unnamed: 84'),(depositos_02['myVarname'] == 'Unnamed: 85'),(depositos_02['myVarname'] == 'Unnamed: 86'),
                 (depositos_02['myVarname'] == 'Unnamed: 87'),(depositos_02['myVarname'] == 'Unnamed: 88'),(depositos_02['myVarname'] == 'Unnamed: 89'),(depositos_02['myVarname'] == 'Unnamed: 90'),(depositos_02['myVarname'] == 'Unnamed: 91'),
                  (depositos_02['myVarname'] == 'Unnamed: 92'),(depositos_02['myVarname'] == 'Unnamed: 93'),(depositos_02['myVarname'] == 'Unnamed: 94'),(depositos_02['myVarname'] == 'Unnamed: 95'),(depositos_02['myVarname'] == 'Unnamed: 96'),
                   (depositos_02['myVarname'] == 'Unnamed: 97'),(depositos_02['myVarname'] == 'Unnamed: 98'),(depositos_02['myVarname'] == 'Unnamed: 99'),(depositos_02['myVarname'] == 'Unnamed: 100'),(depositos_02['myVarname'] == 'Unnamed: 101'),
                    (depositos_02['myVarname'] == 'Unnamed: 102'),(depositos_02['myVarname'] == 'Unnamed: 103'),(depositos_02['myVarname'] == 'Unnamed: 104'),(depositos_02['myVarname'] == 'Unnamed: 105'),(depositos_02['myVarname'] == 'Unnamed: 106'),
                     (depositos_02['myVarname'] == 'Unnamed: 107'),(depositos_02['myVarname'] == 'Unnamed: 108'),(depositos_02['myVarname'] == 'Unnamed: 109'),(depositos_02['myVarname'] == 'Unnamed: 110'),(depositos_02['myVarname'] == 'Unnamed: 111'),
                      (depositos_02['myVarname'] == 'Unnamed: 112'),(depositos_02['myVarname'] == 'Unnamed: 113'),(depositos_02['myVarname'] == 'Unnamed: 114'),(depositos_02['myVarname'] == 'Unnamed: 115'),(depositos_02['myVarname'] == 'Unnamed: 116'),
                       (depositos_02['myVarname'] == 'Unnamed: 117'),(depositos_02['myVarname'] == 'Unnamed: 118'),(depositos_02['myVarname'] == 'Unnamed: 119'),(depositos_02['myVarname'] == 'Unnamed: 120'),(depositos_02['myVarname'] == 'Unnamed: 121'),
                        (depositos_02['myVarname'] == 'Unnamed: 122'),(depositos_02['myVarname'] == 'Unnamed: 123'),(depositos_02['myVarname'] == 'Unnamed: 124'),(depositos_02['myVarname'] == 'Unnamed: 125'),(depositos_02['myVarname'] == 'Unnamed: 126'),
                         (depositos_02['myVarname'] == 'Unnamed: 127'),(depositos_02['myVarname'] == 'Unnamed: 128'),(depositos_02['myVarname'] == 'Unnamed: 129'),(depositos_02['myVarname'] == 'Unnamed: 130'),(depositos_02['myVarname'] == 'Unnamed: 131'),
                          (depositos_02['myVarname'] == 'Unnamed: 132'),(depositos_02['myVarname'] == 'Unnamed: 133'),(depositos_02['myVarname'] == 'Unnamed: 134'),(depositos_02['myVarname'] == 'Unnamed: 135'),(depositos_02['myVarname'] == 'Unnamed: 136'),
                           (depositos_02['myVarname'] == 'Unnamed: 137'),(depositos_02['myVarname'] == 'Unnamed: 138'),(depositos_02['myVarname'] == 'Unnamed: 139'),(depositos_02['myVarname'] == 'Unnamed: 140'),(depositos_02['myVarname'] == 'Unnamed: 141'),
                            (depositos_02['myVarname'] == 'Unnamed: 142'),(depositos_02['myVarname'] == 'Unnamed: 143'),(depositos_02['myVarname'] == 'Unnamed: 144'),(depositos_02['myVarname'] == 'Unnamed: 145'),(depositos_02['myVarname'] == 'Unnamed: 146'),
                             (depositos_02['myVarname'] == 'Unnamed: 147'),(depositos_02['myVarname'] == 'Unnamed: 148'),(depositos_02['myVarname'] == 'Unnamed: 149'),(depositos_02['myVarname'] == 'Unnamed: 150'),(depositos_02['myVarname'] == 'Unnamed: 151'),
                              (depositos_02['myVarname'] == 'Unnamed: 152'),(depositos_02['myVarname'] == 'Unnamed: 153'),(depositos_02['myVarname'] == 'Unnamed: 154'),(depositos_02['myVarname'] == 'Unnamed: 155'),(depositos_02['myVarname'] == 'Unnamed: 156'),
                               (depositos_02['myVarname'] == 'Unnamed: 157'),(depositos_02['myVarname'] == 'Unnamed: 158'),(depositos_02['myVarname'] == 'Unnamed: 159'),(depositos_02['myVarname'] == 'Unnamed: 160'),(depositos_02['myVarname'] == 'Unnamed: 161'),
                                (depositos_02['myVarname'] == 'Unnamed: 162'),(depositos_02['myVarname'] == 'Unnamed: 163'),(depositos_02['myVarname'] == 'Unnamed: 164'),(depositos_02['myVarname'] == 'Unnamed: 165'),(depositos_02['myVarname'] == 'Unnamed: 166')
                                ]

# %%
depositos_02['Fecha'] = np.select(conditions_2, values)

# %%
depositos_02
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor       Fecha
# 5           1599945  2008-01-31
# 6                ND  2008-01-31
# 7             46836  2008-01-31
# 8           9357494  2008-01-31
# ...

# %%
depositos_02.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
depositos_02.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
depositos_02
# Out:
#                                       Institucion            Valor       Fecha
# 5                                      Banco Bice          1599945  2008-01-31
# 6                     Banco BTG Pactual Chile (9)               ND  2008-01-31
# 7                             Banco Consorcio (1)            46836  2008-01-31
# 8                              Banco de Chile (2)          9357494  2008-01-31
# 9                  Banco de Crédito e Inversiones          5973570  2008-01-31
# ..                                            ...              ...         ...
# 26                     JP Morgan Chase Bank, N.A.    319205.349605  2021-09-30
# 27                            Rabobank Chile (15)               ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  18717246.314497  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)               ND  2021-09-30
# 30                             Bank of China (16)       192.749815  2021-09-30
#
# [4290 rows x 3 columns]

# %%
depositos_02['Tipo'] = "Depósito"
depositos_02['Subtipo'] = "Total de depósitos en moneda nacional"
depositos_02['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
depositos_02 = depositos_02.reindex(columns=new_cols)

# %%
depositos_02
# Out:
#          Fecha                                    Institucion      Tipo  \
# 5   2008-01-31                                     Banco Bice  Depósito
# 6   2008-01-31                    Banco BTG Pactual Chile (9)  Depósito
# 7   2008-01-31                            Banco Consorcio (1)  Depósito
# 8   2008-01-31                             Banco de Chile (2)  Depósito
# 9   2008-01-31                 Banco de Crédito e Inversiones  Depósito
# ..         ...                                            ...       ...
# 26  2021-09-30                     JP Morgan Chase Bank, N.A.  Depósito
# 27  2021-09-30                            Rabobank Chile (15)  Depósito
# 28  2021-09-30                      Scotiabank Chile (3) (17)  Depósito
# 29  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Depósito
# 30  2021-09-30                             Bank of China (16)  Depósito
#
#                                   Subtipo            Valor  \
# ...

# %% [markdown]
# ## Depósito 03

# %%
depositos_03.head(5)
# Out:
#         Unnamed: 0                   Unnamed: 1           Unnamed: 2  \
# 0   Índice general                  Cuadro 2.03                  NaN
# 1  Notas generales  Depósitos a menos de un mes                  NaN
# 2              NaN  Saldos en millones de pesos                  NaN
# 3              NaN                          NaN                  NaN
# 4              NaN                          NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
depositos_03.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
depositos_03.head(7)
# Out:
#                     Unnamed: 1           Unnamed: 2           Unnamed: 3  \
# 0                  Cuadro 2.03                  NaN                  NaN
# 1  Depósitos a menos de un mes                  NaN                  NaN
# 2  Saldos en millones de pesos                  NaN                  NaN
# 3                          NaN                  NaN                  NaN
# 4                          NaN  2008-01-31 00:00:00  2008-02-29 00:00:00
# 5                   Banco Bice               203980               182443
# 6  Banco BTG Pactual Chile (9)                   ND                   ND
#
#             Unnamed: 4           Unnamed: 5           Unnamed: 6  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# ...

# %%
depositos_03 = depositos_03.iloc[5:]

# %%
depositos_03.tail(7)
# Out:
#                                        Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 28                      Scotiabank Chile (3) (17)    1145692     994897
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)      13352      17797
# 30                             Bank of China (16)         ND         ND
# 31                                          Total   10728343   10299885
# 32                                            NaN        NaN        NaN
# 33                                            NaN        NaN        NaN
# 34                            ND : No existe dato        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 28     992332    1010881     985033     996374     892414     888439
# 29      14556      12252      10807       9919       7605      14445
# 30         ND         ND         ND         ND         ND         ND
# 31   10700514   11162930   11277275   11387276   10620751   10432393
# ...

# %%
depositos_03.drop(depositos_03.tail(4).index,inplace=True)
# Out:
# <ipython-input-225-113bb162bea7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   depositos_03.drop(depositos_03.tail(4).index,inplace=True)

# %%
depositos_03.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice     203980     182443     201542     234648
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)       2288       3167       5274       5450
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ...  \
# 5     210894     210576     193215     195650      244597  ...
# 6         ND         ND         ND         ND          ND  ...
# 7       5472       5861       4121       4539        3986  ...
#
#      Unnamed: 157    Unnamed: 158    Unnamed: 159    Unnamed: 160  \
# 5  1486880.573041  1372524.826165  1401218.660252  1461389.384402
# 6    83840.775047    138951.46503    93538.952476   133673.376305
# 7   268869.620342   274857.055643   274496.617054   310594.125965
#
#      Unnamed: 161    Unnamed: 162    Unnamed: 163    Unnamed: 164  \
# 5  1468541.148511  1684519.817359  1662296.086308  1812263.520792
# ...

# %%
depositos_03 = depositos_03.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
depositos_03
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#              Valor
# 5           203980
# 6               ND
# 7             2288
# 8          2420269
# 9          1566985
# ..             ...
# 26   259167.753004
# 27              ND
# ...

# %%
# create a list of our conditions
conditions_3 = [(depositos_03['myVarname'] == 'Unnamed: 2'),(depositos_03['myVarname'] == 'Unnamed: 3'),(depositos_03['myVarname'] == 'Unnamed: 4'),(depositos_03['myVarname'] == 'Unnamed: 5'),(depositos_03['myVarname'] == 'Unnamed: 6'),
 (depositos_03['myVarname'] == 'Unnamed: 7'),(depositos_03['myVarname'] == 'Unnamed: 8'),(depositos_03['myVarname'] == 'Unnamed: 9'),(depositos_03['myVarname'] == 'Unnamed: 10'),(depositos_03['myVarname'] == 'Unnamed: 11'),
  (depositos_03['myVarname'] == 'Unnamed: 12'),(depositos_03['myVarname'] == 'Unnamed: 13'),(depositos_03['myVarname'] == 'Unnamed: 14'),(depositos_03['myVarname'] == 'Unnamed: 15'),(depositos_03['myVarname'] == 'Unnamed: 16'),
   (depositos_03['myVarname'] == 'Unnamed: 17'),(depositos_03['myVarname'] == 'Unnamed: 18'),(depositos_03['myVarname'] == 'Unnamed: 19'),(depositos_03['myVarname'] == 'Unnamed: 20'),(depositos_03['myVarname'] == 'Unnamed: 21'),
    (depositos_03['myVarname'] == 'Unnamed: 22'),(depositos_03['myVarname'] == 'Unnamed: 23'),(depositos_03['myVarname'] == 'Unnamed: 24'),(depositos_03['myVarname'] == 'Unnamed: 25'),(depositos_03['myVarname'] == 'Unnamed: 26'),
     (depositos_03['myVarname'] == 'Unnamed: 27'),(depositos_03['myVarname'] == 'Unnamed: 28'),(depositos_03['myVarname'] == 'Unnamed: 29'),(depositos_03['myVarname'] == 'Unnamed: 30'),(depositos_03['myVarname'] == 'Unnamed: 31'),
      (depositos_03['myVarname'] == 'Unnamed: 32'),(depositos_03['myVarname'] == 'Unnamed: 33'),(depositos_03['myVarname'] == 'Unnamed: 34'),(depositos_03['myVarname'] == 'Unnamed: 35'),(depositos_03['myVarname'] == 'Unnamed: 36'),
       (depositos_03['myVarname'] == 'Unnamed: 37'),(depositos_03['myVarname'] == 'Unnamed: 38'),(depositos_03['myVarname'] == 'Unnamed: 39'),(depositos_03['myVarname'] == 'Unnamed: 40'),(depositos_03['myVarname'] == 'Unnamed: 41'),
        (depositos_03['myVarname'] == 'Unnamed: 42'),(depositos_03['myVarname'] == 'Unnamed: 43'),(depositos_03['myVarname'] == 'Unnamed: 44'),(depositos_03['myVarname'] == 'Unnamed: 45'),(depositos_03['myVarname'] == 'Unnamed: 46'),
         (depositos_03['myVarname'] == 'Unnamed: 47'),(depositos_03['myVarname'] == 'Unnamed: 48'),(depositos_03['myVarname'] == 'Unnamed: 49'),(depositos_03['myVarname'] == 'Unnamed: 50'),(depositos_03['myVarname'] == 'Unnamed: 51'),
          (depositos_03['myVarname'] == 'Unnamed: 52'),(depositos_03['myVarname'] == 'Unnamed: 53'),(depositos_03['myVarname'] == 'Unnamed: 54'),(depositos_03['myVarname'] == 'Unnamed: 55'),(depositos_03['myVarname'] == 'Unnamed: 56'),
           (depositos_03['myVarname'] == 'Unnamed: 57'),(depositos_03['myVarname'] == 'Unnamed: 58'),(depositos_03['myVarname'] == 'Unnamed: 59'),(depositos_03['myVarname'] == 'Unnamed: 60'),(depositos_03['myVarname'] == 'Unnamed: 61'),
            (depositos_03['myVarname'] == 'Unnamed: 62'),(depositos_03['myVarname'] == 'Unnamed: 63'),(depositos_03['myVarname'] == 'Unnamed: 64'),(depositos_03['myVarname'] == 'Unnamed: 65'),(depositos_03['myVarname'] == 'Unnamed: 66'),
             (depositos_03['myVarname'] == 'Unnamed: 67'),(depositos_03['myVarname'] == 'Unnamed: 68'),(depositos_03['myVarname'] == 'Unnamed: 69'),(depositos_03['myVarname'] == 'Unnamed: 70'),(depositos_03['myVarname'] == 'Unnamed: 71'),
              (depositos_03['myVarname'] == 'Unnamed: 72'),(depositos_03['myVarname'] == 'Unnamed: 73'),(depositos_03['myVarname'] == 'Unnamed: 74'),(depositos_03['myVarname'] == 'Unnamed: 75'),(depositos_03['myVarname'] == 'Unnamed: 76'),
               (depositos_03['myVarname'] == 'Unnamed: 77'),(depositos_03['myVarname'] == 'Unnamed: 78'),(depositos_03['myVarname'] == 'Unnamed: 79'),(depositos_03['myVarname'] == 'Unnamed: 80'),(depositos_03['myVarname'] == 'Unnamed: 81'),
                (depositos_03['myVarname'] == 'Unnamed: 82'),(depositos_03['myVarname'] == 'Unnamed: 83'),(depositos_03['myVarname'] == 'Unnamed: 84'),(depositos_03['myVarname'] == 'Unnamed: 85'),(depositos_03['myVarname'] == 'Unnamed: 86'),
                 (depositos_03['myVarname'] == 'Unnamed: 87'),(depositos_03['myVarname'] == 'Unnamed: 88'),(depositos_03['myVarname'] == 'Unnamed: 89'),(depositos_03['myVarname'] == 'Unnamed: 90'),(depositos_03['myVarname'] == 'Unnamed: 91'),
                  (depositos_03['myVarname'] == 'Unnamed: 92'),(depositos_03['myVarname'] == 'Unnamed: 93'),(depositos_03['myVarname'] == 'Unnamed: 94'),(depositos_03['myVarname'] == 'Unnamed: 95'),(depositos_03['myVarname'] == 'Unnamed: 96'),
                   (depositos_03['myVarname'] == 'Unnamed: 97'),(depositos_03['myVarname'] == 'Unnamed: 98'),(depositos_03['myVarname'] == 'Unnamed: 99'),(depositos_03['myVarname'] == 'Unnamed: 100'),(depositos_03['myVarname'] == 'Unnamed: 101'),
                    (depositos_03['myVarname'] == 'Unnamed: 102'),(depositos_03['myVarname'] == 'Unnamed: 103'),(depositos_03['myVarname'] == 'Unnamed: 104'),(depositos_03['myVarname'] == 'Unnamed: 105'),(depositos_03['myVarname'] == 'Unnamed: 106'),
                     (depositos_03['myVarname'] == 'Unnamed: 107'),(depositos_03['myVarname'] == 'Unnamed: 108'),(depositos_03['myVarname'] == 'Unnamed: 109'),(depositos_03['myVarname'] == 'Unnamed: 110'),(depositos_03['myVarname'] == 'Unnamed: 111'),
                      (depositos_03['myVarname'] == 'Unnamed: 112'),(depositos_03['myVarname'] == 'Unnamed: 113'),(depositos_03['myVarname'] == 'Unnamed: 114'),(depositos_03['myVarname'] == 'Unnamed: 115'),(depositos_03['myVarname'] == 'Unnamed: 116'),
                       (depositos_03['myVarname'] == 'Unnamed: 117'),(depositos_03['myVarname'] == 'Unnamed: 118'),(depositos_03['myVarname'] == 'Unnamed: 119'),(depositos_03['myVarname'] == 'Unnamed: 120'),(depositos_03['myVarname'] == 'Unnamed: 121'),
                        (depositos_03['myVarname'] == 'Unnamed: 122'),(depositos_03['myVarname'] == 'Unnamed: 123'),(depositos_03['myVarname'] == 'Unnamed: 124'),(depositos_03['myVarname'] == 'Unnamed: 125'),(depositos_03['myVarname'] == 'Unnamed: 126'),
                         (depositos_03['myVarname'] == 'Unnamed: 127'),(depositos_03['myVarname'] == 'Unnamed: 128'),(depositos_03['myVarname'] == 'Unnamed: 129'),(depositos_03['myVarname'] == 'Unnamed: 130'),(depositos_03['myVarname'] == 'Unnamed: 131'),
                          (depositos_03['myVarname'] == 'Unnamed: 132'),(depositos_03['myVarname'] == 'Unnamed: 133'),(depositos_03['myVarname'] == 'Unnamed: 134'),(depositos_03['myVarname'] == 'Unnamed: 135'),(depositos_03['myVarname'] == 'Unnamed: 136'),
                           (depositos_03['myVarname'] == 'Unnamed: 137'),(depositos_03['myVarname'] == 'Unnamed: 138'),(depositos_03['myVarname'] == 'Unnamed: 139'),(depositos_03['myVarname'] == 'Unnamed: 140'),(depositos_03['myVarname'] == 'Unnamed: 141'),
                            (depositos_03['myVarname'] == 'Unnamed: 142'),(depositos_03['myVarname'] == 'Unnamed: 143'),(depositos_03['myVarname'] == 'Unnamed: 144'),(depositos_03['myVarname'] == 'Unnamed: 145'),(depositos_03['myVarname'] == 'Unnamed: 146'),
                             (depositos_03['myVarname'] == 'Unnamed: 147'),(depositos_03['myVarname'] == 'Unnamed: 148'),(depositos_03['myVarname'] == 'Unnamed: 149'),(depositos_03['myVarname'] == 'Unnamed: 150'),(depositos_03['myVarname'] == 'Unnamed: 151'),
                              (depositos_03['myVarname'] == 'Unnamed: 152'),(depositos_03['myVarname'] == 'Unnamed: 153'),(depositos_03['myVarname'] == 'Unnamed: 154'),(depositos_03['myVarname'] == 'Unnamed: 155'),(depositos_03['myVarname'] == 'Unnamed: 156'),
                               (depositos_03['myVarname'] == 'Unnamed: 157'),(depositos_03['myVarname'] == 'Unnamed: 158'),(depositos_03['myVarname'] == 'Unnamed: 159'),(depositos_03['myVarname'] == 'Unnamed: 160'),(depositos_03['myVarname'] == 'Unnamed: 161'),
                                (depositos_03['myVarname'] == 'Unnamed: 162'),(depositos_03['myVarname'] == 'Unnamed: 163'),(depositos_03['myVarname'] == 'Unnamed: 164'),(depositos_03['myVarname'] == 'Unnamed: 165'),(depositos_03['myVarname'] == 'Unnamed: 166')
                                ]

# %%
depositos_03['Fecha'] = np.select(conditions_3, values)

# %%
depositos_03
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#              Valor       Fecha
# 5           203980  2008-01-31
# 6               ND  2008-01-31
# 7             2288  2008-01-31
# 8          2420269  2008-01-31
# 9          1566985  2008-01-31
# ...

# %%
depositos_03.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
depositos_03.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
depositos_03
# Out:
#                                       Institucion           Valor       Fecha
# 5                                      Banco Bice          203980  2008-01-31
# 6                     Banco BTG Pactual Chile (9)              ND  2008-01-31
# 7                             Banco Consorcio (1)            2288  2008-01-31
# 8                              Banco de Chile (2)         2420269  2008-01-31
# 9                  Banco de Crédito e Inversiones         1566985  2008-01-31
# ..                                            ...             ...         ...
# 26                     JP Morgan Chase Bank, N.A.   259167.753004  2021-09-30
# 27                            Rabobank Chile (15)              ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  6823118.622918  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)              ND  2021-09-30
# 30                             Bank of China (16)      192.749815  2021-09-30
#
# [4290 rows x 3 columns]

# %%
depositos_03['Tipo'] = "Depósito"
depositos_03['Subtipo'] = "Depósitos a menos de un mes"
depositos_03['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
depositos_03.head(5)
# Out:
#                       Institucion    Valor       Fecha      Tipo  \
# 5                      Banco Bice   203980  2008-01-31  Depósito
# 6     Banco BTG Pactual Chile (9)       ND  2008-01-31  Depósito
# 7             Banco Consorcio (1)     2288  2008-01-31  Depósito
# 8              Banco de Chile (2)  2420269  2008-01-31  Depósito
# 9  Banco de Crédito e Inversiones  1566985  2008-01-31  Depósito
#
#                        Subtipo               Tipo de Moneda
# 5  Depósitos a menos de un mes  Saldos en millones de pesos
# 6  Depósitos a menos de un mes  Saldos en millones de pesos
# 7  Depósitos a menos de un mes  Saldos en millones de pesos
# 8  Depósitos a menos de un mes  Saldos en millones de pesos
# 9  Depósitos a menos de un mes  Saldos en millones de pesos

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
depositos_03 = depositos_03.reindex(columns=new_cols)

# %%
depositos_03.head(5)
# Out:
#         Fecha                     Institucion      Tipo  \
# 5  2008-01-31                      Banco Bice  Depósito
# 6  2008-01-31     Banco BTG Pactual Chile (9)  Depósito
# 7  2008-01-31             Banco Consorcio (1)  Depósito
# 8  2008-01-31              Banco de Chile (2)  Depósito
# 9  2008-01-31  Banco de Crédito e Inversiones  Depósito
#
#                        Subtipo    Valor               Tipo de Moneda
# 5  Depósitos a menos de un mes   203980  Saldos en millones de pesos
# 6  Depósitos a menos de un mes       ND  Saldos en millones de pesos
# 7  Depósitos a menos de un mes     2288  Saldos en millones de pesos
# 8  Depósitos a menos de un mes  2420269  Saldos en millones de pesos
# 9  Depósitos a menos de un mes  1566985  Saldos en millones de pesos

# %% [markdown]
# ## Depósito 04

# %%
depositos_04.head(5)
# Out:
#         Unnamed: 0                   Unnamed: 1           Unnamed: 2  \
# 0   Índice general                  Cuadro 2.04                  NaN
# 1  Notas generales    Depósitos a más de un mes                  NaN
# 2              NaN  Saldos en millones de pesos                  NaN
# 3              NaN                          NaN                  NaN
# 4              NaN                          NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
depositos_04.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
depositos_04.head(7)
# Out:
#                     Unnamed: 1           Unnamed: 2           Unnamed: 3  \
# 0                  Cuadro 2.04                  NaN                  NaN
# 1    Depósitos a más de un mes                  NaN                  NaN
# 2  Saldos en millones de pesos                  NaN                  NaN
# 3                          NaN                  NaN                  NaN
# 4                          NaN  2008-01-31 00:00:00  2008-02-29 00:00:00
# 5                   Banco Bice              1395965              1340313
# 6  Banco BTG Pactual Chile (9)                   ND                   ND
#
#             Unnamed: 4           Unnamed: 5           Unnamed: 6  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# ...

# %%
depositos_04 = depositos_04.iloc[5:]

# %%
depositos_04.tail(7)
# Out:
#                                        Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 28                      Scotiabank Chile (3) (17)    5964544    5892248
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)          1          1
# 30                             Bank of China (16)         ND         ND
# 31                                          Total   39332657   39961389
# 32                                            NaN        NaN        NaN
# 33                                            NaN        NaN        NaN
# 34                            ND : No existe dato        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 28    6131485    6208797    6208429    6111254    6254383    6275850
# 29          1          1          1          1          1          1
# 30         ND         ND         ND         ND         ND         ND
# 31   40576314   41250044   40842632   40840162   41280360   41351362
# ...

# %%
depositos_04.drop(depositos_04.tail(4).index,inplace=True)
# Out:
# <ipython-input-244-2efae5e9354d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   depositos_04.drop(depositos_04.tail(4).index,inplace=True)

# %%
depositos_04.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice    1395965    1340313    1277425    1273259
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)      44548      49003      39491      35640
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ...  \
# 5    1347688    1329261    1309199    1282261     1320797  ...
# 6         ND         ND         ND         ND          ND  ...
# 7      37130      34775      29208      30834       38421  ...
#
#      Unnamed: 157    Unnamed: 158    Unnamed: 159    Unnamed: 160  \
# 5  4344400.514128  4403275.286353  4443072.221183  4403633.967635
# 6   727537.688822   710934.030592   628209.384099   655680.526683
# 7  3010860.366326   3170225.78696  3277924.352766  3218275.727559
#
#     Unnamed: 161    Unnamed: 162    Unnamed: 163    Unnamed: 164  \
# 5  4147530.34425  4123624.627081  3919586.472426  3784041.464911
# ...

# %%
depositos_04 = depositos_04.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
depositos_04
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor
# 5           1395965
# 6                ND
# 7             44548
# 8           6937225
# 9           4406585
# ..              ...
# 26     60037.596601
# 27               ND
# ...

# %%
# create a list of our conditions
conditions_4 = [(depositos_04['myVarname'] == 'Unnamed: 2'),(depositos_04['myVarname'] == 'Unnamed: 3'),(depositos_04['myVarname'] == 'Unnamed: 4'),(depositos_04['myVarname'] == 'Unnamed: 5'),(depositos_04['myVarname'] == 'Unnamed: 6'),
 (depositos_04['myVarname'] == 'Unnamed: 7'),(depositos_04['myVarname'] == 'Unnamed: 8'),(depositos_04['myVarname'] == 'Unnamed: 9'),(depositos_04['myVarname'] == 'Unnamed: 10'),(depositos_04['myVarname'] == 'Unnamed: 11'),
  (depositos_04['myVarname'] == 'Unnamed: 12'),(depositos_04['myVarname'] == 'Unnamed: 13'),(depositos_04['myVarname'] == 'Unnamed: 14'),(depositos_04['myVarname'] == 'Unnamed: 15'),(depositos_04['myVarname'] == 'Unnamed: 16'),
   (depositos_04['myVarname'] == 'Unnamed: 17'),(depositos_04['myVarname'] == 'Unnamed: 18'),(depositos_04['myVarname'] == 'Unnamed: 19'),(depositos_04['myVarname'] == 'Unnamed: 20'),(depositos_04['myVarname'] == 'Unnamed: 21'),
    (depositos_04['myVarname'] == 'Unnamed: 22'),(depositos_04['myVarname'] == 'Unnamed: 23'),(depositos_04['myVarname'] == 'Unnamed: 24'),(depositos_04['myVarname'] == 'Unnamed: 25'),(depositos_04['myVarname'] == 'Unnamed: 26'),
     (depositos_04['myVarname'] == 'Unnamed: 27'),(depositos_04['myVarname'] == 'Unnamed: 28'),(depositos_04['myVarname'] == 'Unnamed: 29'),(depositos_04['myVarname'] == 'Unnamed: 30'),(depositos_04['myVarname'] == 'Unnamed: 31'),
      (depositos_04['myVarname'] == 'Unnamed: 32'),(depositos_04['myVarname'] == 'Unnamed: 33'),(depositos_04['myVarname'] == 'Unnamed: 34'),(depositos_04['myVarname'] == 'Unnamed: 35'),(depositos_04['myVarname'] == 'Unnamed: 36'),
       (depositos_04['myVarname'] == 'Unnamed: 37'),(depositos_04['myVarname'] == 'Unnamed: 38'),(depositos_04['myVarname'] == 'Unnamed: 39'),(depositos_04['myVarname'] == 'Unnamed: 40'),(depositos_04['myVarname'] == 'Unnamed: 41'),
        (depositos_04['myVarname'] == 'Unnamed: 42'),(depositos_04['myVarname'] == 'Unnamed: 43'),(depositos_04['myVarname'] == 'Unnamed: 44'),(depositos_04['myVarname'] == 'Unnamed: 45'),(depositos_04['myVarname'] == 'Unnamed: 46'),
         (depositos_04['myVarname'] == 'Unnamed: 47'),(depositos_04['myVarname'] == 'Unnamed: 48'),(depositos_04['myVarname'] == 'Unnamed: 49'),(depositos_04['myVarname'] == 'Unnamed: 50'),(depositos_04['myVarname'] == 'Unnamed: 51'),
          (depositos_04['myVarname'] == 'Unnamed: 52'),(depositos_04['myVarname'] == 'Unnamed: 53'),(depositos_04['myVarname'] == 'Unnamed: 54'),(depositos_04['myVarname'] == 'Unnamed: 55'),(depositos_04['myVarname'] == 'Unnamed: 56'),
           (depositos_04['myVarname'] == 'Unnamed: 57'),(depositos_04['myVarname'] == 'Unnamed: 58'),(depositos_04['myVarname'] == 'Unnamed: 59'),(depositos_04['myVarname'] == 'Unnamed: 60'),(depositos_04['myVarname'] == 'Unnamed: 61'),
            (depositos_04['myVarname'] == 'Unnamed: 62'),(depositos_04['myVarname'] == 'Unnamed: 63'),(depositos_04['myVarname'] == 'Unnamed: 64'),(depositos_04['myVarname'] == 'Unnamed: 65'),(depositos_04['myVarname'] == 'Unnamed: 66'),
             (depositos_04['myVarname'] == 'Unnamed: 67'),(depositos_04['myVarname'] == 'Unnamed: 68'),(depositos_04['myVarname'] == 'Unnamed: 69'),(depositos_04['myVarname'] == 'Unnamed: 70'),(depositos_04['myVarname'] == 'Unnamed: 71'),
              (depositos_04['myVarname'] == 'Unnamed: 72'),(depositos_04['myVarname'] == 'Unnamed: 73'),(depositos_04['myVarname'] == 'Unnamed: 74'),(depositos_04['myVarname'] == 'Unnamed: 75'),(depositos_04['myVarname'] == 'Unnamed: 76'),
               (depositos_04['myVarname'] == 'Unnamed: 77'),(depositos_04['myVarname'] == 'Unnamed: 78'),(depositos_04['myVarname'] == 'Unnamed: 79'),(depositos_04['myVarname'] == 'Unnamed: 80'),(depositos_04['myVarname'] == 'Unnamed: 81'),
                (depositos_04['myVarname'] == 'Unnamed: 82'),(depositos_04['myVarname'] == 'Unnamed: 83'),(depositos_04['myVarname'] == 'Unnamed: 84'),(depositos_04['myVarname'] == 'Unnamed: 85'),(depositos_04['myVarname'] == 'Unnamed: 86'),
                 (depositos_04['myVarname'] == 'Unnamed: 87'),(depositos_04['myVarname'] == 'Unnamed: 88'),(depositos_04['myVarname'] == 'Unnamed: 89'),(depositos_04['myVarname'] == 'Unnamed: 90'),(depositos_04['myVarname'] == 'Unnamed: 91'),
                  (depositos_04['myVarname'] == 'Unnamed: 92'),(depositos_04['myVarname'] == 'Unnamed: 93'),(depositos_04['myVarname'] == 'Unnamed: 94'),(depositos_04['myVarname'] == 'Unnamed: 95'),(depositos_04['myVarname'] == 'Unnamed: 96'),
                   (depositos_04['myVarname'] == 'Unnamed: 97'),(depositos_04['myVarname'] == 'Unnamed: 98'),(depositos_04['myVarname'] == 'Unnamed: 99'),(depositos_04['myVarname'] == 'Unnamed: 100'),(depositos_04['myVarname'] == 'Unnamed: 101'),
                    (depositos_04['myVarname'] == 'Unnamed: 102'),(depositos_04['myVarname'] == 'Unnamed: 103'),(depositos_04['myVarname'] == 'Unnamed: 104'),(depositos_04['myVarname'] == 'Unnamed: 105'),(depositos_04['myVarname'] == 'Unnamed: 106'),
                     (depositos_04['myVarname'] == 'Unnamed: 107'),(depositos_04['myVarname'] == 'Unnamed: 108'),(depositos_04['myVarname'] == 'Unnamed: 109'),(depositos_04['myVarname'] == 'Unnamed: 110'),(depositos_04['myVarname'] == 'Unnamed: 111'),
                      (depositos_04['myVarname'] == 'Unnamed: 112'),(depositos_04['myVarname'] == 'Unnamed: 113'),(depositos_04['myVarname'] == 'Unnamed: 114'),(depositos_04['myVarname'] == 'Unnamed: 115'),(depositos_04['myVarname'] == 'Unnamed: 116'),
                       (depositos_04['myVarname'] == 'Unnamed: 117'),(depositos_04['myVarname'] == 'Unnamed: 118'),(depositos_04['myVarname'] == 'Unnamed: 119'),(depositos_04['myVarname'] == 'Unnamed: 120'),(depositos_04['myVarname'] == 'Unnamed: 121'),
                        (depositos_04['myVarname'] == 'Unnamed: 122'),(depositos_04['myVarname'] == 'Unnamed: 123'),(depositos_04['myVarname'] == 'Unnamed: 124'),(depositos_04['myVarname'] == 'Unnamed: 125'),(depositos_04['myVarname'] == 'Unnamed: 126'),
                         (depositos_04['myVarname'] == 'Unnamed: 127'),(depositos_04['myVarname'] == 'Unnamed: 128'),(depositos_04['myVarname'] == 'Unnamed: 129'),(depositos_04['myVarname'] == 'Unnamed: 130'),(depositos_04['myVarname'] == 'Unnamed: 131'),
                          (depositos_04['myVarname'] == 'Unnamed: 132'),(depositos_04['myVarname'] == 'Unnamed: 133'),(depositos_04['myVarname'] == 'Unnamed: 134'),(depositos_04['myVarname'] == 'Unnamed: 135'),(depositos_04['myVarname'] == 'Unnamed: 136'),
                           (depositos_04['myVarname'] == 'Unnamed: 137'),(depositos_04['myVarname'] == 'Unnamed: 138'),(depositos_04['myVarname'] == 'Unnamed: 139'),(depositos_04['myVarname'] == 'Unnamed: 140'),(depositos_04['myVarname'] == 'Unnamed: 141'),
                            (depositos_04['myVarname'] == 'Unnamed: 142'),(depositos_04['myVarname'] == 'Unnamed: 143'),(depositos_04['myVarname'] == 'Unnamed: 144'),(depositos_04['myVarname'] == 'Unnamed: 145'),(depositos_04['myVarname'] == 'Unnamed: 146'),
                             (depositos_04['myVarname'] == 'Unnamed: 147'),(depositos_04['myVarname'] == 'Unnamed: 148'),(depositos_04['myVarname'] == 'Unnamed: 149'),(depositos_04['myVarname'] == 'Unnamed: 150'),(depositos_04['myVarname'] == 'Unnamed: 151'),
                              (depositos_04['myVarname'] == 'Unnamed: 152'),(depositos_04['myVarname'] == 'Unnamed: 153'),(depositos_04['myVarname'] == 'Unnamed: 154'),(depositos_04['myVarname'] == 'Unnamed: 155'),(depositos_04['myVarname'] == 'Unnamed: 156'),
                               (depositos_04['myVarname'] == 'Unnamed: 157'),(depositos_04['myVarname'] == 'Unnamed: 158'),(depositos_04['myVarname'] == 'Unnamed: 159'),(depositos_04['myVarname'] == 'Unnamed: 160'),(depositos_04['myVarname'] == 'Unnamed: 161'),
                                (depositos_04['myVarname'] == 'Unnamed: 162'),(depositos_04['myVarname'] == 'Unnamed: 163'),(depositos_04['myVarname'] == 'Unnamed: 164'),(depositos_04['myVarname'] == 'Unnamed: 165'),(depositos_04['myVarname'] == 'Unnamed: 166')
                                ]

# %%
depositos_04['Fecha'] = np.select(conditions_4, values)

# %%
depositos_04
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#               Valor       Fecha
# 5           1395965  2008-01-31
# 6                ND  2008-01-31
# 7             44548  2008-01-31
# 8           6937225  2008-01-31
# ...

# %%
depositos_04.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
depositos_04.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
depositos_04
# Out:
#                                       Institucion            Valor       Fecha
# 5                                      Banco Bice          1395965  2008-01-31
# 6                     Banco BTG Pactual Chile (9)               ND  2008-01-31
# 7                             Banco Consorcio (1)            44548  2008-01-31
# 8                              Banco de Chile (2)          6937225  2008-01-31
# 9                  Banco de Crédito e Inversiones          4406585  2008-01-31
# ..                                            ...              ...         ...
# 26                     JP Morgan Chase Bank, N.A.     60037.596601  2021-09-30
# 27                            Rabobank Chile (15)               ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)  11894127.691579  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)               ND  2021-09-30
# 30                             Bank of China (16)                0  2021-09-30
#
# [4290 rows x 3 columns]

# %%
depositos_04['Tipo'] = "Depósito"
depositos_04['Subtipo'] = "Depósitos a más de un mes"
depositos_04['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
depositos_04.head(5)
# Out:
#                       Institucion    Valor       Fecha      Tipo  \
# 5                      Banco Bice  1395965  2008-01-31  Depósito
# 6     Banco BTG Pactual Chile (9)       ND  2008-01-31  Depósito
# 7             Banco Consorcio (1)    44548  2008-01-31  Depósito
# 8              Banco de Chile (2)  6937225  2008-01-31  Depósito
# 9  Banco de Crédito e Inversiones  4406585  2008-01-31  Depósito
#
#                      Subtipo               Tipo de Moneda
# 5  Depósitos a más de un mes  Saldos en millones de pesos
# 6  Depósitos a más de un mes  Saldos en millones de pesos
# 7  Depósitos a más de un mes  Saldos en millones de pesos
# 8  Depósitos a más de un mes  Saldos en millones de pesos
# 9  Depósitos a más de un mes  Saldos en millones de pesos

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
depositos_04 = depositos_04.reindex(columns=new_cols)

# %%
depositos_04.head(5)
# Out:
#         Fecha                     Institucion      Tipo  \
# 5  2008-01-31                      Banco Bice  Depósito
# 6  2008-01-31     Banco BTG Pactual Chile (9)  Depósito
# 7  2008-01-31             Banco Consorcio (1)  Depósito
# 8  2008-01-31              Banco de Chile (2)  Depósito
# 9  2008-01-31  Banco de Crédito e Inversiones  Depósito
#
#                      Subtipo    Valor               Tipo de Moneda
# 5  Depósitos a más de un mes  1395965  Saldos en millones de pesos
# 6  Depósitos a más de un mes       ND  Saldos en millones de pesos
# 7  Depósitos a más de un mes    44548  Saldos en millones de pesos
# 8  Depósitos a más de un mes  6937225  Saldos en millones de pesos
# 9  Depósitos a más de un mes  4406585  Saldos en millones de pesos

# %% [markdown]
# ## Depósito 05

# %%
depositos_05.head(5)
# Out:
#         Unnamed: 0                                  Unnamed: 1  \
# 0   Índice general                                 Cuadro 2.05
# 1  Notas generales  Ventas de títulos con pacto de retrocompra
# 2              NaN                 Saldos en millones de pesos
# 3              NaN                                         NaN
# 4              NaN                                         NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
depositos_05.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
depositos_05.head(7)
# Out:
#                                    Unnamed: 1           Unnamed: 2  \
# 0                                 Cuadro 2.05                  NaN
# 1  Ventas de títulos con pacto de retrocompra                  NaN
# 2                 Saldos en millones de pesos                  NaN
# 3                                         NaN                  NaN
# 4                                         NaN  2008-01-31 00:00:00
# 5                                  Banco Bice         12435.568209
# 6                 Banco BTG Pactual Chile (9)                   ND
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
# ...

# %%
depositos_05 = depositos_05.iloc[5:]

# %%
depositos_05.tail(7)
# Out:
#                                        Unnamed: 1     Unnamed: 2  \
# 28                      Scotiabank Chile (3) (17)    1467.863802
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)     2596.94476
# 30                             Bank of China (16)             ND
# 31                                          Total  675254.461568
# 32                                            NaN            NaN
# 33                                            NaN            NaN
# 34                            ND : No existe dato            NaN
#
#        Unnamed: 3     Unnamed: 4     Unnamed: 5     Unnamed: 6    Unnamed: 7  \
# 28   12359.252272   19181.892183    29421.55381   29355.015279  10399.947538
# 29    3354.853304    2524.062719     1380.55934              0   1388.530986
# 30             ND             ND             ND             ND            ND
# 31  445687.096637  557029.910554  869813.160468  927514.167402  582383.61821
# ...

# %%
depositos_05.drop(depositos_05.tail(4).index,inplace=True)

# %%
depositos_05.head(3)
# Out:
#                     Unnamed: 1    Unnamed: 2   Unnamed: 3    Unnamed: 4  \
# 5                   Banco Bice  12435.568209  14199.12428  11233.769121
# 6  Banco BTG Pactual Chile (9)            ND           ND            ND
# 7          Banco Consorcio (1)            50     39.89463    251.031596
#
#      Unnamed: 5   Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  \
# 5  17414.870202  4940.309217  20706.667967  10158.459678  18690.077914
# 6            ND           ND            ND            ND            ND
# 7       150.159   877.550185  21000.196908     48.144365   1880.499132
#
#     Unnamed: 10  ...  Unnamed: 157  Unnamed: 158  Unnamed: 159 Unnamed: 160  \
# 5  12422.282014  ...  35795.954533    53442.1376     1635.0654            0
# 6            ND  ...    999.906155             0  19999.200037  2049.877007
# 7   4379.459566  ...  69382.936548  69212.496601  79239.596285  99931.18493
#
#    Unnamed: 161 Unnamed: 162  Unnamed: 163  Unnamed: 164  Unnamed: 165  \
# ...

# %%
depositos_05 = depositos_05.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
depositos_05
# Out:
#                                        Unnamed: 1     myVarname          Valor
# 5                                      Banco Bice    Unnamed: 2   12435.568209
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2             ND
# 7                             Banco Consorcio (1)    Unnamed: 2             50
# 8                              Banco de Chile (2)    Unnamed: 2   77540.383926
# 9                  Banco de Crédito e Inversiones    Unnamed: 2  101799.791935
# ..                                            ...           ...            ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166              0
# 27                            Rabobank Chile (15)  Unnamed: 166             ND
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166   88001.140088
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166             ND
# 30                             Bank of China (16)  Unnamed: 166              0
#
# [4290 rows x 3 columns]

# %%
# create a list of our conditions
conditions_5 = [(depositos_05['myVarname'] == 'Unnamed: 2'),(depositos_05['myVarname'] == 'Unnamed: 3'),(depositos_05['myVarname'] == 'Unnamed: 4'),(depositos_05['myVarname'] == 'Unnamed: 5'),(depositos_05['myVarname'] == 'Unnamed: 6'),
 (depositos_05['myVarname'] == 'Unnamed: 7'),(depositos_05['myVarname'] == 'Unnamed: 8'),(depositos_05['myVarname'] == 'Unnamed: 9'),(depositos_05['myVarname'] == 'Unnamed: 10'),(depositos_05['myVarname'] == 'Unnamed: 11'),
  (depositos_05['myVarname'] == 'Unnamed: 12'),(depositos_05['myVarname'] == 'Unnamed: 13'),(depositos_05['myVarname'] == 'Unnamed: 14'),(depositos_05['myVarname'] == 'Unnamed: 15'),(depositos_05['myVarname'] == 'Unnamed: 16'),
   (depositos_05['myVarname'] == 'Unnamed: 17'),(depositos_05['myVarname'] == 'Unnamed: 18'),(depositos_05['myVarname'] == 'Unnamed: 19'),(depositos_05['myVarname'] == 'Unnamed: 20'),(depositos_05['myVarname'] == 'Unnamed: 21'),
    (depositos_05['myVarname'] == 'Unnamed: 22'),(depositos_05['myVarname'] == 'Unnamed: 23'),(depositos_05['myVarname'] == 'Unnamed: 24'),(depositos_05['myVarname'] == 'Unnamed: 25'),(depositos_05['myVarname'] == 'Unnamed: 26'),
     (depositos_05['myVarname'] == 'Unnamed: 27'),(depositos_05['myVarname'] == 'Unnamed: 28'),(depositos_05['myVarname'] == 'Unnamed: 29'),(depositos_05['myVarname'] == 'Unnamed: 30'),(depositos_05['myVarname'] == 'Unnamed: 31'),
      (depositos_05['myVarname'] == 'Unnamed: 32'),(depositos_05['myVarname'] == 'Unnamed: 33'),(depositos_05['myVarname'] == 'Unnamed: 34'),(depositos_05['myVarname'] == 'Unnamed: 35'),(depositos_05['myVarname'] == 'Unnamed: 36'),
       (depositos_05['myVarname'] == 'Unnamed: 37'),(depositos_05['myVarname'] == 'Unnamed: 38'),(depositos_05['myVarname'] == 'Unnamed: 39'),(depositos_05['myVarname'] == 'Unnamed: 40'),(depositos_05['myVarname'] == 'Unnamed: 41'),
        (depositos_05['myVarname'] == 'Unnamed: 42'),(depositos_05['myVarname'] == 'Unnamed: 43'),(depositos_05['myVarname'] == 'Unnamed: 44'),(depositos_05['myVarname'] == 'Unnamed: 45'),(depositos_05['myVarname'] == 'Unnamed: 46'),
         (depositos_05['myVarname'] == 'Unnamed: 47'),(depositos_05['myVarname'] == 'Unnamed: 48'),(depositos_05['myVarname'] == 'Unnamed: 49'),(depositos_05['myVarname'] == 'Unnamed: 50'),(depositos_05['myVarname'] == 'Unnamed: 51'),
          (depositos_05['myVarname'] == 'Unnamed: 52'),(depositos_05['myVarname'] == 'Unnamed: 53'),(depositos_05['myVarname'] == 'Unnamed: 54'),(depositos_05['myVarname'] == 'Unnamed: 55'),(depositos_05['myVarname'] == 'Unnamed: 56'),
           (depositos_05['myVarname'] == 'Unnamed: 57'),(depositos_05['myVarname'] == 'Unnamed: 58'),(depositos_05['myVarname'] == 'Unnamed: 59'),(depositos_05['myVarname'] == 'Unnamed: 60'),(depositos_05['myVarname'] == 'Unnamed: 61'),
            (depositos_05['myVarname'] == 'Unnamed: 62'),(depositos_05['myVarname'] == 'Unnamed: 63'),(depositos_05['myVarname'] == 'Unnamed: 64'),(depositos_05['myVarname'] == 'Unnamed: 65'),(depositos_05['myVarname'] == 'Unnamed: 66'),
             (depositos_05['myVarname'] == 'Unnamed: 67'),(depositos_05['myVarname'] == 'Unnamed: 68'),(depositos_05['myVarname'] == 'Unnamed: 69'),(depositos_05['myVarname'] == 'Unnamed: 70'),(depositos_05['myVarname'] == 'Unnamed: 71'),
              (depositos_05['myVarname'] == 'Unnamed: 72'),(depositos_05['myVarname'] == 'Unnamed: 73'),(depositos_05['myVarname'] == 'Unnamed: 74'),(depositos_05['myVarname'] == 'Unnamed: 75'),(depositos_05['myVarname'] == 'Unnamed: 76'),
               (depositos_05['myVarname'] == 'Unnamed: 77'),(depositos_05['myVarname'] == 'Unnamed: 78'),(depositos_05['myVarname'] == 'Unnamed: 79'),(depositos_05['myVarname'] == 'Unnamed: 80'),(depositos_05['myVarname'] == 'Unnamed: 81'),
                (depositos_05['myVarname'] == 'Unnamed: 82'),(depositos_05['myVarname'] == 'Unnamed: 83'),(depositos_05['myVarname'] == 'Unnamed: 84'),(depositos_05['myVarname'] == 'Unnamed: 85'),(depositos_05['myVarname'] == 'Unnamed: 86'),
                 (depositos_05['myVarname'] == 'Unnamed: 87'),(depositos_05['myVarname'] == 'Unnamed: 88'),(depositos_05['myVarname'] == 'Unnamed: 89'),(depositos_05['myVarname'] == 'Unnamed: 90'),(depositos_05['myVarname'] == 'Unnamed: 91'),
                  (depositos_05['myVarname'] == 'Unnamed: 92'),(depositos_05['myVarname'] == 'Unnamed: 93'),(depositos_05['myVarname'] == 'Unnamed: 94'),(depositos_05['myVarname'] == 'Unnamed: 95'),(depositos_05['myVarname'] == 'Unnamed: 96'),
                   (depositos_05['myVarname'] == 'Unnamed: 97'),(depositos_05['myVarname'] == 'Unnamed: 98'),(depositos_05['myVarname'] == 'Unnamed: 99'),(depositos_05['myVarname'] == 'Unnamed: 100'),(depositos_05['myVarname'] == 'Unnamed: 101'),
                    (depositos_05['myVarname'] == 'Unnamed: 102'),(depositos_05['myVarname'] == 'Unnamed: 103'),(depositos_05['myVarname'] == 'Unnamed: 104'),(depositos_05['myVarname'] == 'Unnamed: 105'),(depositos_05['myVarname'] == 'Unnamed: 106'),
                     (depositos_05['myVarname'] == 'Unnamed: 107'),(depositos_05['myVarname'] == 'Unnamed: 108'),(depositos_05['myVarname'] == 'Unnamed: 109'),(depositos_05['myVarname'] == 'Unnamed: 110'),(depositos_05['myVarname'] == 'Unnamed: 111'),
                      (depositos_05['myVarname'] == 'Unnamed: 112'),(depositos_05['myVarname'] == 'Unnamed: 113'),(depositos_05['myVarname'] == 'Unnamed: 114'),(depositos_05['myVarname'] == 'Unnamed: 115'),(depositos_05['myVarname'] == 'Unnamed: 116'),
                       (depositos_05['myVarname'] == 'Unnamed: 117'),(depositos_05['myVarname'] == 'Unnamed: 118'),(depositos_05['myVarname'] == 'Unnamed: 119'),(depositos_05['myVarname'] == 'Unnamed: 120'),(depositos_05['myVarname'] == 'Unnamed: 121'),
                        (depositos_05['myVarname'] == 'Unnamed: 122'),(depositos_05['myVarname'] == 'Unnamed: 123'),(depositos_05['myVarname'] == 'Unnamed: 124'),(depositos_05['myVarname'] == 'Unnamed: 125'),(depositos_05['myVarname'] == 'Unnamed: 126'),
                         (depositos_05['myVarname'] == 'Unnamed: 127'),(depositos_05['myVarname'] == 'Unnamed: 128'),(depositos_05['myVarname'] == 'Unnamed: 129'),(depositos_05['myVarname'] == 'Unnamed: 130'),(depositos_05['myVarname'] == 'Unnamed: 131'),
                          (depositos_05['myVarname'] == 'Unnamed: 132'),(depositos_05['myVarname'] == 'Unnamed: 133'),(depositos_05['myVarname'] == 'Unnamed: 134'),(depositos_05['myVarname'] == 'Unnamed: 135'),(depositos_05['myVarname'] == 'Unnamed: 136'),
                           (depositos_05['myVarname'] == 'Unnamed: 137'),(depositos_05['myVarname'] == 'Unnamed: 138'),(depositos_05['myVarname'] == 'Unnamed: 139'),(depositos_05['myVarname'] == 'Unnamed: 140'),(depositos_05['myVarname'] == 'Unnamed: 141'),
                            (depositos_05['myVarname'] == 'Unnamed: 142'),(depositos_05['myVarname'] == 'Unnamed: 143'),(depositos_05['myVarname'] == 'Unnamed: 144'),(depositos_05['myVarname'] == 'Unnamed: 145'),(depositos_05['myVarname'] == 'Unnamed: 146'),
                             (depositos_05['myVarname'] == 'Unnamed: 147'),(depositos_05['myVarname'] == 'Unnamed: 148'),(depositos_05['myVarname'] == 'Unnamed: 149'),(depositos_05['myVarname'] == 'Unnamed: 150'),(depositos_05['myVarname'] == 'Unnamed: 151'),
                              (depositos_05['myVarname'] == 'Unnamed: 152'),(depositos_05['myVarname'] == 'Unnamed: 153'),(depositos_05['myVarname'] == 'Unnamed: 154'),(depositos_05['myVarname'] == 'Unnamed: 155'),(depositos_05['myVarname'] == 'Unnamed: 156'),
                               (depositos_05['myVarname'] == 'Unnamed: 157'),(depositos_05['myVarname'] == 'Unnamed: 158'),(depositos_05['myVarname'] == 'Unnamed: 159'),(depositos_05['myVarname'] == 'Unnamed: 160'),(depositos_05['myVarname'] == 'Unnamed: 161'),
                                (depositos_05['myVarname'] == 'Unnamed: 162'),(depositos_05['myVarname'] == 'Unnamed: 163'),(depositos_05['myVarname'] == 'Unnamed: 164'),(depositos_05['myVarname'] == 'Unnamed: 165'),(depositos_05['myVarname'] == 'Unnamed: 166')
                                ]

# %%
depositos_05['Fecha'] = np.select(conditions_5, values)

# %%
depositos_05
# Out:
#                                        Unnamed: 1     myVarname  \
# 5                                      Banco Bice    Unnamed: 2
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2
# 7                             Banco Consorcio (1)    Unnamed: 2
# 8                              Banco de Chile (2)    Unnamed: 2
# 9                  Banco de Crédito e Inversiones    Unnamed: 2
# ..                                            ...           ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166
# 27                            Rabobank Chile (15)  Unnamed: 166
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166
# 30                             Bank of China (16)  Unnamed: 166
#
#             Valor       Fecha
# 5    12435.568209  2008-01-31
# 6              ND  2008-01-31
# 7              50  2008-01-31
# 8    77540.383926  2008-01-31
# 9   101799.791935  2008-01-31
# ...

# %%
depositos_05.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
depositos_05.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
depositos_05
# Out:
#                                       Institucion          Valor       Fecha
# 5                                      Banco Bice   12435.568209  2008-01-31
# 6                     Banco BTG Pactual Chile (9)             ND  2008-01-31
# 7                             Banco Consorcio (1)             50  2008-01-31
# 8                              Banco de Chile (2)   77540.383926  2008-01-31
# 9                  Banco de Crédito e Inversiones  101799.791935  2008-01-31
# ..                                            ...            ...         ...
# 26                     JP Morgan Chase Bank, N.A.              0  2021-09-30
# 27                            Rabobank Chile (15)             ND  2021-09-30
# 28                      Scotiabank Chile (3) (17)   88001.140088  2021-09-30
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)             ND  2021-09-30
# 30                             Bank of China (16)              0  2021-09-30
#
# [4290 rows x 3 columns]

# %%
depositos_05['Tipo'] = "Depósito"
depositos_05['Subtipo'] = "Ventas de títulos con pacto de retrocompra"
depositos_05['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
depositos_05.head(5)
# Out:
#                       Institucion          Valor       Fecha      Tipo  \
# 5                      Banco Bice   12435.568209  2008-01-31  Depósito
# 6     Banco BTG Pactual Chile (9)             ND  2008-01-31  Depósito
# 7             Banco Consorcio (1)             50  2008-01-31  Depósito
# 8              Banco de Chile (2)   77540.383926  2008-01-31  Depósito
# 9  Banco de Crédito e Inversiones  101799.791935  2008-01-31  Depósito
#
#                                       Subtipo               Tipo de Moneda
# 5  Ventas de títulos con pacto de retrocompra  Saldos en millones de pesos
# 6  Ventas de títulos con pacto de retrocompra  Saldos en millones de pesos
# 7  Ventas de títulos con pacto de retrocompra  Saldos en millones de pesos
# 8  Ventas de títulos con pacto de retrocompra  Saldos en millones de pesos
# 9  Ventas de títulos con pacto de retrocompra  Saldos en millones de pesos

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
depositos_05 = depositos_05.reindex(columns=new_cols)

# %%
depositos_05.head(7)
# Out:
#          Fecha                        Institucion      Tipo  \
# 5   2008-01-31                         Banco Bice  Depósito
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Depósito
# 7   2008-01-31                Banco Consorcio (1)  Depósito
# 8   2008-01-31                 Banco de Chile (2)  Depósito
# 9   2008-01-31     Banco de Crédito e Inversiones  Depósito
# 10  2008-01-31  Banco de la Nación Argentina (18)  Depósito
# 11  2008-01-31          Banco del Estado de Chile  Depósito
#
#                                        Subtipo          Valor  \
# 5   Ventas de títulos con pacto de retrocompra   12435.568209
# 6   Ventas de títulos con pacto de retrocompra             ND
# 7   Ventas de títulos con pacto de retrocompra             50
# 8   Ventas de títulos con pacto de retrocompra   77540.383926
# 9   Ventas de títulos con pacto de retrocompra  101799.791935
# 10  Ventas de títulos con pacto de retrocompra              0
# ...

# %% [markdown]
# ## Depósito 06

# %%
depositos_06.head(5)
# Out:
#         Unnamed: 0                         Unnamed: 1           Unnamed: 2  \
# 0   Índice general                        Cuadro 2.06                  NaN
# 1  Notas generales  Obligaciones en letras de crédito                  NaN
# 2              NaN        Saldos en millones de pesos                  NaN
# 3              NaN                                NaN                  NaN
# 4              NaN                                NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# ...

# %%
depositos_06.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
depositos_06.head(7)
# Out:
#                           Unnamed: 1           Unnamed: 2  \
# 0                        Cuadro 2.06                  NaN
# 1  Obligaciones en letras de crédito                  NaN
# 2        Saldos en millones de pesos                  NaN
# 3                                NaN                  NaN
# 4                                NaN  2008-01-31 00:00:00
# 5                         Banco Bice         52593.689785
# 6        Banco BTG Pactual Chile (9)                   ND
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
# 5         52261.751638          52016.51531         50851.110706
# ...

# %%
depositos_06 = depositos_06.iloc[5:]

# %%
depositos_06.tail(7)
# Out:
#                                        Unnamed: 1      Unnamed: 2  \
# 28                      Scotiabank Chile (3) (17)    708035.97998
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)               0
# 30                             Bank of China (16)              ND
# 31                                          Total  4574803.714321
# 32                                            NaN             NaN
# 33                                            NaN             NaN
# 34                            ND : No existe dato             NaN
#
#        Unnamed: 3      Unnamed: 4      Unnamed: 5      Unnamed: 6  \
# 28  714354.741612   717056.326274    717171.56959   729527.249966
# 29              0               0               0               0
# 30             ND              ND              ND              ND
# 31  4589191.97081  4609910.956336  4484753.717555  4524163.655576
# 32            NaN             NaN             NaN             NaN
# ...

# %%
depositos_06.drop(depositos_06.tail(4).index,inplace=True)

# %%
depositos_06.head(3)
# Out:
#                     Unnamed: 1    Unnamed: 2    Unnamed: 3   Unnamed: 4  \
# 5                   Banco Bice  52593.689785  52261.751638  52016.51531
# 6  Banco BTG Pactual Chile (9)            ND            ND           ND
# 7          Banco Consorcio (1)             0             0            0
#
#      Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  \
# 5  50851.110706  50936.185703  49856.263963  39033.613936  38996.803082
# 6            ND            ND            ND            ND            ND
# 7             0             0             0             0             0
#
#     Unnamed: 10  ... Unnamed: 157 Unnamed: 158 Unnamed: 159 Unnamed: 160  \
# 5  39261.965786  ...   863.458762   814.787191   809.516508   812.798832
# 6            ND  ...            0            0            0            0
# 7             0  ...            0            0            0            0
#
#   Unnamed: 161 Unnamed: 162 Unnamed: 163 Unnamed: 164 Unnamed: 165  \
# ...

# %%
depositos_06 = depositos_06.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
depositos_06
# Out:
#                                        Unnamed: 1     myVarname          Valor
# 5                                      Banco Bice    Unnamed: 2   52593.689785
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2             ND
# 7                             Banco Consorcio (1)    Unnamed: 2              0
# 8                              Banco de Chile (2)    Unnamed: 2  405710.335734
# 9                  Banco de Crédito e Inversiones    Unnamed: 2  226245.332131
# ..                                            ...           ...            ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166              0
# 27                            Rabobank Chile (15)  Unnamed: 166             ND
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166  109393.459184
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166             ND
# 30                             Bank of China (16)  Unnamed: 166              0
#
# [4290 rows x 3 columns]

# %%
# create a list of our conditions
conditions_6 = [(depositos_06['myVarname'] == 'Unnamed: 2'),(depositos_06['myVarname'] == 'Unnamed: 3'),(depositos_06['myVarname'] == 'Unnamed: 4'),(depositos_06['myVarname'] == 'Unnamed: 5'),(depositos_06['myVarname'] == 'Unnamed: 6'),
 (depositos_06['myVarname'] == 'Unnamed: 7'),(depositos_06['myVarname'] == 'Unnamed: 8'),(depositos_06['myVarname'] == 'Unnamed: 9'),(depositos_06['myVarname'] == 'Unnamed: 10'),(depositos_06['myVarname'] == 'Unnamed: 11'),
  (depositos_06['myVarname'] == 'Unnamed: 12'),(depositos_06['myVarname'] == 'Unnamed: 13'),(depositos_06['myVarname'] == 'Unnamed: 14'),(depositos_06['myVarname'] == 'Unnamed: 15'),(depositos_06['myVarname'] == 'Unnamed: 16'),
   (depositos_06['myVarname'] == 'Unnamed: 17'),(depositos_06['myVarname'] == 'Unnamed: 18'),(depositos_06['myVarname'] == 'Unnamed: 19'),(depositos_06['myVarname'] == 'Unnamed: 20'),(depositos_06['myVarname'] == 'Unnamed: 21'),
    (depositos_06['myVarname'] == 'Unnamed: 22'),(depositos_06['myVarname'] == 'Unnamed: 23'),(depositos_06['myVarname'] == 'Unnamed: 24'),(depositos_06['myVarname'] == 'Unnamed: 25'),(depositos_06['myVarname'] == 'Unnamed: 26'),
     (depositos_06['myVarname'] == 'Unnamed: 27'),(depositos_06['myVarname'] == 'Unnamed: 28'),(depositos_06['myVarname'] == 'Unnamed: 29'),(depositos_06['myVarname'] == 'Unnamed: 30'),(depositos_06['myVarname'] == 'Unnamed: 31'),
      (depositos_06['myVarname'] == 'Unnamed: 32'),(depositos_06['myVarname'] == 'Unnamed: 33'),(depositos_06['myVarname'] == 'Unnamed: 34'),(depositos_06['myVarname'] == 'Unnamed: 35'),(depositos_06['myVarname'] == 'Unnamed: 36'),
       (depositos_06['myVarname'] == 'Unnamed: 37'),(depositos_06['myVarname'] == 'Unnamed: 38'),(depositos_06['myVarname'] == 'Unnamed: 39'),(depositos_06['myVarname'] == 'Unnamed: 40'),(depositos_06['myVarname'] == 'Unnamed: 41'),
        (depositos_06['myVarname'] == 'Unnamed: 42'),(depositos_06['myVarname'] == 'Unnamed: 43'),(depositos_06['myVarname'] == 'Unnamed: 44'),(depositos_06['myVarname'] == 'Unnamed: 45'),(depositos_06['myVarname'] == 'Unnamed: 46'),
         (depositos_06['myVarname'] == 'Unnamed: 47'),(depositos_06['myVarname'] == 'Unnamed: 48'),(depositos_06['myVarname'] == 'Unnamed: 49'),(depositos_06['myVarname'] == 'Unnamed: 50'),(depositos_06['myVarname'] == 'Unnamed: 51'),
          (depositos_06['myVarname'] == 'Unnamed: 52'),(depositos_06['myVarname'] == 'Unnamed: 53'),(depositos_06['myVarname'] == 'Unnamed: 54'),(depositos_06['myVarname'] == 'Unnamed: 55'),(depositos_06['myVarname'] == 'Unnamed: 56'),
           (depositos_06['myVarname'] == 'Unnamed: 57'),(depositos_06['myVarname'] == 'Unnamed: 58'),(depositos_06['myVarname'] == 'Unnamed: 59'),(depositos_06['myVarname'] == 'Unnamed: 60'),(depositos_06['myVarname'] == 'Unnamed: 61'),
            (depositos_06['myVarname'] == 'Unnamed: 62'),(depositos_06['myVarname'] == 'Unnamed: 63'),(depositos_06['myVarname'] == 'Unnamed: 64'),(depositos_06['myVarname'] == 'Unnamed: 65'),(depositos_06['myVarname'] == 'Unnamed: 66'),
             (depositos_06['myVarname'] == 'Unnamed: 67'),(depositos_06['myVarname'] == 'Unnamed: 68'),(depositos_06['myVarname'] == 'Unnamed: 69'),(depositos_06['myVarname'] == 'Unnamed: 70'),(depositos_06['myVarname'] == 'Unnamed: 71'),
              (depositos_06['myVarname'] == 'Unnamed: 72'),(depositos_06['myVarname'] == 'Unnamed: 73'),(depositos_06['myVarname'] == 'Unnamed: 74'),(depositos_06['myVarname'] == 'Unnamed: 75'),(depositos_06['myVarname'] == 'Unnamed: 76'),
               (depositos_06['myVarname'] == 'Unnamed: 77'),(depositos_06['myVarname'] == 'Unnamed: 78'),(depositos_06['myVarname'] == 'Unnamed: 79'),(depositos_06['myVarname'] == 'Unnamed: 80'),(depositos_06['myVarname'] == 'Unnamed: 81'),
                (depositos_06['myVarname'] == 'Unnamed: 82'),(depositos_06['myVarname'] == 'Unnamed: 83'),(depositos_06['myVarname'] == 'Unnamed: 84'),(depositos_06['myVarname'] == 'Unnamed: 85'),(depositos_06['myVarname'] == 'Unnamed: 86'),
                 (depositos_06['myVarname'] == 'Unnamed: 87'),(depositos_06['myVarname'] == 'Unnamed: 88'),(depositos_06['myVarname'] == 'Unnamed: 89'),(depositos_06['myVarname'] == 'Unnamed: 90'),(depositos_06['myVarname'] == 'Unnamed: 91'),
                  (depositos_06['myVarname'] == 'Unnamed: 92'),(depositos_06['myVarname'] == 'Unnamed: 93'),(depositos_06['myVarname'] == 'Unnamed: 94'),(depositos_06['myVarname'] == 'Unnamed: 95'),(depositos_06['myVarname'] == 'Unnamed: 96'),
                   (depositos_06['myVarname'] == 'Unnamed: 97'),(depositos_06['myVarname'] == 'Unnamed: 98'),(depositos_06['myVarname'] == 'Unnamed: 99'),(depositos_06['myVarname'] == 'Unnamed: 100'),(depositos_06['myVarname'] == 'Unnamed: 101'),
                    (depositos_06['myVarname'] == 'Unnamed: 102'),(depositos_06['myVarname'] == 'Unnamed: 103'),(depositos_06['myVarname'] == 'Unnamed: 104'),(depositos_06['myVarname'] == 'Unnamed: 105'),(depositos_06['myVarname'] == 'Unnamed: 106'),
                     (depositos_06['myVarname'] == 'Unnamed: 107'),(depositos_06['myVarname'] == 'Unnamed: 108'),(depositos_06['myVarname'] == 'Unnamed: 109'),(depositos_06['myVarname'] == 'Unnamed: 110'),(depositos_06['myVarname'] == 'Unnamed: 111'),
                      (depositos_06['myVarname'] == 'Unnamed: 112'),(depositos_06['myVarname'] == 'Unnamed: 113'),(depositos_06['myVarname'] == 'Unnamed: 114'),(depositos_06['myVarname'] == 'Unnamed: 115'),(depositos_06['myVarname'] == 'Unnamed: 116'),
                       (depositos_06['myVarname'] == 'Unnamed: 117'),(depositos_06['myVarname'] == 'Unnamed: 118'),(depositos_06['myVarname'] == 'Unnamed: 119'),(depositos_06['myVarname'] == 'Unnamed: 120'),(depositos_06['myVarname'] == 'Unnamed: 121'),
                        (depositos_06['myVarname'] == 'Unnamed: 122'),(depositos_06['myVarname'] == 'Unnamed: 123'),(depositos_06['myVarname'] == 'Unnamed: 124'),(depositos_06['myVarname'] == 'Unnamed: 125'),(depositos_06['myVarname'] == 'Unnamed: 126'),
                         (depositos_06['myVarname'] == 'Unnamed: 127'),(depositos_06['myVarname'] == 'Unnamed: 128'),(depositos_06['myVarname'] == 'Unnamed: 129'),(depositos_06['myVarname'] == 'Unnamed: 130'),(depositos_06['myVarname'] == 'Unnamed: 131'),
                          (depositos_06['myVarname'] == 'Unnamed: 132'),(depositos_06['myVarname'] == 'Unnamed: 133'),(depositos_06['myVarname'] == 'Unnamed: 134'),(depositos_06['myVarname'] == 'Unnamed: 135'),(depositos_06['myVarname'] == 'Unnamed: 136'),
                           (depositos_06['myVarname'] == 'Unnamed: 137'),(depositos_06['myVarname'] == 'Unnamed: 138'),(depositos_06['myVarname'] == 'Unnamed: 139'),(depositos_06['myVarname'] == 'Unnamed: 140'),(depositos_06['myVarname'] == 'Unnamed: 141'),
                            (depositos_06['myVarname'] == 'Unnamed: 142'),(depositos_06['myVarname'] == 'Unnamed: 143'),(depositos_06['myVarname'] == 'Unnamed: 144'),(depositos_06['myVarname'] == 'Unnamed: 145'),(depositos_06['myVarname'] == 'Unnamed: 146'),
                             (depositos_06['myVarname'] == 'Unnamed: 147'),(depositos_06['myVarname'] == 'Unnamed: 148'),(depositos_06['myVarname'] == 'Unnamed: 149'),(depositos_06['myVarname'] == 'Unnamed: 150'),(depositos_06['myVarname'] == 'Unnamed: 151'),
                              (depositos_06['myVarname'] == 'Unnamed: 152'),(depositos_06['myVarname'] == 'Unnamed: 153'),(depositos_06['myVarname'] == 'Unnamed: 154'),(depositos_06['myVarname'] == 'Unnamed: 155'),(depositos_06['myVarname'] == 'Unnamed: 156'),
                               (depositos_06['myVarname'] == 'Unnamed: 157'),(depositos_06['myVarname'] == 'Unnamed: 158'),(depositos_06['myVarname'] == 'Unnamed: 159'),(depositos_06['myVarname'] == 'Unnamed: 160'),(depositos_06['myVarname'] == 'Unnamed: 161'),
                                (depositos_06['myVarname'] == 'Unnamed: 162'),(depositos_06['myVarname'] == 'Unnamed: 163'),(depositos_06['myVarname'] == 'Unnamed: 164'),(depositos_06['myVarname'] == 'Unnamed: 165'),(depositos_06['myVarname'] == 'Unnamed: 166')
                                ]

# %%
depositos_06['Fecha'] = np.select(conditions_6, values)

# %%
depositos_06.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
depositos_06.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
depositos_06['Tipo'] = "Depósito"
depositos_06['Subtipo'] = "Obligaciones en letras de crédito"
depositos_06['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
depositos_06.head(5)
# Out:
#                       Institucion          Valor       Fecha      Tipo  \
# 5                      Banco Bice   52593.689785  2008-01-31  Depósito
# 6     Banco BTG Pactual Chile (9)             ND  2008-01-31  Depósito
# 7             Banco Consorcio (1)              0  2008-01-31  Depósito
# 8              Banco de Chile (2)  405710.335734  2008-01-31  Depósito
# 9  Banco de Crédito e Inversiones  226245.332131  2008-01-31  Depósito
#
#                              Subtipo               Tipo de Moneda
# 5  Obligaciones en letras de crédito  Saldos en millones de pesos
# 6  Obligaciones en letras de crédito  Saldos en millones de pesos
# 7  Obligaciones en letras de crédito  Saldos en millones de pesos
# 8  Obligaciones en letras de crédito  Saldos en millones de pesos
# 9  Obligaciones en letras de crédito  Saldos en millones de pesos

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
depositos_06 = depositos_06.reindex(columns=new_cols)

# %%
depositos_06.head(7)
# Out:
#          Fecha                        Institucion      Tipo  \
# 5   2008-01-31                         Banco Bice  Depósito
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Depósito
# 7   2008-01-31                Banco Consorcio (1)  Depósito
# 8   2008-01-31                 Banco de Chile (2)  Depósito
# 9   2008-01-31     Banco de Crédito e Inversiones  Depósito
# 10  2008-01-31  Banco de la Nación Argentina (18)  Depósito
# 11  2008-01-31          Banco del Estado de Chile  Depósito
#
#                               Subtipo           Valor  \
# 5   Obligaciones en letras de crédito    52593.689785
# 6   Obligaciones en letras de crédito              ND
# 7   Obligaciones en letras de crédito               0
# 8   Obligaciones en letras de crédito   405710.335734
# 9   Obligaciones en letras de crédito   226245.332131
# 10  Obligaciones en letras de crédito               0
# 11  Obligaciones en letras de crédito  2009193.575693
#
#                  Tipo de Moneda
# ...

# %% [markdown]
# ## Depósito 07

# %%
depositos_07.head(5)
# Out:
#         Unnamed: 0                            Unnamed: 1           Unnamed: 2  \
# 0   Índice general                           Cuadro 2.07                  NaN
# 1  Notas generales  Total depósitos en moneda extranjera                  NaN
# 2              NaN         Saldos en millones de dólares                  NaN
# 3              NaN                                   NaN                  NaN
# 4              NaN                                   NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# ...

# %%
depositos_07.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
depositos_07.head(7)
# Out:
#                              Unnamed: 1           Unnamed: 2  \
# 0                           Cuadro 2.07                  NaN
# 1  Total depósitos en moneda extranjera                  NaN
# 2         Saldos en millones de dólares                  NaN
# 3                                   NaN                  NaN
# 4                                   NaN  2008-01-31 00:00:00
# 5                            Banco Bice              187.862
# 6           Banco BTG Pactual Chile (9)                   ND
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
# 5              206.237              196.636              177.428
# ...

# %%
depositos_07 = depositos_07.iloc[5:]

# %%
depositos_07.tail(7)
# Out:
#                                        Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 28                      Scotiabank Chile (3) (17)    940.286    835.837
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)     87.011     91.798
# 30                             Bank of China (16)         ND         ND
# 31                                          Total  11794.215  11780.928
# 32                                            NaN        NaN        NaN
# 33                                            NaN        NaN        NaN
# 34                            ND : No existe dato        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 28    897.587     738.66    952.455   1087.514   1276.247   1441.695
# 29     65.405     73.235      77.88     76.513     99.132    110.533
# 30         ND         ND         ND         ND         ND         ND
# 31  12293.677  13257.389  13772.713    15208.4  16038.178  16277.716
# ...

# %%
depositos_07.drop(depositos_07.tail(4).index,inplace=True)
# Out:
# <ipython-input-299-e9adff5cf60b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   depositos_07.drop(depositos_07.tail(4).index,inplace=True)

# %%
depositos_07.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice    187.862    206.237    196.636    177.428
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)     10.771      9.598     18.549     19.987
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 157  \
# 5    195.294    214.293    254.027    283.658     327.843  ...  1329.846754
# 6         ND         ND         ND         ND          ND  ...    458.15382
# 7     23.997     24.864     26.873     15.864      15.386  ...   808.511252
#
#   Unnamed: 158 Unnamed: 159 Unnamed: 160 Unnamed: 161 Unnamed: 162  \
# 5   1186.93873  1317.395089  1266.149819  1422.233578  1505.186571
# 6   430.830742   493.087142    461.50322   550.341237   596.789234
# 7   871.817788   911.074533   892.403743   773.956613   814.526647
#
#   Unnamed: 163 Unnamed: 164 Unnamed: 165 Unnamed: 166
# ...

# %%
depositos_07 = depositos_07.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_7 = [(depositos_07['myVarname'] == 'Unnamed: 2'),(depositos_07['myVarname'] == 'Unnamed: 3'),(depositos_07['myVarname'] == 'Unnamed: 4'),(depositos_07['myVarname'] == 'Unnamed: 5'),(depositos_07['myVarname'] == 'Unnamed: 6'),
 (depositos_07['myVarname'] == 'Unnamed: 7'),(depositos_07['myVarname'] == 'Unnamed: 8'),(depositos_07['myVarname'] == 'Unnamed: 9'),(depositos_07['myVarname'] == 'Unnamed: 10'),(depositos_07['myVarname'] == 'Unnamed: 11'),
  (depositos_07['myVarname'] == 'Unnamed: 12'),(depositos_07['myVarname'] == 'Unnamed: 13'),(depositos_07['myVarname'] == 'Unnamed: 14'),(depositos_07['myVarname'] == 'Unnamed: 15'),(depositos_07['myVarname'] == 'Unnamed: 16'),
   (depositos_07['myVarname'] == 'Unnamed: 17'),(depositos_07['myVarname'] == 'Unnamed: 18'),(depositos_07['myVarname'] == 'Unnamed: 19'),(depositos_07['myVarname'] == 'Unnamed: 20'),(depositos_07['myVarname'] == 'Unnamed: 21'),
    (depositos_07['myVarname'] == 'Unnamed: 22'),(depositos_07['myVarname'] == 'Unnamed: 23'),(depositos_07['myVarname'] == 'Unnamed: 24'),(depositos_07['myVarname'] == 'Unnamed: 25'),(depositos_07['myVarname'] == 'Unnamed: 26'),
     (depositos_07['myVarname'] == 'Unnamed: 27'),(depositos_07['myVarname'] == 'Unnamed: 28'),(depositos_07['myVarname'] == 'Unnamed: 29'),(depositos_07['myVarname'] == 'Unnamed: 30'),(depositos_07['myVarname'] == 'Unnamed: 31'),
      (depositos_07['myVarname'] == 'Unnamed: 32'),(depositos_07['myVarname'] == 'Unnamed: 33'),(depositos_07['myVarname'] == 'Unnamed: 34'),(depositos_07['myVarname'] == 'Unnamed: 35'),(depositos_07['myVarname'] == 'Unnamed: 36'),
       (depositos_07['myVarname'] == 'Unnamed: 37'),(depositos_07['myVarname'] == 'Unnamed: 38'),(depositos_07['myVarname'] == 'Unnamed: 39'),(depositos_07['myVarname'] == 'Unnamed: 40'),(depositos_07['myVarname'] == 'Unnamed: 41'),
        (depositos_07['myVarname'] == 'Unnamed: 42'),(depositos_07['myVarname'] == 'Unnamed: 43'),(depositos_07['myVarname'] == 'Unnamed: 44'),(depositos_07['myVarname'] == 'Unnamed: 45'),(depositos_07['myVarname'] == 'Unnamed: 46'),
         (depositos_07['myVarname'] == 'Unnamed: 47'),(depositos_07['myVarname'] == 'Unnamed: 48'),(depositos_07['myVarname'] == 'Unnamed: 49'),(depositos_07['myVarname'] == 'Unnamed: 50'),(depositos_07['myVarname'] == 'Unnamed: 51'),
          (depositos_07['myVarname'] == 'Unnamed: 52'),(depositos_07['myVarname'] == 'Unnamed: 53'),(depositos_07['myVarname'] == 'Unnamed: 54'),(depositos_07['myVarname'] == 'Unnamed: 55'),(depositos_07['myVarname'] == 'Unnamed: 56'),
           (depositos_07['myVarname'] == 'Unnamed: 57'),(depositos_07['myVarname'] == 'Unnamed: 58'),(depositos_07['myVarname'] == 'Unnamed: 59'),(depositos_07['myVarname'] == 'Unnamed: 60'),(depositos_07['myVarname'] == 'Unnamed: 61'),
            (depositos_07['myVarname'] == 'Unnamed: 62'),(depositos_07['myVarname'] == 'Unnamed: 63'),(depositos_07['myVarname'] == 'Unnamed: 64'),(depositos_07['myVarname'] == 'Unnamed: 65'),(depositos_07['myVarname'] == 'Unnamed: 66'),
             (depositos_07['myVarname'] == 'Unnamed: 67'),(depositos_07['myVarname'] == 'Unnamed: 68'),(depositos_07['myVarname'] == 'Unnamed: 69'),(depositos_07['myVarname'] == 'Unnamed: 70'),(depositos_07['myVarname'] == 'Unnamed: 71'),
              (depositos_07['myVarname'] == 'Unnamed: 72'),(depositos_07['myVarname'] == 'Unnamed: 73'),(depositos_07['myVarname'] == 'Unnamed: 74'),(depositos_07['myVarname'] == 'Unnamed: 75'),(depositos_07['myVarname'] == 'Unnamed: 76'),
               (depositos_07['myVarname'] == 'Unnamed: 77'),(depositos_07['myVarname'] == 'Unnamed: 78'),(depositos_07['myVarname'] == 'Unnamed: 79'),(depositos_07['myVarname'] == 'Unnamed: 80'),(depositos_07['myVarname'] == 'Unnamed: 81'),
                (depositos_07['myVarname'] == 'Unnamed: 82'),(depositos_07['myVarname'] == 'Unnamed: 83'),(depositos_07['myVarname'] == 'Unnamed: 84'),(depositos_07['myVarname'] == 'Unnamed: 85'),(depositos_07['myVarname'] == 'Unnamed: 86'),
                 (depositos_07['myVarname'] == 'Unnamed: 87'),(depositos_07['myVarname'] == 'Unnamed: 88'),(depositos_07['myVarname'] == 'Unnamed: 89'),(depositos_07['myVarname'] == 'Unnamed: 90'),(depositos_07['myVarname'] == 'Unnamed: 91'),
                  (depositos_07['myVarname'] == 'Unnamed: 92'),(depositos_07['myVarname'] == 'Unnamed: 93'),(depositos_07['myVarname'] == 'Unnamed: 94'),(depositos_07['myVarname'] == 'Unnamed: 95'),(depositos_07['myVarname'] == 'Unnamed: 96'),
                   (depositos_07['myVarname'] == 'Unnamed: 97'),(depositos_07['myVarname'] == 'Unnamed: 98'),(depositos_07['myVarname'] == 'Unnamed: 99'),(depositos_07['myVarname'] == 'Unnamed: 100'),(depositos_07['myVarname'] == 'Unnamed: 101'),
                    (depositos_07['myVarname'] == 'Unnamed: 102'),(depositos_07['myVarname'] == 'Unnamed: 103'),(depositos_07['myVarname'] == 'Unnamed: 104'),(depositos_07['myVarname'] == 'Unnamed: 105'),(depositos_07['myVarname'] == 'Unnamed: 106'),
                     (depositos_07['myVarname'] == 'Unnamed: 107'),(depositos_07['myVarname'] == 'Unnamed: 108'),(depositos_07['myVarname'] == 'Unnamed: 109'),(depositos_07['myVarname'] == 'Unnamed: 110'),(depositos_07['myVarname'] == 'Unnamed: 111'),
                      (depositos_07['myVarname'] == 'Unnamed: 112'),(depositos_07['myVarname'] == 'Unnamed: 113'),(depositos_07['myVarname'] == 'Unnamed: 114'),(depositos_07['myVarname'] == 'Unnamed: 115'),(depositos_07['myVarname'] == 'Unnamed: 116'),
                       (depositos_07['myVarname'] == 'Unnamed: 117'),(depositos_07['myVarname'] == 'Unnamed: 118'),(depositos_07['myVarname'] == 'Unnamed: 119'),(depositos_07['myVarname'] == 'Unnamed: 120'),(depositos_07['myVarname'] == 'Unnamed: 121'),
                        (depositos_07['myVarname'] == 'Unnamed: 122'),(depositos_07['myVarname'] == 'Unnamed: 123'),(depositos_07['myVarname'] == 'Unnamed: 124'),(depositos_07['myVarname'] == 'Unnamed: 125'),(depositos_07['myVarname'] == 'Unnamed: 126'),
                         (depositos_07['myVarname'] == 'Unnamed: 127'),(depositos_07['myVarname'] == 'Unnamed: 128'),(depositos_07['myVarname'] == 'Unnamed: 129'),(depositos_07['myVarname'] == 'Unnamed: 130'),(depositos_07['myVarname'] == 'Unnamed: 131'),
                          (depositos_07['myVarname'] == 'Unnamed: 132'),(depositos_07['myVarname'] == 'Unnamed: 133'),(depositos_07['myVarname'] == 'Unnamed: 134'),(depositos_07['myVarname'] == 'Unnamed: 135'),(depositos_07['myVarname'] == 'Unnamed: 136'),
                           (depositos_07['myVarname'] == 'Unnamed: 137'),(depositos_07['myVarname'] == 'Unnamed: 138'),(depositos_07['myVarname'] == 'Unnamed: 139'),(depositos_07['myVarname'] == 'Unnamed: 140'),(depositos_07['myVarname'] == 'Unnamed: 141'),
                            (depositos_07['myVarname'] == 'Unnamed: 142'),(depositos_07['myVarname'] == 'Unnamed: 143'),(depositos_07['myVarname'] == 'Unnamed: 144'),(depositos_07['myVarname'] == 'Unnamed: 145'),(depositos_07['myVarname'] == 'Unnamed: 146'),
                             (depositos_07['myVarname'] == 'Unnamed: 147'),(depositos_07['myVarname'] == 'Unnamed: 148'),(depositos_07['myVarname'] == 'Unnamed: 149'),(depositos_07['myVarname'] == 'Unnamed: 150'),(depositos_07['myVarname'] == 'Unnamed: 151'),
                              (depositos_07['myVarname'] == 'Unnamed: 152'),(depositos_07['myVarname'] == 'Unnamed: 153'),(depositos_07['myVarname'] == 'Unnamed: 154'),(depositos_07['myVarname'] == 'Unnamed: 155'),(depositos_07['myVarname'] == 'Unnamed: 156'),
                               (depositos_07['myVarname'] == 'Unnamed: 157'),(depositos_07['myVarname'] == 'Unnamed: 158'),(depositos_07['myVarname'] == 'Unnamed: 159'),(depositos_07['myVarname'] == 'Unnamed: 160'),(depositos_07['myVarname'] == 'Unnamed: 161'),
                                (depositos_07['myVarname'] == 'Unnamed: 162'),(depositos_07['myVarname'] == 'Unnamed: 163'),(depositos_07['myVarname'] == 'Unnamed: 164'),(depositos_07['myVarname'] == 'Unnamed: 165'),(depositos_07['myVarname'] == 'Unnamed: 166')
                                ]

# %%
depositos_07['Fecha'] = np.select(conditions_7, values)

# %%
depositos_07.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
depositos_07.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
depositos_07['Tipo'] = "Depósito"
depositos_07['Subtipo'] = "Total depósitos en moneda extranjera"
depositos_07['Tipo de Moneda'] = "Saldos en millones de dólares"

# %%
depositos_07.head(5)
# Out:
#                       Institucion     Valor       Fecha      Tipo  \
# 5                      Banco Bice   187.862  2008-01-31  Depósito
# 6     Banco BTG Pactual Chile (9)        ND  2008-01-31  Depósito
# 7             Banco Consorcio (1)    10.771  2008-01-31  Depósito
# 8              Banco de Chile (2)  2591.701  2008-01-31  Depósito
# 9  Banco de Crédito e Inversiones  1367.473  2008-01-31  Depósito
#
#                                 Subtipo                 Tipo de Moneda
# 5  Total depósitos en moneda extranjera  Saldos en millones de dólares
# 6  Total depósitos en moneda extranjera  Saldos en millones de dólares
# 7  Total depósitos en moneda extranjera  Saldos en millones de dólares
# 8  Total depósitos en moneda extranjera  Saldos en millones de dólares
# 9  Total depósitos en moneda extranjera  Saldos en millones de dólares

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
depositos_07 = depositos_07.reindex(columns=new_cols)

# %%
depositos_07.head(7)
# Out:
#          Fecha                        Institucion      Tipo  \
# 5   2008-01-31                         Banco Bice  Depósito
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Depósito
# 7   2008-01-31                Banco Consorcio (1)  Depósito
# 8   2008-01-31                 Banco de Chile (2)  Depósito
# 9   2008-01-31     Banco de Crédito e Inversiones  Depósito
# 10  2008-01-31  Banco de la Nación Argentina (18)  Depósito
# 11  2008-01-31          Banco del Estado de Chile  Depósito
#
#                                  Subtipo     Valor  \
# 5   Total depósitos en moneda extranjera   187.862
# 6   Total depósitos en moneda extranjera        ND
# 7   Total depósitos en moneda extranjera    10.771
# 8   Total depósitos en moneda extranjera  2591.701
# 9   Total depósitos en moneda extranjera  1367.473
# 10  Total depósitos en moneda extranjera     5.618
# 11  Total depósitos en moneda extranjera  1212.856
#
#                    Tipo de Moneda
# ...

# %% [markdown]
# ## Depósito 08

# %%
depositos_08.head(5)
# Out:
#         Unnamed: 0                     Unnamed: 1           Unnamed: 2  \
# 0   Índice general                    Cuadro 2.08                  NaN
# 1  Notas generales           Depósitos a la vista                  NaN
# 2              NaN  Saldos en millones de dólares                  NaN
# 3              NaN                            NaN                  NaN
# 4              NaN                            NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
depositos_08.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
depositos_08.head(7)
# Out:
#                       Unnamed: 1           Unnamed: 2           Unnamed: 3  \
# 0                    Cuadro 2.08                  NaN                  NaN
# 1           Depósitos a la vista                  NaN                  NaN
# 2  Saldos en millones de dólares                  NaN                  NaN
# 3                            NaN                  NaN                  NaN
# 4                            NaN  2008-01-31 00:00:00  2008-02-29 00:00:00
# 5                     Banco Bice               56.474               60.294
# 6    Banco BTG Pactual Chile (9)                   ND                   ND
#
#             Unnamed: 4           Unnamed: 5           Unnamed: 6  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# ...

# %%
depositos_08 = depositos_08.iloc[5:]

# %%
depositos_08.tail(7)
# Out:
#                                        Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 28                      Scotiabank Chile (3) (17)    115.007    108.153
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)     11.788     29.981
# 30                             Bank of China (16)         ND         ND
# 31                                          Total   2104.346   1928.102
# 32                                            NaN        NaN        NaN
# 33                                            NaN        NaN        NaN
# 34                            ND : No existe dato        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 28    156.677    146.123    121.036    145.061    136.801     144.31
# 29     34.325     25.458     28.028      30.08     51.817     32.899
# 30         ND         ND         ND         ND         ND         ND
# 31   2165.995   2156.634   2074.725   2176.851   1995.279   2066.861
# ...

# %%
depositos_08.drop(depositos_08.tail(4).index,inplace=True)
# Out:
# <ipython-input-315-3f5cbe3d697d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   depositos_08.drop(depositos_08.tail(4).index,inplace=True)

# %%
depositos_08.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice     56.474     60.294      61.08     58.283
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)      5.036       3.79      5.531      3.535
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 157  \
# 5     59.136     66.552     57.174      56.73     119.606  ...   811.980086
# 6         ND         ND         ND         ND          ND  ...      30.6014
# 7      5.822      5.767      6.174      1.839        1.89  ...     65.76699
#
#   Unnamed: 158 Unnamed: 159 Unnamed: 160 Unnamed: 161 Unnamed: 162  \
# 5    696.98543   676.274411   633.491194   791.936932   916.062307
# 6    30.320933    78.560412    69.971679    25.350882    19.778963
# 7    57.390278    61.515354    75.220955    59.279668   109.154387
#
#   Unnamed: 163 Unnamed: 164 Unnamed: 165 Unnamed: 166
# ...

# %%
depositos_08 = depositos_08.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_8 = [(depositos_08['myVarname'] == 'Unnamed: 2'),(depositos_08['myVarname'] == 'Unnamed: 3'),(depositos_08['myVarname'] == 'Unnamed: 4'),(depositos_08['myVarname'] == 'Unnamed: 5'),(depositos_08['myVarname'] == 'Unnamed: 6'),
 (depositos_08['myVarname'] == 'Unnamed: 7'),(depositos_08['myVarname'] == 'Unnamed: 8'),(depositos_08['myVarname'] == 'Unnamed: 9'),(depositos_08['myVarname'] == 'Unnamed: 10'),(depositos_08['myVarname'] == 'Unnamed: 11'),
  (depositos_08['myVarname'] == 'Unnamed: 12'),(depositos_08['myVarname'] == 'Unnamed: 13'),(depositos_08['myVarname'] == 'Unnamed: 14'),(depositos_08['myVarname'] == 'Unnamed: 15'),(depositos_08['myVarname'] == 'Unnamed: 16'),
   (depositos_08['myVarname'] == 'Unnamed: 17'),(depositos_08['myVarname'] == 'Unnamed: 18'),(depositos_08['myVarname'] == 'Unnamed: 19'),(depositos_08['myVarname'] == 'Unnamed: 20'),(depositos_08['myVarname'] == 'Unnamed: 21'),
    (depositos_08['myVarname'] == 'Unnamed: 22'),(depositos_08['myVarname'] == 'Unnamed: 23'),(depositos_08['myVarname'] == 'Unnamed: 24'),(depositos_08['myVarname'] == 'Unnamed: 25'),(depositos_08['myVarname'] == 'Unnamed: 26'),
     (depositos_08['myVarname'] == 'Unnamed: 27'),(depositos_08['myVarname'] == 'Unnamed: 28'),(depositos_08['myVarname'] == 'Unnamed: 29'),(depositos_08['myVarname'] == 'Unnamed: 30'),(depositos_08['myVarname'] == 'Unnamed: 31'),
      (depositos_08['myVarname'] == 'Unnamed: 32'),(depositos_08['myVarname'] == 'Unnamed: 33'),(depositos_08['myVarname'] == 'Unnamed: 34'),(depositos_08['myVarname'] == 'Unnamed: 35'),(depositos_08['myVarname'] == 'Unnamed: 36'),
       (depositos_08['myVarname'] == 'Unnamed: 37'),(depositos_08['myVarname'] == 'Unnamed: 38'),(depositos_08['myVarname'] == 'Unnamed: 39'),(depositos_08['myVarname'] == 'Unnamed: 40'),(depositos_08['myVarname'] == 'Unnamed: 41'),
        (depositos_08['myVarname'] == 'Unnamed: 42'),(depositos_08['myVarname'] == 'Unnamed: 43'),(depositos_08['myVarname'] == 'Unnamed: 44'),(depositos_08['myVarname'] == 'Unnamed: 45'),(depositos_08['myVarname'] == 'Unnamed: 46'),
         (depositos_08['myVarname'] == 'Unnamed: 47'),(depositos_08['myVarname'] == 'Unnamed: 48'),(depositos_08['myVarname'] == 'Unnamed: 49'),(depositos_08['myVarname'] == 'Unnamed: 50'),(depositos_08['myVarname'] == 'Unnamed: 51'),
          (depositos_08['myVarname'] == 'Unnamed: 52'),(depositos_08['myVarname'] == 'Unnamed: 53'),(depositos_08['myVarname'] == 'Unnamed: 54'),(depositos_08['myVarname'] == 'Unnamed: 55'),(depositos_08['myVarname'] == 'Unnamed: 56'),
           (depositos_08['myVarname'] == 'Unnamed: 57'),(depositos_08['myVarname'] == 'Unnamed: 58'),(depositos_08['myVarname'] == 'Unnamed: 59'),(depositos_08['myVarname'] == 'Unnamed: 60'),(depositos_08['myVarname'] == 'Unnamed: 61'),
            (depositos_08['myVarname'] == 'Unnamed: 62'),(depositos_08['myVarname'] == 'Unnamed: 63'),(depositos_08['myVarname'] == 'Unnamed: 64'),(depositos_08['myVarname'] == 'Unnamed: 65'),(depositos_08['myVarname'] == 'Unnamed: 66'),
             (depositos_08['myVarname'] == 'Unnamed: 67'),(depositos_08['myVarname'] == 'Unnamed: 68'),(depositos_08['myVarname'] == 'Unnamed: 69'),(depositos_08['myVarname'] == 'Unnamed: 70'),(depositos_08['myVarname'] == 'Unnamed: 71'),
              (depositos_08['myVarname'] == 'Unnamed: 72'),(depositos_08['myVarname'] == 'Unnamed: 73'),(depositos_08['myVarname'] == 'Unnamed: 74'),(depositos_08['myVarname'] == 'Unnamed: 75'),(depositos_08['myVarname'] == 'Unnamed: 76'),
               (depositos_08['myVarname'] == 'Unnamed: 77'),(depositos_08['myVarname'] == 'Unnamed: 78'),(depositos_08['myVarname'] == 'Unnamed: 79'),(depositos_08['myVarname'] == 'Unnamed: 80'),(depositos_08['myVarname'] == 'Unnamed: 81'),
                (depositos_08['myVarname'] == 'Unnamed: 82'),(depositos_08['myVarname'] == 'Unnamed: 83'),(depositos_08['myVarname'] == 'Unnamed: 84'),(depositos_08['myVarname'] == 'Unnamed: 85'),(depositos_08['myVarname'] == 'Unnamed: 86'),
                 (depositos_08['myVarname'] == 'Unnamed: 87'),(depositos_08['myVarname'] == 'Unnamed: 88'),(depositos_08['myVarname'] == 'Unnamed: 89'),(depositos_08['myVarname'] == 'Unnamed: 90'),(depositos_08['myVarname'] == 'Unnamed: 91'),
                  (depositos_08['myVarname'] == 'Unnamed: 92'),(depositos_08['myVarname'] == 'Unnamed: 93'),(depositos_08['myVarname'] == 'Unnamed: 94'),(depositos_08['myVarname'] == 'Unnamed: 95'),(depositos_08['myVarname'] == 'Unnamed: 96'),
                   (depositos_08['myVarname'] == 'Unnamed: 97'),(depositos_08['myVarname'] == 'Unnamed: 98'),(depositos_08['myVarname'] == 'Unnamed: 99'),(depositos_08['myVarname'] == 'Unnamed: 100'),(depositos_08['myVarname'] == 'Unnamed: 101'),
                    (depositos_08['myVarname'] == 'Unnamed: 102'),(depositos_08['myVarname'] == 'Unnamed: 103'),(depositos_08['myVarname'] == 'Unnamed: 104'),(depositos_08['myVarname'] == 'Unnamed: 105'),(depositos_08['myVarname'] == 'Unnamed: 106'),
                     (depositos_08['myVarname'] == 'Unnamed: 107'),(depositos_08['myVarname'] == 'Unnamed: 108'),(depositos_08['myVarname'] == 'Unnamed: 109'),(depositos_08['myVarname'] == 'Unnamed: 110'),(depositos_08['myVarname'] == 'Unnamed: 111'),
                      (depositos_08['myVarname'] == 'Unnamed: 112'),(depositos_08['myVarname'] == 'Unnamed: 113'),(depositos_08['myVarname'] == 'Unnamed: 114'),(depositos_08['myVarname'] == 'Unnamed: 115'),(depositos_08['myVarname'] == 'Unnamed: 116'),
                       (depositos_08['myVarname'] == 'Unnamed: 117'),(depositos_08['myVarname'] == 'Unnamed: 118'),(depositos_08['myVarname'] == 'Unnamed: 119'),(depositos_08['myVarname'] == 'Unnamed: 120'),(depositos_08['myVarname'] == 'Unnamed: 121'),
                        (depositos_08['myVarname'] == 'Unnamed: 122'),(depositos_08['myVarname'] == 'Unnamed: 123'),(depositos_08['myVarname'] == 'Unnamed: 124'),(depositos_08['myVarname'] == 'Unnamed: 125'),(depositos_08['myVarname'] == 'Unnamed: 126'),
                         (depositos_08['myVarname'] == 'Unnamed: 127'),(depositos_08['myVarname'] == 'Unnamed: 128'),(depositos_08['myVarname'] == 'Unnamed: 129'),(depositos_08['myVarname'] == 'Unnamed: 130'),(depositos_08['myVarname'] == 'Unnamed: 131'),
                          (depositos_08['myVarname'] == 'Unnamed: 132'),(depositos_08['myVarname'] == 'Unnamed: 133'),(depositos_08['myVarname'] == 'Unnamed: 134'),(depositos_08['myVarname'] == 'Unnamed: 135'),(depositos_08['myVarname'] == 'Unnamed: 136'),
                           (depositos_08['myVarname'] == 'Unnamed: 137'),(depositos_08['myVarname'] == 'Unnamed: 138'),(depositos_08['myVarname'] == 'Unnamed: 139'),(depositos_08['myVarname'] == 'Unnamed: 140'),(depositos_08['myVarname'] == 'Unnamed: 141'),
                            (depositos_08['myVarname'] == 'Unnamed: 142'),(depositos_08['myVarname'] == 'Unnamed: 143'),(depositos_08['myVarname'] == 'Unnamed: 144'),(depositos_08['myVarname'] == 'Unnamed: 145'),(depositos_08['myVarname'] == 'Unnamed: 146'),
                             (depositos_08['myVarname'] == 'Unnamed: 147'),(depositos_08['myVarname'] == 'Unnamed: 148'),(depositos_08['myVarname'] == 'Unnamed: 149'),(depositos_08['myVarname'] == 'Unnamed: 150'),(depositos_08['myVarname'] == 'Unnamed: 151'),
                              (depositos_08['myVarname'] == 'Unnamed: 152'),(depositos_08['myVarname'] == 'Unnamed: 153'),(depositos_08['myVarname'] == 'Unnamed: 154'),(depositos_08['myVarname'] == 'Unnamed: 155'),(depositos_08['myVarname'] == 'Unnamed: 156'),
                               (depositos_08['myVarname'] == 'Unnamed: 157'),(depositos_08['myVarname'] == 'Unnamed: 158'),(depositos_08['myVarname'] == 'Unnamed: 159'),(depositos_08['myVarname'] == 'Unnamed: 160'),(depositos_08['myVarname'] == 'Unnamed: 161'),
                                (depositos_08['myVarname'] == 'Unnamed: 162'),(depositos_08['myVarname'] == 'Unnamed: 163'),(depositos_08['myVarname'] == 'Unnamed: 164'),(depositos_08['myVarname'] == 'Unnamed: 165'),(depositos_08['myVarname'] == 'Unnamed: 166')
                                ]

# %%
depositos_08['Fecha'] = np.select(conditions_8, values)

# %%
depositos_08.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
depositos_08.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
depositos_08['Tipo'] = "Depósito"
depositos_08['Subtipo'] = "Depósitos a la vista"
depositos_08['Tipo de Moneda'] = "Saldos en millones de dólares"

# %%
depositos_08.head(5)
# Out:
#                       Institucion    Valor       Fecha      Tipo  \
# 5                      Banco Bice   56.474  2008-01-31  Depósito
# 6     Banco BTG Pactual Chile (9)       ND  2008-01-31  Depósito
# 7             Banco Consorcio (1)    5.036  2008-01-31  Depósito
# 8              Banco de Chile (2)  812.854  2008-01-31  Depósito
# 9  Banco de Crédito e Inversiones  274.444  2008-01-31  Depósito
#
#                 Subtipo                 Tipo de Moneda
# 5  Depósitos a la vista  Saldos en millones de dólares
# 6  Depósitos a la vista  Saldos en millones de dólares
# 7  Depósitos a la vista  Saldos en millones de dólares
# 8  Depósitos a la vista  Saldos en millones de dólares
# 9  Depósitos a la vista  Saldos en millones de dólares

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
depositos_08 = depositos_08.reindex(columns=new_cols)

# %%
depositos_08.head(7)
# Out:
#          Fecha                        Institucion      Tipo  \
# 5   2008-01-31                         Banco Bice  Depósito
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Depósito
# 7   2008-01-31                Banco Consorcio (1)  Depósito
# 8   2008-01-31                 Banco de Chile (2)  Depósito
# 9   2008-01-31     Banco de Crédito e Inversiones  Depósito
# 10  2008-01-31  Banco de la Nación Argentina (18)  Depósito
# 11  2008-01-31          Banco del Estado de Chile  Depósito
#
#                  Subtipo    Valor                 Tipo de Moneda
# 5   Depósitos a la vista   56.474  Saldos en millones de dólares
# 6   Depósitos a la vista       ND  Saldos en millones de dólares
# 7   Depósitos a la vista    5.036  Saldos en millones de dólares
# 8   Depósitos a la vista  812.854  Saldos en millones de dólares
# 9   Depósitos a la vista  274.444  Saldos en millones de dólares
# 10  Depósitos a la vista    1.147  Saldos en millones de dólares
# ...

# %% [markdown]
# ## Depósito 09

# %%
depositos_09.head(5)
# Out:
#         Unnamed: 0                     Unnamed: 1           Unnamed: 2  \
# 0   Índice general                    Cuadro 2.09                  NaN
# 1  Notas generales              Depósitos a plazo                  NaN
# 2              NaN  Saldos en millones de dólares                  NaN
# 3              NaN                            NaN                  NaN
# 4              NaN                            NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
depositos_09.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
depositos_09.head(7)
# Out:
#                       Unnamed: 1           Unnamed: 2           Unnamed: 3  \
# 0                    Cuadro 2.09                  NaN                  NaN
# 1              Depósitos a plazo                  NaN                  NaN
# 2  Saldos en millones de dólares                  NaN                  NaN
# 3                            NaN                  NaN                  NaN
# 4                            NaN  2008-01-31 00:00:00  2008-02-29 00:00:00
# 5                     Banco Bice              131.388              145.943
# 6    Banco BTG Pactual Chile (9)                   ND                   ND
#
#             Unnamed: 4           Unnamed: 5           Unnamed: 6  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# ...

# %%
depositos_09 = depositos_09.iloc[5:]

# %%
depositos_09.tail(7)
# Out:
#                                        Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 28                      Scotiabank Chile (3) (17)    825.279    727.684
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)     75.223     61.817
# 30                             Bank of China (16)         ND         ND
# 31                                          Total   9689.869   9852.826
# 32                                            NaN        NaN        NaN
# 33                                            NaN        NaN        NaN
# 34                            ND : No existe dato        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 28     740.91    592.537    831.419    942.453   1139.446   1297.385
# 29      31.08     47.777     49.852     46.433     47.315     77.634
# 30         ND         ND         ND         ND         ND         ND
# 31  10127.682  11100.755  11697.988  13031.549  14042.899  14210.855
# ...

# %%
depositos_09.drop(depositos_09.tail(4).index,inplace=True)
# Out:
# <ipython-input-331-ebce5348bf9b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   depositos_09.drop(depositos_09.tail(4).index,inplace=True)

# %%
depositos_09.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice    131.388    145.943    135.556    119.145
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)      5.735      5.808     13.018     16.452
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 157  \
# 5    136.158    147.741    196.853    226.928     208.237  ...   517.866668
# 6         ND         ND         ND         ND          ND  ...    427.55242
# 7     18.175     19.097     20.699     14.025      13.496  ...   742.744262
#
#   Unnamed: 158 Unnamed: 159 Unnamed: 160 Unnamed: 161 Unnamed: 162  \
# 5     489.9533   641.120678   632.658626   630.296646   589.124265
# 6   400.509809    414.52673    391.53154   524.990354   577.010271
# 7    814.42751   849.559179   817.182788   714.676944    705.37226
#
#   Unnamed: 163 Unnamed: 164 Unnamed: 165 Unnamed: 166
# ...

# %%
depositos_09 = depositos_09.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_9 = [(depositos_09['myVarname'] == 'Unnamed: 2'),(depositos_09['myVarname'] == 'Unnamed: 3'),(depositos_09['myVarname'] == 'Unnamed: 4'),(depositos_09['myVarname'] == 'Unnamed: 5'),(depositos_09['myVarname'] == 'Unnamed: 6'),
 (depositos_09['myVarname'] == 'Unnamed: 7'),(depositos_09['myVarname'] == 'Unnamed: 8'),(depositos_09['myVarname'] == 'Unnamed: 9'),(depositos_09['myVarname'] == 'Unnamed: 10'),(depositos_09['myVarname'] == 'Unnamed: 11'),
  (depositos_09['myVarname'] == 'Unnamed: 12'),(depositos_09['myVarname'] == 'Unnamed: 13'),(depositos_09['myVarname'] == 'Unnamed: 14'),(depositos_09['myVarname'] == 'Unnamed: 15'),(depositos_09['myVarname'] == 'Unnamed: 16'),
   (depositos_09['myVarname'] == 'Unnamed: 17'),(depositos_09['myVarname'] == 'Unnamed: 18'),(depositos_09['myVarname'] == 'Unnamed: 19'),(depositos_09['myVarname'] == 'Unnamed: 20'),(depositos_09['myVarname'] == 'Unnamed: 21'),
    (depositos_09['myVarname'] == 'Unnamed: 22'),(depositos_09['myVarname'] == 'Unnamed: 23'),(depositos_09['myVarname'] == 'Unnamed: 24'),(depositos_09['myVarname'] == 'Unnamed: 25'),(depositos_09['myVarname'] == 'Unnamed: 26'),
     (depositos_09['myVarname'] == 'Unnamed: 27'),(depositos_09['myVarname'] == 'Unnamed: 28'),(depositos_09['myVarname'] == 'Unnamed: 29'),(depositos_09['myVarname'] == 'Unnamed: 30'),(depositos_09['myVarname'] == 'Unnamed: 31'),
      (depositos_09['myVarname'] == 'Unnamed: 32'),(depositos_09['myVarname'] == 'Unnamed: 33'),(depositos_09['myVarname'] == 'Unnamed: 34'),(depositos_09['myVarname'] == 'Unnamed: 35'),(depositos_09['myVarname'] == 'Unnamed: 36'),
       (depositos_09['myVarname'] == 'Unnamed: 37'),(depositos_09['myVarname'] == 'Unnamed: 38'),(depositos_09['myVarname'] == 'Unnamed: 39'),(depositos_09['myVarname'] == 'Unnamed: 40'),(depositos_09['myVarname'] == 'Unnamed: 41'),
        (depositos_09['myVarname'] == 'Unnamed: 42'),(depositos_09['myVarname'] == 'Unnamed: 43'),(depositos_09['myVarname'] == 'Unnamed: 44'),(depositos_09['myVarname'] == 'Unnamed: 45'),(depositos_09['myVarname'] == 'Unnamed: 46'),
         (depositos_09['myVarname'] == 'Unnamed: 47'),(depositos_09['myVarname'] == 'Unnamed: 48'),(depositos_09['myVarname'] == 'Unnamed: 49'),(depositos_09['myVarname'] == 'Unnamed: 50'),(depositos_09['myVarname'] == 'Unnamed: 51'),
          (depositos_09['myVarname'] == 'Unnamed: 52'),(depositos_09['myVarname'] == 'Unnamed: 53'),(depositos_09['myVarname'] == 'Unnamed: 54'),(depositos_09['myVarname'] == 'Unnamed: 55'),(depositos_09['myVarname'] == 'Unnamed: 56'),
           (depositos_09['myVarname'] == 'Unnamed: 57'),(depositos_09['myVarname'] == 'Unnamed: 58'),(depositos_09['myVarname'] == 'Unnamed: 59'),(depositos_09['myVarname'] == 'Unnamed: 60'),(depositos_09['myVarname'] == 'Unnamed: 61'),
            (depositos_09['myVarname'] == 'Unnamed: 62'),(depositos_09['myVarname'] == 'Unnamed: 63'),(depositos_09['myVarname'] == 'Unnamed: 64'),(depositos_09['myVarname'] == 'Unnamed: 65'),(depositos_09['myVarname'] == 'Unnamed: 66'),
             (depositos_09['myVarname'] == 'Unnamed: 67'),(depositos_09['myVarname'] == 'Unnamed: 68'),(depositos_09['myVarname'] == 'Unnamed: 69'),(depositos_09['myVarname'] == 'Unnamed: 70'),(depositos_09['myVarname'] == 'Unnamed: 71'),
              (depositos_09['myVarname'] == 'Unnamed: 72'),(depositos_09['myVarname'] == 'Unnamed: 73'),(depositos_09['myVarname'] == 'Unnamed: 74'),(depositos_09['myVarname'] == 'Unnamed: 75'),(depositos_09['myVarname'] == 'Unnamed: 76'),
               (depositos_09['myVarname'] == 'Unnamed: 77'),(depositos_09['myVarname'] == 'Unnamed: 78'),(depositos_09['myVarname'] == 'Unnamed: 79'),(depositos_09['myVarname'] == 'Unnamed: 80'),(depositos_09['myVarname'] == 'Unnamed: 81'),
                (depositos_09['myVarname'] == 'Unnamed: 82'),(depositos_09['myVarname'] == 'Unnamed: 83'),(depositos_09['myVarname'] == 'Unnamed: 84'),(depositos_09['myVarname'] == 'Unnamed: 85'),(depositos_09['myVarname'] == 'Unnamed: 86'),
                 (depositos_09['myVarname'] == 'Unnamed: 87'),(depositos_09['myVarname'] == 'Unnamed: 88'),(depositos_09['myVarname'] == 'Unnamed: 89'),(depositos_09['myVarname'] == 'Unnamed: 90'),(depositos_09['myVarname'] == 'Unnamed: 91'),
                  (depositos_09['myVarname'] == 'Unnamed: 92'),(depositos_09['myVarname'] == 'Unnamed: 93'),(depositos_09['myVarname'] == 'Unnamed: 94'),(depositos_09['myVarname'] == 'Unnamed: 95'),(depositos_09['myVarname'] == 'Unnamed: 96'),
                   (depositos_09['myVarname'] == 'Unnamed: 97'),(depositos_09['myVarname'] == 'Unnamed: 98'),(depositos_09['myVarname'] == 'Unnamed: 99'),(depositos_09['myVarname'] == 'Unnamed: 100'),(depositos_09['myVarname'] == 'Unnamed: 101'),
                    (depositos_09['myVarname'] == 'Unnamed: 102'),(depositos_09['myVarname'] == 'Unnamed: 103'),(depositos_09['myVarname'] == 'Unnamed: 104'),(depositos_09['myVarname'] == 'Unnamed: 105'),(depositos_09['myVarname'] == 'Unnamed: 106'),
                     (depositos_09['myVarname'] == 'Unnamed: 107'),(depositos_09['myVarname'] == 'Unnamed: 108'),(depositos_09['myVarname'] == 'Unnamed: 109'),(depositos_09['myVarname'] == 'Unnamed: 110'),(depositos_09['myVarname'] == 'Unnamed: 111'),
                      (depositos_09['myVarname'] == 'Unnamed: 112'),(depositos_09['myVarname'] == 'Unnamed: 113'),(depositos_09['myVarname'] == 'Unnamed: 114'),(depositos_09['myVarname'] == 'Unnamed: 115'),(depositos_09['myVarname'] == 'Unnamed: 116'),
                       (depositos_09['myVarname'] == 'Unnamed: 117'),(depositos_09['myVarname'] == 'Unnamed: 118'),(depositos_09['myVarname'] == 'Unnamed: 119'),(depositos_09['myVarname'] == 'Unnamed: 120'),(depositos_09['myVarname'] == 'Unnamed: 121'),
                        (depositos_09['myVarname'] == 'Unnamed: 122'),(depositos_09['myVarname'] == 'Unnamed: 123'),(depositos_09['myVarname'] == 'Unnamed: 124'),(depositos_09['myVarname'] == 'Unnamed: 125'),(depositos_09['myVarname'] == 'Unnamed: 126'),
                         (depositos_09['myVarname'] == 'Unnamed: 127'),(depositos_09['myVarname'] == 'Unnamed: 128'),(depositos_09['myVarname'] == 'Unnamed: 129'),(depositos_09['myVarname'] == 'Unnamed: 130'),(depositos_09['myVarname'] == 'Unnamed: 131'),
                          (depositos_09['myVarname'] == 'Unnamed: 132'),(depositos_09['myVarname'] == 'Unnamed: 133'),(depositos_09['myVarname'] == 'Unnamed: 134'),(depositos_09['myVarname'] == 'Unnamed: 135'),(depositos_09['myVarname'] == 'Unnamed: 136'),
                           (depositos_09['myVarname'] == 'Unnamed: 137'),(depositos_09['myVarname'] == 'Unnamed: 138'),(depositos_09['myVarname'] == 'Unnamed: 139'),(depositos_09['myVarname'] == 'Unnamed: 140'),(depositos_09['myVarname'] == 'Unnamed: 141'),
                            (depositos_09['myVarname'] == 'Unnamed: 142'),(depositos_09['myVarname'] == 'Unnamed: 143'),(depositos_09['myVarname'] == 'Unnamed: 144'),(depositos_09['myVarname'] == 'Unnamed: 145'),(depositos_09['myVarname'] == 'Unnamed: 146'),
                             (depositos_09['myVarname'] == 'Unnamed: 147'),(depositos_09['myVarname'] == 'Unnamed: 148'),(depositos_09['myVarname'] == 'Unnamed: 149'),(depositos_09['myVarname'] == 'Unnamed: 150'),(depositos_09['myVarname'] == 'Unnamed: 151'),
                              (depositos_09['myVarname'] == 'Unnamed: 152'),(depositos_09['myVarname'] == 'Unnamed: 153'),(depositos_09['myVarname'] == 'Unnamed: 154'),(depositos_09['myVarname'] == 'Unnamed: 155'),(depositos_09['myVarname'] == 'Unnamed: 156'),
                               (depositos_09['myVarname'] == 'Unnamed: 157'),(depositos_09['myVarname'] == 'Unnamed: 158'),(depositos_09['myVarname'] == 'Unnamed: 159'),(depositos_09['myVarname'] == 'Unnamed: 160'),(depositos_09['myVarname'] == 'Unnamed: 161'),
                                (depositos_09['myVarname'] == 'Unnamed: 162'),(depositos_09['myVarname'] == 'Unnamed: 163'),(depositos_09['myVarname'] == 'Unnamed: 164'),(depositos_09['myVarname'] == 'Unnamed: 165'),(depositos_09['myVarname'] == 'Unnamed: 166')
                                ]

# %%
depositos_09['Fecha'] = np.select(conditions_9, values)

# %%
depositos_09
# Out:
#                                        Unnamed: 1     myVarname        Valor  \
# 5                                      Banco Bice    Unnamed: 2      131.388
# 6                     Banco BTG Pactual Chile (9)    Unnamed: 2           ND
# 7                             Banco Consorcio (1)    Unnamed: 2        5.735
# 8                              Banco de Chile (2)    Unnamed: 2     1778.847
# 9                  Banco de Crédito e Inversiones    Unnamed: 2     1093.029
# ..                                            ...           ...          ...
# 26                     JP Morgan Chase Bank, N.A.  Unnamed: 166            0
# 27                            Rabobank Chile (15)  Unnamed: 166           ND
# 28                      Scotiabank Chile (3) (17)  Unnamed: 166  4328.045499
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Unnamed: 166           ND
# 30                             Bank of China (16)  Unnamed: 166     1.010701
#
#          Fecha
# 5   2008-01-31
# ...

# %%
depositos_09.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
depositos_09.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
depositos_09['Tipo'] = "Depósito"
depositos_09['Subtipo'] = "Depósitos a plazo"
depositos_09['Tipo de Moneda'] = "Saldos en millones de dólares"

# %%
depositos_09.head(5)
# Out:
#                       Institucion     Valor       Fecha      Tipo  \
# 5                      Banco Bice   131.388  2008-01-31  Depósito
# 6     Banco BTG Pactual Chile (9)        ND  2008-01-31  Depósito
# 7             Banco Consorcio (1)     5.735  2008-01-31  Depósito
# 8              Banco de Chile (2)  1778.847  2008-01-31  Depósito
# 9  Banco de Crédito e Inversiones  1093.029  2008-01-31  Depósito
#
#              Subtipo                 Tipo de Moneda
# 5  Depósitos a plazo  Saldos en millones de dólares
# 6  Depósitos a plazo  Saldos en millones de dólares
# 7  Depósitos a plazo  Saldos en millones de dólares
# 8  Depósitos a plazo  Saldos en millones de dólares
# 9  Depósitos a plazo  Saldos en millones de dólares

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
depositos_09 = depositos_09.reindex(columns=new_cols)

# %%
depositos_09.head(7)
# Out:
#          Fecha                        Institucion      Tipo  \
# 5   2008-01-31                         Banco Bice  Depósito
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Depósito
# 7   2008-01-31                Banco Consorcio (1)  Depósito
# 8   2008-01-31                 Banco de Chile (2)  Depósito
# 9   2008-01-31     Banco de Crédito e Inversiones  Depósito
# 10  2008-01-31  Banco de la Nación Argentina (18)  Depósito
# 11  2008-01-31          Banco del Estado de Chile  Depósito
#
#               Subtipo     Valor                 Tipo de Moneda
# 5   Depósitos a plazo   131.388  Saldos en millones de dólares
# 6   Depósitos a plazo        ND  Saldos en millones de dólares
# 7   Depósitos a plazo     5.735  Saldos en millones de dólares
# 8   Depósitos a plazo  1778.847  Saldos en millones de dólares
# 9   Depósitos a plazo  1093.029  Saldos en millones de dólares
# 10  Depósitos a plazo     4.471  Saldos en millones de dólares
# ...

# %% [markdown]
# # Inversiones

# %%
#inversiones
inversion_01 = pd.read_excel('/content/sdbinv_092021.xlsx',sheet_name='3_01')
inversion_02 = pd.read_excel('/content/sdbinv_092021.xlsx',sheet_name='3_02')
inversion_03 = pd.read_excel('/content/sdbinv_092021.xlsx',sheet_name='3_03')
inversion_04 = pd.read_excel('/content/sdbinv_092021.xlsx',sheet_name='3_04')
inversion_05 = pd.read_excel('/content/sdbinv_092021.xlsx',sheet_name='3_05')
inversion_06 = pd.read_excel('/content/sdbinv_092021.xlsx',sheet_name='3_06')
inversion_07 = pd.read_excel('/content/sdbinv_092021.xlsx',sheet_name='3_07')
inversion_08 = pd.read_excel('/content/sdbinv_092021.xlsx',sheet_name='3_08')
inversion_09 = pd.read_excel('/content/sdbinv_092021.xlsx',sheet_name='3_09')
inversion_10 = pd.read_excel('/content/sdbinv_092021.xlsx',sheet_name='3_10')
inversion_11 = pd.read_excel('/content/sdbinv_092021.xlsx',sheet_name='3_11')
inversion_12 = pd.read_excel('/content/sdbinv_092021.xlsx',sheet_name='3_12')
inversion_13 = pd.read_excel('/content/sdbinv_092021.xlsx',sheet_name='3_13')

# %% [markdown]
# ## Inversión 01

# %%
inversion_01.head(5)
# Out:
#         Unnamed: 0                       Unnamed: 1           Unnamed: 2  \
# 0   Índice general                      Cuadro 3.01                  NaN
# 1  Notas generales  Total inversion moneda nacional                  NaN
# 2              NaN      Saldos en millones de pesos                  NaN
# 3              NaN                              NaN                  NaN
# 4              NaN                              NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
inversion_01.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
inversion_01 = inversion_01.iloc[5:]

# %%
inversion_01.tail(7)
# Out:
#                                        Unnamed: 1      Unnamed: 2  \
# 28                      Scotiabank Chile (3) (17)   758324.430573
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)     5453.081272
# 30                             Bank of China (16)              ND
# 31                                          Total  9239478.372692
# 32                                            NaN             NaN
# 33                                            NaN             NaN
# 34                            ND : No existe dato             NaN
#
#         Unnamed: 3     Unnamed: 4      Unnamed: 5      Unnamed: 6  \
# 28   745153.148096  740992.213673   770875.125107   699376.111298
# 29     4964.377017    4959.982598      3969.86299     4963.601083
# 30              ND             ND              ND              ND
# 31  9195212.392141  9292980.57044  9139987.286296  9228265.766792
# 32             NaN            NaN             NaN             NaN
# ...

# %%
inversion_01.drop(inversion_01.tail(4).index,inplace=True)
# Out:
# <ipython-input-348-520095228c4b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inversion_01.drop(inversion_01.tail(4).index,inplace=True)

# %%
inversion_01.head(3)
# Out:
#                     Unnamed: 1     Unnamed: 2     Unnamed: 3     Unnamed: 4  \
# 5                   Banco Bice  436033.276665  444413.104734  288841.383071
# 6  Banco BTG Pactual Chile (9)             ND             ND             ND
# 7          Banco Consorcio (1)   36917.250048    20420.11332    29007.05156
#
#       Unnamed: 5     Unnamed: 6     Unnamed: 7     Unnamed: 8    Unnamed: 9  \
# 5  309191.056784  290533.303262  284346.978034  264268.771935  273314.01844
# 6             ND             ND             ND             ND            ND
# 7   42279.811041   39700.518636   36900.204291   36773.955644  35108.397633
#
#      Unnamed: 10  ...    Unnamed: 157    Unnamed: 158    Unnamed: 159  \
# 5  250527.021304  ...  1153036.089007  1153387.836155  1169224.732885
# 6             ND  ...   344277.243006   221816.204426    212473.82062
# 7   33233.902873  ...   925829.940696  1250199.328486   937399.965603
#
#      Unnamed: 160    Unnamed: 161    Unnamed: 162    Unnamed: 163  \
# ...

# %%
inversion_01 = inversion_01.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_1 = [(inversion_01['myVarname'] == 'Unnamed: 2'),(inversion_01['myVarname'] == 'Unnamed: 3'),(inversion_01['myVarname'] == 'Unnamed: 4'),(inversion_01['myVarname'] == 'Unnamed: 5'),(inversion_01['myVarname'] == 'Unnamed: 6'),
 (inversion_01['myVarname'] == 'Unnamed: 7'),(inversion_01['myVarname'] == 'Unnamed: 8'),(inversion_01['myVarname'] == 'Unnamed: 9'),(inversion_01['myVarname'] == 'Unnamed: 10'),(inversion_01['myVarname'] == 'Unnamed: 11'),
  (inversion_01['myVarname'] == 'Unnamed: 12'),(inversion_01['myVarname'] == 'Unnamed: 13'),(inversion_01['myVarname'] == 'Unnamed: 14'),(inversion_01['myVarname'] == 'Unnamed: 15'),(inversion_01['myVarname'] == 'Unnamed: 16'),
   (inversion_01['myVarname'] == 'Unnamed: 17'),(inversion_01['myVarname'] == 'Unnamed: 18'),(inversion_01['myVarname'] == 'Unnamed: 19'),(inversion_01['myVarname'] == 'Unnamed: 20'),(inversion_01['myVarname'] == 'Unnamed: 21'),
    (inversion_01['myVarname'] == 'Unnamed: 22'),(inversion_01['myVarname'] == 'Unnamed: 23'),(inversion_01['myVarname'] == 'Unnamed: 24'),(inversion_01['myVarname'] == 'Unnamed: 25'),(inversion_01['myVarname'] == 'Unnamed: 26'),
     (inversion_01['myVarname'] == 'Unnamed: 27'),(inversion_01['myVarname'] == 'Unnamed: 28'),(inversion_01['myVarname'] == 'Unnamed: 29'),(inversion_01['myVarname'] == 'Unnamed: 30'),(inversion_01['myVarname'] == 'Unnamed: 31'),
      (inversion_01['myVarname'] == 'Unnamed: 32'),(inversion_01['myVarname'] == 'Unnamed: 33'),(inversion_01['myVarname'] == 'Unnamed: 34'),(inversion_01['myVarname'] == 'Unnamed: 35'),(inversion_01['myVarname'] == 'Unnamed: 36'),
       (inversion_01['myVarname'] == 'Unnamed: 37'),(inversion_01['myVarname'] == 'Unnamed: 38'),(inversion_01['myVarname'] == 'Unnamed: 39'),(inversion_01['myVarname'] == 'Unnamed: 40'),(inversion_01['myVarname'] == 'Unnamed: 41'),
        (inversion_01['myVarname'] == 'Unnamed: 42'),(inversion_01['myVarname'] == 'Unnamed: 43'),(inversion_01['myVarname'] == 'Unnamed: 44'),(inversion_01['myVarname'] == 'Unnamed: 45'),(inversion_01['myVarname'] == 'Unnamed: 46'),
         (inversion_01['myVarname'] == 'Unnamed: 47'),(inversion_01['myVarname'] == 'Unnamed: 48'),(inversion_01['myVarname'] == 'Unnamed: 49'),(inversion_01['myVarname'] == 'Unnamed: 50'),(inversion_01['myVarname'] == 'Unnamed: 51'),
          (inversion_01['myVarname'] == 'Unnamed: 52'),(inversion_01['myVarname'] == 'Unnamed: 53'),(inversion_01['myVarname'] == 'Unnamed: 54'),(inversion_01['myVarname'] == 'Unnamed: 55'),(inversion_01['myVarname'] == 'Unnamed: 56'),
           (inversion_01['myVarname'] == 'Unnamed: 57'),(inversion_01['myVarname'] == 'Unnamed: 58'),(inversion_01['myVarname'] == 'Unnamed: 59'),(inversion_01['myVarname'] == 'Unnamed: 60'),(inversion_01['myVarname'] == 'Unnamed: 61'),
            (inversion_01['myVarname'] == 'Unnamed: 62'),(inversion_01['myVarname'] == 'Unnamed: 63'),(inversion_01['myVarname'] == 'Unnamed: 64'),(inversion_01['myVarname'] == 'Unnamed: 65'),(inversion_01['myVarname'] == 'Unnamed: 66'),
             (inversion_01['myVarname'] == 'Unnamed: 67'),(inversion_01['myVarname'] == 'Unnamed: 68'),(inversion_01['myVarname'] == 'Unnamed: 69'),(inversion_01['myVarname'] == 'Unnamed: 70'),(inversion_01['myVarname'] == 'Unnamed: 71'),
              (inversion_01['myVarname'] == 'Unnamed: 72'),(inversion_01['myVarname'] == 'Unnamed: 73'),(inversion_01['myVarname'] == 'Unnamed: 74'),(inversion_01['myVarname'] == 'Unnamed: 75'),(inversion_01['myVarname'] == 'Unnamed: 76'),
               (inversion_01['myVarname'] == 'Unnamed: 77'),(inversion_01['myVarname'] == 'Unnamed: 78'),(inversion_01['myVarname'] == 'Unnamed: 79'),(inversion_01['myVarname'] == 'Unnamed: 80'),(inversion_01['myVarname'] == 'Unnamed: 81'),
                (inversion_01['myVarname'] == 'Unnamed: 82'),(inversion_01['myVarname'] == 'Unnamed: 83'),(inversion_01['myVarname'] == 'Unnamed: 84'),(inversion_01['myVarname'] == 'Unnamed: 85'),(inversion_01['myVarname'] == 'Unnamed: 86'),
                 (inversion_01['myVarname'] == 'Unnamed: 87'),(inversion_01['myVarname'] == 'Unnamed: 88'),(inversion_01['myVarname'] == 'Unnamed: 89'),(inversion_01['myVarname'] == 'Unnamed: 90'),(inversion_01['myVarname'] == 'Unnamed: 91'),
                  (inversion_01['myVarname'] == 'Unnamed: 92'),(inversion_01['myVarname'] == 'Unnamed: 93'),(inversion_01['myVarname'] == 'Unnamed: 94'),(inversion_01['myVarname'] == 'Unnamed: 95'),(inversion_01['myVarname'] == 'Unnamed: 96'),
                   (inversion_01['myVarname'] == 'Unnamed: 97'),(inversion_01['myVarname'] == 'Unnamed: 98'),(inversion_01['myVarname'] == 'Unnamed: 99'),(inversion_01['myVarname'] == 'Unnamed: 100'),(inversion_01['myVarname'] == 'Unnamed: 101'),
                    (inversion_01['myVarname'] == 'Unnamed: 102'),(inversion_01['myVarname'] == 'Unnamed: 103'),(inversion_01['myVarname'] == 'Unnamed: 104'),(inversion_01['myVarname'] == 'Unnamed: 105'),(inversion_01['myVarname'] == 'Unnamed: 106'),
                     (inversion_01['myVarname'] == 'Unnamed: 107'),(inversion_01['myVarname'] == 'Unnamed: 108'),(inversion_01['myVarname'] == 'Unnamed: 109'),(inversion_01['myVarname'] == 'Unnamed: 110'),(inversion_01['myVarname'] == 'Unnamed: 111'),
                      (inversion_01['myVarname'] == 'Unnamed: 112'),(inversion_01['myVarname'] == 'Unnamed: 113'),(inversion_01['myVarname'] == 'Unnamed: 114'),(inversion_01['myVarname'] == 'Unnamed: 115'),(inversion_01['myVarname'] == 'Unnamed: 116'),
                       (inversion_01['myVarname'] == 'Unnamed: 117'),(inversion_01['myVarname'] == 'Unnamed: 118'),(inversion_01['myVarname'] == 'Unnamed: 119'),(inversion_01['myVarname'] == 'Unnamed: 120'),(inversion_01['myVarname'] == 'Unnamed: 121'),
                        (inversion_01['myVarname'] == 'Unnamed: 122'),(inversion_01['myVarname'] == 'Unnamed: 123'),(inversion_01['myVarname'] == 'Unnamed: 124'),(inversion_01['myVarname'] == 'Unnamed: 125'),(inversion_01['myVarname'] == 'Unnamed: 126'),
                         (inversion_01['myVarname'] == 'Unnamed: 127'),(inversion_01['myVarname'] == 'Unnamed: 128'),(inversion_01['myVarname'] == 'Unnamed: 129'),(inversion_01['myVarname'] == 'Unnamed: 130'),(inversion_01['myVarname'] == 'Unnamed: 131'),
                          (inversion_01['myVarname'] == 'Unnamed: 132'),(inversion_01['myVarname'] == 'Unnamed: 133'),(inversion_01['myVarname'] == 'Unnamed: 134'),(inversion_01['myVarname'] == 'Unnamed: 135'),(inversion_01['myVarname'] == 'Unnamed: 136'),
                           (inversion_01['myVarname'] == 'Unnamed: 137'),(inversion_01['myVarname'] == 'Unnamed: 138'),(inversion_01['myVarname'] == 'Unnamed: 139'),(inversion_01['myVarname'] == 'Unnamed: 140'),(inversion_01['myVarname'] == 'Unnamed: 141'),
                            (inversion_01['myVarname'] == 'Unnamed: 142'),(inversion_01['myVarname'] == 'Unnamed: 143'),(inversion_01['myVarname'] == 'Unnamed: 144'),(inversion_01['myVarname'] == 'Unnamed: 145'),(inversion_01['myVarname'] == 'Unnamed: 146'),
                             (inversion_01['myVarname'] == 'Unnamed: 147'),(inversion_01['myVarname'] == 'Unnamed: 148'),(inversion_01['myVarname'] == 'Unnamed: 149'),(inversion_01['myVarname'] == 'Unnamed: 150'),(inversion_01['myVarname'] == 'Unnamed: 151'),
                              (inversion_01['myVarname'] == 'Unnamed: 152'),(inversion_01['myVarname'] == 'Unnamed: 153'),(inversion_01['myVarname'] == 'Unnamed: 154'),(inversion_01['myVarname'] == 'Unnamed: 155'),(inversion_01['myVarname'] == 'Unnamed: 156'),
                               (inversion_01['myVarname'] == 'Unnamed: 157'),(inversion_01['myVarname'] == 'Unnamed: 158'),(inversion_01['myVarname'] == 'Unnamed: 159'),(inversion_01['myVarname'] == 'Unnamed: 160'),(inversion_01['myVarname'] == 'Unnamed: 161'),
                                (inversion_01['myVarname'] == 'Unnamed: 162'),(inversion_01['myVarname'] == 'Unnamed: 163'),(inversion_01['myVarname'] == 'Unnamed: 164'),(inversion_01['myVarname'] == 'Unnamed: 165'),(inversion_01['myVarname'] == 'Unnamed: 166')
                                ]

# %%
inversion_01['Fecha'] = np.select(conditions_1, values)

# %%
inversion_01.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
inversion_01.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
inversion_01['Tipo'] = "Inversión"
inversion_01['Subtipo'] = "Total inversion moneda nacional"
inversion_01['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
inversion_01 = inversion_01.reindex(columns=new_cols)

# %%
inversion_01.head(7)
# Out:
#          Fecha                        Institucion       Tipo  \
# 5   2008-01-31                         Banco Bice  Inversión
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Inversión
# 7   2008-01-31                Banco Consorcio (1)  Inversión
# 8   2008-01-31                 Banco de Chile (2)  Inversión
# 9   2008-01-31     Banco de Crédito e Inversiones  Inversión
# 10  2008-01-31  Banco de la Nación Argentina (18)  Inversión
# 11  2008-01-31          Banco del Estado de Chile  Inversión
#
#                             Subtipo           Valor  \
# 5   Total inversion moneda nacional   436033.276665
# 6   Total inversion moneda nacional              ND
# 7   Total inversion moneda nacional    36917.250048
# 8   Total inversion moneda nacional   826278.725894
# 9   Total inversion moneda nacional   732597.632347
# 10  Total inversion moneda nacional     3077.726955
# 11  Total inversion moneda nacional  3527698.443268
#
#                  Tipo de Moneda
# ...

# %% [markdown]
# ## Inversión 02

# %%
inversion_02.head(5)
# Out:
#         Unnamed: 0                             Unnamed: 1  \
# 0   Índice general                            Cuadro 3.02
# 1  Notas generales  Documentos del Banco Central de Chile
# 2              NaN            Saldos en millones de pesos
# 3              NaN                                    NaN
# 4              NaN                                    NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# ...

# %%
inversion_02.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
inversion_02 = inversion_02.iloc[5:]

# %%
inversion_02.tail(7)
# Out:
#                                        Unnamed: 1      Unnamed: 2  \
# 28                      Scotiabank Chile (3) (17)   303758.460998
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)     5453.081272
# 30                             Bank of China (16)              ND
# 31                                          Total  4558005.330338
# 32                                            NaN             NaN
# 33                                            NaN             NaN
# 34                            ND : No existe dato             NaN
#
#         Unnamed: 3      Unnamed: 4      Unnamed: 5      Unnamed: 6  \
# 28   298877.253297   319779.176545   313954.245336    279639.67701
# 29     4964.377017     4959.982598      3969.86299     4963.601083
# 30              ND              ND              ND              ND
# 31  4503964.699789  4351965.373526  4326807.998141  4508492.396557
# 32             NaN             NaN             NaN             NaN
# ...

# %%
inversion_02.drop(inversion_02.tail(4).index,inplace=True)
# Out:
# <ipython-input-362-ea5a7428f042>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inversion_02.drop(inversion_02.tail(4).index,inplace=True)

# %%
inversion_02.head(3)
# Out:
#                     Unnamed: 1     Unnamed: 2     Unnamed: 3     Unnamed: 4  \
# 5                   Banco Bice  254082.527019  272194.905169  145681.548055
# 6  Banco BTG Pactual Chile (9)             ND             ND             ND
# 7          Banco Consorcio (1)   35801.933737   19842.298851    26732.51547
#
#      Unnamed: 5     Unnamed: 6     Unnamed: 7     Unnamed: 8     Unnamed: 9  \
# 5  144399.55842  135855.385419  146097.429082  138735.928324  130264.057823
# 6            ND             ND             ND             ND             ND
# 7  40397.149374    37854.27307   35062.570896   33234.025126   32284.784778
#
#      Unnamed: 10  ...   Unnamed: 157   Unnamed: 158  Unnamed: 159  \
# 5  110801.301344  ...  734999.589394  740021.300386  784964.75188
# 6             ND  ...  189862.384295  113712.228515  76257.104201
# 7   31774.828551  ...    5058.492155  306183.579492    8876.56409
#
#     Unnamed: 160   Unnamed: 161   Unnamed: 162   Unnamed: 163   Unnamed: 164  \
# ...

# %%
inversion_02 = inversion_02.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_2 = [(inversion_02['myVarname'] == 'Unnamed: 2'),(inversion_02['myVarname'] == 'Unnamed: 3'),(inversion_02['myVarname'] == 'Unnamed: 4'),(inversion_02['myVarname'] == 'Unnamed: 5'),(inversion_02['myVarname'] == 'Unnamed: 6'),
 (inversion_02['myVarname'] == 'Unnamed: 7'),(inversion_02['myVarname'] == 'Unnamed: 8'),(inversion_02['myVarname'] == 'Unnamed: 9'),(inversion_02['myVarname'] == 'Unnamed: 10'),(inversion_02['myVarname'] == 'Unnamed: 11'),
  (inversion_02['myVarname'] == 'Unnamed: 12'),(inversion_02['myVarname'] == 'Unnamed: 13'),(inversion_02['myVarname'] == 'Unnamed: 14'),(inversion_02['myVarname'] == 'Unnamed: 15'),(inversion_02['myVarname'] == 'Unnamed: 16'),
   (inversion_02['myVarname'] == 'Unnamed: 17'),(inversion_02['myVarname'] == 'Unnamed: 18'),(inversion_02['myVarname'] == 'Unnamed: 19'),(inversion_02['myVarname'] == 'Unnamed: 20'),(inversion_02['myVarname'] == 'Unnamed: 21'),
    (inversion_02['myVarname'] == 'Unnamed: 22'),(inversion_02['myVarname'] == 'Unnamed: 23'),(inversion_02['myVarname'] == 'Unnamed: 24'),(inversion_02['myVarname'] == 'Unnamed: 25'),(inversion_02['myVarname'] == 'Unnamed: 26'),
     (inversion_02['myVarname'] == 'Unnamed: 27'),(inversion_02['myVarname'] == 'Unnamed: 28'),(inversion_02['myVarname'] == 'Unnamed: 29'),(inversion_02['myVarname'] == 'Unnamed: 30'),(inversion_02['myVarname'] == 'Unnamed: 31'),
      (inversion_02['myVarname'] == 'Unnamed: 32'),(inversion_02['myVarname'] == 'Unnamed: 33'),(inversion_02['myVarname'] == 'Unnamed: 34'),(inversion_02['myVarname'] == 'Unnamed: 35'),(inversion_02['myVarname'] == 'Unnamed: 36'),
       (inversion_02['myVarname'] == 'Unnamed: 37'),(inversion_02['myVarname'] == 'Unnamed: 38'),(inversion_02['myVarname'] == 'Unnamed: 39'),(inversion_02['myVarname'] == 'Unnamed: 40'),(inversion_02['myVarname'] == 'Unnamed: 41'),
        (inversion_02['myVarname'] == 'Unnamed: 42'),(inversion_02['myVarname'] == 'Unnamed: 43'),(inversion_02['myVarname'] == 'Unnamed: 44'),(inversion_02['myVarname'] == 'Unnamed: 45'),(inversion_02['myVarname'] == 'Unnamed: 46'),
         (inversion_02['myVarname'] == 'Unnamed: 47'),(inversion_02['myVarname'] == 'Unnamed: 48'),(inversion_02['myVarname'] == 'Unnamed: 49'),(inversion_02['myVarname'] == 'Unnamed: 50'),(inversion_02['myVarname'] == 'Unnamed: 51'),
          (inversion_02['myVarname'] == 'Unnamed: 52'),(inversion_02['myVarname'] == 'Unnamed: 53'),(inversion_02['myVarname'] == 'Unnamed: 54'),(inversion_02['myVarname'] == 'Unnamed: 55'),(inversion_02['myVarname'] == 'Unnamed: 56'),
           (inversion_02['myVarname'] == 'Unnamed: 57'),(inversion_02['myVarname'] == 'Unnamed: 58'),(inversion_02['myVarname'] == 'Unnamed: 59'),(inversion_02['myVarname'] == 'Unnamed: 60'),(inversion_02['myVarname'] == 'Unnamed: 61'),
            (inversion_02['myVarname'] == 'Unnamed: 62'),(inversion_02['myVarname'] == 'Unnamed: 63'),(inversion_02['myVarname'] == 'Unnamed: 64'),(inversion_02['myVarname'] == 'Unnamed: 65'),(inversion_02['myVarname'] == 'Unnamed: 66'),
             (inversion_02['myVarname'] == 'Unnamed: 67'),(inversion_02['myVarname'] == 'Unnamed: 68'),(inversion_02['myVarname'] == 'Unnamed: 69'),(inversion_02['myVarname'] == 'Unnamed: 70'),(inversion_02['myVarname'] == 'Unnamed: 71'),
              (inversion_02['myVarname'] == 'Unnamed: 72'),(inversion_02['myVarname'] == 'Unnamed: 73'),(inversion_02['myVarname'] == 'Unnamed: 74'),(inversion_02['myVarname'] == 'Unnamed: 75'),(inversion_02['myVarname'] == 'Unnamed: 76'),
               (inversion_02['myVarname'] == 'Unnamed: 77'),(inversion_02['myVarname'] == 'Unnamed: 78'),(inversion_02['myVarname'] == 'Unnamed: 79'),(inversion_02['myVarname'] == 'Unnamed: 80'),(inversion_02['myVarname'] == 'Unnamed: 81'),
                (inversion_02['myVarname'] == 'Unnamed: 82'),(inversion_02['myVarname'] == 'Unnamed: 83'),(inversion_02['myVarname'] == 'Unnamed: 84'),(inversion_02['myVarname'] == 'Unnamed: 85'),(inversion_02['myVarname'] == 'Unnamed: 86'),
                 (inversion_02['myVarname'] == 'Unnamed: 87'),(inversion_02['myVarname'] == 'Unnamed: 88'),(inversion_02['myVarname'] == 'Unnamed: 89'),(inversion_02['myVarname'] == 'Unnamed: 90'),(inversion_02['myVarname'] == 'Unnamed: 91'),
                  (inversion_02['myVarname'] == 'Unnamed: 92'),(inversion_02['myVarname'] == 'Unnamed: 93'),(inversion_02['myVarname'] == 'Unnamed: 94'),(inversion_02['myVarname'] == 'Unnamed: 95'),(inversion_02['myVarname'] == 'Unnamed: 96'),
                   (inversion_02['myVarname'] == 'Unnamed: 97'),(inversion_02['myVarname'] == 'Unnamed: 98'),(inversion_02['myVarname'] == 'Unnamed: 99'),(inversion_02['myVarname'] == 'Unnamed: 100'),(inversion_02['myVarname'] == 'Unnamed: 101'),
                    (inversion_02['myVarname'] == 'Unnamed: 102'),(inversion_02['myVarname'] == 'Unnamed: 103'),(inversion_02['myVarname'] == 'Unnamed: 104'),(inversion_02['myVarname'] == 'Unnamed: 105'),(inversion_02['myVarname'] == 'Unnamed: 106'),
                     (inversion_02['myVarname'] == 'Unnamed: 107'),(inversion_02['myVarname'] == 'Unnamed: 108'),(inversion_02['myVarname'] == 'Unnamed: 109'),(inversion_02['myVarname'] == 'Unnamed: 110'),(inversion_02['myVarname'] == 'Unnamed: 111'),
                      (inversion_02['myVarname'] == 'Unnamed: 112'),(inversion_02['myVarname'] == 'Unnamed: 113'),(inversion_02['myVarname'] == 'Unnamed: 114'),(inversion_02['myVarname'] == 'Unnamed: 115'),(inversion_02['myVarname'] == 'Unnamed: 116'),
                       (inversion_02['myVarname'] == 'Unnamed: 117'),(inversion_02['myVarname'] == 'Unnamed: 118'),(inversion_02['myVarname'] == 'Unnamed: 119'),(inversion_02['myVarname'] == 'Unnamed: 120'),(inversion_02['myVarname'] == 'Unnamed: 121'),
                        (inversion_02['myVarname'] == 'Unnamed: 122'),(inversion_02['myVarname'] == 'Unnamed: 123'),(inversion_02['myVarname'] == 'Unnamed: 124'),(inversion_02['myVarname'] == 'Unnamed: 125'),(inversion_02['myVarname'] == 'Unnamed: 126'),
                         (inversion_02['myVarname'] == 'Unnamed: 127'),(inversion_02['myVarname'] == 'Unnamed: 128'),(inversion_02['myVarname'] == 'Unnamed: 129'),(inversion_02['myVarname'] == 'Unnamed: 130'),(inversion_02['myVarname'] == 'Unnamed: 131'),
                          (inversion_02['myVarname'] == 'Unnamed: 132'),(inversion_02['myVarname'] == 'Unnamed: 133'),(inversion_02['myVarname'] == 'Unnamed: 134'),(inversion_02['myVarname'] == 'Unnamed: 135'),(inversion_02['myVarname'] == 'Unnamed: 136'),
                           (inversion_02['myVarname'] == 'Unnamed: 137'),(inversion_02['myVarname'] == 'Unnamed: 138'),(inversion_02['myVarname'] == 'Unnamed: 139'),(inversion_02['myVarname'] == 'Unnamed: 140'),(inversion_02['myVarname'] == 'Unnamed: 141'),
                            (inversion_02['myVarname'] == 'Unnamed: 142'),(inversion_02['myVarname'] == 'Unnamed: 143'),(inversion_02['myVarname'] == 'Unnamed: 144'),(inversion_02['myVarname'] == 'Unnamed: 145'),(inversion_02['myVarname'] == 'Unnamed: 146'),
                             (inversion_02['myVarname'] == 'Unnamed: 147'),(inversion_02['myVarname'] == 'Unnamed: 148'),(inversion_02['myVarname'] == 'Unnamed: 149'),(inversion_02['myVarname'] == 'Unnamed: 150'),(inversion_02['myVarname'] == 'Unnamed: 151'),
                              (inversion_02['myVarname'] == 'Unnamed: 152'),(inversion_02['myVarname'] == 'Unnamed: 153'),(inversion_02['myVarname'] == 'Unnamed: 154'),(inversion_02['myVarname'] == 'Unnamed: 155'),(inversion_02['myVarname'] == 'Unnamed: 156'),
                               (inversion_02['myVarname'] == 'Unnamed: 157'),(inversion_02['myVarname'] == 'Unnamed: 158'),(inversion_02['myVarname'] == 'Unnamed: 159'),(inversion_02['myVarname'] == 'Unnamed: 160'),(inversion_02['myVarname'] == 'Unnamed: 161'),
                                (inversion_02['myVarname'] == 'Unnamed: 162'),(inversion_02['myVarname'] == 'Unnamed: 163'),(inversion_02['myVarname'] == 'Unnamed: 164'),(inversion_02['myVarname'] == 'Unnamed: 165'),(inversion_02['myVarname'] == 'Unnamed: 166')
                                ]

# %%
inversion_02['Fecha'] = np.select(conditions_2, values)

# %%
inversion_02.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
inversion_02.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
inversion_02['Tipo'] = "Inversión"
inversion_02['Subtipo'] = "Documentos del Banco Central de Chile"
inversion_02['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
inversion_02 = inversion_02.reindex(columns=new_cols)

# %%
inversion_02.head(7)
# Out:
#          Fecha                        Institucion       Tipo  \
# 5   2008-01-31                         Banco Bice  Inversión
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Inversión
# 7   2008-01-31                Banco Consorcio (1)  Inversión
# 8   2008-01-31                 Banco de Chile (2)  Inversión
# 9   2008-01-31     Banco de Crédito e Inversiones  Inversión
# 10  2008-01-31  Banco de la Nación Argentina (18)  Inversión
# 11  2008-01-31          Banco del Estado de Chile  Inversión
#
#                                   Subtipo           Valor  \
# 5   Documentos del Banco Central de Chile   254082.527019
# 6   Documentos del Banco Central de Chile              ND
# 7   Documentos del Banco Central de Chile    35801.933737
# 8   Documentos del Banco Central de Chile   455717.858213
# 9   Documentos del Banco Central de Chile   366371.739054
# 10  Documentos del Banco Central de Chile               0
# 11  Documentos del Banco Central de Chile  1315881.755696
#
# ...

# %% [markdown]
# ## Inversión 03

# %%
inversion_03.head(5)
# Out:
#         Unnamed: 0                                         Unnamed: 1  \
# 0   Índice general                                        Cuadro 3.03
# 1  Notas generales  Documentos de la Tesorería General de la Repúb...
# 2              NaN                        Saldos en millones de pesos
# 3              NaN                                                NaN
# 4              NaN                                                NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
inversion_03.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
inversion_03 = inversion_03.iloc[5:]

# %%
inversion_03.tail(7)
# Out:
#                                        Unnamed: 1     Unnamed: 2  \
# 28                      Scotiabank Chile (3) (17)    4118.718476
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)              0
# 30                             Bank of China (16)             ND
# 31                                          Total  420611.249697
# 32                                            NaN            NaN
# 33                                            NaN            NaN
# 34                            ND : No existe dato            NaN
#
#        Unnamed: 3     Unnamed: 4     Unnamed: 5     Unnamed: 6    Unnamed: 7  \
# 28    6567.310353    3454.137099   15569.155483   14518.464872  16896.882178
# 29              0              0              0              0             0
# 30             ND             ND             ND             ND            ND
# 31  551734.918714  537352.261839  443509.651134  437144.421214   446268.8278
# ...

# %%
inversion_03.drop(inversion_03.tail(4).index,inplace=True)
# Out:
# <ipython-input-376-b279aa588676>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inversion_03.drop(inversion_03.tail(4).index,inplace=True)

# %%
inversion_03.head(3)
# Out:
#                     Unnamed: 1    Unnamed: 2    Unnamed: 3    Unnamed: 4  \
# 5                   Banco Bice  36472.743341  37295.222063  39404.610892
# 6  Banco BTG Pactual Chile (9)            ND            ND            ND
# 7          Banco Consorcio (1)   1115.316311    577.814469    2274.53609
#
#      Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  \
# 5  39181.607209  39865.939029  41583.016194  41528.103923  42836.906061
# 6            ND            ND            ND            ND            ND
# 7   1882.661667   1846.245566   1837.633395   1398.535394    1403.23528
#
#     Unnamed: 10  ...   Unnamed: 157   Unnamed: 158   Unnamed: 159  \
# 5  39412.708257  ...  365401.681327  358625.730101  329282.555653
# 6            ND  ...   68584.004273   23687.801233   56090.600533
# 7   1459.074322  ...  638078.508995  651940.173585  679948.683439
#
#     Unnamed: 160   Unnamed: 161   Unnamed: 162   Unnamed: 163   Unnamed: 164  \
# ...

# %%
inversion_03 = inversion_03.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_3 = [(inversion_03['myVarname'] == 'Unnamed: 2'),(inversion_03['myVarname'] == 'Unnamed: 3'),(inversion_03['myVarname'] == 'Unnamed: 4'),(inversion_03['myVarname'] == 'Unnamed: 5'),(inversion_03['myVarname'] == 'Unnamed: 6'),
 (inversion_03['myVarname'] == 'Unnamed: 7'),(inversion_03['myVarname'] == 'Unnamed: 8'),(inversion_03['myVarname'] == 'Unnamed: 9'),(inversion_03['myVarname'] == 'Unnamed: 10'),(inversion_03['myVarname'] == 'Unnamed: 11'),
  (inversion_03['myVarname'] == 'Unnamed: 12'),(inversion_03['myVarname'] == 'Unnamed: 13'),(inversion_03['myVarname'] == 'Unnamed: 14'),(inversion_03['myVarname'] == 'Unnamed: 15'),(inversion_03['myVarname'] == 'Unnamed: 16'),
   (inversion_03['myVarname'] == 'Unnamed: 17'),(inversion_03['myVarname'] == 'Unnamed: 18'),(inversion_03['myVarname'] == 'Unnamed: 19'),(inversion_03['myVarname'] == 'Unnamed: 20'),(inversion_03['myVarname'] == 'Unnamed: 21'),
    (inversion_03['myVarname'] == 'Unnamed: 22'),(inversion_03['myVarname'] == 'Unnamed: 23'),(inversion_03['myVarname'] == 'Unnamed: 24'),(inversion_03['myVarname'] == 'Unnamed: 25'),(inversion_03['myVarname'] == 'Unnamed: 26'),
     (inversion_03['myVarname'] == 'Unnamed: 27'),(inversion_03['myVarname'] == 'Unnamed: 28'),(inversion_03['myVarname'] == 'Unnamed: 29'),(inversion_03['myVarname'] == 'Unnamed: 30'),(inversion_03['myVarname'] == 'Unnamed: 31'),
      (inversion_03['myVarname'] == 'Unnamed: 32'),(inversion_03['myVarname'] == 'Unnamed: 33'),(inversion_03['myVarname'] == 'Unnamed: 34'),(inversion_03['myVarname'] == 'Unnamed: 35'),(inversion_03['myVarname'] == 'Unnamed: 36'),
       (inversion_03['myVarname'] == 'Unnamed: 37'),(inversion_03['myVarname'] == 'Unnamed: 38'),(inversion_03['myVarname'] == 'Unnamed: 39'),(inversion_03['myVarname'] == 'Unnamed: 40'),(inversion_03['myVarname'] == 'Unnamed: 41'),
        (inversion_03['myVarname'] == 'Unnamed: 42'),(inversion_03['myVarname'] == 'Unnamed: 43'),(inversion_03['myVarname'] == 'Unnamed: 44'),(inversion_03['myVarname'] == 'Unnamed: 45'),(inversion_03['myVarname'] == 'Unnamed: 46'),
         (inversion_03['myVarname'] == 'Unnamed: 47'),(inversion_03['myVarname'] == 'Unnamed: 48'),(inversion_03['myVarname'] == 'Unnamed: 49'),(inversion_03['myVarname'] == 'Unnamed: 50'),(inversion_03['myVarname'] == 'Unnamed: 51'),
          (inversion_03['myVarname'] == 'Unnamed: 52'),(inversion_03['myVarname'] == 'Unnamed: 53'),(inversion_03['myVarname'] == 'Unnamed: 54'),(inversion_03['myVarname'] == 'Unnamed: 55'),(inversion_03['myVarname'] == 'Unnamed: 56'),
           (inversion_03['myVarname'] == 'Unnamed: 57'),(inversion_03['myVarname'] == 'Unnamed: 58'),(inversion_03['myVarname'] == 'Unnamed: 59'),(inversion_03['myVarname'] == 'Unnamed: 60'),(inversion_03['myVarname'] == 'Unnamed: 61'),
            (inversion_03['myVarname'] == 'Unnamed: 62'),(inversion_03['myVarname'] == 'Unnamed: 63'),(inversion_03['myVarname'] == 'Unnamed: 64'),(inversion_03['myVarname'] == 'Unnamed: 65'),(inversion_03['myVarname'] == 'Unnamed: 66'),
             (inversion_03['myVarname'] == 'Unnamed: 67'),(inversion_03['myVarname'] == 'Unnamed: 68'),(inversion_03['myVarname'] == 'Unnamed: 69'),(inversion_03['myVarname'] == 'Unnamed: 70'),(inversion_03['myVarname'] == 'Unnamed: 71'),
              (inversion_03['myVarname'] == 'Unnamed: 72'),(inversion_03['myVarname'] == 'Unnamed: 73'),(inversion_03['myVarname'] == 'Unnamed: 74'),(inversion_03['myVarname'] == 'Unnamed: 75'),(inversion_03['myVarname'] == 'Unnamed: 76'),
               (inversion_03['myVarname'] == 'Unnamed: 77'),(inversion_03['myVarname'] == 'Unnamed: 78'),(inversion_03['myVarname'] == 'Unnamed: 79'),(inversion_03['myVarname'] == 'Unnamed: 80'),(inversion_03['myVarname'] == 'Unnamed: 81'),
                (inversion_03['myVarname'] == 'Unnamed: 82'),(inversion_03['myVarname'] == 'Unnamed: 83'),(inversion_03['myVarname'] == 'Unnamed: 84'),(inversion_03['myVarname'] == 'Unnamed: 85'),(inversion_03['myVarname'] == 'Unnamed: 86'),
                 (inversion_03['myVarname'] == 'Unnamed: 87'),(inversion_03['myVarname'] == 'Unnamed: 88'),(inversion_03['myVarname'] == 'Unnamed: 89'),(inversion_03['myVarname'] == 'Unnamed: 90'),(inversion_03['myVarname'] == 'Unnamed: 91'),
                  (inversion_03['myVarname'] == 'Unnamed: 92'),(inversion_03['myVarname'] == 'Unnamed: 93'),(inversion_03['myVarname'] == 'Unnamed: 94'),(inversion_03['myVarname'] == 'Unnamed: 95'),(inversion_03['myVarname'] == 'Unnamed: 96'),
                   (inversion_03['myVarname'] == 'Unnamed: 97'),(inversion_03['myVarname'] == 'Unnamed: 98'),(inversion_03['myVarname'] == 'Unnamed: 99'),(inversion_03['myVarname'] == 'Unnamed: 100'),(inversion_03['myVarname'] == 'Unnamed: 101'),
                    (inversion_03['myVarname'] == 'Unnamed: 102'),(inversion_03['myVarname'] == 'Unnamed: 103'),(inversion_03['myVarname'] == 'Unnamed: 104'),(inversion_03['myVarname'] == 'Unnamed: 105'),(inversion_03['myVarname'] == 'Unnamed: 106'),
                     (inversion_03['myVarname'] == 'Unnamed: 107'),(inversion_03['myVarname'] == 'Unnamed: 108'),(inversion_03['myVarname'] == 'Unnamed: 109'),(inversion_03['myVarname'] == 'Unnamed: 110'),(inversion_03['myVarname'] == 'Unnamed: 111'),
                      (inversion_03['myVarname'] == 'Unnamed: 112'),(inversion_03['myVarname'] == 'Unnamed: 113'),(inversion_03['myVarname'] == 'Unnamed: 114'),(inversion_03['myVarname'] == 'Unnamed: 115'),(inversion_03['myVarname'] == 'Unnamed: 116'),
                       (inversion_03['myVarname'] == 'Unnamed: 117'),(inversion_03['myVarname'] == 'Unnamed: 118'),(inversion_03['myVarname'] == 'Unnamed: 119'),(inversion_03['myVarname'] == 'Unnamed: 120'),(inversion_03['myVarname'] == 'Unnamed: 121'),
                        (inversion_03['myVarname'] == 'Unnamed: 122'),(inversion_03['myVarname'] == 'Unnamed: 123'),(inversion_03['myVarname'] == 'Unnamed: 124'),(inversion_03['myVarname'] == 'Unnamed: 125'),(inversion_03['myVarname'] == 'Unnamed: 126'),
                         (inversion_03['myVarname'] == 'Unnamed: 127'),(inversion_03['myVarname'] == 'Unnamed: 128'),(inversion_03['myVarname'] == 'Unnamed: 129'),(inversion_03['myVarname'] == 'Unnamed: 130'),(inversion_03['myVarname'] == 'Unnamed: 131'),
                          (inversion_03['myVarname'] == 'Unnamed: 132'),(inversion_03['myVarname'] == 'Unnamed: 133'),(inversion_03['myVarname'] == 'Unnamed: 134'),(inversion_03['myVarname'] == 'Unnamed: 135'),(inversion_03['myVarname'] == 'Unnamed: 136'),
                           (inversion_03['myVarname'] == 'Unnamed: 137'),(inversion_03['myVarname'] == 'Unnamed: 138'),(inversion_03['myVarname'] == 'Unnamed: 139'),(inversion_03['myVarname'] == 'Unnamed: 140'),(inversion_03['myVarname'] == 'Unnamed: 141'),
                            (inversion_03['myVarname'] == 'Unnamed: 142'),(inversion_03['myVarname'] == 'Unnamed: 143'),(inversion_03['myVarname'] == 'Unnamed: 144'),(inversion_03['myVarname'] == 'Unnamed: 145'),(inversion_03['myVarname'] == 'Unnamed: 146'),
                             (inversion_03['myVarname'] == 'Unnamed: 147'),(inversion_03['myVarname'] == 'Unnamed: 148'),(inversion_03['myVarname'] == 'Unnamed: 149'),(inversion_03['myVarname'] == 'Unnamed: 150'),(inversion_03['myVarname'] == 'Unnamed: 151'),
                              (inversion_03['myVarname'] == 'Unnamed: 152'),(inversion_03['myVarname'] == 'Unnamed: 153'),(inversion_03['myVarname'] == 'Unnamed: 154'),(inversion_03['myVarname'] == 'Unnamed: 155'),(inversion_03['myVarname'] == 'Unnamed: 156'),
                               (inversion_03['myVarname'] == 'Unnamed: 157'),(inversion_03['myVarname'] == 'Unnamed: 158'),(inversion_03['myVarname'] == 'Unnamed: 159'),(inversion_03['myVarname'] == 'Unnamed: 160'),(inversion_03['myVarname'] == 'Unnamed: 161'),
                                (inversion_03['myVarname'] == 'Unnamed: 162'),(inversion_03['myVarname'] == 'Unnamed: 163'),(inversion_03['myVarname'] == 'Unnamed: 164'),(inversion_03['myVarname'] == 'Unnamed: 165'),(inversion_03['myVarname'] == 'Unnamed: 166')
                                ]

# %%
inversion_03['Fecha'] = np.select(conditions_3, values)

# %%
inversion_03.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
inversion_03.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
inversion_03['Tipo'] = "Inversión"
inversion_03['Subtipo'] = "Documentos de la Tesorería General de la República"
inversion_03['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
inversion_03 = inversion_03.reindex(columns=new_cols)

# %%
inversion_03.head(7)
# Out:
#          Fecha                        Institucion       Tipo  \
# 5   2008-01-31                         Banco Bice  Inversión
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Inversión
# 7   2008-01-31                Banco Consorcio (1)  Inversión
# 8   2008-01-31                 Banco de Chile (2)  Inversión
# 9   2008-01-31     Banco de Crédito e Inversiones  Inversión
# 10  2008-01-31  Banco de la Nación Argentina (18)  Inversión
# 11  2008-01-31          Banco del Estado de Chile  Inversión
#
#                                               Subtipo          Valor  \
# 5   Documentos de la Tesorería General de la Repúb...   36472.743341
# 6   Documentos de la Tesorería General de la Repúb...             ND
# 7   Documentos de la Tesorería General de la Repúb...    1115.316311
# 8   Documentos de la Tesorería General de la Repúb...    25574.73171
# 9   Documentos de la Tesorería General de la Repúb...    7673.288211
# ...

# %% [markdown]
# ## Inversión 04

# %%
inversion_04.head(5)
# Out:
#         Unnamed: 0                                         Unnamed: 1  \
# 0   Índice general                                        Cuadro 3.04
# 1  Notas generales  Otros documentos emitidos por organismos fiscales
# 2              NaN                        Saldos en millones de pesos
# 3              NaN                                                NaN
# 4              NaN                                                NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
inversion_04.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
inversion_04 = inversion_04.iloc[5:]

# %%
inversion_04.tail(7)
# Out:
#                                        Unnamed: 1    Unnamed: 2    Unnamed: 3  \
# 28                      Scotiabank Chile (3) (17)             0             0
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)             0             0
# 30                             Bank of China (16)            ND            ND
# 31                                          Total  73854.735321  69941.388009
# 32                                            NaN           NaN           NaN
# 33                                            NaN           NaN           NaN
# 34                            ND : No existe dato           NaN           NaN
#
#       Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8  \
# 28    766.919289    615.724512    592.337205    600.672206    570.455677
# 29             0             0             0             0             0
# 30            ND            ND            ND            ND            ND
# ...

# %%
inversion_04.drop(inversion_04.tail(4).index,inplace=True)
# Out:
# <ipython-input-390-a00007025c00>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inversion_04.drop(inversion_04.tail(4).index,inplace=True)

# %%
inversion_04.head(3)
# Out:
#                     Unnamed: 1   Unnamed: 2   Unnamed: 3   Unnamed: 4  \
# 5                   Banco Bice  3027.489784  1991.776951  1776.576557
# 6  Banco BTG Pactual Chile (9)           ND           ND           ND
# 7          Banco Consorcio (1)            0            0            0
#
#     Unnamed: 5  Unnamed: 6 Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10  \
# 5  1472.674204  1025.76744   825.3062  237.858752  241.242852           0
# 6           ND          ND         ND          ND          ND          ND
# 7            0           0          0           0           0           0
#
#    ... Unnamed: 157 Unnamed: 158 Unnamed: 159 Unnamed: 160 Unnamed: 161  \
# 5  ...            0            0            0            0            0
# 6  ...            0            0            0            0            0
# 7  ...            0            0            0            0            0
#
#   Unnamed: 162 Unnamed: 163 Unnamed: 164 Unnamed: 165 Unnamed: 166
# ...

# %%
inversion_04 = inversion_04.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_4 = [(inversion_04['myVarname'] == 'Unnamed: 2'),(inversion_04['myVarname'] == 'Unnamed: 3'),(inversion_04['myVarname'] == 'Unnamed: 4'),(inversion_04['myVarname'] == 'Unnamed: 5'),(inversion_04['myVarname'] == 'Unnamed: 6'),
 (inversion_04['myVarname'] == 'Unnamed: 7'),(inversion_04['myVarname'] == 'Unnamed: 8'),(inversion_04['myVarname'] == 'Unnamed: 9'),(inversion_04['myVarname'] == 'Unnamed: 10'),(inversion_04['myVarname'] == 'Unnamed: 11'),
  (inversion_04['myVarname'] == 'Unnamed: 12'),(inversion_04['myVarname'] == 'Unnamed: 13'),(inversion_04['myVarname'] == 'Unnamed: 14'),(inversion_04['myVarname'] == 'Unnamed: 15'),(inversion_04['myVarname'] == 'Unnamed: 16'),
   (inversion_04['myVarname'] == 'Unnamed: 17'),(inversion_04['myVarname'] == 'Unnamed: 18'),(inversion_04['myVarname'] == 'Unnamed: 19'),(inversion_04['myVarname'] == 'Unnamed: 20'),(inversion_04['myVarname'] == 'Unnamed: 21'),
    (inversion_04['myVarname'] == 'Unnamed: 22'),(inversion_04['myVarname'] == 'Unnamed: 23'),(inversion_04['myVarname'] == 'Unnamed: 24'),(inversion_04['myVarname'] == 'Unnamed: 25'),(inversion_04['myVarname'] == 'Unnamed: 26'),
     (inversion_04['myVarname'] == 'Unnamed: 27'),(inversion_04['myVarname'] == 'Unnamed: 28'),(inversion_04['myVarname'] == 'Unnamed: 29'),(inversion_04['myVarname'] == 'Unnamed: 30'),(inversion_04['myVarname'] == 'Unnamed: 31'),
      (inversion_04['myVarname'] == 'Unnamed: 32'),(inversion_04['myVarname'] == 'Unnamed: 33'),(inversion_04['myVarname'] == 'Unnamed: 34'),(inversion_04['myVarname'] == 'Unnamed: 35'),(inversion_04['myVarname'] == 'Unnamed: 36'),
       (inversion_04['myVarname'] == 'Unnamed: 37'),(inversion_04['myVarname'] == 'Unnamed: 38'),(inversion_04['myVarname'] == 'Unnamed: 39'),(inversion_04['myVarname'] == 'Unnamed: 40'),(inversion_04['myVarname'] == 'Unnamed: 41'),
        (inversion_04['myVarname'] == 'Unnamed: 42'),(inversion_04['myVarname'] == 'Unnamed: 43'),(inversion_04['myVarname'] == 'Unnamed: 44'),(inversion_04['myVarname'] == 'Unnamed: 45'),(inversion_04['myVarname'] == 'Unnamed: 46'),
         (inversion_04['myVarname'] == 'Unnamed: 47'),(inversion_04['myVarname'] == 'Unnamed: 48'),(inversion_04['myVarname'] == 'Unnamed: 49'),(inversion_04['myVarname'] == 'Unnamed: 50'),(inversion_04['myVarname'] == 'Unnamed: 51'),
          (inversion_04['myVarname'] == 'Unnamed: 52'),(inversion_04['myVarname'] == 'Unnamed: 53'),(inversion_04['myVarname'] == 'Unnamed: 54'),(inversion_04['myVarname'] == 'Unnamed: 55'),(inversion_04['myVarname'] == 'Unnamed: 56'),
           (inversion_04['myVarname'] == 'Unnamed: 57'),(inversion_04['myVarname'] == 'Unnamed: 58'),(inversion_04['myVarname'] == 'Unnamed: 59'),(inversion_04['myVarname'] == 'Unnamed: 60'),(inversion_04['myVarname'] == 'Unnamed: 61'),
            (inversion_04['myVarname'] == 'Unnamed: 62'),(inversion_04['myVarname'] == 'Unnamed: 63'),(inversion_04['myVarname'] == 'Unnamed: 64'),(inversion_04['myVarname'] == 'Unnamed: 65'),(inversion_04['myVarname'] == 'Unnamed: 66'),
             (inversion_04['myVarname'] == 'Unnamed: 67'),(inversion_04['myVarname'] == 'Unnamed: 68'),(inversion_04['myVarname'] == 'Unnamed: 69'),(inversion_04['myVarname'] == 'Unnamed: 70'),(inversion_04['myVarname'] == 'Unnamed: 71'),
              (inversion_04['myVarname'] == 'Unnamed: 72'),(inversion_04['myVarname'] == 'Unnamed: 73'),(inversion_04['myVarname'] == 'Unnamed: 74'),(inversion_04['myVarname'] == 'Unnamed: 75'),(inversion_04['myVarname'] == 'Unnamed: 76'),
               (inversion_04['myVarname'] == 'Unnamed: 77'),(inversion_04['myVarname'] == 'Unnamed: 78'),(inversion_04['myVarname'] == 'Unnamed: 79'),(inversion_04['myVarname'] == 'Unnamed: 80'),(inversion_04['myVarname'] == 'Unnamed: 81'),
                (inversion_04['myVarname'] == 'Unnamed: 82'),(inversion_04['myVarname'] == 'Unnamed: 83'),(inversion_04['myVarname'] == 'Unnamed: 84'),(inversion_04['myVarname'] == 'Unnamed: 85'),(inversion_04['myVarname'] == 'Unnamed: 86'),
                 (inversion_04['myVarname'] == 'Unnamed: 87'),(inversion_04['myVarname'] == 'Unnamed: 88'),(inversion_04['myVarname'] == 'Unnamed: 89'),(inversion_04['myVarname'] == 'Unnamed: 90'),(inversion_04['myVarname'] == 'Unnamed: 91'),
                  (inversion_04['myVarname'] == 'Unnamed: 92'),(inversion_04['myVarname'] == 'Unnamed: 93'),(inversion_04['myVarname'] == 'Unnamed: 94'),(inversion_04['myVarname'] == 'Unnamed: 95'),(inversion_04['myVarname'] == 'Unnamed: 96'),
                   (inversion_04['myVarname'] == 'Unnamed: 97'),(inversion_04['myVarname'] == 'Unnamed: 98'),(inversion_04['myVarname'] == 'Unnamed: 99'),(inversion_04['myVarname'] == 'Unnamed: 100'),(inversion_04['myVarname'] == 'Unnamed: 101'),
                    (inversion_04['myVarname'] == 'Unnamed: 102'),(inversion_04['myVarname'] == 'Unnamed: 103'),(inversion_04['myVarname'] == 'Unnamed: 104'),(inversion_04['myVarname'] == 'Unnamed: 105'),(inversion_04['myVarname'] == 'Unnamed: 106'),
                     (inversion_04['myVarname'] == 'Unnamed: 107'),(inversion_04['myVarname'] == 'Unnamed: 108'),(inversion_04['myVarname'] == 'Unnamed: 109'),(inversion_04['myVarname'] == 'Unnamed: 110'),(inversion_04['myVarname'] == 'Unnamed: 111'),
                      (inversion_04['myVarname'] == 'Unnamed: 112'),(inversion_04['myVarname'] == 'Unnamed: 113'),(inversion_04['myVarname'] == 'Unnamed: 114'),(inversion_04['myVarname'] == 'Unnamed: 115'),(inversion_04['myVarname'] == 'Unnamed: 116'),
                       (inversion_04['myVarname'] == 'Unnamed: 117'),(inversion_04['myVarname'] == 'Unnamed: 118'),(inversion_04['myVarname'] == 'Unnamed: 119'),(inversion_04['myVarname'] == 'Unnamed: 120'),(inversion_04['myVarname'] == 'Unnamed: 121'),
                        (inversion_04['myVarname'] == 'Unnamed: 122'),(inversion_04['myVarname'] == 'Unnamed: 123'),(inversion_04['myVarname'] == 'Unnamed: 124'),(inversion_04['myVarname'] == 'Unnamed: 125'),(inversion_04['myVarname'] == 'Unnamed: 126'),
                         (inversion_04['myVarname'] == 'Unnamed: 127'),(inversion_04['myVarname'] == 'Unnamed: 128'),(inversion_04['myVarname'] == 'Unnamed: 129'),(inversion_04['myVarname'] == 'Unnamed: 130'),(inversion_04['myVarname'] == 'Unnamed: 131'),
                          (inversion_04['myVarname'] == 'Unnamed: 132'),(inversion_04['myVarname'] == 'Unnamed: 133'),(inversion_04['myVarname'] == 'Unnamed: 134'),(inversion_04['myVarname'] == 'Unnamed: 135'),(inversion_04['myVarname'] == 'Unnamed: 136'),
                           (inversion_04['myVarname'] == 'Unnamed: 137'),(inversion_04['myVarname'] == 'Unnamed: 138'),(inversion_04['myVarname'] == 'Unnamed: 139'),(inversion_04['myVarname'] == 'Unnamed: 140'),(inversion_04['myVarname'] == 'Unnamed: 141'),
                            (inversion_04['myVarname'] == 'Unnamed: 142'),(inversion_04['myVarname'] == 'Unnamed: 143'),(inversion_04['myVarname'] == 'Unnamed: 144'),(inversion_04['myVarname'] == 'Unnamed: 145'),(inversion_04['myVarname'] == 'Unnamed: 146'),
                             (inversion_04['myVarname'] == 'Unnamed: 147'),(inversion_04['myVarname'] == 'Unnamed: 148'),(inversion_04['myVarname'] == 'Unnamed: 149'),(inversion_04['myVarname'] == 'Unnamed: 150'),(inversion_04['myVarname'] == 'Unnamed: 151'),
                              (inversion_04['myVarname'] == 'Unnamed: 152'),(inversion_04['myVarname'] == 'Unnamed: 153'),(inversion_04['myVarname'] == 'Unnamed: 154'),(inversion_04['myVarname'] == 'Unnamed: 155'),(inversion_04['myVarname'] == 'Unnamed: 156'),
                               (inversion_04['myVarname'] == 'Unnamed: 157'),(inversion_04['myVarname'] == 'Unnamed: 158'),(inversion_04['myVarname'] == 'Unnamed: 159'),(inversion_04['myVarname'] == 'Unnamed: 160'),(inversion_04['myVarname'] == 'Unnamed: 161'),
                                (inversion_04['myVarname'] == 'Unnamed: 162'),(inversion_04['myVarname'] == 'Unnamed: 163'),(inversion_04['myVarname'] == 'Unnamed: 164'),(inversion_04['myVarname'] == 'Unnamed: 165'),(inversion_04['myVarname'] == 'Unnamed: 166')
                                ]

# %%
inversion_04['Fecha'] = np.select(conditions_4, values)

# %%
inversion_04.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
inversion_04.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
inversion_04['Tipo'] = "Inversión"
inversion_04['Subtipo'] = "Otros documentos emitidos por organismos fiscales"
inversion_04['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
inversion_04 = inversion_04.reindex(columns=new_cols)

# %%
inversion_04.head(7)
# Out:
#          Fecha                        Institucion       Tipo  \
# 5   2008-01-31                         Banco Bice  Inversión
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Inversión
# 7   2008-01-31                Banco Consorcio (1)  Inversión
# 8   2008-01-31                 Banco de Chile (2)  Inversión
# 9   2008-01-31     Banco de Crédito e Inversiones  Inversión
# 10  2008-01-31  Banco de la Nación Argentina (18)  Inversión
# 11  2008-01-31          Banco del Estado de Chile  Inversión
#
#                                               Subtipo         Valor  \
# 5   Otros documentos emitidos por organismos fiscales   3027.489784
# 6   Otros documentos emitidos por organismos fiscales            ND
# 7   Otros documentos emitidos por organismos fiscales             0
# 8   Otros documentos emitidos por organismos fiscales    385.009179
# 9   Otros documentos emitidos por organismos fiscales  13702.300487
# ...

# %% [markdown]
# ## Inversión 05

# %%
inversion_05.head(5)
# Out:
#         Unnamed: 0                                         Unnamed: 1  \
# 0   Índice general                                        Cuadro 3.05
# 1  Notas generales  Otros documentos emitidos por otras institucio...
# 2              NaN                        Saldos en millones de pesos
# 3              NaN                                                NaN
# 4              NaN                                                NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
inversion_05.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
inversion_05 = inversion_05.iloc[5:]

# %%
inversion_05.tail(7)
# Out:
#                                        Unnamed: 1      Unnamed: 2  \
# 28                      Scotiabank Chile (3) (17)   419408.121028
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)               0
# 30                             Bank of China (16)              ND
# 31                                          Total  3763360.415235
# 32                                            NaN             NaN
# 33                                            NaN             NaN
# 34                            ND : No existe dato             NaN
#
#         Unnamed: 3      Unnamed: 4      Unnamed: 5      Unnamed: 6  \
# 28   415938.149864   401218.756107   427041.846934   383291.270484
# 29               0               0               0               0
# 30              ND              ND              ND              ND
# 31  3825331.283078  4052381.978166  4015586.736323  3907817.460517
# 32             NaN             NaN             NaN             NaN
# ...

# %%
inversion_05.drop(inversion_05.tail(4).index,inplace=True)
# Out:
# <ipython-input-404-370d203a7767>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inversion_05.drop(inversion_05.tail(4).index,inplace=True)

# %%
inversion_05.head(3)
# Out:
#                     Unnamed: 1     Unnamed: 2     Unnamed: 3     Unnamed: 4  \
# 5                   Banco Bice  141565.286649  132053.904926  101280.017188
# 6  Banco BTG Pactual Chile (9)             ND             ND             ND
# 7          Banco Consorcio (1)              0              0              0
#
#       Unnamed: 5     Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  \
# 5  123405.267375  113019.384115  89447.523658  83373.413615  97655.722899
# 6             ND             ND            ND            ND            ND
# 7              0              0             0   2139.746272   1420.495903
#
#     Unnamed: 10  ...  Unnamed: 157  Unnamed: 158  Unnamed: 159  Unnamed: 160  \
# 5  99881.852583  ...    343.714776   3348.965167   3348.898092    136.178879
# 6            ND  ...  18771.914458  15718.169611  11772.838617  14794.994324
# 7             0  ...  75320.000002  72501.838097  21009.358878  45422.981739
#
# ...

# %%
inversion_05 = inversion_05.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_5 = [(inversion_05['myVarname'] == 'Unnamed: 2'),(inversion_05['myVarname'] == 'Unnamed: 3'),(inversion_05['myVarname'] == 'Unnamed: 4'),(inversion_05['myVarname'] == 'Unnamed: 5'),(inversion_05['myVarname'] == 'Unnamed: 6'),
 (inversion_05['myVarname'] == 'Unnamed: 7'),(inversion_05['myVarname'] == 'Unnamed: 8'),(inversion_05['myVarname'] == 'Unnamed: 9'),(inversion_05['myVarname'] == 'Unnamed: 10'),(inversion_05['myVarname'] == 'Unnamed: 11'),
  (inversion_05['myVarname'] == 'Unnamed: 12'),(inversion_05['myVarname'] == 'Unnamed: 13'),(inversion_05['myVarname'] == 'Unnamed: 14'),(inversion_05['myVarname'] == 'Unnamed: 15'),(inversion_05['myVarname'] == 'Unnamed: 16'),
   (inversion_05['myVarname'] == 'Unnamed: 17'),(inversion_05['myVarname'] == 'Unnamed: 18'),(inversion_05['myVarname'] == 'Unnamed: 19'),(inversion_05['myVarname'] == 'Unnamed: 20'),(inversion_05['myVarname'] == 'Unnamed: 21'),
    (inversion_05['myVarname'] == 'Unnamed: 22'),(inversion_05['myVarname'] == 'Unnamed: 23'),(inversion_05['myVarname'] == 'Unnamed: 24'),(inversion_05['myVarname'] == 'Unnamed: 25'),(inversion_05['myVarname'] == 'Unnamed: 26'),
     (inversion_05['myVarname'] == 'Unnamed: 27'),(inversion_05['myVarname'] == 'Unnamed: 28'),(inversion_05['myVarname'] == 'Unnamed: 29'),(inversion_05['myVarname'] == 'Unnamed: 30'),(inversion_05['myVarname'] == 'Unnamed: 31'),
      (inversion_05['myVarname'] == 'Unnamed: 32'),(inversion_05['myVarname'] == 'Unnamed: 33'),(inversion_05['myVarname'] == 'Unnamed: 34'),(inversion_05['myVarname'] == 'Unnamed: 35'),(inversion_05['myVarname'] == 'Unnamed: 36'),
       (inversion_05['myVarname'] == 'Unnamed: 37'),(inversion_05['myVarname'] == 'Unnamed: 38'),(inversion_05['myVarname'] == 'Unnamed: 39'),(inversion_05['myVarname'] == 'Unnamed: 40'),(inversion_05['myVarname'] == 'Unnamed: 41'),
        (inversion_05['myVarname'] == 'Unnamed: 42'),(inversion_05['myVarname'] == 'Unnamed: 43'),(inversion_05['myVarname'] == 'Unnamed: 44'),(inversion_05['myVarname'] == 'Unnamed: 45'),(inversion_05['myVarname'] == 'Unnamed: 46'),
         (inversion_05['myVarname'] == 'Unnamed: 47'),(inversion_05['myVarname'] == 'Unnamed: 48'),(inversion_05['myVarname'] == 'Unnamed: 49'),(inversion_05['myVarname'] == 'Unnamed: 50'),(inversion_05['myVarname'] == 'Unnamed: 51'),
          (inversion_05['myVarname'] == 'Unnamed: 52'),(inversion_05['myVarname'] == 'Unnamed: 53'),(inversion_05['myVarname'] == 'Unnamed: 54'),(inversion_05['myVarname'] == 'Unnamed: 55'),(inversion_05['myVarname'] == 'Unnamed: 56'),
           (inversion_05['myVarname'] == 'Unnamed: 57'),(inversion_05['myVarname'] == 'Unnamed: 58'),(inversion_05['myVarname'] == 'Unnamed: 59'),(inversion_05['myVarname'] == 'Unnamed: 60'),(inversion_05['myVarname'] == 'Unnamed: 61'),
            (inversion_05['myVarname'] == 'Unnamed: 62'),(inversion_05['myVarname'] == 'Unnamed: 63'),(inversion_05['myVarname'] == 'Unnamed: 64'),(inversion_05['myVarname'] == 'Unnamed: 65'),(inversion_05['myVarname'] == 'Unnamed: 66'),
             (inversion_05['myVarname'] == 'Unnamed: 67'),(inversion_05['myVarname'] == 'Unnamed: 68'),(inversion_05['myVarname'] == 'Unnamed: 69'),(inversion_05['myVarname'] == 'Unnamed: 70'),(inversion_05['myVarname'] == 'Unnamed: 71'),
              (inversion_05['myVarname'] == 'Unnamed: 72'),(inversion_05['myVarname'] == 'Unnamed: 73'),(inversion_05['myVarname'] == 'Unnamed: 74'),(inversion_05['myVarname'] == 'Unnamed: 75'),(inversion_05['myVarname'] == 'Unnamed: 76'),
               (inversion_05['myVarname'] == 'Unnamed: 77'),(inversion_05['myVarname'] == 'Unnamed: 78'),(inversion_05['myVarname'] == 'Unnamed: 79'),(inversion_05['myVarname'] == 'Unnamed: 80'),(inversion_05['myVarname'] == 'Unnamed: 81'),
                (inversion_05['myVarname'] == 'Unnamed: 82'),(inversion_05['myVarname'] == 'Unnamed: 83'),(inversion_05['myVarname'] == 'Unnamed: 84'),(inversion_05['myVarname'] == 'Unnamed: 85'),(inversion_05['myVarname'] == 'Unnamed: 86'),
                 (inversion_05['myVarname'] == 'Unnamed: 87'),(inversion_05['myVarname'] == 'Unnamed: 88'),(inversion_05['myVarname'] == 'Unnamed: 89'),(inversion_05['myVarname'] == 'Unnamed: 90'),(inversion_05['myVarname'] == 'Unnamed: 91'),
                  (inversion_05['myVarname'] == 'Unnamed: 92'),(inversion_05['myVarname'] == 'Unnamed: 93'),(inversion_05['myVarname'] == 'Unnamed: 94'),(inversion_05['myVarname'] == 'Unnamed: 95'),(inversion_05['myVarname'] == 'Unnamed: 96'),
                   (inversion_05['myVarname'] == 'Unnamed: 97'),(inversion_05['myVarname'] == 'Unnamed: 98'),(inversion_05['myVarname'] == 'Unnamed: 99'),(inversion_05['myVarname'] == 'Unnamed: 100'),(inversion_05['myVarname'] == 'Unnamed: 101'),
                    (inversion_05['myVarname'] == 'Unnamed: 102'),(inversion_05['myVarname'] == 'Unnamed: 103'),(inversion_05['myVarname'] == 'Unnamed: 104'),(inversion_05['myVarname'] == 'Unnamed: 105'),(inversion_05['myVarname'] == 'Unnamed: 106'),
                     (inversion_05['myVarname'] == 'Unnamed: 107'),(inversion_05['myVarname'] == 'Unnamed: 108'),(inversion_05['myVarname'] == 'Unnamed: 109'),(inversion_05['myVarname'] == 'Unnamed: 110'),(inversion_05['myVarname'] == 'Unnamed: 111'),
                      (inversion_05['myVarname'] == 'Unnamed: 112'),(inversion_05['myVarname'] == 'Unnamed: 113'),(inversion_05['myVarname'] == 'Unnamed: 114'),(inversion_05['myVarname'] == 'Unnamed: 115'),(inversion_05['myVarname'] == 'Unnamed: 116'),
                       (inversion_05['myVarname'] == 'Unnamed: 117'),(inversion_05['myVarname'] == 'Unnamed: 118'),(inversion_05['myVarname'] == 'Unnamed: 119'),(inversion_05['myVarname'] == 'Unnamed: 120'),(inversion_05['myVarname'] == 'Unnamed: 121'),
                        (inversion_05['myVarname'] == 'Unnamed: 122'),(inversion_05['myVarname'] == 'Unnamed: 123'),(inversion_05['myVarname'] == 'Unnamed: 124'),(inversion_05['myVarname'] == 'Unnamed: 125'),(inversion_05['myVarname'] == 'Unnamed: 126'),
                         (inversion_05['myVarname'] == 'Unnamed: 127'),(inversion_05['myVarname'] == 'Unnamed: 128'),(inversion_05['myVarname'] == 'Unnamed: 129'),(inversion_05['myVarname'] == 'Unnamed: 130'),(inversion_05['myVarname'] == 'Unnamed: 131'),
                          (inversion_05['myVarname'] == 'Unnamed: 132'),(inversion_05['myVarname'] == 'Unnamed: 133'),(inversion_05['myVarname'] == 'Unnamed: 134'),(inversion_05['myVarname'] == 'Unnamed: 135'),(inversion_05['myVarname'] == 'Unnamed: 136'),
                           (inversion_05['myVarname'] == 'Unnamed: 137'),(inversion_05['myVarname'] == 'Unnamed: 138'),(inversion_05['myVarname'] == 'Unnamed: 139'),(inversion_05['myVarname'] == 'Unnamed: 140'),(inversion_05['myVarname'] == 'Unnamed: 141'),
                            (inversion_05['myVarname'] == 'Unnamed: 142'),(inversion_05['myVarname'] == 'Unnamed: 143'),(inversion_05['myVarname'] == 'Unnamed: 144'),(inversion_05['myVarname'] == 'Unnamed: 145'),(inversion_05['myVarname'] == 'Unnamed: 146'),
                             (inversion_05['myVarname'] == 'Unnamed: 147'),(inversion_05['myVarname'] == 'Unnamed: 148'),(inversion_05['myVarname'] == 'Unnamed: 149'),(inversion_05['myVarname'] == 'Unnamed: 150'),(inversion_05['myVarname'] == 'Unnamed: 151'),
                              (inversion_05['myVarname'] == 'Unnamed: 152'),(inversion_05['myVarname'] == 'Unnamed: 153'),(inversion_05['myVarname'] == 'Unnamed: 154'),(inversion_05['myVarname'] == 'Unnamed: 155'),(inversion_05['myVarname'] == 'Unnamed: 156'),
                               (inversion_05['myVarname'] == 'Unnamed: 157'),(inversion_05['myVarname'] == 'Unnamed: 158'),(inversion_05['myVarname'] == 'Unnamed: 159'),(inversion_05['myVarname'] == 'Unnamed: 160'),(inversion_05['myVarname'] == 'Unnamed: 161'),
                                (inversion_05['myVarname'] == 'Unnamed: 162'),(inversion_05['myVarname'] == 'Unnamed: 163'),(inversion_05['myVarname'] == 'Unnamed: 164'),(inversion_05['myVarname'] == 'Unnamed: 165'),(inversion_05['myVarname'] == 'Unnamed: 166')
                                ]

# %%
inversion_05['Fecha'] = np.select(conditions_5, values)

# %%
inversion_05.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
inversion_05.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
inversion_05['Tipo'] = "Inversión"
inversion_05['Subtipo'] = "Otros documentos emitidos por otras instituciones financieras del país"
inversion_05['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
inversion_05 = inversion_05.reindex(columns=new_cols)

# %%
inversion_05.head(7)
# Out:
#          Fecha                        Institucion       Tipo  \
# 5   2008-01-31                         Banco Bice  Inversión
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Inversión
# 7   2008-01-31                Banco Consorcio (1)  Inversión
# 8   2008-01-31                 Banco de Chile (2)  Inversión
# 9   2008-01-31     Banco de Crédito e Inversiones  Inversión
# 10  2008-01-31  Banco de la Nación Argentina (18)  Inversión
# 11  2008-01-31          Banco del Estado de Chile  Inversión
#
#                                               Subtipo          Valor  \
# 5   Otros documentos emitidos por otras institucio...  141565.286649
# 6   Otros documentos emitidos por otras institucio...             ND
# 7   Otros documentos emitidos por otras institucio...              0
# 8   Otros documentos emitidos por otras institucio...  155661.608139
# 9   Otros documentos emitidos por otras institucio...  278718.566152
# ...

# %% [markdown]
# ## Inversión 06

# %%
inversion_06.head(5)
# Out:
#         Unnamed: 0                                   Unnamed: 1  \
# 0   Índice general                                  Cuadro 3.06
# 1  Notas generales  Instrumentos de empresa emitidos en el país
# 2              NaN                  Saldos en millones de pesos
# 3              NaN                                          NaN
# 4              NaN                                          NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
inversion_06.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
inversion_06 = inversion_06.iloc[5:]

# %%
inversion_06.tail(7)
# Out:
#                                        Unnamed: 1    Unnamed: 2  \
# 28                      Scotiabank Chile (3) (17)   1737.199212
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)             0
# 30                             Bank of China (16)            ND
# 31                                          Total  146033.39884
# 32                                            NaN           NaN
# 33                                            NaN           NaN
# 34                            ND : No existe dato           NaN
#
#        Unnamed: 3     Unnamed: 4     Unnamed: 5     Unnamed: 6     Unnamed: 7  \
# 28    1767.579463     821.736457     541.825171     527.540661     527.030397
# 29              0              0              0              0              0
# 30             ND             ND             ND             ND             ND
# 31  145505.310828  150310.189762  151898.731707  145918.753547  144538.076157
# ...

# %%
inversion_06.drop(inversion_06.tail(4).index,inplace=True)
# Out:
# <ipython-input-418-5f127cb37bd7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inversion_06.drop(inversion_06.tail(4).index,inplace=True)

# %%
inversion_06.head(3)
# Out:
#                     Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 5                   Banco Bice  885.229872  877.295625  698.630379
# 6  Banco BTG Pactual Chile (9)          ND          ND          ND
# 7          Banco Consorcio (1)           0           0           0
#
#    Unnamed: 5  Unnamed: 6 Unnamed: 7  Unnamed: 8   Unnamed: 9 Unnamed: 10  \
# 5  731.949576  766.827259  6393.7029  393.467321  2316.088805   431.15912
# 6          ND          ND         ND          ND           ND          ND
# 7           0           0          0    1.648852    -0.118328           0
#
#    ...   Unnamed: 157   Unnamed: 158   Unnamed: 159   Unnamed: 160  \
# 5  ...    52291.10351   51391.840501    51628.52726   53215.848293
# 6  ...    67058.93998   68698.005067   68353.277269   69276.846314
# 7  ...  207372.939544  219573.737312  227565.359196  226256.762873
#
#     Unnamed: 161   Unnamed: 162  Unnamed: 163   Unnamed: 164   Unnamed: 165  \
# ...

# %%
inversion_06 = inversion_06.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_6 = [(inversion_06['myVarname'] == 'Unnamed: 2'),(inversion_06['myVarname'] == 'Unnamed: 3'),(inversion_06['myVarname'] == 'Unnamed: 4'),(inversion_06['myVarname'] == 'Unnamed: 5'),(inversion_06['myVarname'] == 'Unnamed: 6'),
 (inversion_06['myVarname'] == 'Unnamed: 7'),(inversion_06['myVarname'] == 'Unnamed: 8'),(inversion_06['myVarname'] == 'Unnamed: 9'),(inversion_06['myVarname'] == 'Unnamed: 10'),(inversion_06['myVarname'] == 'Unnamed: 11'),
  (inversion_06['myVarname'] == 'Unnamed: 12'),(inversion_06['myVarname'] == 'Unnamed: 13'),(inversion_06['myVarname'] == 'Unnamed: 14'),(inversion_06['myVarname'] == 'Unnamed: 15'),(inversion_06['myVarname'] == 'Unnamed: 16'),
   (inversion_06['myVarname'] == 'Unnamed: 17'),(inversion_06['myVarname'] == 'Unnamed: 18'),(inversion_06['myVarname'] == 'Unnamed: 19'),(inversion_06['myVarname'] == 'Unnamed: 20'),(inversion_06['myVarname'] == 'Unnamed: 21'),
    (inversion_06['myVarname'] == 'Unnamed: 22'),(inversion_06['myVarname'] == 'Unnamed: 23'),(inversion_06['myVarname'] == 'Unnamed: 24'),(inversion_06['myVarname'] == 'Unnamed: 25'),(inversion_06['myVarname'] == 'Unnamed: 26'),
     (inversion_06['myVarname'] == 'Unnamed: 27'),(inversion_06['myVarname'] == 'Unnamed: 28'),(inversion_06['myVarname'] == 'Unnamed: 29'),(inversion_06['myVarname'] == 'Unnamed: 30'),(inversion_06['myVarname'] == 'Unnamed: 31'),
      (inversion_06['myVarname'] == 'Unnamed: 32'),(inversion_06['myVarname'] == 'Unnamed: 33'),(inversion_06['myVarname'] == 'Unnamed: 34'),(inversion_06['myVarname'] == 'Unnamed: 35'),(inversion_06['myVarname'] == 'Unnamed: 36'),
       (inversion_06['myVarname'] == 'Unnamed: 37'),(inversion_06['myVarname'] == 'Unnamed: 38'),(inversion_06['myVarname'] == 'Unnamed: 39'),(inversion_06['myVarname'] == 'Unnamed: 40'),(inversion_06['myVarname'] == 'Unnamed: 41'),
        (inversion_06['myVarname'] == 'Unnamed: 42'),(inversion_06['myVarname'] == 'Unnamed: 43'),(inversion_06['myVarname'] == 'Unnamed: 44'),(inversion_06['myVarname'] == 'Unnamed: 45'),(inversion_06['myVarname'] == 'Unnamed: 46'),
         (inversion_06['myVarname'] == 'Unnamed: 47'),(inversion_06['myVarname'] == 'Unnamed: 48'),(inversion_06['myVarname'] == 'Unnamed: 49'),(inversion_06['myVarname'] == 'Unnamed: 50'),(inversion_06['myVarname'] == 'Unnamed: 51'),
          (inversion_06['myVarname'] == 'Unnamed: 52'),(inversion_06['myVarname'] == 'Unnamed: 53'),(inversion_06['myVarname'] == 'Unnamed: 54'),(inversion_06['myVarname'] == 'Unnamed: 55'),(inversion_06['myVarname'] == 'Unnamed: 56'),
           (inversion_06['myVarname'] == 'Unnamed: 57'),(inversion_06['myVarname'] == 'Unnamed: 58'),(inversion_06['myVarname'] == 'Unnamed: 59'),(inversion_06['myVarname'] == 'Unnamed: 60'),(inversion_06['myVarname'] == 'Unnamed: 61'),
            (inversion_06['myVarname'] == 'Unnamed: 62'),(inversion_06['myVarname'] == 'Unnamed: 63'),(inversion_06['myVarname'] == 'Unnamed: 64'),(inversion_06['myVarname'] == 'Unnamed: 65'),(inversion_06['myVarname'] == 'Unnamed: 66'),
             (inversion_06['myVarname'] == 'Unnamed: 67'),(inversion_06['myVarname'] == 'Unnamed: 68'),(inversion_06['myVarname'] == 'Unnamed: 69'),(inversion_06['myVarname'] == 'Unnamed: 70'),(inversion_06['myVarname'] == 'Unnamed: 71'),
              (inversion_06['myVarname'] == 'Unnamed: 72'),(inversion_06['myVarname'] == 'Unnamed: 73'),(inversion_06['myVarname'] == 'Unnamed: 74'),(inversion_06['myVarname'] == 'Unnamed: 75'),(inversion_06['myVarname'] == 'Unnamed: 76'),
               (inversion_06['myVarname'] == 'Unnamed: 77'),(inversion_06['myVarname'] == 'Unnamed: 78'),(inversion_06['myVarname'] == 'Unnamed: 79'),(inversion_06['myVarname'] == 'Unnamed: 80'),(inversion_06['myVarname'] == 'Unnamed: 81'),
                (inversion_06['myVarname'] == 'Unnamed: 82'),(inversion_06['myVarname'] == 'Unnamed: 83'),(inversion_06['myVarname'] == 'Unnamed: 84'),(inversion_06['myVarname'] == 'Unnamed: 85'),(inversion_06['myVarname'] == 'Unnamed: 86'),
                 (inversion_06['myVarname'] == 'Unnamed: 87'),(inversion_06['myVarname'] == 'Unnamed: 88'),(inversion_06['myVarname'] == 'Unnamed: 89'),(inversion_06['myVarname'] == 'Unnamed: 90'),(inversion_06['myVarname'] == 'Unnamed: 91'),
                  (inversion_06['myVarname'] == 'Unnamed: 92'),(inversion_06['myVarname'] == 'Unnamed: 93'),(inversion_06['myVarname'] == 'Unnamed: 94'),(inversion_06['myVarname'] == 'Unnamed: 95'),(inversion_06['myVarname'] == 'Unnamed: 96'),
                   (inversion_06['myVarname'] == 'Unnamed: 97'),(inversion_06['myVarname'] == 'Unnamed: 98'),(inversion_06['myVarname'] == 'Unnamed: 99'),(inversion_06['myVarname'] == 'Unnamed: 100'),(inversion_06['myVarname'] == 'Unnamed: 101'),
                    (inversion_06['myVarname'] == 'Unnamed: 102'),(inversion_06['myVarname'] == 'Unnamed: 103'),(inversion_06['myVarname'] == 'Unnamed: 104'),(inversion_06['myVarname'] == 'Unnamed: 105'),(inversion_06['myVarname'] == 'Unnamed: 106'),
                     (inversion_06['myVarname'] == 'Unnamed: 107'),(inversion_06['myVarname'] == 'Unnamed: 108'),(inversion_06['myVarname'] == 'Unnamed: 109'),(inversion_06['myVarname'] == 'Unnamed: 110'),(inversion_06['myVarname'] == 'Unnamed: 111'),
                      (inversion_06['myVarname'] == 'Unnamed: 112'),(inversion_06['myVarname'] == 'Unnamed: 113'),(inversion_06['myVarname'] == 'Unnamed: 114'),(inversion_06['myVarname'] == 'Unnamed: 115'),(inversion_06['myVarname'] == 'Unnamed: 116'),
                       (inversion_06['myVarname'] == 'Unnamed: 117'),(inversion_06['myVarname'] == 'Unnamed: 118'),(inversion_06['myVarname'] == 'Unnamed: 119'),(inversion_06['myVarname'] == 'Unnamed: 120'),(inversion_06['myVarname'] == 'Unnamed: 121'),
                        (inversion_06['myVarname'] == 'Unnamed: 122'),(inversion_06['myVarname'] == 'Unnamed: 123'),(inversion_06['myVarname'] == 'Unnamed: 124'),(inversion_06['myVarname'] == 'Unnamed: 125'),(inversion_06['myVarname'] == 'Unnamed: 126'),
                         (inversion_06['myVarname'] == 'Unnamed: 127'),(inversion_06['myVarname'] == 'Unnamed: 128'),(inversion_06['myVarname'] == 'Unnamed: 129'),(inversion_06['myVarname'] == 'Unnamed: 130'),(inversion_06['myVarname'] == 'Unnamed: 131'),
                          (inversion_06['myVarname'] == 'Unnamed: 132'),(inversion_06['myVarname'] == 'Unnamed: 133'),(inversion_06['myVarname'] == 'Unnamed: 134'),(inversion_06['myVarname'] == 'Unnamed: 135'),(inversion_06['myVarname'] == 'Unnamed: 136'),
                           (inversion_06['myVarname'] == 'Unnamed: 137'),(inversion_06['myVarname'] == 'Unnamed: 138'),(inversion_06['myVarname'] == 'Unnamed: 139'),(inversion_06['myVarname'] == 'Unnamed: 140'),(inversion_06['myVarname'] == 'Unnamed: 141'),
                            (inversion_06['myVarname'] == 'Unnamed: 142'),(inversion_06['myVarname'] == 'Unnamed: 143'),(inversion_06['myVarname'] == 'Unnamed: 144'),(inversion_06['myVarname'] == 'Unnamed: 145'),(inversion_06['myVarname'] == 'Unnamed: 146'),
                             (inversion_06['myVarname'] == 'Unnamed: 147'),(inversion_06['myVarname'] == 'Unnamed: 148'),(inversion_06['myVarname'] == 'Unnamed: 149'),(inversion_06['myVarname'] == 'Unnamed: 150'),(inversion_06['myVarname'] == 'Unnamed: 151'),
                              (inversion_06['myVarname'] == 'Unnamed: 152'),(inversion_06['myVarname'] == 'Unnamed: 153'),(inversion_06['myVarname'] == 'Unnamed: 154'),(inversion_06['myVarname'] == 'Unnamed: 155'),(inversion_06['myVarname'] == 'Unnamed: 156'),
                               (inversion_06['myVarname'] == 'Unnamed: 157'),(inversion_06['myVarname'] == 'Unnamed: 158'),(inversion_06['myVarname'] == 'Unnamed: 159'),(inversion_06['myVarname'] == 'Unnamed: 160'),(inversion_06['myVarname'] == 'Unnamed: 161'),
                                (inversion_06['myVarname'] == 'Unnamed: 162'),(inversion_06['myVarname'] == 'Unnamed: 163'),(inversion_06['myVarname'] == 'Unnamed: 164'),(inversion_06['myVarname'] == 'Unnamed: 165'),(inversion_06['myVarname'] == 'Unnamed: 166')
                                ]

# %%
inversion_06['Fecha'] = np.select(conditions_6, values)

# %%
inversion_06.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
inversion_06.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
inversion_06['Tipo'] = "Inversión"
inversion_06['Subtipo'] = "Instrumentos de empresa emitidos en el país"
inversion_06['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
inversion_06 = inversion_06.reindex(columns=new_cols)

# %%
inversion_06.head(7)
# Out:
#          Fecha                        Institucion       Tipo  \
# 5   2008-01-31                         Banco Bice  Inversión
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Inversión
# 7   2008-01-31                Banco Consorcio (1)  Inversión
# 8   2008-01-31                 Banco de Chile (2)  Inversión
# 9   2008-01-31     Banco de Crédito e Inversiones  Inversión
# 10  2008-01-31  Banco de la Nación Argentina (18)  Inversión
# 11  2008-01-31          Banco del Estado de Chile  Inversión
#
#                                         Subtipo         Valor  \
# 5   Instrumentos de empresa emitidos en el país    885.229872
# 6   Instrumentos de empresa emitidos en el país            ND
# 7   Instrumentos de empresa emitidos en el país             0
# 8   Instrumentos de empresa emitidos en el país  13976.960265
# 9   Instrumentos de empresa emitidos en el país  66131.738443
# 10  Instrumentos de empresa emitidos en el país             0
# ...

# %% [markdown]
# ## Inversión 07

# %%
inversion_07.head(5)
# Out:
#         Unnamed: 0                              Unnamed: 1  \
# 0   Índice general                             Cuadro 3.07
# 1  Notas generales  Otros instrumentos emitidos en el país
# 2              NaN             Saldos en millones de pesos
# 3              NaN                                     NaN
# 4              NaN                                     NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# ...

# %%
inversion_07.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
inversion_07 = inversion_07.iloc[5:]

# %%
inversion_07.tail(7)
# Out:
#                                        Unnamed: 1    Unnamed: 2    Unnamed: 3  \
# 28                      Scotiabank Chile (3) (17)             0             0
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)             0             0
# 30                             Bank of China (16)            ND            ND
# 31                                          Total  23475.640092  13246.321572
# 32                                            NaN           NaN           NaN
# 33                                            NaN           NaN           NaN
# 34                            ND : No existe dato           NaN           NaN
#
#       Unnamed: 4    Unnamed: 5    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 28             0             0             0          0          0          0
# 29             0             0             0          0          0          0
# 30            ND            ND            ND         ND         ND         ND
# ...

# %%
inversion_07.drop(inversion_07.tail(4).index,inplace=True)
# Out:
# <ipython-input-432-dc62a75bb8d5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inversion_07.drop(inversion_07.tail(4).index,inplace=True)

# %%
inversion_07.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice          0          0          0          0
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)          0          0          0          0
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 157  \
# 5          0          0          0          0           0  ...            0
# 6         ND         ND         ND         ND          ND  ...            0
# 7          0          0          0          0           0  ...            0
#
#   Unnamed: 158 Unnamed: 159 Unnamed: 160 Unnamed: 161 Unnamed: 162  \
# 5            0            0            0            0            0
# 6            0            0            0            0            0
# 7            0            0            0            0            0
#
#   Unnamed: 163 Unnamed: 164 Unnamed: 165 Unnamed: 166
# ...

# %%
inversion_07 = inversion_07.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_7 = [(inversion_07['myVarname'] == 'Unnamed: 2'),(inversion_07['myVarname'] == 'Unnamed: 3'),(inversion_07['myVarname'] == 'Unnamed: 4'),(inversion_07['myVarname'] == 'Unnamed: 5'),(inversion_07['myVarname'] == 'Unnamed: 6'),
 (inversion_07['myVarname'] == 'Unnamed: 7'),(inversion_07['myVarname'] == 'Unnamed: 8'),(inversion_07['myVarname'] == 'Unnamed: 9'),(inversion_07['myVarname'] == 'Unnamed: 10'),(inversion_07['myVarname'] == 'Unnamed: 11'),
  (inversion_07['myVarname'] == 'Unnamed: 12'),(inversion_07['myVarname'] == 'Unnamed: 13'),(inversion_07['myVarname'] == 'Unnamed: 14'),(inversion_07['myVarname'] == 'Unnamed: 15'),(inversion_07['myVarname'] == 'Unnamed: 16'),
   (inversion_07['myVarname'] == 'Unnamed: 17'),(inversion_07['myVarname'] == 'Unnamed: 18'),(inversion_07['myVarname'] == 'Unnamed: 19'),(inversion_07['myVarname'] == 'Unnamed: 20'),(inversion_07['myVarname'] == 'Unnamed: 21'),
    (inversion_07['myVarname'] == 'Unnamed: 22'),(inversion_07['myVarname'] == 'Unnamed: 23'),(inversion_07['myVarname'] == 'Unnamed: 24'),(inversion_07['myVarname'] == 'Unnamed: 25'),(inversion_07['myVarname'] == 'Unnamed: 26'),
     (inversion_07['myVarname'] == 'Unnamed: 27'),(inversion_07['myVarname'] == 'Unnamed: 28'),(inversion_07['myVarname'] == 'Unnamed: 29'),(inversion_07['myVarname'] == 'Unnamed: 30'),(inversion_07['myVarname'] == 'Unnamed: 31'),
      (inversion_07['myVarname'] == 'Unnamed: 32'),(inversion_07['myVarname'] == 'Unnamed: 33'),(inversion_07['myVarname'] == 'Unnamed: 34'),(inversion_07['myVarname'] == 'Unnamed: 35'),(inversion_07['myVarname'] == 'Unnamed: 36'),
       (inversion_07['myVarname'] == 'Unnamed: 37'),(inversion_07['myVarname'] == 'Unnamed: 38'),(inversion_07['myVarname'] == 'Unnamed: 39'),(inversion_07['myVarname'] == 'Unnamed: 40'),(inversion_07['myVarname'] == 'Unnamed: 41'),
        (inversion_07['myVarname'] == 'Unnamed: 42'),(inversion_07['myVarname'] == 'Unnamed: 43'),(inversion_07['myVarname'] == 'Unnamed: 44'),(inversion_07['myVarname'] == 'Unnamed: 45'),(inversion_07['myVarname'] == 'Unnamed: 46'),
         (inversion_07['myVarname'] == 'Unnamed: 47'),(inversion_07['myVarname'] == 'Unnamed: 48'),(inversion_07['myVarname'] == 'Unnamed: 49'),(inversion_07['myVarname'] == 'Unnamed: 50'),(inversion_07['myVarname'] == 'Unnamed: 51'),
          (inversion_07['myVarname'] == 'Unnamed: 52'),(inversion_07['myVarname'] == 'Unnamed: 53'),(inversion_07['myVarname'] == 'Unnamed: 54'),(inversion_07['myVarname'] == 'Unnamed: 55'),(inversion_07['myVarname'] == 'Unnamed: 56'),
           (inversion_07['myVarname'] == 'Unnamed: 57'),(inversion_07['myVarname'] == 'Unnamed: 58'),(inversion_07['myVarname'] == 'Unnamed: 59'),(inversion_07['myVarname'] == 'Unnamed: 60'),(inversion_07['myVarname'] == 'Unnamed: 61'),
            (inversion_07['myVarname'] == 'Unnamed: 62'),(inversion_07['myVarname'] == 'Unnamed: 63'),(inversion_07['myVarname'] == 'Unnamed: 64'),(inversion_07['myVarname'] == 'Unnamed: 65'),(inversion_07['myVarname'] == 'Unnamed: 66'),
             (inversion_07['myVarname'] == 'Unnamed: 67'),(inversion_07['myVarname'] == 'Unnamed: 68'),(inversion_07['myVarname'] == 'Unnamed: 69'),(inversion_07['myVarname'] == 'Unnamed: 70'),(inversion_07['myVarname'] == 'Unnamed: 71'),
              (inversion_07['myVarname'] == 'Unnamed: 72'),(inversion_07['myVarname'] == 'Unnamed: 73'),(inversion_07['myVarname'] == 'Unnamed: 74'),(inversion_07['myVarname'] == 'Unnamed: 75'),(inversion_07['myVarname'] == 'Unnamed: 76'),
               (inversion_07['myVarname'] == 'Unnamed: 77'),(inversion_07['myVarname'] == 'Unnamed: 78'),(inversion_07['myVarname'] == 'Unnamed: 79'),(inversion_07['myVarname'] == 'Unnamed: 80'),(inversion_07['myVarname'] == 'Unnamed: 81'),
                (inversion_07['myVarname'] == 'Unnamed: 82'),(inversion_07['myVarname'] == 'Unnamed: 83'),(inversion_07['myVarname'] == 'Unnamed: 84'),(inversion_07['myVarname'] == 'Unnamed: 85'),(inversion_07['myVarname'] == 'Unnamed: 86'),
                 (inversion_07['myVarname'] == 'Unnamed: 87'),(inversion_07['myVarname'] == 'Unnamed: 88'),(inversion_07['myVarname'] == 'Unnamed: 89'),(inversion_07['myVarname'] == 'Unnamed: 90'),(inversion_07['myVarname'] == 'Unnamed: 91'),
                  (inversion_07['myVarname'] == 'Unnamed: 92'),(inversion_07['myVarname'] == 'Unnamed: 93'),(inversion_07['myVarname'] == 'Unnamed: 94'),(inversion_07['myVarname'] == 'Unnamed: 95'),(inversion_07['myVarname'] == 'Unnamed: 96'),
                   (inversion_07['myVarname'] == 'Unnamed: 97'),(inversion_07['myVarname'] == 'Unnamed: 98'),(inversion_07['myVarname'] == 'Unnamed: 99'),(inversion_07['myVarname'] == 'Unnamed: 100'),(inversion_07['myVarname'] == 'Unnamed: 101'),
                    (inversion_07['myVarname'] == 'Unnamed: 102'),(inversion_07['myVarname'] == 'Unnamed: 103'),(inversion_07['myVarname'] == 'Unnamed: 104'),(inversion_07['myVarname'] == 'Unnamed: 105'),(inversion_07['myVarname'] == 'Unnamed: 106'),
                     (inversion_07['myVarname'] == 'Unnamed: 107'),(inversion_07['myVarname'] == 'Unnamed: 108'),(inversion_07['myVarname'] == 'Unnamed: 109'),(inversion_07['myVarname'] == 'Unnamed: 110'),(inversion_07['myVarname'] == 'Unnamed: 111'),
                      (inversion_07['myVarname'] == 'Unnamed: 112'),(inversion_07['myVarname'] == 'Unnamed: 113'),(inversion_07['myVarname'] == 'Unnamed: 114'),(inversion_07['myVarname'] == 'Unnamed: 115'),(inversion_07['myVarname'] == 'Unnamed: 116'),
                       (inversion_07['myVarname'] == 'Unnamed: 117'),(inversion_07['myVarname'] == 'Unnamed: 118'),(inversion_07['myVarname'] == 'Unnamed: 119'),(inversion_07['myVarname'] == 'Unnamed: 120'),(inversion_07['myVarname'] == 'Unnamed: 121'),
                        (inversion_07['myVarname'] == 'Unnamed: 122'),(inversion_07['myVarname'] == 'Unnamed: 123'),(inversion_07['myVarname'] == 'Unnamed: 124'),(inversion_07['myVarname'] == 'Unnamed: 125'),(inversion_07['myVarname'] == 'Unnamed: 126'),
                         (inversion_07['myVarname'] == 'Unnamed: 127'),(inversion_07['myVarname'] == 'Unnamed: 128'),(inversion_07['myVarname'] == 'Unnamed: 129'),(inversion_07['myVarname'] == 'Unnamed: 130'),(inversion_07['myVarname'] == 'Unnamed: 131'),
                          (inversion_07['myVarname'] == 'Unnamed: 132'),(inversion_07['myVarname'] == 'Unnamed: 133'),(inversion_07['myVarname'] == 'Unnamed: 134'),(inversion_07['myVarname'] == 'Unnamed: 135'),(inversion_07['myVarname'] == 'Unnamed: 136'),
                           (inversion_07['myVarname'] == 'Unnamed: 137'),(inversion_07['myVarname'] == 'Unnamed: 138'),(inversion_07['myVarname'] == 'Unnamed: 139'),(inversion_07['myVarname'] == 'Unnamed: 140'),(inversion_07['myVarname'] == 'Unnamed: 141'),
                            (inversion_07['myVarname'] == 'Unnamed: 142'),(inversion_07['myVarname'] == 'Unnamed: 143'),(inversion_07['myVarname'] == 'Unnamed: 144'),(inversion_07['myVarname'] == 'Unnamed: 145'),(inversion_07['myVarname'] == 'Unnamed: 146'),
                             (inversion_07['myVarname'] == 'Unnamed: 147'),(inversion_07['myVarname'] == 'Unnamed: 148'),(inversion_07['myVarname'] == 'Unnamed: 149'),(inversion_07['myVarname'] == 'Unnamed: 150'),(inversion_07['myVarname'] == 'Unnamed: 151'),
                              (inversion_07['myVarname'] == 'Unnamed: 152'),(inversion_07['myVarname'] == 'Unnamed: 153'),(inversion_07['myVarname'] == 'Unnamed: 154'),(inversion_07['myVarname'] == 'Unnamed: 155'),(inversion_07['myVarname'] == 'Unnamed: 156'),
                               (inversion_07['myVarname'] == 'Unnamed: 157'),(inversion_07['myVarname'] == 'Unnamed: 158'),(inversion_07['myVarname'] == 'Unnamed: 159'),(inversion_07['myVarname'] == 'Unnamed: 160'),(inversion_07['myVarname'] == 'Unnamed: 161'),
                                (inversion_07['myVarname'] == 'Unnamed: 162'),(inversion_07['myVarname'] == 'Unnamed: 163'),(inversion_07['myVarname'] == 'Unnamed: 164'),(inversion_07['myVarname'] == 'Unnamed: 165'),(inversion_07['myVarname'] == 'Unnamed: 166')
                                ]

# %%
inversion_07['Fecha'] = np.select(conditions_7, values)

# %%
inversion_07.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
inversion_07.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
inversion_07['Tipo'] = "Inversión"
inversion_07['Subtipo'] = "Otros instrumentos emitidos en el país"
inversion_07['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
inversion_07 = inversion_07.reindex(columns=new_cols)

# %%
inversion_07.head(7)
# Out:
#          Fecha                        Institucion       Tipo  \
# 5   2008-01-31                         Banco Bice  Inversión
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Inversión
# 7   2008-01-31                Banco Consorcio (1)  Inversión
# 8   2008-01-31                 Banco de Chile (2)  Inversión
# 9   2008-01-31     Banco de Crédito e Inversiones  Inversión
# 10  2008-01-31  Banco de la Nación Argentina (18)  Inversión
# 11  2008-01-31          Banco del Estado de Chile  Inversión
#
#                                    Subtipo        Valor  \
# 5   Otros instrumentos emitidos en el país            0
# 6   Otros instrumentos emitidos en el país           ND
# 7   Otros instrumentos emitidos en el país            0
# 8   Otros instrumentos emitidos en el país  4919.275055
# 9   Otros instrumentos emitidos en el país            0
# 10  Otros instrumentos emitidos en el país            0
# 11  Otros instrumentos emitidos en el país            0
#
# ...

# %% [markdown]
# ## Inversión 08

# %%
inversion_08.head(5)
# Out:
#         Unnamed: 0                                  Unnamed: 1  \
# 0   Índice general                                 Cuadro 3.08
# 1  Notas generales  Otros instrumentos emitidos en el exterior
# 2              NaN                 Saldos en millones de pesos
# 3              NaN                                         NaN
# 4              NaN                                         NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
inversion_08.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
inversion_08 = inversion_08.iloc[5:]

# %%
inversion_08.tail(7)
# Out:
#                                        Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 28                      Scotiabank Chile (3) (17)          0          0
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)          0          0
# 30                             Bank of China (16)         ND         ND
# 31                                          Total -228.44287 -30.375868
# 32                                            NaN        NaN        NaN
# 33                                            NaN        NaN        NaN
# 34                            ND : No existe dato        NaN        NaN
#
#    Unnamed: 4 Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8 Unnamed: 9  \
# 28          0          0           0           0           0          0
# 29          0          0           0           0           0          0
# 30         ND         ND          ND          ND          ND         ND
# 31   2.104244  -85.09627 -102.408435 -348.443135 -304.795236  -352.0528
# ...

# %%
inversion_08.drop(inversion_08.tail(4).index,inplace=True)

# %%
inversion_08.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice          0          0          0          0
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)          0          0          0          0
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 157  \
# 5          0          0          0          0           0  ...            0
# 6         ND         ND         ND         ND          ND  ...            0
# 7          0          0          0          0           0  ...            0
#
#   Unnamed: 158 Unnamed: 159 Unnamed: 160 Unnamed: 161 Unnamed: 162  \
# 5            0            0            0            0            0
# 6            0            0            0            0            0
# 7            0            0            0            0            0
#
#   Unnamed: 163 Unnamed: 164 Unnamed: 165 Unnamed: 166
# ...

# %%
inversion_08 = inversion_08.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_8 = [(inversion_08['myVarname'] == 'Unnamed: 2'),(inversion_08['myVarname'] == 'Unnamed: 3'),(inversion_08['myVarname'] == 'Unnamed: 4'),(inversion_08['myVarname'] == 'Unnamed: 5'),(inversion_08['myVarname'] == 'Unnamed: 6'),
 (inversion_08['myVarname'] == 'Unnamed: 7'),(inversion_08['myVarname'] == 'Unnamed: 8'),(inversion_08['myVarname'] == 'Unnamed: 9'),(inversion_08['myVarname'] == 'Unnamed: 10'),(inversion_08['myVarname'] == 'Unnamed: 11'),
  (inversion_08['myVarname'] == 'Unnamed: 12'),(inversion_08['myVarname'] == 'Unnamed: 13'),(inversion_08['myVarname'] == 'Unnamed: 14'),(inversion_08['myVarname'] == 'Unnamed: 15'),(inversion_08['myVarname'] == 'Unnamed: 16'),
   (inversion_08['myVarname'] == 'Unnamed: 17'),(inversion_08['myVarname'] == 'Unnamed: 18'),(inversion_08['myVarname'] == 'Unnamed: 19'),(inversion_08['myVarname'] == 'Unnamed: 20'),(inversion_08['myVarname'] == 'Unnamed: 21'),
    (inversion_08['myVarname'] == 'Unnamed: 22'),(inversion_08['myVarname'] == 'Unnamed: 23'),(inversion_08['myVarname'] == 'Unnamed: 24'),(inversion_08['myVarname'] == 'Unnamed: 25'),(inversion_08['myVarname'] == 'Unnamed: 26'),
     (inversion_08['myVarname'] == 'Unnamed: 27'),(inversion_08['myVarname'] == 'Unnamed: 28'),(inversion_08['myVarname'] == 'Unnamed: 29'),(inversion_08['myVarname'] == 'Unnamed: 30'),(inversion_08['myVarname'] == 'Unnamed: 31'),
      (inversion_08['myVarname'] == 'Unnamed: 32'),(inversion_08['myVarname'] == 'Unnamed: 33'),(inversion_08['myVarname'] == 'Unnamed: 34'),(inversion_08['myVarname'] == 'Unnamed: 35'),(inversion_08['myVarname'] == 'Unnamed: 36'),
       (inversion_08['myVarname'] == 'Unnamed: 37'),(inversion_08['myVarname'] == 'Unnamed: 38'),(inversion_08['myVarname'] == 'Unnamed: 39'),(inversion_08['myVarname'] == 'Unnamed: 40'),(inversion_08['myVarname'] == 'Unnamed: 41'),
        (inversion_08['myVarname'] == 'Unnamed: 42'),(inversion_08['myVarname'] == 'Unnamed: 43'),(inversion_08['myVarname'] == 'Unnamed: 44'),(inversion_08['myVarname'] == 'Unnamed: 45'),(inversion_08['myVarname'] == 'Unnamed: 46'),
         (inversion_08['myVarname'] == 'Unnamed: 47'),(inversion_08['myVarname'] == 'Unnamed: 48'),(inversion_08['myVarname'] == 'Unnamed: 49'),(inversion_08['myVarname'] == 'Unnamed: 50'),(inversion_08['myVarname'] == 'Unnamed: 51'),
          (inversion_08['myVarname'] == 'Unnamed: 52'),(inversion_08['myVarname'] == 'Unnamed: 53'),(inversion_08['myVarname'] == 'Unnamed: 54'),(inversion_08['myVarname'] == 'Unnamed: 55'),(inversion_08['myVarname'] == 'Unnamed: 56'),
           (inversion_08['myVarname'] == 'Unnamed: 57'),(inversion_08['myVarname'] == 'Unnamed: 58'),(inversion_08['myVarname'] == 'Unnamed: 59'),(inversion_08['myVarname'] == 'Unnamed: 60'),(inversion_08['myVarname'] == 'Unnamed: 61'),
            (inversion_08['myVarname'] == 'Unnamed: 62'),(inversion_08['myVarname'] == 'Unnamed: 63'),(inversion_08['myVarname'] == 'Unnamed: 64'),(inversion_08['myVarname'] == 'Unnamed: 65'),(inversion_08['myVarname'] == 'Unnamed: 66'),
             (inversion_08['myVarname'] == 'Unnamed: 67'),(inversion_08['myVarname'] == 'Unnamed: 68'),(inversion_08['myVarname'] == 'Unnamed: 69'),(inversion_08['myVarname'] == 'Unnamed: 70'),(inversion_08['myVarname'] == 'Unnamed: 71'),
              (inversion_08['myVarname'] == 'Unnamed: 72'),(inversion_08['myVarname'] == 'Unnamed: 73'),(inversion_08['myVarname'] == 'Unnamed: 74'),(inversion_08['myVarname'] == 'Unnamed: 75'),(inversion_08['myVarname'] == 'Unnamed: 76'),
               (inversion_08['myVarname'] == 'Unnamed: 77'),(inversion_08['myVarname'] == 'Unnamed: 78'),(inversion_08['myVarname'] == 'Unnamed: 79'),(inversion_08['myVarname'] == 'Unnamed: 80'),(inversion_08['myVarname'] == 'Unnamed: 81'),
                (inversion_08['myVarname'] == 'Unnamed: 82'),(inversion_08['myVarname'] == 'Unnamed: 83'),(inversion_08['myVarname'] == 'Unnamed: 84'),(inversion_08['myVarname'] == 'Unnamed: 85'),(inversion_08['myVarname'] == 'Unnamed: 86'),
                 (inversion_08['myVarname'] == 'Unnamed: 87'),(inversion_08['myVarname'] == 'Unnamed: 88'),(inversion_08['myVarname'] == 'Unnamed: 89'),(inversion_08['myVarname'] == 'Unnamed: 90'),(inversion_08['myVarname'] == 'Unnamed: 91'),
                  (inversion_08['myVarname'] == 'Unnamed: 92'),(inversion_08['myVarname'] == 'Unnamed: 93'),(inversion_08['myVarname'] == 'Unnamed: 94'),(inversion_08['myVarname'] == 'Unnamed: 95'),(inversion_08['myVarname'] == 'Unnamed: 96'),
                   (inversion_08['myVarname'] == 'Unnamed: 97'),(inversion_08['myVarname'] == 'Unnamed: 98'),(inversion_08['myVarname'] == 'Unnamed: 99'),(inversion_08['myVarname'] == 'Unnamed: 100'),(inversion_08['myVarname'] == 'Unnamed: 101'),
                    (inversion_08['myVarname'] == 'Unnamed: 102'),(inversion_08['myVarname'] == 'Unnamed: 103'),(inversion_08['myVarname'] == 'Unnamed: 104'),(inversion_08['myVarname'] == 'Unnamed: 105'),(inversion_08['myVarname'] == 'Unnamed: 106'),
                     (inversion_08['myVarname'] == 'Unnamed: 107'),(inversion_08['myVarname'] == 'Unnamed: 108'),(inversion_08['myVarname'] == 'Unnamed: 109'),(inversion_08['myVarname'] == 'Unnamed: 110'),(inversion_08['myVarname'] == 'Unnamed: 111'),
                      (inversion_08['myVarname'] == 'Unnamed: 112'),(inversion_08['myVarname'] == 'Unnamed: 113'),(inversion_08['myVarname'] == 'Unnamed: 114'),(inversion_08['myVarname'] == 'Unnamed: 115'),(inversion_08['myVarname'] == 'Unnamed: 116'),
                       (inversion_08['myVarname'] == 'Unnamed: 117'),(inversion_08['myVarname'] == 'Unnamed: 118'),(inversion_08['myVarname'] == 'Unnamed: 119'),(inversion_08['myVarname'] == 'Unnamed: 120'),(inversion_08['myVarname'] == 'Unnamed: 121'),
                        (inversion_08['myVarname'] == 'Unnamed: 122'),(inversion_08['myVarname'] == 'Unnamed: 123'),(inversion_08['myVarname'] == 'Unnamed: 124'),(inversion_08['myVarname'] == 'Unnamed: 125'),(inversion_08['myVarname'] == 'Unnamed: 126'),
                         (inversion_08['myVarname'] == 'Unnamed: 127'),(inversion_08['myVarname'] == 'Unnamed: 128'),(inversion_08['myVarname'] == 'Unnamed: 129'),(inversion_08['myVarname'] == 'Unnamed: 130'),(inversion_08['myVarname'] == 'Unnamed: 131'),
                          (inversion_08['myVarname'] == 'Unnamed: 132'),(inversion_08['myVarname'] == 'Unnamed: 133'),(inversion_08['myVarname'] == 'Unnamed: 134'),(inversion_08['myVarname'] == 'Unnamed: 135'),(inversion_08['myVarname'] == 'Unnamed: 136'),
                           (inversion_08['myVarname'] == 'Unnamed: 137'),(inversion_08['myVarname'] == 'Unnamed: 138'),(inversion_08['myVarname'] == 'Unnamed: 139'),(inversion_08['myVarname'] == 'Unnamed: 140'),(inversion_08['myVarname'] == 'Unnamed: 141'),
                            (inversion_08['myVarname'] == 'Unnamed: 142'),(inversion_08['myVarname'] == 'Unnamed: 143'),(inversion_08['myVarname'] == 'Unnamed: 144'),(inversion_08['myVarname'] == 'Unnamed: 145'),(inversion_08['myVarname'] == 'Unnamed: 146'),
                             (inversion_08['myVarname'] == 'Unnamed: 147'),(inversion_08['myVarname'] == 'Unnamed: 148'),(inversion_08['myVarname'] == 'Unnamed: 149'),(inversion_08['myVarname'] == 'Unnamed: 150'),(inversion_08['myVarname'] == 'Unnamed: 151'),
                              (inversion_08['myVarname'] == 'Unnamed: 152'),(inversion_08['myVarname'] == 'Unnamed: 153'),(inversion_08['myVarname'] == 'Unnamed: 154'),(inversion_08['myVarname'] == 'Unnamed: 155'),(inversion_08['myVarname'] == 'Unnamed: 156'),
                               (inversion_08['myVarname'] == 'Unnamed: 157'),(inversion_08['myVarname'] == 'Unnamed: 158'),(inversion_08['myVarname'] == 'Unnamed: 159'),(inversion_08['myVarname'] == 'Unnamed: 160'),(inversion_08['myVarname'] == 'Unnamed: 161'),
                                (inversion_08['myVarname'] == 'Unnamed: 162'),(inversion_08['myVarname'] == 'Unnamed: 163'),(inversion_08['myVarname'] == 'Unnamed: 164'),(inversion_08['myVarname'] == 'Unnamed: 165'),(inversion_08['myVarname'] == 'Unnamed: 166')
                                ]

# %%
inversion_08['Fecha'] = np.select(conditions_8, values)

# %%
inversion_08.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
inversion_08.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
inversion_08['Tipo'] = "Inversión"
inversion_08['Subtipo'] = "Otros instrumentos emitidos en el exterior"
inversion_08['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
inversion_08 = inversion_08.reindex(columns=new_cols)

# %%
inversion_08.head(7)
# Out:
#          Fecha                        Institucion       Tipo  \
# 5   2008-01-31                         Banco Bice  Inversión
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Inversión
# 7   2008-01-31                Banco Consorcio (1)  Inversión
# 8   2008-01-31                 Banco de Chile (2)  Inversión
# 9   2008-01-31     Banco de Crédito e Inversiones  Inversión
# 10  2008-01-31  Banco de la Nación Argentina (18)  Inversión
# 11  2008-01-31          Banco del Estado de Chile  Inversión
#
#                                        Subtipo      Valor  \
# 5   Otros instrumentos emitidos en el exterior          0
# 6   Otros instrumentos emitidos en el exterior         ND
# 7   Otros instrumentos emitidos en el exterior          0
# 8   Otros instrumentos emitidos en el exterior          0
# 9   Otros instrumentos emitidos en el exterior          0
# 10  Otros instrumentos emitidos en el exterior          0
# 11  Otros instrumentos emitidos en el exterior -228.44287
#
# ...

# %% [markdown]
# ## Inversión 09

# %%
inversion_09.head(5)
# Out:
#         Unnamed: 0                                         Unnamed: 1  \
# 0   Índice general                                        Cuadro 3.09
# 1  Notas generales  Fondos mutuos administrado por sociedades rela...
# 2              NaN                        Saldos en millones de pesos
# 3              NaN                                                NaN
# 4              NaN                                                NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
inversion_09.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
inversion_09 = inversion_09.iloc[5:]

# %%
inversion_09.tail(7)
# Out:
#                                        Unnamed: 1     Unnamed: 2  \
# 28                      Scotiabank Chile (3) (17)   29301.930859
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)              0
# 30                             Bank of China (16)             ND
# 31                                          Total  254366.046039
# 32                                            NaN            NaN
# 33                                            NaN            NaN
# 34                            ND : No existe dato            NaN
#
#       Unnamed: 3     Unnamed: 4    Unnamed: 5     Unnamed: 6   Unnamed: 7  \
# 28  22002.855119   14951.488176  13152.327671   20806.821066  3064.537828
# 29             0              0             0              0            0
# 30            ND             ND            ND             ND           ND
# 31  85518.846019  100292.435576  96851.326722  132256.249526   95331.6478
# 32           NaN            NaN           NaN            NaN          NaN
# ...

# %%
inversion_09.drop(inversion_09.tail(4).index,inplace=True)
# Out:
# <ipython-input-460-ea0b43fd8599>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inversion_09.drop(inversion_09.tail(4).index,inplace=True)

# %%
inversion_09.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice          0          0          0          0
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)          0          0          0          0
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 157  \
# 5          0          0          0          0           0  ...            0
# 6         ND         ND         ND         ND          ND  ...            0
# 7          0          0          0          0           0  ...            0
#
#   Unnamed: 158 Unnamed: 159 Unnamed: 160 Unnamed: 161 Unnamed: 162  \
# 5            0            0            0            0            0
# 6            0            0            0            0            0
# 7            0            0            0            0            0
#
#   Unnamed: 163 Unnamed: 164 Unnamed: 165 Unnamed: 166
# ...

# %%
inversion_09 = inversion_09.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_9 = [(inversion_09['myVarname'] == 'Unnamed: 2'),(inversion_09['myVarname'] == 'Unnamed: 3'),(inversion_09['myVarname'] == 'Unnamed: 4'),(inversion_09['myVarname'] == 'Unnamed: 5'),(inversion_09['myVarname'] == 'Unnamed: 6'),
 (inversion_09['myVarname'] == 'Unnamed: 7'),(inversion_09['myVarname'] == 'Unnamed: 8'),(inversion_09['myVarname'] == 'Unnamed: 9'),(inversion_09['myVarname'] == 'Unnamed: 10'),(inversion_09['myVarname'] == 'Unnamed: 11'),
  (inversion_09['myVarname'] == 'Unnamed: 12'),(inversion_09['myVarname'] == 'Unnamed: 13'),(inversion_09['myVarname'] == 'Unnamed: 14'),(inversion_09['myVarname'] == 'Unnamed: 15'),(inversion_09['myVarname'] == 'Unnamed: 16'),
   (inversion_09['myVarname'] == 'Unnamed: 17'),(inversion_09['myVarname'] == 'Unnamed: 18'),(inversion_09['myVarname'] == 'Unnamed: 19'),(inversion_09['myVarname'] == 'Unnamed: 20'),(inversion_09['myVarname'] == 'Unnamed: 21'),
    (inversion_09['myVarname'] == 'Unnamed: 22'),(inversion_09['myVarname'] == 'Unnamed: 23'),(inversion_09['myVarname'] == 'Unnamed: 24'),(inversion_09['myVarname'] == 'Unnamed: 25'),(inversion_09['myVarname'] == 'Unnamed: 26'),
     (inversion_09['myVarname'] == 'Unnamed: 27'),(inversion_09['myVarname'] == 'Unnamed: 28'),(inversion_09['myVarname'] == 'Unnamed: 29'),(inversion_09['myVarname'] == 'Unnamed: 30'),(inversion_09['myVarname'] == 'Unnamed: 31'),
      (inversion_09['myVarname'] == 'Unnamed: 32'),(inversion_09['myVarname'] == 'Unnamed: 33'),(inversion_09['myVarname'] == 'Unnamed: 34'),(inversion_09['myVarname'] == 'Unnamed: 35'),(inversion_09['myVarname'] == 'Unnamed: 36'),
       (inversion_09['myVarname'] == 'Unnamed: 37'),(inversion_09['myVarname'] == 'Unnamed: 38'),(inversion_09['myVarname'] == 'Unnamed: 39'),(inversion_09['myVarname'] == 'Unnamed: 40'),(inversion_09['myVarname'] == 'Unnamed: 41'),
        (inversion_09['myVarname'] == 'Unnamed: 42'),(inversion_09['myVarname'] == 'Unnamed: 43'),(inversion_09['myVarname'] == 'Unnamed: 44'),(inversion_09['myVarname'] == 'Unnamed: 45'),(inversion_09['myVarname'] == 'Unnamed: 46'),
         (inversion_09['myVarname'] == 'Unnamed: 47'),(inversion_09['myVarname'] == 'Unnamed: 48'),(inversion_09['myVarname'] == 'Unnamed: 49'),(inversion_09['myVarname'] == 'Unnamed: 50'),(inversion_09['myVarname'] == 'Unnamed: 51'),
          (inversion_09['myVarname'] == 'Unnamed: 52'),(inversion_09['myVarname'] == 'Unnamed: 53'),(inversion_09['myVarname'] == 'Unnamed: 54'),(inversion_09['myVarname'] == 'Unnamed: 55'),(inversion_09['myVarname'] == 'Unnamed: 56'),
           (inversion_09['myVarname'] == 'Unnamed: 57'),(inversion_09['myVarname'] == 'Unnamed: 58'),(inversion_09['myVarname'] == 'Unnamed: 59'),(inversion_09['myVarname'] == 'Unnamed: 60'),(inversion_09['myVarname'] == 'Unnamed: 61'),
            (inversion_09['myVarname'] == 'Unnamed: 62'),(inversion_09['myVarname'] == 'Unnamed: 63'),(inversion_09['myVarname'] == 'Unnamed: 64'),(inversion_09['myVarname'] == 'Unnamed: 65'),(inversion_09['myVarname'] == 'Unnamed: 66'),
             (inversion_09['myVarname'] == 'Unnamed: 67'),(inversion_09['myVarname'] == 'Unnamed: 68'),(inversion_09['myVarname'] == 'Unnamed: 69'),(inversion_09['myVarname'] == 'Unnamed: 70'),(inversion_09['myVarname'] == 'Unnamed: 71'),
              (inversion_09['myVarname'] == 'Unnamed: 72'),(inversion_09['myVarname'] == 'Unnamed: 73'),(inversion_09['myVarname'] == 'Unnamed: 74'),(inversion_09['myVarname'] == 'Unnamed: 75'),(inversion_09['myVarname'] == 'Unnamed: 76'),
               (inversion_09['myVarname'] == 'Unnamed: 77'),(inversion_09['myVarname'] == 'Unnamed: 78'),(inversion_09['myVarname'] == 'Unnamed: 79'),(inversion_09['myVarname'] == 'Unnamed: 80'),(inversion_09['myVarname'] == 'Unnamed: 81'),
                (inversion_09['myVarname'] == 'Unnamed: 82'),(inversion_09['myVarname'] == 'Unnamed: 83'),(inversion_09['myVarname'] == 'Unnamed: 84'),(inversion_09['myVarname'] == 'Unnamed: 85'),(inversion_09['myVarname'] == 'Unnamed: 86'),
                 (inversion_09['myVarname'] == 'Unnamed: 87'),(inversion_09['myVarname'] == 'Unnamed: 88'),(inversion_09['myVarname'] == 'Unnamed: 89'),(inversion_09['myVarname'] == 'Unnamed: 90'),(inversion_09['myVarname'] == 'Unnamed: 91'),
                  (inversion_09['myVarname'] == 'Unnamed: 92'),(inversion_09['myVarname'] == 'Unnamed: 93'),(inversion_09['myVarname'] == 'Unnamed: 94'),(inversion_09['myVarname'] == 'Unnamed: 95'),(inversion_09['myVarname'] == 'Unnamed: 96'),
                   (inversion_09['myVarname'] == 'Unnamed: 97'),(inversion_09['myVarname'] == 'Unnamed: 98'),(inversion_09['myVarname'] == 'Unnamed: 99'),(inversion_09['myVarname'] == 'Unnamed: 100'),(inversion_09['myVarname'] == 'Unnamed: 101'),
                    (inversion_09['myVarname'] == 'Unnamed: 102'),(inversion_09['myVarname'] == 'Unnamed: 103'),(inversion_09['myVarname'] == 'Unnamed: 104'),(inversion_09['myVarname'] == 'Unnamed: 105'),(inversion_09['myVarname'] == 'Unnamed: 106'),
                     (inversion_09['myVarname'] == 'Unnamed: 107'),(inversion_09['myVarname'] == 'Unnamed: 108'),(inversion_09['myVarname'] == 'Unnamed: 109'),(inversion_09['myVarname'] == 'Unnamed: 110'),(inversion_09['myVarname'] == 'Unnamed: 111'),
                      (inversion_09['myVarname'] == 'Unnamed: 112'),(inversion_09['myVarname'] == 'Unnamed: 113'),(inversion_09['myVarname'] == 'Unnamed: 114'),(inversion_09['myVarname'] == 'Unnamed: 115'),(inversion_09['myVarname'] == 'Unnamed: 116'),
                       (inversion_09['myVarname'] == 'Unnamed: 117'),(inversion_09['myVarname'] == 'Unnamed: 118'),(inversion_09['myVarname'] == 'Unnamed: 119'),(inversion_09['myVarname'] == 'Unnamed: 120'),(inversion_09['myVarname'] == 'Unnamed: 121'),
                        (inversion_09['myVarname'] == 'Unnamed: 122'),(inversion_09['myVarname'] == 'Unnamed: 123'),(inversion_09['myVarname'] == 'Unnamed: 124'),(inversion_09['myVarname'] == 'Unnamed: 125'),(inversion_09['myVarname'] == 'Unnamed: 126'),
                         (inversion_09['myVarname'] == 'Unnamed: 127'),(inversion_09['myVarname'] == 'Unnamed: 128'),(inversion_09['myVarname'] == 'Unnamed: 129'),(inversion_09['myVarname'] == 'Unnamed: 130'),(inversion_09['myVarname'] == 'Unnamed: 131'),
                          (inversion_09['myVarname'] == 'Unnamed: 132'),(inversion_09['myVarname'] == 'Unnamed: 133'),(inversion_09['myVarname'] == 'Unnamed: 134'),(inversion_09['myVarname'] == 'Unnamed: 135'),(inversion_09['myVarname'] == 'Unnamed: 136'),
                           (inversion_09['myVarname'] == 'Unnamed: 137'),(inversion_09['myVarname'] == 'Unnamed: 138'),(inversion_09['myVarname'] == 'Unnamed: 139'),(inversion_09['myVarname'] == 'Unnamed: 140'),(inversion_09['myVarname'] == 'Unnamed: 141'),
                            (inversion_09['myVarname'] == 'Unnamed: 142'),(inversion_09['myVarname'] == 'Unnamed: 143'),(inversion_09['myVarname'] == 'Unnamed: 144'),(inversion_09['myVarname'] == 'Unnamed: 145'),(inversion_09['myVarname'] == 'Unnamed: 146'),
                             (inversion_09['myVarname'] == 'Unnamed: 147'),(inversion_09['myVarname'] == 'Unnamed: 148'),(inversion_09['myVarname'] == 'Unnamed: 149'),(inversion_09['myVarname'] == 'Unnamed: 150'),(inversion_09['myVarname'] == 'Unnamed: 151'),
                              (inversion_09['myVarname'] == 'Unnamed: 152'),(inversion_09['myVarname'] == 'Unnamed: 153'),(inversion_09['myVarname'] == 'Unnamed: 154'),(inversion_09['myVarname'] == 'Unnamed: 155'),(inversion_09['myVarname'] == 'Unnamed: 156'),
                               (inversion_09['myVarname'] == 'Unnamed: 157'),(inversion_09['myVarname'] == 'Unnamed: 158'),(inversion_09['myVarname'] == 'Unnamed: 159'),(inversion_09['myVarname'] == 'Unnamed: 160'),(inversion_09['myVarname'] == 'Unnamed: 161'),
                                (inversion_09['myVarname'] == 'Unnamed: 162'),(inversion_09['myVarname'] == 'Unnamed: 163'),(inversion_09['myVarname'] == 'Unnamed: 164'),(inversion_09['myVarname'] == 'Unnamed: 165'),(inversion_09['myVarname'] == 'Unnamed: 166')
                                ]

# %%
inversion_09['Fecha'] = np.select(conditions_9, values)

# %%
inversion_09.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
inversion_09.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
inversion_09['Tipo'] = "Inversión"
inversion_09['Subtipo'] = "Fondos mutuos administrado por sociedades relacionadas"
inversion_09['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
inversion_09 = inversion_09.reindex(columns=new_cols)

# %%
inversion_09.head(7)
# Out:
#          Fecha                        Institucion       Tipo  \
# 5   2008-01-31                         Banco Bice  Inversión
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Inversión
# 7   2008-01-31                Banco Consorcio (1)  Inversión
# 8   2008-01-31                 Banco de Chile (2)  Inversión
# 9   2008-01-31     Banco de Crédito e Inversiones  Inversión
# 10  2008-01-31  Banco de la Nación Argentina (18)  Inversión
# 11  2008-01-31          Banco del Estado de Chile  Inversión
#
#                                               Subtipo          Valor  \
# 5   Fondos mutuos administrado por sociedades rela...              0
# 6   Fondos mutuos administrado por sociedades rela...             ND
# 7   Fondos mutuos administrado por sociedades rela...              0
# 8   Fondos mutuos administrado por sociedades rela...  170043.283333
# 9   Fondos mutuos administrado por sociedades rela...              0
# ...

# %% [markdown]
# ## Inversión 10

# %%
inversion_10.head(5)
# Out:
#         Unnamed: 0                               Unnamed: 1  \
# 0   Índice general                              Cuadro 3.10
# 1  Notas generales  Total de inversion en moneda extranjera
# 2              NaN              Saldos en millones de pesos
# 3              NaN                                      NaN
# 4              NaN                                      NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# ...

# %%
inversion_10.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# 35                NaN
# Name: Unnamed: 0, dtype: object

# %%
inversion_10 = inversion_10.iloc[5:]

# %%
inversion_10.tail(7)
# Out:
#                                        Unnamed: 1    Unnamed: 2  \
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)   2952.315101
# 30                             Bank of China (16)            ND
# 31                                          Total  601055.84349
# 32                                            NaN           NaN
# 33                                            NaN           NaN
# 34                            ND : No existe dato           NaN
# 35                                            NaN           NaN
#
#        Unnamed: 3     Unnamed: 4     Unnamed: 5    Unnamed: 6     Unnamed: 7  \
# 29    6580.709763    3091.055467    3235.810351   3392.265391    3686.248216
# 30             ND             ND             ND            ND             ND
# 31  604886.225557  617508.060113  485821.944334  544318.97365  483870.684341
# 32            NaN            NaN            NaN           NaN            NaN
# ...

# %%
inversion_10.drop(inversion_10.tail(5).index,inplace=True)
# Out:
# <ipython-input-474-6e04c4790601>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inversion_10.drop(inversion_10.tail(5).index,inplace=True)

# %%
inversion_10.head(3)
# Out:
#                     Unnamed: 1   Unnamed: 2   Unnamed: 3   Unnamed: 4  \
# 5                   Banco Bice    701.76822   688.806597   665.070431
# 6  Banco BTG Pactual Chile (9)           ND           ND           ND
# 7          Banco Consorcio (1)  2274.338176  2236.396967  2158.762893
#
#     Unnamed: 5   Unnamed: 6   Unnamed: 7  Unnamed: 8   Unnamed: 9  \
# 5   672.975249   702.387511   770.261743  742.854745   758.118085
# 6           ND           ND           ND          ND           ND
# 7  1811.470856  1511.165075  1247.285266  1190.57746  1232.118273
#
#    Unnamed: 10  ...   Unnamed: 157   Unnamed: 158   Unnamed: 159  \
# 5   811.305011  ...   41323.599194   49297.459496   70885.947937
# 6           ND  ...              0              0              0
# 7  1120.671655  ...  405293.911969  460591.249291  455701.402223
#
#     Unnamed: 160   Unnamed: 161   Unnamed: 162   Unnamed: 163   Unnamed: 164  \
# ...

# %%
inversion_10 = inversion_10.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_10 = [(inversion_10['myVarname'] == 'Unnamed: 2'),(inversion_10['myVarname'] == 'Unnamed: 3'),(inversion_10['myVarname'] == 'Unnamed: 4'),(inversion_10['myVarname'] == 'Unnamed: 5'),(inversion_10['myVarname'] == 'Unnamed: 6'),
 (inversion_10['myVarname'] == 'Unnamed: 7'),(inversion_10['myVarname'] == 'Unnamed: 8'),(inversion_10['myVarname'] == 'Unnamed: 9'),(inversion_10['myVarname'] == 'Unnamed: 10'),(inversion_10['myVarname'] == 'Unnamed: 11'),
  (inversion_10['myVarname'] == 'Unnamed: 12'),(inversion_10['myVarname'] == 'Unnamed: 13'),(inversion_10['myVarname'] == 'Unnamed: 14'),(inversion_10['myVarname'] == 'Unnamed: 15'),(inversion_10['myVarname'] == 'Unnamed: 16'),
   (inversion_10['myVarname'] == 'Unnamed: 17'),(inversion_10['myVarname'] == 'Unnamed: 18'),(inversion_10['myVarname'] == 'Unnamed: 19'),(inversion_10['myVarname'] == 'Unnamed: 20'),(inversion_10['myVarname'] == 'Unnamed: 21'),
    (inversion_10['myVarname'] == 'Unnamed: 22'),(inversion_10['myVarname'] == 'Unnamed: 23'),(inversion_10['myVarname'] == 'Unnamed: 24'),(inversion_10['myVarname'] == 'Unnamed: 25'),(inversion_10['myVarname'] == 'Unnamed: 26'),
     (inversion_10['myVarname'] == 'Unnamed: 27'),(inversion_10['myVarname'] == 'Unnamed: 28'),(inversion_10['myVarname'] == 'Unnamed: 29'),(inversion_10['myVarname'] == 'Unnamed: 30'),(inversion_10['myVarname'] == 'Unnamed: 31'),
      (inversion_10['myVarname'] == 'Unnamed: 32'),(inversion_10['myVarname'] == 'Unnamed: 33'),(inversion_10['myVarname'] == 'Unnamed: 34'),(inversion_10['myVarname'] == 'Unnamed: 35'),(inversion_10['myVarname'] == 'Unnamed: 36'),
       (inversion_10['myVarname'] == 'Unnamed: 37'),(inversion_10['myVarname'] == 'Unnamed: 38'),(inversion_10['myVarname'] == 'Unnamed: 39'),(inversion_10['myVarname'] == 'Unnamed: 40'),(inversion_10['myVarname'] == 'Unnamed: 41'),
        (inversion_10['myVarname'] == 'Unnamed: 42'),(inversion_10['myVarname'] == 'Unnamed: 43'),(inversion_10['myVarname'] == 'Unnamed: 44'),(inversion_10['myVarname'] == 'Unnamed: 45'),(inversion_10['myVarname'] == 'Unnamed: 46'),
         (inversion_10['myVarname'] == 'Unnamed: 47'),(inversion_10['myVarname'] == 'Unnamed: 48'),(inversion_10['myVarname'] == 'Unnamed: 49'),(inversion_10['myVarname'] == 'Unnamed: 50'),(inversion_10['myVarname'] == 'Unnamed: 51'),
          (inversion_10['myVarname'] == 'Unnamed: 52'),(inversion_10['myVarname'] == 'Unnamed: 53'),(inversion_10['myVarname'] == 'Unnamed: 54'),(inversion_10['myVarname'] == 'Unnamed: 55'),(inversion_10['myVarname'] == 'Unnamed: 56'),
           (inversion_10['myVarname'] == 'Unnamed: 57'),(inversion_10['myVarname'] == 'Unnamed: 58'),(inversion_10['myVarname'] == 'Unnamed: 59'),(inversion_10['myVarname'] == 'Unnamed: 60'),(inversion_10['myVarname'] == 'Unnamed: 61'),
            (inversion_10['myVarname'] == 'Unnamed: 62'),(inversion_10['myVarname'] == 'Unnamed: 63'),(inversion_10['myVarname'] == 'Unnamed: 64'),(inversion_10['myVarname'] == 'Unnamed: 65'),(inversion_10['myVarname'] == 'Unnamed: 66'),
             (inversion_10['myVarname'] == 'Unnamed: 67'),(inversion_10['myVarname'] == 'Unnamed: 68'),(inversion_10['myVarname'] == 'Unnamed: 69'),(inversion_10['myVarname'] == 'Unnamed: 70'),(inversion_10['myVarname'] == 'Unnamed: 71'),
              (inversion_10['myVarname'] == 'Unnamed: 72'),(inversion_10['myVarname'] == 'Unnamed: 73'),(inversion_10['myVarname'] == 'Unnamed: 74'),(inversion_10['myVarname'] == 'Unnamed: 75'),(inversion_10['myVarname'] == 'Unnamed: 76'),
               (inversion_10['myVarname'] == 'Unnamed: 77'),(inversion_10['myVarname'] == 'Unnamed: 78'),(inversion_10['myVarname'] == 'Unnamed: 79'),(inversion_10['myVarname'] == 'Unnamed: 80'),(inversion_10['myVarname'] == 'Unnamed: 81'),
                (inversion_10['myVarname'] == 'Unnamed: 82'),(inversion_10['myVarname'] == 'Unnamed: 83'),(inversion_10['myVarname'] == 'Unnamed: 84'),(inversion_10['myVarname'] == 'Unnamed: 85'),(inversion_10['myVarname'] == 'Unnamed: 86'),
                 (inversion_10['myVarname'] == 'Unnamed: 87'),(inversion_10['myVarname'] == 'Unnamed: 88'),(inversion_10['myVarname'] == 'Unnamed: 89'),(inversion_10['myVarname'] == 'Unnamed: 90'),(inversion_10['myVarname'] == 'Unnamed: 91'),
                  (inversion_10['myVarname'] == 'Unnamed: 92'),(inversion_10['myVarname'] == 'Unnamed: 93'),(inversion_10['myVarname'] == 'Unnamed: 94'),(inversion_10['myVarname'] == 'Unnamed: 95'),(inversion_10['myVarname'] == 'Unnamed: 96'),
                   (inversion_10['myVarname'] == 'Unnamed: 97'),(inversion_10['myVarname'] == 'Unnamed: 98'),(inversion_10['myVarname'] == 'Unnamed: 99'),(inversion_10['myVarname'] == 'Unnamed: 100'),(inversion_10['myVarname'] == 'Unnamed: 101'),
                    (inversion_10['myVarname'] == 'Unnamed: 102'),(inversion_10['myVarname'] == 'Unnamed: 103'),(inversion_10['myVarname'] == 'Unnamed: 104'),(inversion_10['myVarname'] == 'Unnamed: 105'),(inversion_10['myVarname'] == 'Unnamed: 106'),
                     (inversion_10['myVarname'] == 'Unnamed: 107'),(inversion_10['myVarname'] == 'Unnamed: 108'),(inversion_10['myVarname'] == 'Unnamed: 109'),(inversion_10['myVarname'] == 'Unnamed: 110'),(inversion_10['myVarname'] == 'Unnamed: 111'),
                      (inversion_10['myVarname'] == 'Unnamed: 112'),(inversion_10['myVarname'] == 'Unnamed: 113'),(inversion_10['myVarname'] == 'Unnamed: 114'),(inversion_10['myVarname'] == 'Unnamed: 115'),(inversion_10['myVarname'] == 'Unnamed: 116'),
                       (inversion_10['myVarname'] == 'Unnamed: 117'),(inversion_10['myVarname'] == 'Unnamed: 118'),(inversion_10['myVarname'] == 'Unnamed: 119'),(inversion_10['myVarname'] == 'Unnamed: 120'),(inversion_10['myVarname'] == 'Unnamed: 121'),
                        (inversion_10['myVarname'] == 'Unnamed: 122'),(inversion_10['myVarname'] == 'Unnamed: 123'),(inversion_10['myVarname'] == 'Unnamed: 124'),(inversion_10['myVarname'] == 'Unnamed: 125'),(inversion_10['myVarname'] == 'Unnamed: 126'),
                         (inversion_10['myVarname'] == 'Unnamed: 127'),(inversion_10['myVarname'] == 'Unnamed: 128'),(inversion_10['myVarname'] == 'Unnamed: 129'),(inversion_10['myVarname'] == 'Unnamed: 130'),(inversion_10['myVarname'] == 'Unnamed: 131'),
                          (inversion_10['myVarname'] == 'Unnamed: 132'),(inversion_10['myVarname'] == 'Unnamed: 133'),(inversion_10['myVarname'] == 'Unnamed: 134'),(inversion_10['myVarname'] == 'Unnamed: 135'),(inversion_10['myVarname'] == 'Unnamed: 136'),
                           (inversion_10['myVarname'] == 'Unnamed: 137'),(inversion_10['myVarname'] == 'Unnamed: 138'),(inversion_10['myVarname'] == 'Unnamed: 139'),(inversion_10['myVarname'] == 'Unnamed: 140'),(inversion_10['myVarname'] == 'Unnamed: 141'),
                            (inversion_10['myVarname'] == 'Unnamed: 142'),(inversion_10['myVarname'] == 'Unnamed: 143'),(inversion_10['myVarname'] == 'Unnamed: 144'),(inversion_10['myVarname'] == 'Unnamed: 145'),(inversion_10['myVarname'] == 'Unnamed: 146'),
                             (inversion_10['myVarname'] == 'Unnamed: 147'),(inversion_10['myVarname'] == 'Unnamed: 148'),(inversion_10['myVarname'] == 'Unnamed: 149'),(inversion_10['myVarname'] == 'Unnamed: 150'),(inversion_10['myVarname'] == 'Unnamed: 151'),
                              (inversion_10['myVarname'] == 'Unnamed: 152'),(inversion_10['myVarname'] == 'Unnamed: 153'),(inversion_10['myVarname'] == 'Unnamed: 154'),(inversion_10['myVarname'] == 'Unnamed: 155'),(inversion_10['myVarname'] == 'Unnamed: 156'),
                               (inversion_10['myVarname'] == 'Unnamed: 157'),(inversion_10['myVarname'] == 'Unnamed: 158'),(inversion_10['myVarname'] == 'Unnamed: 159'),(inversion_10['myVarname'] == 'Unnamed: 160'),(inversion_10['myVarname'] == 'Unnamed: 161'),
                                (inversion_10['myVarname'] == 'Unnamed: 162'),(inversion_10['myVarname'] == 'Unnamed: 163'),(inversion_10['myVarname'] == 'Unnamed: 164'),(inversion_10['myVarname'] == 'Unnamed: 165'),(inversion_10['myVarname'] == 'Unnamed: 166')
                                ]

# %%
inversion_10['Fecha'] = np.select(conditions_10, values)

# %%
inversion_10.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
inversion_10.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
inversion_10['Tipo'] = "Inversión"
inversion_10['Subtipo'] = "Total de inversion en moneda extranjera"
inversion_10['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
inversion_10 = inversion_10.reindex(columns=new_cols)

# %%
inversion_10.head(7)
# Out:
#          Fecha                        Institucion       Tipo  \
# 5   2008-01-31                         Banco Bice  Inversión
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Inversión
# 7   2008-01-31                Banco Consorcio (1)  Inversión
# 8   2008-01-31                 Banco de Chile (2)  Inversión
# 9   2008-01-31     Banco de Crédito e Inversiones  Inversión
# 10  2008-01-31  Banco de la Nación Argentina (18)  Inversión
# 11  2008-01-31          Banco del Estado de Chile  Inversión
#
#                                     Subtipo          Valor  \
# 5   Total de inversion en moneda extranjera      701.76822
# 6   Total de inversion en moneda extranjera             ND
# 7   Total de inversion en moneda extranjera    2274.338176
# 8   Total de inversion en moneda extranjera  109201.826343
# 9   Total de inversion en moneda extranjera  115142.683746
# 10  Total de inversion en moneda extranjera              0
# 11  Total de inversion en moneda extranjera   58261.081301
# ...

# %% [markdown]
# ## Inversión 11

# %%
inversion_11.head(5)
# Out:
#         Unnamed: 0                                         Unnamed: 1  \
# 0   Índice general                                        Cuadro 3.11
# 1  Notas generales  Documentos emitidos por otras instituciones fi...
# 2              NaN                        Saldos en millones de pesos
# 3              NaN                                                NaN
# 4              NaN                                                NaN
#
#             Unnamed: 2           Unnamed: 3           Unnamed: 4  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-01-31 00:00:00  2008-02-29 00:00:00  2008-03-31 00:00:00
#
#             Unnamed: 5           Unnamed: 6           Unnamed: 7  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
inversion_11.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
inversion_11 = inversion_11.iloc[5:]

# %%
inversion_11.tail(7)
# Out:
#                                        Unnamed: 1    Unnamed: 2   Unnamed: 3  \
# 28                      Scotiabank Chile (3) (17)             0            0
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)   2792.762929  3211.707806
# 30                             Bank of China (16)            ND           ND
# 31                                          Total  68592.677468  67606.89196
# 32                                            NaN           NaN          NaN
# 33                                            NaN           NaN          NaN
# 34                            ND : No existe dato           NaN          NaN
#
#       Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8  \
# 28             0             0             0             0   2221.254233
# 29   3091.055467   3235.810351   3392.265391   3686.248216    3571.03026
# 30            ND            ND            ND            ND            ND
# ...

# %%
inversion_11.drop(inversion_11.tail(4).index,inplace=True)

# %%
inversion_11.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 5                   Banco Bice  701.76822  688.806597  665.070431  672.975249
# 6  Banco BTG Pactual Chile (9)         ND          ND          ND          ND
# 7          Banco Consorcio (1)          0           0           0           0
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10  ...  \
# 5  702.387511  770.261743  742.854745  758.118085  811.305011  ...
# 6          ND          ND          ND          ND          ND  ...
# 7           0           0           0           0           0  ...
#
#    Unnamed: 157 Unnamed: 158 Unnamed: 159  Unnamed: 160  Unnamed: 161  \
# 5   3027.675033  2610.295413  9797.527831   9069.303324   2233.780237
# 6             0            0            0             0             0
# 7  69458.298399  59834.64037  59676.64212  59160.976716  61394.676226
#
#    Unnamed: 162  Unnamed: 163  Unnamed: 164  Unnamed: 165  Unnamed: 166
# ...

# %%
inversion_11 = inversion_11.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_11 = [(inversion_11['myVarname'] == 'Unnamed: 2'),(inversion_11['myVarname'] == 'Unnamed: 3'),(inversion_11['myVarname'] == 'Unnamed: 4'),(inversion_11['myVarname'] == 'Unnamed: 5'),(inversion_11['myVarname'] == 'Unnamed: 6'),
 (inversion_11['myVarname'] == 'Unnamed: 7'),(inversion_11['myVarname'] == 'Unnamed: 8'),(inversion_11['myVarname'] == 'Unnamed: 9'),(inversion_11['myVarname'] == 'Unnamed: 10'),(inversion_11['myVarname'] == 'Unnamed: 11'),
  (inversion_11['myVarname'] == 'Unnamed: 12'),(inversion_11['myVarname'] == 'Unnamed: 13'),(inversion_11['myVarname'] == 'Unnamed: 14'),(inversion_11['myVarname'] == 'Unnamed: 15'),(inversion_11['myVarname'] == 'Unnamed: 16'),
   (inversion_11['myVarname'] == 'Unnamed: 17'),(inversion_11['myVarname'] == 'Unnamed: 18'),(inversion_11['myVarname'] == 'Unnamed: 19'),(inversion_11['myVarname'] == 'Unnamed: 20'),(inversion_11['myVarname'] == 'Unnamed: 21'),
    (inversion_11['myVarname'] == 'Unnamed: 22'),(inversion_11['myVarname'] == 'Unnamed: 23'),(inversion_11['myVarname'] == 'Unnamed: 24'),(inversion_11['myVarname'] == 'Unnamed: 25'),(inversion_11['myVarname'] == 'Unnamed: 26'),
     (inversion_11['myVarname'] == 'Unnamed: 27'),(inversion_11['myVarname'] == 'Unnamed: 28'),(inversion_11['myVarname'] == 'Unnamed: 29'),(inversion_11['myVarname'] == 'Unnamed: 30'),(inversion_11['myVarname'] == 'Unnamed: 31'),
      (inversion_11['myVarname'] == 'Unnamed: 32'),(inversion_11['myVarname'] == 'Unnamed: 33'),(inversion_11['myVarname'] == 'Unnamed: 34'),(inversion_11['myVarname'] == 'Unnamed: 35'),(inversion_11['myVarname'] == 'Unnamed: 36'),
       (inversion_11['myVarname'] == 'Unnamed: 37'),(inversion_11['myVarname'] == 'Unnamed: 38'),(inversion_11['myVarname'] == 'Unnamed: 39'),(inversion_11['myVarname'] == 'Unnamed: 40'),(inversion_11['myVarname'] == 'Unnamed: 41'),
        (inversion_11['myVarname'] == 'Unnamed: 42'),(inversion_11['myVarname'] == 'Unnamed: 43'),(inversion_11['myVarname'] == 'Unnamed: 44'),(inversion_11['myVarname'] == 'Unnamed: 45'),(inversion_11['myVarname'] == 'Unnamed: 46'),
         (inversion_11['myVarname'] == 'Unnamed: 47'),(inversion_11['myVarname'] == 'Unnamed: 48'),(inversion_11['myVarname'] == 'Unnamed: 49'),(inversion_11['myVarname'] == 'Unnamed: 50'),(inversion_11['myVarname'] == 'Unnamed: 51'),
          (inversion_11['myVarname'] == 'Unnamed: 52'),(inversion_11['myVarname'] == 'Unnamed: 53'),(inversion_11['myVarname'] == 'Unnamed: 54'),(inversion_11['myVarname'] == 'Unnamed: 55'),(inversion_11['myVarname'] == 'Unnamed: 56'),
           (inversion_11['myVarname'] == 'Unnamed: 57'),(inversion_11['myVarname'] == 'Unnamed: 58'),(inversion_11['myVarname'] == 'Unnamed: 59'),(inversion_11['myVarname'] == 'Unnamed: 60'),(inversion_11['myVarname'] == 'Unnamed: 61'),
            (inversion_11['myVarname'] == 'Unnamed: 62'),(inversion_11['myVarname'] == 'Unnamed: 63'),(inversion_11['myVarname'] == 'Unnamed: 64'),(inversion_11['myVarname'] == 'Unnamed: 65'),(inversion_11['myVarname'] == 'Unnamed: 66'),
             (inversion_11['myVarname'] == 'Unnamed: 67'),(inversion_11['myVarname'] == 'Unnamed: 68'),(inversion_11['myVarname'] == 'Unnamed: 69'),(inversion_11['myVarname'] == 'Unnamed: 70'),(inversion_11['myVarname'] == 'Unnamed: 71'),
              (inversion_11['myVarname'] == 'Unnamed: 72'),(inversion_11['myVarname'] == 'Unnamed: 73'),(inversion_11['myVarname'] == 'Unnamed: 74'),(inversion_11['myVarname'] == 'Unnamed: 75'),(inversion_11['myVarname'] == 'Unnamed: 76'),
               (inversion_11['myVarname'] == 'Unnamed: 77'),(inversion_11['myVarname'] == 'Unnamed: 78'),(inversion_11['myVarname'] == 'Unnamed: 79'),(inversion_11['myVarname'] == 'Unnamed: 80'),(inversion_11['myVarname'] == 'Unnamed: 81'),
                (inversion_11['myVarname'] == 'Unnamed: 82'),(inversion_11['myVarname'] == 'Unnamed: 83'),(inversion_11['myVarname'] == 'Unnamed: 84'),(inversion_11['myVarname'] == 'Unnamed: 85'),(inversion_11['myVarname'] == 'Unnamed: 86'),
                 (inversion_11['myVarname'] == 'Unnamed: 87'),(inversion_11['myVarname'] == 'Unnamed: 88'),(inversion_11['myVarname'] == 'Unnamed: 89'),(inversion_11['myVarname'] == 'Unnamed: 90'),(inversion_11['myVarname'] == 'Unnamed: 91'),
                  (inversion_11['myVarname'] == 'Unnamed: 92'),(inversion_11['myVarname'] == 'Unnamed: 93'),(inversion_11['myVarname'] == 'Unnamed: 94'),(inversion_11['myVarname'] == 'Unnamed: 95'),(inversion_11['myVarname'] == 'Unnamed: 96'),
                   (inversion_11['myVarname'] == 'Unnamed: 97'),(inversion_11['myVarname'] == 'Unnamed: 98'),(inversion_11['myVarname'] == 'Unnamed: 99'),(inversion_11['myVarname'] == 'Unnamed: 100'),(inversion_11['myVarname'] == 'Unnamed: 101'),
                    (inversion_11['myVarname'] == 'Unnamed: 102'),(inversion_11['myVarname'] == 'Unnamed: 103'),(inversion_11['myVarname'] == 'Unnamed: 104'),(inversion_11['myVarname'] == 'Unnamed: 105'),(inversion_11['myVarname'] == 'Unnamed: 106'),
                     (inversion_11['myVarname'] == 'Unnamed: 107'),(inversion_11['myVarname'] == 'Unnamed: 108'),(inversion_11['myVarname'] == 'Unnamed: 109'),(inversion_11['myVarname'] == 'Unnamed: 110'),(inversion_11['myVarname'] == 'Unnamed: 111'),
                      (inversion_11['myVarname'] == 'Unnamed: 112'),(inversion_11['myVarname'] == 'Unnamed: 113'),(inversion_11['myVarname'] == 'Unnamed: 114'),(inversion_11['myVarname'] == 'Unnamed: 115'),(inversion_11['myVarname'] == 'Unnamed: 116'),
                       (inversion_11['myVarname'] == 'Unnamed: 117'),(inversion_11['myVarname'] == 'Unnamed: 118'),(inversion_11['myVarname'] == 'Unnamed: 119'),(inversion_11['myVarname'] == 'Unnamed: 120'),(inversion_11['myVarname'] == 'Unnamed: 121'),
                        (inversion_11['myVarname'] == 'Unnamed: 122'),(inversion_11['myVarname'] == 'Unnamed: 123'),(inversion_11['myVarname'] == 'Unnamed: 124'),(inversion_11['myVarname'] == 'Unnamed: 125'),(inversion_11['myVarname'] == 'Unnamed: 126'),
                         (inversion_11['myVarname'] == 'Unnamed: 127'),(inversion_11['myVarname'] == 'Unnamed: 128'),(inversion_11['myVarname'] == 'Unnamed: 129'),(inversion_11['myVarname'] == 'Unnamed: 130'),(inversion_11['myVarname'] == 'Unnamed: 131'),
                          (inversion_11['myVarname'] == 'Unnamed: 132'),(inversion_11['myVarname'] == 'Unnamed: 133'),(inversion_11['myVarname'] == 'Unnamed: 134'),(inversion_11['myVarname'] == 'Unnamed: 135'),(inversion_11['myVarname'] == 'Unnamed: 136'),
                           (inversion_11['myVarname'] == 'Unnamed: 137'),(inversion_11['myVarname'] == 'Unnamed: 138'),(inversion_11['myVarname'] == 'Unnamed: 139'),(inversion_11['myVarname'] == 'Unnamed: 140'),(inversion_11['myVarname'] == 'Unnamed: 141'),
                            (inversion_11['myVarname'] == 'Unnamed: 142'),(inversion_11['myVarname'] == 'Unnamed: 143'),(inversion_11['myVarname'] == 'Unnamed: 144'),(inversion_11['myVarname'] == 'Unnamed: 145'),(inversion_11['myVarname'] == 'Unnamed: 146'),
                             (inversion_11['myVarname'] == 'Unnamed: 147'),(inversion_11['myVarname'] == 'Unnamed: 148'),(inversion_11['myVarname'] == 'Unnamed: 149'),(inversion_11['myVarname'] == 'Unnamed: 150'),(inversion_11['myVarname'] == 'Unnamed: 151'),
                              (inversion_11['myVarname'] == 'Unnamed: 152'),(inversion_11['myVarname'] == 'Unnamed: 153'),(inversion_11['myVarname'] == 'Unnamed: 154'),(inversion_11['myVarname'] == 'Unnamed: 155'),(inversion_11['myVarname'] == 'Unnamed: 156'),
                               (inversion_11['myVarname'] == 'Unnamed: 157'),(inversion_11['myVarname'] == 'Unnamed: 158'),(inversion_11['myVarname'] == 'Unnamed: 159'),(inversion_11['myVarname'] == 'Unnamed: 160'),(inversion_11['myVarname'] == 'Unnamed: 161'),
                                (inversion_11['myVarname'] == 'Unnamed: 162'),(inversion_11['myVarname'] == 'Unnamed: 163'),(inversion_11['myVarname'] == 'Unnamed: 164'),(inversion_11['myVarname'] == 'Unnamed: 165'),(inversion_11['myVarname'] == 'Unnamed: 166')
                                ]

# %%
inversion_11['Fecha'] = np.select(conditions_11, values)

# %%
inversion_11.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
inversion_11.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
inversion_11['Tipo'] = "Inversión"
inversion_11['Subtipo'] = "Documentos emitidos por otras instituciones financieras del pais"
inversion_11['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
inversion_11 = inversion_11.reindex(columns=new_cols)

# %%
inversion_11.head(7)
# Out:
#          Fecha                        Institucion       Tipo  \
# 5   2008-01-31                         Banco Bice  Inversión
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Inversión
# 7   2008-01-31                Banco Consorcio (1)  Inversión
# 8   2008-01-31                 Banco de Chile (2)  Inversión
# 9   2008-01-31     Banco de Crédito e Inversiones  Inversión
# 10  2008-01-31  Banco de la Nación Argentina (18)  Inversión
# 11  2008-01-31          Banco del Estado de Chile  Inversión
#
#                                               Subtipo         Valor  \
# 5   Documentos emitidos por otras instituciones fi...     701.76822
# 6   Documentos emitidos por otras instituciones fi...            ND
# 7   Documentos emitidos por otras instituciones fi...             0
# 8   Documentos emitidos por otras instituciones fi...  62683.929059
# 9   Documentos emitidos por otras instituciones fi...             0
# ...

# %% [markdown]
# ## Inversión 12

# %%
inversion_12.head(5)
# Out:
#         Unnamed: 0                   Unnamed: 1           Unnamed: 2  \
# 0   Índice general                  Cuadro 3.12                  NaN
# 1  Notas generales   Inversiones en el exterior                  NaN
# 2              NaN  Saldos en millones de pesos                  NaN
# 3              NaN                          NaN                  NaN
# 4              NaN                          NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# 0                  NaN                  NaN                  NaN
# ...

# %%
inversion_12.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
inversion_12 = inversion_12.iloc[5:]

# %%
inversion_12.tail(7)
# Out:
#                                        Unnamed: 1     Unnamed: 2  \
# 28                      Scotiabank Chile (3) (17)   18595.635254
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)     159.552172
# 30                             Bank of China (16)             ND
# 31                                          Total  531083.251761
# 32                                            NaN            NaN
# 33                                            NaN            NaN
# 34                            ND : No existe dato            NaN
#
#        Unnamed: 3    Unnamed: 4     Unnamed: 5     Unnamed: 6     Unnamed: 7  \
# 28              0             0              0    3288.696074     3652.39184
# 29    3369.001957             0              0              0              0
# 30             ND            ND             ND             ND             ND
# 31  536656.858364  549982.96594  415881.283774  465728.919117  399379.012478
# ...

# %%
inversion_12.drop(inversion_12.tail(4).index,inplace=True)
# Out:
# <ipython-input-502-350b130f5c70>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inversion_12.drop(inversion_12.tail(4).index,inplace=True)

# %%
inversion_12.head(3)
# Out:
#                     Unnamed: 1   Unnamed: 2   Unnamed: 3   Unnamed: 4  \
# 5                   Banco Bice            0            0            0
# 6  Banco BTG Pactual Chile (9)           ND           ND           ND
# 7          Banco Consorcio (1)  2274.338176  2236.396967  2158.762893
#
#     Unnamed: 5   Unnamed: 6   Unnamed: 7  Unnamed: 8   Unnamed: 9  \
# 5            0            0            0           0            0
# 6           ND           ND           ND          ND           ND
# 7  1811.470856  1511.165075  1247.285266  1190.57746  1232.118273
#
#    Unnamed: 10  ...  Unnamed: 157   Unnamed: 158   Unnamed: 159  \
# 5            0  ...  38295.924161   46687.164083   61088.420106
# 6           ND  ...             0              0              0
# 7  1120.671655  ...  335835.61357  400756.608921  396024.760103
#
#     Unnamed: 160   Unnamed: 161   Unnamed: 162   Unnamed: 163   Unnamed: 164  \
# 5    66794.93626   81825.381875  117331.107817  119624.997694  126443.836609
# ...

# %%
inversion_12 = inversion_12.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_12 = [(inversion_12['myVarname'] == 'Unnamed: 2'),(inversion_12['myVarname'] == 'Unnamed: 3'),(inversion_12['myVarname'] == 'Unnamed: 4'),(inversion_12['myVarname'] == 'Unnamed: 5'),(inversion_12['myVarname'] == 'Unnamed: 6'),
 (inversion_12['myVarname'] == 'Unnamed: 7'),(inversion_12['myVarname'] == 'Unnamed: 8'),(inversion_12['myVarname'] == 'Unnamed: 9'),(inversion_12['myVarname'] == 'Unnamed: 10'),(inversion_12['myVarname'] == 'Unnamed: 11'),
  (inversion_12['myVarname'] == 'Unnamed: 12'),(inversion_12['myVarname'] == 'Unnamed: 13'),(inversion_12['myVarname'] == 'Unnamed: 14'),(inversion_12['myVarname'] == 'Unnamed: 15'),(inversion_12['myVarname'] == 'Unnamed: 16'),
   (inversion_12['myVarname'] == 'Unnamed: 17'),(inversion_12['myVarname'] == 'Unnamed: 18'),(inversion_12['myVarname'] == 'Unnamed: 19'),(inversion_12['myVarname'] == 'Unnamed: 20'),(inversion_12['myVarname'] == 'Unnamed: 21'),
    (inversion_12['myVarname'] == 'Unnamed: 22'),(inversion_12['myVarname'] == 'Unnamed: 23'),(inversion_12['myVarname'] == 'Unnamed: 24'),(inversion_12['myVarname'] == 'Unnamed: 25'),(inversion_12['myVarname'] == 'Unnamed: 26'),
     (inversion_12['myVarname'] == 'Unnamed: 27'),(inversion_12['myVarname'] == 'Unnamed: 28'),(inversion_12['myVarname'] == 'Unnamed: 29'),(inversion_12['myVarname'] == 'Unnamed: 30'),(inversion_12['myVarname'] == 'Unnamed: 31'),
      (inversion_12['myVarname'] == 'Unnamed: 32'),(inversion_12['myVarname'] == 'Unnamed: 33'),(inversion_12['myVarname'] == 'Unnamed: 34'),(inversion_12['myVarname'] == 'Unnamed: 35'),(inversion_12['myVarname'] == 'Unnamed: 36'),
       (inversion_12['myVarname'] == 'Unnamed: 37'),(inversion_12['myVarname'] == 'Unnamed: 38'),(inversion_12['myVarname'] == 'Unnamed: 39'),(inversion_12['myVarname'] == 'Unnamed: 40'),(inversion_12['myVarname'] == 'Unnamed: 41'),
        (inversion_12['myVarname'] == 'Unnamed: 42'),(inversion_12['myVarname'] == 'Unnamed: 43'),(inversion_12['myVarname'] == 'Unnamed: 44'),(inversion_12['myVarname'] == 'Unnamed: 45'),(inversion_12['myVarname'] == 'Unnamed: 46'),
         (inversion_12['myVarname'] == 'Unnamed: 47'),(inversion_12['myVarname'] == 'Unnamed: 48'),(inversion_12['myVarname'] == 'Unnamed: 49'),(inversion_12['myVarname'] == 'Unnamed: 50'),(inversion_12['myVarname'] == 'Unnamed: 51'),
          (inversion_12['myVarname'] == 'Unnamed: 52'),(inversion_12['myVarname'] == 'Unnamed: 53'),(inversion_12['myVarname'] == 'Unnamed: 54'),(inversion_12['myVarname'] == 'Unnamed: 55'),(inversion_12['myVarname'] == 'Unnamed: 56'),
           (inversion_12['myVarname'] == 'Unnamed: 57'),(inversion_12['myVarname'] == 'Unnamed: 58'),(inversion_12['myVarname'] == 'Unnamed: 59'),(inversion_12['myVarname'] == 'Unnamed: 60'),(inversion_12['myVarname'] == 'Unnamed: 61'),
            (inversion_12['myVarname'] == 'Unnamed: 62'),(inversion_12['myVarname'] == 'Unnamed: 63'),(inversion_12['myVarname'] == 'Unnamed: 64'),(inversion_12['myVarname'] == 'Unnamed: 65'),(inversion_12['myVarname'] == 'Unnamed: 66'),
             (inversion_12['myVarname'] == 'Unnamed: 67'),(inversion_12['myVarname'] == 'Unnamed: 68'),(inversion_12['myVarname'] == 'Unnamed: 69'),(inversion_12['myVarname'] == 'Unnamed: 70'),(inversion_12['myVarname'] == 'Unnamed: 71'),
              (inversion_12['myVarname'] == 'Unnamed: 72'),(inversion_12['myVarname'] == 'Unnamed: 73'),(inversion_12['myVarname'] == 'Unnamed: 74'),(inversion_12['myVarname'] == 'Unnamed: 75'),(inversion_12['myVarname'] == 'Unnamed: 76'),
               (inversion_12['myVarname'] == 'Unnamed: 77'),(inversion_12['myVarname'] == 'Unnamed: 78'),(inversion_12['myVarname'] == 'Unnamed: 79'),(inversion_12['myVarname'] == 'Unnamed: 80'),(inversion_12['myVarname'] == 'Unnamed: 81'),
                (inversion_12['myVarname'] == 'Unnamed: 82'),(inversion_12['myVarname'] == 'Unnamed: 83'),(inversion_12['myVarname'] == 'Unnamed: 84'),(inversion_12['myVarname'] == 'Unnamed: 85'),(inversion_12['myVarname'] == 'Unnamed: 86'),
                 (inversion_12['myVarname'] == 'Unnamed: 87'),(inversion_12['myVarname'] == 'Unnamed: 88'),(inversion_12['myVarname'] == 'Unnamed: 89'),(inversion_12['myVarname'] == 'Unnamed: 90'),(inversion_12['myVarname'] == 'Unnamed: 91'),
                  (inversion_12['myVarname'] == 'Unnamed: 92'),(inversion_12['myVarname'] == 'Unnamed: 93'),(inversion_12['myVarname'] == 'Unnamed: 94'),(inversion_12['myVarname'] == 'Unnamed: 95'),(inversion_12['myVarname'] == 'Unnamed: 96'),
                   (inversion_12['myVarname'] == 'Unnamed: 97'),(inversion_12['myVarname'] == 'Unnamed: 98'),(inversion_12['myVarname'] == 'Unnamed: 99'),(inversion_12['myVarname'] == 'Unnamed: 100'),(inversion_12['myVarname'] == 'Unnamed: 101'),
                    (inversion_12['myVarname'] == 'Unnamed: 102'),(inversion_12['myVarname'] == 'Unnamed: 103'),(inversion_12['myVarname'] == 'Unnamed: 104'),(inversion_12['myVarname'] == 'Unnamed: 105'),(inversion_12['myVarname'] == 'Unnamed: 106'),
                     (inversion_12['myVarname'] == 'Unnamed: 107'),(inversion_12['myVarname'] == 'Unnamed: 108'),(inversion_12['myVarname'] == 'Unnamed: 109'),(inversion_12['myVarname'] == 'Unnamed: 110'),(inversion_12['myVarname'] == 'Unnamed: 111'),
                      (inversion_12['myVarname'] == 'Unnamed: 112'),(inversion_12['myVarname'] == 'Unnamed: 113'),(inversion_12['myVarname'] == 'Unnamed: 114'),(inversion_12['myVarname'] == 'Unnamed: 115'),(inversion_12['myVarname'] == 'Unnamed: 116'),
                       (inversion_12['myVarname'] == 'Unnamed: 117'),(inversion_12['myVarname'] == 'Unnamed: 118'),(inversion_12['myVarname'] == 'Unnamed: 119'),(inversion_12['myVarname'] == 'Unnamed: 120'),(inversion_12['myVarname'] == 'Unnamed: 121'),
                        (inversion_12['myVarname'] == 'Unnamed: 122'),(inversion_12['myVarname'] == 'Unnamed: 123'),(inversion_12['myVarname'] == 'Unnamed: 124'),(inversion_12['myVarname'] == 'Unnamed: 125'),(inversion_12['myVarname'] == 'Unnamed: 126'),
                         (inversion_12['myVarname'] == 'Unnamed: 127'),(inversion_12['myVarname'] == 'Unnamed: 128'),(inversion_12['myVarname'] == 'Unnamed: 129'),(inversion_12['myVarname'] == 'Unnamed: 130'),(inversion_12['myVarname'] == 'Unnamed: 131'),
                          (inversion_12['myVarname'] == 'Unnamed: 132'),(inversion_12['myVarname'] == 'Unnamed: 133'),(inversion_12['myVarname'] == 'Unnamed: 134'),(inversion_12['myVarname'] == 'Unnamed: 135'),(inversion_12['myVarname'] == 'Unnamed: 136'),
                           (inversion_12['myVarname'] == 'Unnamed: 137'),(inversion_12['myVarname'] == 'Unnamed: 138'),(inversion_12['myVarname'] == 'Unnamed: 139'),(inversion_12['myVarname'] == 'Unnamed: 140'),(inversion_12['myVarname'] == 'Unnamed: 141'),
                            (inversion_12['myVarname'] == 'Unnamed: 142'),(inversion_12['myVarname'] == 'Unnamed: 143'),(inversion_12['myVarname'] == 'Unnamed: 144'),(inversion_12['myVarname'] == 'Unnamed: 145'),(inversion_12['myVarname'] == 'Unnamed: 146'),
                             (inversion_12['myVarname'] == 'Unnamed: 147'),(inversion_12['myVarname'] == 'Unnamed: 148'),(inversion_12['myVarname'] == 'Unnamed: 149'),(inversion_12['myVarname'] == 'Unnamed: 150'),(inversion_12['myVarname'] == 'Unnamed: 151'),
                              (inversion_12['myVarname'] == 'Unnamed: 152'),(inversion_12['myVarname'] == 'Unnamed: 153'),(inversion_12['myVarname'] == 'Unnamed: 154'),(inversion_12['myVarname'] == 'Unnamed: 155'),(inversion_12['myVarname'] == 'Unnamed: 156'),
                               (inversion_12['myVarname'] == 'Unnamed: 157'),(inversion_12['myVarname'] == 'Unnamed: 158'),(inversion_12['myVarname'] == 'Unnamed: 159'),(inversion_12['myVarname'] == 'Unnamed: 160'),(inversion_12['myVarname'] == 'Unnamed: 161'),
                                (inversion_12['myVarname'] == 'Unnamed: 162'),(inversion_12['myVarname'] == 'Unnamed: 163'),(inversion_12['myVarname'] == 'Unnamed: 164'),(inversion_12['myVarname'] == 'Unnamed: 165'),(inversion_12['myVarname'] == 'Unnamed: 166')
                                ]

# %%
inversion_12['Fecha'] = np.select(conditions_12, values)

# %%
inversion_12.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
inversion_12.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
inversion_12['Tipo'] = "Inversión"
inversion_12['Subtipo'] = "Inversiones en el exterior"
inversion_12['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
inversion_12 = inversion_12.reindex(columns=new_cols)

# %%
inversion_12.head(7)
# Out:
#          Fecha                        Institucion       Tipo  \
# 5   2008-01-31                         Banco Bice  Inversión
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Inversión
# 7   2008-01-31                Banco Consorcio (1)  Inversión
# 8   2008-01-31                 Banco de Chile (2)  Inversión
# 9   2008-01-31     Banco de Crédito e Inversiones  Inversión
# 10  2008-01-31  Banco de la Nación Argentina (18)  Inversión
# 11  2008-01-31          Banco del Estado de Chile  Inversión
#
#                        Subtipo          Valor               Tipo de Moneda
# 5   Inversiones en el exterior              0  Saldos en millones de pesos
# 6   Inversiones en el exterior             ND  Saldos en millones de pesos
# 7   Inversiones en el exterior    2274.338176  Saldos en millones de pesos
# 8   Inversiones en el exterior   46517.897284  Saldos en millones de pesos
# 9   Inversiones en el exterior  115142.683746  Saldos en millones de pesos
# ...

# %% [markdown]
# ## Inversión 13

# %%
inversion_13.head(5)
# Out:
#         Unnamed: 0                        Unnamed: 1           Unnamed: 2  \
# 0   Índice general                       Cuadro 3.13                  NaN
# 1  Notas generales  Resto de inversiones financieras                  NaN
# 2              NaN       Saldos en millones de pesos                  NaN
# 3              NaN                               NaN                  NaN
# 4              NaN                               NaN  2008-01-31 00:00:00
#
#             Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4  2008-02-29 00:00:00  2008-03-31 00:00:00  2008-04-30 00:00:00
#
#             Unnamed: 6           Unnamed: 7           Unnamed: 8  \
# ...

# %%
inversion_13.pop("Unnamed: 0")
# Out:
# 0      Índice general
# 1     Notas generales
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# 30                NaN
# 31                NaN
# 32                NaN
# 33                NaN
# 34                NaN
# Name: Unnamed: 0, dtype: object

# %%
inversion_13 = inversion_13.iloc[5:]

# %%
inversion_13.tail(7)
# Out:
#                                        Unnamed: 1   Unnamed: 2  Unnamed: 3  \
# 28                      Scotiabank Chile (3) (17)            0           0
# 29  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)            0           0
# 30                             Bank of China (16)           ND          ND
# 31                                          Total  1211.115391  457.141859
# 32                                            NaN          NaN         NaN
# 33                                            NaN          NaN         NaN
# 34                            ND : No existe dato          NaN         NaN
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 28          0          0          0          0          0          0
# 29          0          0          0          0          0          0
# 30         ND         ND         ND         ND         ND         ND
# 31          0          0          0    577.775          0          0
# ...

# %%
inversion_13.drop(inversion_13.tail(4).index,inplace=True)
# Out:
# <ipython-input-516-7e77f41ea730>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inversion_13.drop(inversion_13.tail(4).index,inplace=True)

# %%
inversion_13.head(3)
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 5                   Banco Bice          0          0          0          0
# 6  Banco BTG Pactual Chile (9)         ND         ND         ND         ND
# 7          Banco Consorcio (1)          0          0          0          0
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  ... Unnamed: 157  \
# 5          0          0          0          0           0  ...            0
# 6         ND         ND         ND         ND          ND  ...            0
# 7          0          0          0          0           0  ...            0
#
#   Unnamed: 158 Unnamed: 159 Unnamed: 160 Unnamed: 161 Unnamed: 162  \
# 5            0            0            0            0            0
# 6            0            0            0            0            0
# 7            0            0            0            0            0
#
#   Unnamed: 163 Unnamed: 164 Unnamed: 165 Unnamed: 166
# ...

# %%
inversion_13 = inversion_13.melt(id_vars=['Unnamed: 1'], value_vars=['Unnamed: 2','Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11',
                                                   'Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21',
                                                   'Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','Unnamed: 27','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31',
                                                   'Unnamed: 32','Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41',
                                                   'Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','Unnamed: 48','Unnamed: 49','Unnamed: 50','Unnamed: 51',
                                                   'Unnamed: 52','Unnamed: 53','Unnamed: 54','Unnamed: 55','Unnamed: 56','Unnamed: 57','Unnamed: 58','Unnamed: 59','Unnamed: 60','Unnamed: 61',
                                                   'Unnamed: 62','Unnamed: 63','Unnamed: 64','Unnamed: 65','Unnamed: 66','Unnamed: 67','Unnamed: 68','Unnamed: 69','Unnamed: 70','Unnamed: 71',
                                                   'Unnamed: 72','Unnamed: 73','Unnamed: 74','Unnamed: 75','Unnamed: 76','Unnamed: 77','Unnamed: 78','Unnamed: 79','Unnamed: 80','Unnamed: 81',
                                                   'Unnamed: 82','Unnamed: 83','Unnamed: 84','Unnamed: 85','Unnamed: 86','Unnamed: 87','Unnamed: 88','Unnamed: 89','Unnamed: 90','Unnamed: 91',
                                                   'Unnamed: 92','Unnamed: 93','Unnamed: 94','Unnamed: 95','Unnamed: 96','Unnamed: 97','Unnamed: 98','Unnamed: 99','Unnamed: 100','Unnamed: 101',
                                                   'Unnamed: 102','Unnamed: 103','Unnamed: 104','Unnamed: 105','Unnamed: 106','Unnamed: 107','Unnamed: 108','Unnamed: 109','Unnamed: 110','Unnamed: 111',
                                                   'Unnamed: 112','Unnamed: 113','Unnamed: 114','Unnamed: 115','Unnamed: 116','Unnamed: 117','Unnamed: 118','Unnamed: 119','Unnamed: 120','Unnamed: 121',
                                                   'Unnamed: 122','Unnamed: 123','Unnamed: 124','Unnamed: 125','Unnamed: 126','Unnamed: 127','Unnamed: 128','Unnamed: 129','Unnamed: 130','Unnamed: 131',
                                                   'Unnamed: 132','Unnamed: 133','Unnamed: 134','Unnamed: 135','Unnamed: 136','Unnamed: 137','Unnamed: 138','Unnamed: 139','Unnamed: 140','Unnamed: 141',
                                                   'Unnamed: 142','Unnamed: 143','Unnamed: 144','Unnamed: 145','Unnamed: 146','Unnamed: 147','Unnamed: 148','Unnamed: 149','Unnamed: 150','Unnamed: 151',
                                                   'Unnamed: 152','Unnamed: 153','Unnamed: 154','Unnamed: 155','Unnamed: 156','Unnamed: 157','Unnamed: 158','Unnamed: 159','Unnamed: 160','Unnamed: 161',
                                                   'Unnamed: 162','Unnamed: 163','Unnamed: 164','Unnamed: 165','Unnamed: 166'],
               var_name='myVarname',
               value_name='Valor',
               ignore_index=False
               )

# %%
# create a list of our conditions
conditions_13 = [(inversion_13['myVarname'] == 'Unnamed: 2'),(inversion_13['myVarname'] == 'Unnamed: 3'),(inversion_13['myVarname'] == 'Unnamed: 4'),(inversion_13['myVarname'] == 'Unnamed: 5'),(inversion_13['myVarname'] == 'Unnamed: 6'),
 (inversion_13['myVarname'] == 'Unnamed: 7'),(inversion_13['myVarname'] == 'Unnamed: 8'),(inversion_13['myVarname'] == 'Unnamed: 9'),(inversion_13['myVarname'] == 'Unnamed: 10'),(inversion_13['myVarname'] == 'Unnamed: 11'),
  (inversion_13['myVarname'] == 'Unnamed: 12'),(inversion_13['myVarname'] == 'Unnamed: 13'),(inversion_13['myVarname'] == 'Unnamed: 14'),(inversion_13['myVarname'] == 'Unnamed: 15'),(inversion_13['myVarname'] == 'Unnamed: 16'),
   (inversion_13['myVarname'] == 'Unnamed: 17'),(inversion_13['myVarname'] == 'Unnamed: 18'),(inversion_13['myVarname'] == 'Unnamed: 19'),(inversion_13['myVarname'] == 'Unnamed: 20'),(inversion_13['myVarname'] == 'Unnamed: 21'),
    (inversion_13['myVarname'] == 'Unnamed: 22'),(inversion_13['myVarname'] == 'Unnamed: 23'),(inversion_13['myVarname'] == 'Unnamed: 24'),(inversion_13['myVarname'] == 'Unnamed: 25'),(inversion_13['myVarname'] == 'Unnamed: 26'),
     (inversion_13['myVarname'] == 'Unnamed: 27'),(inversion_13['myVarname'] == 'Unnamed: 28'),(inversion_13['myVarname'] == 'Unnamed: 29'),(inversion_13['myVarname'] == 'Unnamed: 30'),(inversion_13['myVarname'] == 'Unnamed: 31'),
      (inversion_13['myVarname'] == 'Unnamed: 32'),(inversion_13['myVarname'] == 'Unnamed: 33'),(inversion_13['myVarname'] == 'Unnamed: 34'),(inversion_13['myVarname'] == 'Unnamed: 35'),(inversion_13['myVarname'] == 'Unnamed: 36'),
       (inversion_13['myVarname'] == 'Unnamed: 37'),(inversion_13['myVarname'] == 'Unnamed: 38'),(inversion_13['myVarname'] == 'Unnamed: 39'),(inversion_13['myVarname'] == 'Unnamed: 40'),(inversion_13['myVarname'] == 'Unnamed: 41'),
        (inversion_13['myVarname'] == 'Unnamed: 42'),(inversion_13['myVarname'] == 'Unnamed: 43'),(inversion_13['myVarname'] == 'Unnamed: 44'),(inversion_13['myVarname'] == 'Unnamed: 45'),(inversion_13['myVarname'] == 'Unnamed: 46'),
         (inversion_13['myVarname'] == 'Unnamed: 47'),(inversion_13['myVarname'] == 'Unnamed: 48'),(inversion_13['myVarname'] == 'Unnamed: 49'),(inversion_13['myVarname'] == 'Unnamed: 50'),(inversion_13['myVarname'] == 'Unnamed: 51'),
          (inversion_13['myVarname'] == 'Unnamed: 52'),(inversion_13['myVarname'] == 'Unnamed: 53'),(inversion_13['myVarname'] == 'Unnamed: 54'),(inversion_13['myVarname'] == 'Unnamed: 55'),(inversion_13['myVarname'] == 'Unnamed: 56'),
           (inversion_13['myVarname'] == 'Unnamed: 57'),(inversion_13['myVarname'] == 'Unnamed: 58'),(inversion_13['myVarname'] == 'Unnamed: 59'),(inversion_13['myVarname'] == 'Unnamed: 60'),(inversion_13['myVarname'] == 'Unnamed: 61'),
            (inversion_13['myVarname'] == 'Unnamed: 62'),(inversion_13['myVarname'] == 'Unnamed: 63'),(inversion_13['myVarname'] == 'Unnamed: 64'),(inversion_13['myVarname'] == 'Unnamed: 65'),(inversion_13['myVarname'] == 'Unnamed: 66'),
             (inversion_13['myVarname'] == 'Unnamed: 67'),(inversion_13['myVarname'] == 'Unnamed: 68'),(inversion_13['myVarname'] == 'Unnamed: 69'),(inversion_13['myVarname'] == 'Unnamed: 70'),(inversion_13['myVarname'] == 'Unnamed: 71'),
              (inversion_13['myVarname'] == 'Unnamed: 72'),(inversion_13['myVarname'] == 'Unnamed: 73'),(inversion_13['myVarname'] == 'Unnamed: 74'),(inversion_13['myVarname'] == 'Unnamed: 75'),(inversion_13['myVarname'] == 'Unnamed: 76'),
               (inversion_13['myVarname'] == 'Unnamed: 77'),(inversion_13['myVarname'] == 'Unnamed: 78'),(inversion_13['myVarname'] == 'Unnamed: 79'),(inversion_13['myVarname'] == 'Unnamed: 80'),(inversion_13['myVarname'] == 'Unnamed: 81'),
                (inversion_13['myVarname'] == 'Unnamed: 82'),(inversion_13['myVarname'] == 'Unnamed: 83'),(inversion_13['myVarname'] == 'Unnamed: 84'),(inversion_13['myVarname'] == 'Unnamed: 85'),(inversion_13['myVarname'] == 'Unnamed: 86'),
                 (inversion_13['myVarname'] == 'Unnamed: 87'),(inversion_13['myVarname'] == 'Unnamed: 88'),(inversion_13['myVarname'] == 'Unnamed: 89'),(inversion_13['myVarname'] == 'Unnamed: 90'),(inversion_13['myVarname'] == 'Unnamed: 91'),
                  (inversion_13['myVarname'] == 'Unnamed: 92'),(inversion_13['myVarname'] == 'Unnamed: 93'),(inversion_13['myVarname'] == 'Unnamed: 94'),(inversion_13['myVarname'] == 'Unnamed: 95'),(inversion_13['myVarname'] == 'Unnamed: 96'),
                   (inversion_13['myVarname'] == 'Unnamed: 97'),(inversion_13['myVarname'] == 'Unnamed: 98'),(inversion_13['myVarname'] == 'Unnamed: 99'),(inversion_13['myVarname'] == 'Unnamed: 100'),(inversion_13['myVarname'] == 'Unnamed: 101'),
                    (inversion_13['myVarname'] == 'Unnamed: 102'),(inversion_13['myVarname'] == 'Unnamed: 103'),(inversion_13['myVarname'] == 'Unnamed: 104'),(inversion_13['myVarname'] == 'Unnamed: 105'),(inversion_13['myVarname'] == 'Unnamed: 106'),
                     (inversion_13['myVarname'] == 'Unnamed: 107'),(inversion_13['myVarname'] == 'Unnamed: 108'),(inversion_13['myVarname'] == 'Unnamed: 109'),(inversion_13['myVarname'] == 'Unnamed: 110'),(inversion_13['myVarname'] == 'Unnamed: 111'),
                      (inversion_13['myVarname'] == 'Unnamed: 112'),(inversion_13['myVarname'] == 'Unnamed: 113'),(inversion_13['myVarname'] == 'Unnamed: 114'),(inversion_13['myVarname'] == 'Unnamed: 115'),(inversion_13['myVarname'] == 'Unnamed: 116'),
                       (inversion_13['myVarname'] == 'Unnamed: 117'),(inversion_13['myVarname'] == 'Unnamed: 118'),(inversion_13['myVarname'] == 'Unnamed: 119'),(inversion_13['myVarname'] == 'Unnamed: 120'),(inversion_13['myVarname'] == 'Unnamed: 121'),
                        (inversion_13['myVarname'] == 'Unnamed: 122'),(inversion_13['myVarname'] == 'Unnamed: 123'),(inversion_13['myVarname'] == 'Unnamed: 124'),(inversion_13['myVarname'] == 'Unnamed: 125'),(inversion_13['myVarname'] == 'Unnamed: 126'),
                         (inversion_13['myVarname'] == 'Unnamed: 127'),(inversion_13['myVarname'] == 'Unnamed: 128'),(inversion_13['myVarname'] == 'Unnamed: 129'),(inversion_13['myVarname'] == 'Unnamed: 130'),(inversion_13['myVarname'] == 'Unnamed: 131'),
                          (inversion_13['myVarname'] == 'Unnamed: 132'),(inversion_13['myVarname'] == 'Unnamed: 133'),(inversion_13['myVarname'] == 'Unnamed: 134'),(inversion_13['myVarname'] == 'Unnamed: 135'),(inversion_13['myVarname'] == 'Unnamed: 136'),
                           (inversion_13['myVarname'] == 'Unnamed: 137'),(inversion_13['myVarname'] == 'Unnamed: 138'),(inversion_13['myVarname'] == 'Unnamed: 139'),(inversion_13['myVarname'] == 'Unnamed: 140'),(inversion_13['myVarname'] == 'Unnamed: 141'),
                            (inversion_13['myVarname'] == 'Unnamed: 142'),(inversion_13['myVarname'] == 'Unnamed: 143'),(inversion_13['myVarname'] == 'Unnamed: 144'),(inversion_13['myVarname'] == 'Unnamed: 145'),(inversion_13['myVarname'] == 'Unnamed: 146'),
                             (inversion_13['myVarname'] == 'Unnamed: 147'),(inversion_13['myVarname'] == 'Unnamed: 148'),(inversion_13['myVarname'] == 'Unnamed: 149'),(inversion_13['myVarname'] == 'Unnamed: 150'),(inversion_13['myVarname'] == 'Unnamed: 151'),
                              (inversion_13['myVarname'] == 'Unnamed: 152'),(inversion_13['myVarname'] == 'Unnamed: 153'),(inversion_13['myVarname'] == 'Unnamed: 154'),(inversion_13['myVarname'] == 'Unnamed: 155'),(inversion_13['myVarname'] == 'Unnamed: 156'),
                               (inversion_13['myVarname'] == 'Unnamed: 157'),(inversion_13['myVarname'] == 'Unnamed: 158'),(inversion_13['myVarname'] == 'Unnamed: 159'),(inversion_13['myVarname'] == 'Unnamed: 160'),(inversion_13['myVarname'] == 'Unnamed: 161'),
                                (inversion_13['myVarname'] == 'Unnamed: 162'),(inversion_13['myVarname'] == 'Unnamed: 163'),(inversion_13['myVarname'] == 'Unnamed: 164'),(inversion_13['myVarname'] == 'Unnamed: 165'),(inversion_13['myVarname'] == 'Unnamed: 166')
                                ]

# %%
inversion_13['Fecha'] = np.select(conditions_1, values)

# %%
inversion_13.pop("myVarname")
# Out:
# 5       Unnamed: 2
# 6       Unnamed: 2
# 7       Unnamed: 2
# 8       Unnamed: 2
# 9       Unnamed: 2
#           ...
# 26    Unnamed: 166
# 27    Unnamed: 166
# 28    Unnamed: 166
# 29    Unnamed: 166
# 30    Unnamed: 166
# Name: myVarname, Length: 4290, dtype: object

# %%
inversion_13.rename(columns={"Unnamed: 1": "Institucion"}, inplace=True)

# %%
inversion_13['Tipo'] = "Inversión"
inversion_13['Subtipo'] = "Resto de inversiones financieras"
inversion_13['Tipo de Moneda'] = "Saldos en millones de pesos"

# %%
new_cols = ["Fecha","Institucion","Tipo","Subtipo","Valor","Tipo de Moneda"]
inversion_13 = inversion_13.reindex(columns=new_cols)

# %%
inversion_13.head(7)
# Out:
#          Fecha                        Institucion       Tipo  \
# 5   2008-01-31                         Banco Bice  Inversión
# 6   2008-01-31        Banco BTG Pactual Chile (9)  Inversión
# 7   2008-01-31                Banco Consorcio (1)  Inversión
# 8   2008-01-31                 Banco de Chile (2)  Inversión
# 9   2008-01-31     Banco de Crédito e Inversiones  Inversión
# 10  2008-01-31  Banco de la Nación Argentina (18)  Inversión
# 11  2008-01-31          Banco del Estado de Chile  Inversión
#
#                              Subtipo Valor               Tipo de Moneda
# 5   Resto de inversiones financieras     0  Saldos en millones de pesos
# 6   Resto de inversiones financieras    ND  Saldos en millones de pesos
# 7   Resto de inversiones financieras     0  Saldos en millones de pesos
# 8   Resto de inversiones financieras     0  Saldos en millones de pesos
# 9   Resto de inversiones financieras     0  Saldos en millones de pesos
# ...

# %% [markdown]
# # Unión de las tablas transformadas

# %% [markdown]
# ## Unión colocaciones

# %%
union_colocaciones = pd.concat([colocaciones_01, colocaciones_02, colocaciones_03, colocaciones_04, colocaciones_05,
                                colocaciones_06, colocaciones_07, colocaciones_08, colocaciones_09, colocaciones_10], ignore_index=True)

# %%
union_colocaciones
# Out:
#             Fecha                                    Institucion        Tipo  \
# 0      2008-01-31                                     Banco Bice  Colocación
# 1      2008-01-31                    Banco BTG Pactual Chile (9)  Colocación
# 2      2008-01-31                            Banco Consorcio (1)  Colocación
# 3      2008-01-31                             Banco de Chile (2)  Colocación
# 4      2008-01-31                 Banco de Crédito e Inversiones  Colocación
# ...           ...                                            ...         ...
# 42895  2021-09-30                     JP Morgan Chase Bank, N.A.  Colocación
# 42896  2021-09-30                            Rabobank Chile (15)  Colocación
# 42897  2021-09-30                      Scotiabank Chile (3) (17)  Colocación
# 42898  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Colocación
# 42899  2021-09-30                             Bank of China (16)  Colocación
#
# ...

# %% [markdown]
# ## Unión depósitos

# %%
union_depositos = pd.concat([depositos_01, depositos_02, depositos_03, depositos_04, depositos_05,
                                depositos_06, depositos_07, depositos_08, depositos_08, depositos_09], ignore_index=True)

# %%
union_depositos
# Out:
#             Fecha                                    Institucion      Tipo  \
# 0      2008-01-31                                     Banco Bice  Depósito
# 1      2008-01-31                    Banco BTG Pactual Chile (9)  Depósito
# 2      2008-01-31                            Banco Consorcio (1)  Depósito
# 3      2008-01-31                             Banco de Chile (2)  Depósito
# 4      2008-01-31                 Banco de Crédito e Inversiones  Depósito
# ...           ...                                            ...       ...
# 42895  2021-09-30                     JP Morgan Chase Bank, N.A.  Depósito
# 42896  2021-09-30                            Rabobank Chile (15)  Depósito
# 42897  2021-09-30                      Scotiabank Chile (3) (17)  Depósito
# 42898  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Depósito
# 42899  2021-09-30                             Bank of China (16)  Depósito
#
# ...

# %% [markdown]
# ## Unión inversiones

# %%
union_inversion = pd.concat([inversion_01, inversion_02, inversion_03, inversion_04, inversion_05, inversion_06, 
                             inversion_07, inversion_08, inversion_09, inversion_10, inversion_11, inversion_12, 
                             inversion_13], ignore_index=True)

# %%
union_inversion
# Out:
#             Fecha                                    Institucion       Tipo  \
# 0      2008-01-31                                     Banco Bice  Inversión
# 1      2008-01-31                    Banco BTG Pactual Chile (9)  Inversión
# 2      2008-01-31                            Banco Consorcio (1)  Inversión
# 3      2008-01-31                             Banco de Chile (2)  Inversión
# 4      2008-01-31                 Banco de Crédito e Inversiones  Inversión
# ...           ...                                            ...        ...
# 55765  2021-09-30                     JP Morgan Chase Bank, N.A.  Inversión
# 55766  2021-09-30                            Rabobank Chile (15)  Inversión
# 55767  2021-09-30                      Scotiabank Chile (3) (17)  Inversión
# 55768  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. (19)  Inversión
# 55769  2021-09-30                             Bank of China (16)  Inversión
#
# ...

# %% [markdown]
# # Tabla Final

# %%
soporte_final = pd.concat([union_colocaciones,union_depositos,union_inversion], ignore_index=True)

# %%
soporte_final
# Out:
#              Fecha                                  Institucion        Tipo  \
# 0       2008-01-31                                   Banco Bice  Colocación
# 1       2008-01-31                   Banco BTG Pactual Chile ()  Colocación
# 2       2008-01-31                           Banco Consorcio ()  Colocación
# 3       2008-01-31                            Banco de Chile ()  Colocación
# 4       2008-01-31               Banco de Crédito e Inversiones  Colocación
# ...            ...                                          ...         ...
# 141565  2021-09-30                   JP Morgan Chase Bank, N.A.   Inversión
# 141566  2021-09-30                            Rabobank Chile ()   Inversión
# 141567  2021-09-30                       Scotiabank Chile () ()   Inversión
# 141568  2021-09-30  The Bank of Tokyo - Mitsubishi Ufj. Ltd. ()   Inversión
# 141569  2021-09-30                             Bank of China ()   Inversión
#
# ...

# %% [markdown]
# ## Reemplazo de valores en el campo institucion

# %%
#Reemplazo de valores mediante expresiones regulares

soporte_final['Institucion'] = soporte_final['Institucion'].str.replace("[1-9]","", regex=True)
soporte_final['Institucion'] = soporte_final['Institucion'].str.replace(r"\(.*\)","", regex=True)
soporte_final['Institucion'] = soporte_final['Institucion'].str.replace(", N.A.","", regex=True)

# %%
soporte_final
# Out:
#              Fecha                                 Institucion        Tipo  \
# 0       2008-01-31                                  Banco Bice  Colocación
# 2       2008-01-31                            Banco Consorcio   Colocación
# 3       2008-01-31                             Banco de Chile   Colocación
# 4       2008-01-31              Banco de Crédito e Inversiones  Colocación
# 5       2008-01-31               Banco de la Nación Argentina   Colocación
# ...            ...                                         ...         ...
# 141561  2021-09-30  China Construction Bank, Agencia en Chile    Inversión
# 141564  2021-09-30                                  HSBC Bank    Inversión
# 141565  2021-09-30                        JP Morgan Chase Bank   Inversión
# 141567  2021-09-30                           Scotiabank Chile    Inversión
# 141569  2021-09-30                              Bank of China    Inversión
#
#                                          Subtipo            Valor  \
# ...

# %% [markdown]
# ## Eliminacion de filas con valores ND en el campo Valor (ND = No Identificado), no sera imputado por 0 porque no se tiene información

# %%
#Eliminacion de ND

soporte_final.drop(soporte_final[soporte_final['Valor'] == 'ND'].index, inplace = True)

# %%
soporte_final
# Out:
#              Fecha                                 Institucion        Tipo  \
# 0       2008-01-31                                  Banco Bice  Colocación
# 2       2008-01-31                            Banco Consorcio   Colocación
# 3       2008-01-31                             Banco de Chile   Colocación
# 4       2008-01-31              Banco de Crédito e Inversiones  Colocación
# 5       2008-01-31               Banco de la Nación Argentina   Colocación
# ...            ...                                         ...         ...
# 141561  2021-09-30  China Construction Bank, Agencia en Chile    Inversión
# 141564  2021-09-30                                  HSBC Bank    Inversión
# 141565  2021-09-30                        JP Morgan Chase Bank   Inversión
# 141567  2021-09-30                           Scotiabank Chile    Inversión
# 141569  2021-09-30                              Bank of China    Inversión
#
#                                          Subtipo            Valor  \
# ...

# %% [markdown]
# # Exportación final de soporte

# %%
#Importacion de archivo, para la salida

from google.colab import files

soporte_final.to_excel("soporte_final.xlsx") 
files.download("soporte_final.xlsx")
