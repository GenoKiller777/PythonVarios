# %%
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import pandas as pd

# %%
X, y = load_digits(return_X_y=True)

# %%
norm = StandardScaler()

# %%
x_std = norm.fit_transform(X)

# %%
x_std.shape
# Out:
# (1797, 64)

# %%
pca = PCA(n_components=2)

X_transformada = pca.fit_transform(x_std)

X_transformada = pd.DataFrame(X_transformada, columns = ['C1', 'C2'])
X_transformada['label'] = y

# %%
X_transformada.head()
# Out:
#          C1        C2  label
# 0  1.914215 -0.954503      0
# 1  0.588972  0.924624      1
# 2  1.302024 -0.317230      2
# 3 -3.020768 -0.868755      3
# 4  4.528946 -1.093482      4

# %%
plt.figure(figsize=(10,10))
colores = ['b.', 'g.', 'r.', 'c.', 'm.', 'y.', 'k.', 'w.','y>', 'r>']
for i in range(0,10):
    plt.plot(X_transformada['C1'][X_transformada['label']==i],
             X_transformada['C2'][X_transformada['label']==i], colores[i], label=i)  
plt.legend()
plt.show()

# %%
pca3 = PCA(n_components=3)
X_transformada = pca3.fit_transform(x_std)
X_transformada = pd.DataFrame(X_transformada, columns = ['C1', 'C2', 'C3'])
X_transformada['label'] = y

# %%
fig = px.scatter_3d(X_transformada, x='C1', y='C2', z='C3',
              color='label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b66ee1e5-4854-4137-bbb9-ad8e825c043f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b66ee1e5-4854-4137-bbb9-ad8e825c043f")) {
#                     Plotly.newPlot(
#                         'b66ee1e5-4854-4137-bbb9-ad8e825c043f',
# ...

# %%
pca3.explained_variance_ratio_
# Out:
# array([0.12033916, 0.09561054, 0.08444415])
